# %% [markdown]
# # Important Libraries

# %%
# Check GPU
# !nvidia-smi

# Core libs (GPU-ready)
# %pip -q install -U torch --index-url https://download.pytorch.org/whl/cu121
# %pip -q install -U sentence-transformers pillow tqdm huggingface_hub

# Index backends (FAISS preferred; hnswlib as fallback)
# %pip -q install -U faiss-cpu hnswlib
# Out:
# Tue Sep 16 23:21:42 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 576.40                 Driver Version: 576.40         CUDA Version: 12.9     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce GTX 1660 Ti   WDDM  |   00000000:01:00.0  On |                  N/A |
# | N/A   44C    P8             10W /   80W |     859MiB /   6144MiB |      5%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A             328    C+G   ...xyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A            3280    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A            5868    C+G   ...App_cw5n1h2txyewy\LockApp.exe      N/A      |
# |    0   N/A  N/A            6912    C+G   ...5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A            8548    C+G   ...ntrolPanel\SystemSettings.exe      N/A      |
# |    0   N/A  N/A            9624    C+G   C:\Windows\explorer.exe               N/A      |
# |    0   N/A  N/A           10964    C+G   ...4__8wekyb3d8bbwe\Video.UI.exe      N/A      |
# |    0   N/A  N/A           11376    C+G   ...h_cw5n1h2txyewy\SearchApp.exe      N/A      |
# |    0   N/A  N/A           11744    C+G   ...4__cv1g1gvanyjgm\WhatsApp.exe      N/A      |
# |    0   N/A  N/A           11764    C+G   ...y\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A           12592    C+G   ...h_cw5n1h2txyewy\SearchApp.exe      N/A      |
# |    0   N/A  N/A           12640    C+G   ....0.3485.66\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           12992    C+G   ...Telegram Desktop\Telegram.exe      N/A      |
# |    0   N/A  N/A           13244    C+G   ...ms\Microsoft VS Code\Code.exe      N/A      |
# |    0   N/A  N/A           20368    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           22616    C+G   ...we\Microsoft.Media.Player.exe      N/A      |
# +-----------------------------------------------------------------------------------------+
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\danes\AppData\Roaming\Python\Python311\site-packages\~il'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# streamlit 1.30.0 requires importlib-metadata<8,>=1.4, but you have importlib-metadata 8.6.1 which is incompatible.
# streamlit 1.30.0 requires packaging<24,>=16.8, but you have packaging 24.0 which is incompatible.
# streamlit 1.30.0 requires pillow<11,>=7.1.0, but you have pillow 11.3.0 which is incompatible.
# streamlit 1.30.0 requires protobuf<5,>=3.20, but you have protobuf 6.30.2 which is incompatible.
# streamlit 1.30.0 requires rich<14,>=10.14.0, but you have rich 14.0.0 which is incompatible.
# streamlit 1.30.0 requires tenacity<9,>=8.1.0, but you have tenacity 9.1.2 which is incompatible.
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × Building wheel for hnswlib (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [5 lines of output]
#       running bdist_wheel
#       running build
#       running build_ext
#       building 'hnswlib' extension
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for hnswlib
# error: failed-wheel-build-for-install
#
# × Failed to build installable wheels for some pyproject.toml based projects
# ╰─> hnswlib

# %%
import json, re
from pathlib import Path

import os, torch
from tqdm import tqdm
from huggingface_hub import snapshot_download
from sentence_transformers import SentenceTransformer
import numpy as np
# Out:
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\pywrap_tensorflow.py:73
#      72 try:
# ---> 73   from tensorflow.python._pywrap_tensorflow_internal import *
#      74 # This try catch logic is because there is no bazel equivalent for py_extension.
#      75 # Externally in opensource we must enable exceptions to load the shared object
#      76 # by exposing the PyInit symbols with pybind. This error will only be
#      77 # caught internally or if someone changes the name of the target _pywrap_tensorflow_internal.
#      78
#      79 # This logic is used in other internal projects using py_extension.
#
# ImportError: DLL load failed while importing _pywrap_tensorflow_internal: A dynamic link library (DLL) initialization routine failed.
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\transformers\utils\import_utils.py:1967, in _LazyModule._get_module(self, module_name)
#    1966 try:
# -> 1967     return importlib.import_module("." + module_name, self.__name__)
#    1968 except Exception as e:
#
# File c:\Users\danes\anaconda3\Lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1147, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:940, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\transformers\modeling_utils.py:69
#      65 from .integrations.tensor_parallel import (
#      66     SUPPORTED_TP_STYLES,
#      67     shard_and_distribute_module,
#      68 )
# ---> 69 from .loss.loss_utils import LOSS_MAPPING
#      70 from .pytorch_utils import (  # noqa: F401
#      71     Conv1D,
#      72     apply_chunking_to_forward,
#    (...)
#      77     prune_linear_layer,
#      78 )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\transformers\loss\loss_utils.py:21
#      19 from torch.nn import BCEWithLogitsLoss, MSELoss
# ---> 21 from .loss_deformable_detr import DeformableDetrForObjectDetectionLoss, DeformableDetrForSegmentationLoss
#      22 from .loss_for_object_detection import ForObjectDetectionLoss, ForSegmentationLoss
#
# File ~\AppData\Roaming\Python\Python311\site-packages\transformers\loss\loss_deformable_detr.py:4
#       2 import torch.nn as nn
# ----> 4 from ..image_transforms import center_to_corners_format
#       5 from ..utils import is_scipy_available
#
# File ~\AppData\Roaming\Python\Python311\site-packages\transformers\image_transforms.py:47
#      46 if is_tf_available():
# ---> 47     import tensorflow as tf
#      49 if is_flax_available():
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\__init__.py:40
#      39 # Do not remove this line; See https://github.com/tensorflow/tensorflow/issues/42596
# ---> 40 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow  # pylint: disable=unused-import
#      41 from tensorflow.python.tools import module_util as _module_util
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\pywrap_tensorflow.py:88
#      87 except ImportError:
# ---> 88   raise ImportError(
#      89       f'{traceback.format_exc()}'
#      90       f'\n\nFailed to load the native TensorFlow runtime.\n'
#      91       f'See https://www.tensorflow.org/install/errors '
#      92       f'for some common causes and solutions.\n'
#      93       f'If you need help, create an issue '
#      94       f'at https://github.com/tensorflow/tensorflow/issues '
#      95       f'and include the entire stack trace above this error message.')
#      97 # pylint: enable=wildcard-import,g-import-not-at-top,unused-import,line-too-long
#
# ImportError: Traceback (most recent call last):
#   File "C:\Users\danes\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\pywrap_tensorflow.py", line 73, in <module>
#     from tensorflow.python._pywrap_tensorflow_internal import *
# ImportError: DLL load failed while importing _pywrap_tensorflow_internal: A dynamic link library (DLL) initialization routine failed.
#
#
# Failed to load the native TensorFlow runtime.
# See https://www.tensorflow.org/install/errors for some common causes and solutions.
# If you need help, create an issue at https://github.com/tensorflow/tensorflow/issues and include the entire stack trace above this error message.
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 7
#       5 from tqdm import tqdm
#       6 from huggingface_hub import snapshot_download
# ----> 7 from sentence_transformers import SentenceTransformer
#       8 import numpy as np
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sentence_transformers\__init__.py:15
#       8 import warnings
#      10 from sentence_transformers.backend import (
#      11     export_dynamic_quantized_onnx_model,
#      12     export_optimized_onnx_model,
#      13     export_static_quantized_openvino_model,
#      14 )
# ---> 15 from sentence_transformers.cross_encoder import (
#      16     CrossEncoder,
#      17     CrossEncoderModelCardData,
#      18     CrossEncoderTrainer,
#      19     CrossEncoderTrainingArguments,
#      20 )
#      21 from sentence_transformers.datasets import ParallelSentencesDataset, SentencesDataset
#      22 from sentence_transformers.LoggingHandler import LoggingHandler
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sentence_transformers\cross_encoder\__init__.py:3
#       1 from __future__ import annotations
# ----> 3 from .CrossEncoder import CrossEncoder
#       4 from .model_card import CrossEncoderModelCardData
#       5 from .trainer import CrossEncoderTrainer
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py:16
#      14 from torch import nn
#      15 from tqdm.autonotebook import trange
# ---> 16 from transformers import (
#      17     AutoConfig,
#      18     AutoModelForSequenceClassification,
#      19     AutoTokenizer,
#      20     PretrainedConfig,
#      21     PreTrainedModel,
#      22     PreTrainedTokenizer,
#      23 )
#      24 from transformers.utils import PushToHubMixin
#      25 from typing_extensions import deprecated
#
# File <frozen importlib._bootstrap>:1229, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\transformers\utils\import_utils.py:1955, in _LazyModule.__getattr__(self, name)
#    1953     value = Placeholder
#    1954 elif name in self._class_to_module.keys():
# -> 1955     module = self._get_module(self._class_to_module[name])
#    1956     value = getattr(module, name)
#    1957 elif name in self._modules:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\transformers\utils\import_utils.py:1969, in _LazyModule._get_module(self, module_name)
#    1967     return importlib.import_module("." + module_name, self.__name__)
#    1968 except Exception as e:
# -> 1969     raise RuntimeError(
#    1970         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1971         f" traceback):\n{e}"
#    1972     ) from e
#
# RuntimeError: Failed to import transformers.modeling_utils because of the following error (look up to see its traceback):
# Traceback (most recent call last):
#   File "C:\Users\danes\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\pywrap_tensorflow.py", line 73, in <module>
#     from tensorflow.python._pywrap_tensorflow_internal import *
# ImportError: DLL load failed while importing _pywrap_tensorflow_internal: A dynamic link library (DLL) initialization routine failed.
#
#
# Failed to load the native TensorFlow runtime.
# See https://www.tensorflow.org/install/errors for some common causes and solutions.
# If you need help, create an issue at https://github.com/tensorflow/tensorflow/issues and include the entire stack trace above this error message.
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host

# %%
from pathlib import Path

NB_DIR = Path.cwd()
PROJECT_ROOT = NB_DIR.resolve().parents[1]

DATA_DIR = PROJECT_ROOT / "data"
RAW_JSON = DATA_DIR / "raw" / "normalized_data_final.json"
DOCS_MAP = DATA_DIR / "processed" / "docs.jsonl"

UNIMODAL_ROOT = PROJECT_ROOT / "artifacts" / "unimodal"
EMB_DIR = UNIMODAL_ROOT / "embeddings"
IDX_DIR = UNIMODAL_ROOT / "indexes"
RUNS_DIR = UNIMODAL_ROOT / "runs"

JSON_IN = RAW_JSON
OUT_DIR = UNIMODAL_ROOT
OUT_DIR.mkdir(parents=True, exist_ok=True)

TEXT_INDEX = IDX_DIR / "faiss_text.idx"
TEXT_IDS = IDX_DIR / "text_ids.npy"
TEXT_EMBEDS = EMB_DIR / "text_embeds.npy"

MCQ_JSON = PROJECT_ROOT / "questions" / "mcq_questions_90.json"
TEXT_MCQ_JSON = RUNS_DIR / "mcq_questions_90.json"
TOP3_CSV = RUNS_DIR / "text_mcq_top3_results.csv"
GEN_SUMMARY = PROJECT_ROOT / "artifacts" / "unimodal" / "reports" / "generative_metrics_summary.json"

print("JSON exists:", JSON_IN.exists(), JSON_IN)
print("Index exists:", TEXT_INDEX.exists(), TEXT_INDEX)
# Out:
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# JSON exists: True E:\Sharif\Term 6\Natural Language Processing\Mashahir_rag_2\data\raw\normalized_data_final.json
# Index exists: True E:\Sharif\Term 6\Natural Language Processing\Mashahir_rag_2\artifacts\unimodal\indexes\faiss_text.idx
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ...
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve().parents[1]

JSON_IN = PROJECT_ROOT / "data" / "raw" / "normalized_data_final.json"
OUT_DIR = PROJECT_ROOT / "rag_out"
OUT_DIR.mkdir(parents=True, exist_ok=True)

TEXT_INDEX = OUT_DIR / "faiss_text.idx"
DOCS_MAP = OUT_DIR / "docs.jsonl"

print("JSON exists:", JSON_IN.exists(), JSON_IN)
print("OUT_DIR:", OUT_DIR.resolve())
# Out:
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# JSON exists: True E:\Sharif\Term 6\Natural Language Processing\Mashahir_rag_2\data\raw\normalized_data_final.json
# OUT_DIR: E:\Sharif\Term 6\Natural Language Processing\Mashahir_rag_2\rag_out
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host

# %% [markdown]
# # Embedding and train process

# %%
E5_DIR = snapshot_download(
    repo_id="intfloat/multilingual-e5-base",
    local_dir=str(OUT_DIR / "m-e5-base"),
    local_dir_use_symlinks=False,
    resume_download=True,
)
print("E5 model at:", E5_DIR)
# Out:
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 E5_DIR = snapshot_download(
#       2     repo_id="intfloat/multilingual-e5-base",
# ----> 3     local_dir=str(OUT_DIR / "m-e5-base"),
#       4     local_dir_use_symlinks=False,
#       5     resume_download=True,
#       6 )
#       7 print("E5 model at:", E5_DIR)
#
# NameError: name 'OUT_DIR' is not defined
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
# ...
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\danes\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\danes\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host

# %%
with JSON_IN.open("r", encoding="utf-8") as f:
    records = json.load(f)

print(f"Loaded records: {len(records)}")

with DOCS_MAP.open("w", encoding="utf-8") as f:
    for r in records:
        f.write(json.dumps(r, ensure_ascii=False) + "\n")

print(f"Wrote {len(records)} lines to:", DOCS_MAP.resolve())
# Out:
# Loaded records: 4092
# Wrote 4092 lines to: /content/rag_out/docs.jsonl

# %%
assert torch.cuda.is_available(), "CUDA not visible in this runtime."
device = "cuda"

# %%
os.environ["HF_HUB_ENABLE_HF_TRANSFER"] = "1"

# %%
text_model = SentenceTransformer(E5_DIR, device=device)

# %%
records = []
with DOCS_MAP.open("r", encoding="utf-8") as f:
    for line in f:
        records.append(json.loads(line))

print("Loaded from docs.jsonl:", len(records))

def get_str(x):
    return x if isinstance(x, str) else ("" if x is None else str(x))

texts = []
for r in records:
    name    = get_str(r.get("name"))
    summary = get_str(r.get("summary"))
    txt = " | ".join([s for s in (name.strip(), summary.strip()) if s])
    texts.append(f"passage: {txt}" if txt else "passage:")
# Out:
# Loaded from docs.jsonl: 4092

# %%
text_vecs = text_model.encode(
    texts,
    batch_size=64,
    convert_to_numpy=True,
    normalize_embeddings=True,   # need this for good embeddings
    show_progress_bar=True
).astype("float32")

print("Text embedding shape:", text_vecs.shape)
# Out:
# Batches:   0%|          | 0/64 [00:00<?, ?it/s]
# Text embedding shape: (4092, 768)

# %%
# ---- Indexing Text (FAISS/hnswlib) ----

USE_FAISS = False
USE_HNSW  = False

try:
    import faiss
    USE_FAISS = True
    print("Using FAISS (CPU) for indexing.")
except Exception:
    try:
        import hnswlib
        USE_HNSW = True
        print("FAISS not available, using hnswlib.")
    except Exception as e:
        raise RuntimeError("Neither FAISS nor hnswlib is available.") from e

N, D = text_vecs.shape

if USE_FAISS:
    # bcz we did normalizing: IP == cosine
    index = faiss.IndexFlatIP(D)
    index.add(text_vecs)
    faiss.write_index(index, str(TEXT_INDEX))
else:
    # hnswlib with space: cosine
    import hnswlib
    p = hnswlib.Index(space='cosine', dim=D)
    p.init_index(max_elements=N, ef_construction=200, M=64)
    p.add_items(text_vecs, ids=np.arange(N))
    p.set_ef(64)  # for query
    p.save_index(str(TEXT_INDEX))

print("Saved text index to:", TEXT_INDEX.resolve())
# Out:
# Using FAISS (CPU) for indexing.
# Saved text index to: /content/rag_out/faiss_text.idx

# %%
TEXT_EMB_NPY= OUT_DIR / "text_embeds.npy"
TEXT_IDS_NPY= OUT_DIR / "text_ids.npy"        # row mappings
TEXTS_TXT   = OUT_DIR / "texts.txt"           # summary texts

# %%
np.save(TEXT_EMB_NPY, text_vecs)             # saving emb
np.save(TEXT_IDS_NPY, np.arange(len(texts))) # pairing indices
print("Saved embeds to:", TEXT_EMB_NPY)
# Out:
# Saved embeds to: rag_out/text_embeds.npy

# %%
def build_index(vectors: np.ndarray, out_path: Path, metric: str = "ip"):
    n, d = vectors.shape
    if n == 0:
        return None
    if USE_FAISS:
        index = faiss.IndexFlatIP(d) if metric == "ip" else faiss.IndexFlatL2(d)
        index.add(vectors)
        faiss.write_index(index, str(out_path))
        return index
    else:
        import hnswlib
        index = hnswlib.Index(space=("cosine" if metric=="ip" else "l2"), dim=d)
        index.init_index(max_elements=n, ef_construction=200, M=16)
        index.add_items(vectors, np.arange(n))
        index.set_ef(64)
        index.save_index(str(out_path).replace(".idx",".bin"))
        return index

text_index = build_index(text_vecs, TEXT_INDEX, metric="ip")
print("Saved index:", TEXT_INDEX)
# Out:
# Saved index: rag_out/faiss_text.idx

# %%
def load_index(path: Path, dim: int, metric="ip"):
    if path.exists():
        if USE_FAISS:
            return faiss.read_index(str(path))
        else:
            import hnswlib
            index = hnswlib.Index(space=("cosine" if metric=="ip" else "l2"), dim=dim)
            index.load_index(str(path).replace(".idx",".bin"))
            index.set_ef(64)
            return index
    return None

# reload to confirm correctness
text_index = load_index(TEXT_INDEX, text_vecs.shape[1], metric="ip")

# %%
# ---- knn & search -> text ----

def knn(index, q, k=10, metric="ip"):
    if index is None:
        return np.array([], dtype=np.float32), np.array([], dtype=np.int64)
    if USE_FAISS:
        D, I = index.search(q.reshape(1,-1).astype("float32"), k)
        return D[0], I[0]
    else:
        I, D = index.knn_query(q.reshape(1,-1).astype("float32"), k)
        # hnswlib with space: cosine
        return (1.0 - D[0]) if metric == "ip" else (-D[0]), I[0]

def search(query: str, k=5, use_norm=USE_QUERY_NORM):
    if text_index is None:
        print("No text index loaded.")
        return []

    # ensure docs loaded (lazy)
    global docs
    if 'docs' not in globals() or docs is None or not isinstance(docs, list) or len(docs) == 0:
        docs = [json.loads(line) for line in DOCS_MAP.open("r", encoding="utf-8")]

    # soft normalizing just on query
    q_in = normalize_query_min(query) if use_norm else query

    q_t = text_model.encode(
        f"query: {q_in}",
        convert_to_numpy=True,
        normalize_embeddings=True
    ).astype("float32")

    D_t, I_t = knn(text_index, q_t, k=k, metric="ip")
    out = []
    for i, s in zip(I_t, D_t):
        if 0 <= int(i) < len(docs):
            rec = dict(docs[int(i)])
            rec["_score"] = float(s)
            rec["_row"]   = int(i)
            out.append(rec)
    return out
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 14
#      11         # hnswlib with space: cosine
#      12         return (1.0 - D[0]) if metric == "ip" else (-D[0]), I[0]
# ---> 14 def search(query: str, k=5, use_norm=USE_QUERY_NORM):
#      15     if text_index is None:
#      16         print("No text index loaded.")
#
# NameError: name 'USE_QUERY_NORM' is not defined

# %%
# --- run & display queries (text-only) + logging ---
from datetime import datetime
from pathlib import Path
import json

SEARCH_LOG = OUT_DIR / "search_logs.jsonl"  # logging for better report/monitor process

def _truncate(s, n=90):
    if not s:
        return ""
    return s if len(s) <= n else (s[:n].rstrip() + "…")

# %%
# sample query just for testing
q = "قهرمان مشهور کشتی آزاد ایران"

docs = [json.loads(line) for line in DOCS_MAP.open("r", encoding="utf-8")]
print("docs loaded:", len(docs))

hits = search(q, k=5)
for r in hits:
    print("—", r.get("name","<no name>"),
          "| score:", f"{r.get('_score', 0.0):.3f}",
          "| row:", r.get("_row", -1),
          "| sum:", _truncate(r.get("summary","")))
# Out:
# docs loaded: 4092
# — مرتضی خوشبخت  | score: 0.851 | row: 2220 | sum: مرتضی خوشبخت، ورزشکار کشتی، در تاریخ 10 اردیبهشت 1359 (44 سال) در تهران متولد شده است، قد…
# — حسین تهامی | score: 0.843 | row: 1014 | sum: حسین تهامی، متولد ایران، کشتی‌گیر آزاد با ملیت ایرانی بود. او در اسفند 1385 درگذشت.
# — رضا یزدانی  | score: 0.843 | row: 1230 | sum: رضا یزدانی، ورزشکار کشتی، در تاریخ 3 شهریور 1363 (در 40 سال) متولد شده است، قد ایشان 1، 72…
# — احمد وفادار | score: 0.843 | row: 600 | sum: احمد وفادار، ورزشکار کشتی، در تاریخ 15 خردادماه سال 1306 در روستای متولد شده است، قد ایشان…
# — هومن توکلیان | score: 0.840 | row: 2582 | sum: هومن توکلیان، ورزشکار کشتی، در تاریخ ایران متولد شده است.

# %%
# helper for running some queries and printing correctly

def run_queries(queries, k=5, log=True):
    for q in queries:
        print("\n" + "—"*100)
        print("Q:", q)
        try:
            hits = search(q, k=k)
            if not hits:
                print("  (no results)")
            else:
                for r in hits:
                    print("  —", r.get("name","<no name>"),
                          "| score:", f"{r.get('_score', 0.0):.3f}",
                          "| row:", r.get("_row", -1),
                          "| sum:", _truncate(r.get("summary","")))
            # save logging
            if log:
                with SEARCH_LOG.open("a", encoding="utf-8") as f:
                    f.write(json.dumps({
                        "ts": datetime.now().isoformat(timespec="seconds"),
                        "query": q,
                        "k": k,
                        "results": [
                            {
                                "row": r.get("_row", -1),
                                "name": r.get("name"),
                                "score": float(r.get("_score", 0.0)),
                            } for r in hits
                        ]
                    }, ensure_ascii=False) + "\n")
        except Exception as e:
            print("  ERROR:", e)

# Query set 1 — sport/attribute style (Persian)
attr_queries = [
    "قهرمان مشهور کشتی آزاد ایران",
    "قهرمان المپیک ایران در وزنه‌برداری",
    "ملی‌پوش سرشناس والیبال ایران",
    "دارنده بیشترین مدال تکواندو ایران",
    "چهره مطرح کاراته ایران",
    "ستاره دوومیدانی ایران",
    "بازیکن نامدار فوتسال ایران",
    "دروازه‌بان تیم ملی فوتبال ایران",
    "کاپیتان سابق تیم ملی فوتبال ایران",
    "قهرمان جهان در کشتی فرنگی ایران",
]

# Query set 2 — named lookups
name_queries = [
    "غلامرضا تختی",
    "حسن یزدانی",
    "علیرضا دبیر",
    "هادی ساعی",
    "کیمیا علیزاده",
    "سعید مولایی",
    "سردار آزمون",
    "مهدی طارمی",
    "علی دایی",
    "الهه احمدی",
]

# Query set 4 — fuzzy & variants
fuzzy_queries = [
    "کشتي آزاد ايران",
    "قهرمان كشتی فرنگی ايران",
    "هادی ساعي",
    "كيميا عليزاده",
    "حسن یزدانی چهره",
    "تختی قهرمان کشتی",
    "دبیر کشتی ایران",
    "بانوی تیراندازی ایران",
    "وزنه بردار طلایی ایران",
    "مدال‌آور پارالمپیک ایران",
]

print("### Running attribute-style queries")
run_queries(attr_queries, k=5)

print("\n\n### Running name queries")
run_queries(name_queries, k=5)

print("\n\n### Running fuzzy/variant queries")
run_queries(fuzzy_queries, k=5)

print("\nLogs saved to:", SEARCH_LOG)
# Out:
# ### Running attribute-style queries
#
# ————————————————————————————————————————————————————————————————————————————————————————————————————
# Q: قهرمان مشهور کشتی آزاد ایران
#   — مرتضی خوشبخت  | score: 0.851 | row: 2220 | sum: مرتضی خوشبخت، ورزشکار کشتی، در تاریخ 10 اردیبهشت 1359 (44 سال) در تهران متولد شده است، قد…
#   — حسین تهامی | score: 0.843 | row: 1014 | sum: حسین تهامی، متولد ایران، کشتی‌گیر آزاد با ملیت ایرانی بود. او در اسفند 1385 درگذشت.
#   — رضا یزدانی  | score: 0.843 | row: 1230 | sum: رضا یزدانی، ورزشکار کشتی، در تاریخ 3 شهریور 1363 (در 40 سال) متولد شده است، قد ایشان 1، 72…
#   — احمد وفادار | score: 0.843 | row: 600 | sum: احمد وفادار، ورزشکار کشتی، در تاریخ 15 خردادماه سال 1306 در روستای متولد شده است، قد ایشان…
#   — هومن توکلیان | score: 0.840 | row: 2582 | sum: هومن توکلیان، ورزشکار کشتی، در تاریخ ایران متولد شده است.
#
# ————————————————————————————————————————————————————————————————————————————————————————————————————
# Q: قهرمان المپیک ایران در وزنه‌برداری
#   — علیرضا یوسفی | score: 0.859 | row: 1723 | sum: علیرضا یوسفی، ورزشکار وزنه‌برداری، در تاریخ 27 اوت 2003 (در 21 سال) متولد شده است، وزن ایش…
#   — سجاد انوشیروانی | score: 0.857 | row: 1314 | sum: سجاد انوشیروانی، ورزشکار وزنه‌برداری.
#   — علی صفاسنبلی | score: 0.855 | row: 1622 | sum: علی صفاسنبلی، ورزشکار وزنه‌برداری، در تاریخ 29 آبان 1311 در 1957 تهران متولد شده است، قد ا…
#   — بهرام افشارزاده | score: 0.855 | row: 853 | sum: بهرام افشارزاده، ورزشکار وزنه‌برداری، در تاریخ 1321 در اصفهان متولد شده است.
#   — بهادر مولایی | score: 0.854 | row: 847 | sum: بهادر مولایی، ورزشکار وزنه‌برداری، در تاریخ 21 مارس 1992 (در 33 سال) متولد شده است، وزن ای…
#
# ————————————————————————————————————————————————————————————————————————————————————————————————————
# Q: ملی‌پوش سرشناس والیبال ایران
#   — مسعود آرمات | score: 0.855 | row: 2246 | sum: مسعود آرمات، ورزشکار والیبال.
#   — حمید دستمالچی | score: 0.853 | row: 1079 | sum: حمید دستمالچی، ورزشکار والیبال.
#   — حسین هاشمی | score: 0.845 | row: 1057 | sum: حسین هاشمی، ورزشکار بسکتبال.
#   — فاطمه حسنی سعدی | score: 0.842 | row: 1756 | sum: فاطمه حسنی سعدی، ورزشکار والیبال، در تاریخ 20 آذر 1373 (30 سال) کرمان در تیم ملی بزرگسالان…
#   — ژنیک شهبازیان | score: 0.842 | row: 2699 | sum: ژنیک شهبازیان، ورزشکار بسکتبال.
#
# ————————————————————————————————————————————————————————————————————————————————————————————————————
# Q: دارنده بیشترین مدال تکواندو ایران
#   — حسن زاهدی  | score: 0.863 | row: 995 | sum: حسن زاهدی، ورزشکار تکواندو، در تاریخ 1340 در رشت متولد شده است، افتخارات مدال نقره قهرمانی…
#   — روناک حسین زاده | score: 0.859 | row: 1247 | sum: روناک حسین زاده، ورزشکار تکواندو، در تاریخ 15 تیر 1377 (26 سال) در سقز متولد شده است، افتخ…
#   — سجاد مردانی | score: 0.858 | row: 1322 | sum: سجاد مردانی، ورزشکار تکواندو، در 2019 ووشی متولد شده است، افتخارات مدال نقره مسابقات جهانی…
#   — میلاد بیگی | score: 0.856 | row: 2447 | sum: میلاد بیگی، ورزشکار تکواندو، در تاریخ 10 اسفند 1369 در اصفهان متولد شده است، قد ایشان 1، 9…
#   — حمید نظری | score: 0.852 | row: 1086 | sum: حمید نظری، ورزشکار تکواندو، در تاریخ 22 دی 1367 (در 36 سال) متولد شده است، قد ایشان 176 سا…
#
# ————————————————————————————————————————————————————————————————————————————————————————————————————
# Q: چهره مطرح کاراته ایران
#   — امیر مهدی‌زاده | score: 0.854 | row: 718 | sum: امیر مهدی‌زاده، ورزشکار کاراته، در تاریخ 31 شهریور 1368 در قم متولد شده است، قد ایشان 173…
#   — ذبیح‌الله پورشیب | score: 0.850 | row: 1153 | sum: ذبیح‌الله پورشیب، ورزشکار کاراته، در تاریخ 27 تیر 1367 (در 37 سال) متولد شده است، قد ایشان…
#   — حمید نعمتیان | score: 0.848 | row: 1087 | sum: حمید نعمتیان، ورزشکار کاراته، در تاریخ 28 تیر 1361 در تهران متولد شده است.
#   — میثم یاراحمدی | score: 0.845 | row: 2436 | sum: میثم یاراحمدی، ورزشکار کاراته، در تاریخ 4 شهریور 1369 در خرم‌آباد، لرستان متولد شده است.
#   — صادق علی‌اکبرزاده | score: 0.844 | row: 1502 | sum: صادق علی‌اکبرزاده، ورزشکار کاراته، در تاریخ 13 شهریور 1311 متولد شده است.
#
# ————————————————————————————————————————————————————————————————————————————————————————————————————
# Q: ستاره دوومیدانی ایران
#   — نجمه خدمتی | score: 0.822 | row: 2503 | sum: نجمه خدمتی، ورزشکار تیراندازی، در تاریخ 20 خرداد 1375 در 9 ژوئن 1996 (متولد شده است، قد ای…
#   — فهرست پرچم‌داران کاروان ایران در المپیک | score: 0.816 | row: 1844 | sum: فهرست پرچم‌داران کاروان ایران در المپیک، ورزشکار اسکی.
#   — مجتبی عابدینی | score: 0.814 | row: 1935 | sum: مجتبی عابدینی، ورزشکار رزمی، در تاریخ 11 اوت 1984 (در 40 سال) متولد شده است، قد ایشان 1، 7…
#   — هانیه رستمیان | score: 0.814 | row: 2567 | sum: هانیه رستمیان، ورزشکار تیراندازی، در تاریخ 20 شهریور 1377 (26 سال) در [متولد شده است، قد ا…
#   — ملینا اسماعیلی | score: 0.814 | row: 2284 | sum: ملینا اسماعیلی، متولد 12 خرداد 1384 در البرز، ورزشکار دو و می‌دانی در رشته دو سرعت با قد 1…
#
# ————————————————————————————————————————————————————————————————————————————————————————————————————
# Q: بازیکن نامدار فوتسال ایران
#   — محمدرضا منصوری  | score: 0.852 | row: 2163 | sum: محمدرضا منصوری، ورزشکار فوتبال.
#   — رامین محرم نژاد | score: 0.847 | row: 1166 | sum: رامین محرم نژاد، ورزشکار فوتبال.
#   — دیوید بختیاری | score: 0.847 | row: 1150 | sum: دیوید بختیاری، ورزشکار فوتبال.
#   — اشکان نامداری | score: 0.844 | row: 647 | sum: اشکان نامداری، ورزشکار فوتبال، در تاریخ 12 بهمن 1355 (47 سال) در ایران متولد شده است، در ت…
#   — علی حجت کاشانی | score: 0.844 | row: 1594 | sum: علی حجت کاشانی، ورزشکار فوتبال.
#
# ————————————————————————————————————————————————————————————————————————————————————————————————————
# Q: دروازه‌بان تیم ملی فوتبال ایران
#   — حجت صدقی | score: 0.824 | row: 981 | sum: حجت صدقی، متولد 18 بهمن 1371 در کرمان، ایران، دروازه‌بان فوتبال با قد 1، 87 متر است. او با…
#   — علیرضا حقیقی | score: 0.822 | row: 1682 | sum: علیرضا حقیقی، متولد 12 اردیبهشت 1367 در تهران، ایران، دروازه‌بان فوتبال با قد 1، 93 متر اس…
#   — فهرست مربیان تیم ملی فوتبال ایران | score: 0.822 | row: 1843 | sum: فهرست مربیان تیم ملی فوتبال ایران، ورزشکار فوتبال.
#   — سوشا مکانی | score: 0.818 | row: 1391 | sum: سوشا مکانی، متولد 27 آبان 1365 در بندر انزلی، دروازه‌بان فوتبال با قد 1، 92 متر است. او در…
#   — معراج اسماعیلی | score: 0.817 | row: 2280 | sum: معراج اسماعیلی، متولد 23 دی 1378 در اندیمشک، خوزستان، ایران، دروازه‌بان فوتبال با قد 1، 93…
#
# ————————————————————————————————————————————————————————————————————————————————————————————————————
# Q: کاپیتان سابق تیم ملی فوتبال ایران
#   — اکبر میثاقیان | score: 0.828 | row: 779 | sum: اکبر میثاقیان، متولد 31 اردیبهشت 1332 در گنبد کاووس، گلستان، ایران، بازیکن و مربی فوتبال ا…
#   — مهدی هاشمی‌نسب | score: 0.818 | row: 2358 | sum: مهدی هاشمی‌نسب، متولد 7 بهمن 1352 در آبادان، ایران، بازیکن و مربی فوتبال با قد 1، 85 متر ا…
#   — علی حجت کاشانی | score: 0.818 | row: 1594 | sum: علی حجت کاشانی، ورزشکار فوتبال.
#   — فهرست مربیان تیم ملی فوتبال ایران | score: 0.816 | row: 1843 | sum: فهرست مربیان تیم ملی فوتبال ایران، ورزشکار فوتبال.
#   — سیروس دین‌محمدی | score: 0.813 | row: 1443 | sum: سیروس دین‌محمدی، متولد 11 تیر 1349 در تبریز، ایران، بازیکن و مربی فوتبال با قد 1، 66 متر ا…
#
# ————————————————————————————————————————————————————————————————————————————————————————————————————
# Q: قهرمان جهان در کشتی فرنگی ایران
#   — رضا یزدانی  | score: 0.849 | row: 1230 | sum: رضا یزدانی، ورزشکار کشتی، در تاریخ 3 شهریور 1363 (در 40 سال) متولد شده است، قد ایشان 1، 72…
#   — امین میرزازاده | score: 0.844 | row: 761 | sum: امین میرزازاده، ملقب به تانک بختیاری، متولد 18 دی 1376 در گتوند، خوزستان، ایران، ورزشکار ک…
#   — احمد وفادار | score: 0.842 | row: 600 | sum: احمد وفادار، ورزشکار کشتی، در تاریخ 15 خردادماه سال 1306 در روستای متولد شده است، قد ایشان…
#   — غلام‌رضا قصاب | score: 0.841 | row: 1749 | sum: غلام‌رضا قصاب، متولد 21 مارس 1956 در دزفول، کشتی‌گیر فرنگی ایرانی است که به مدت 8 سال در ا…
#   — بهرام مشتاقی | score: 0.836 | row: 856 | sum: بهرام مشتاقی، متولد 2 اردیبهشت 1331 در ایران، ورزشکار کشتی فرنگی با ملیت ایرانی است. او 72…
#
#
# ### Running name queries
#
# ————————————————————————————————————————————————————————————————————————————————————————————————————
# Q: غلامرضا تختی
#   — غلامرضا تختی | score: 0.852 | row: 1746 | sum: غلامرضا تختی، ورزشکار کشتی، در تاریخ 5 شهریور 1309 در تهران متولد شده است، در تاریخ 17 دی…
#   — غلامرضا رضایی | score: 0.828 | row: 1747 | sum: غلامرضا رضایی، ورزشکار فوتبال، در تاریخ 6 اوت 1984 (40 سال) در مسابقات فوتبال غرب آسیا 200…
#   — غلامرضا انصاری | score: 0.824 | row: 3248 | sum: غلامرضا انصاری در تاریخ 1956 - 10 - 24 در شهر مشهد واقع در خراسان رضوی به دنیا آمد. زمینه‌…
#   — غلام‌رضا عنایتی | score: 0.821 | row: 1748 | sum: غلام‌رضا عنایتی، ورزشکار فوتبال، در تاریخ 1 مهر 1355 (48 سال) [2] در مشهد، ایران متولد شده…
#   — غلامرضا اعوانی | score: 0.819 | row: 3066 | sum: غلامرضا اعوانی، در سال 1322 شمسی در سمنان متولد شد. او به عنوان فیلسوف و استاد دانشگاه فعا…
#
# ————————————————————————————————————————————————————————————————————————————————————————————————————
# Q: حسن یزدانی
#   — حسن یزدانی | score: 0.863 | row: 1004 | sum: حسن یزدانی، ورزشکار کشتی، در تاریخ 5 دی 1373 (30 سال) در جویبار متولد شده است، قد ایشان 1،…
#   — رضا یزدانی | score: 0.842 | row: 324 | sum: رضا یزدانی، متولد 24 مهر 1352 در تهران، خواننده، آهنگساز، نوازنده و بازیگر ایرانی است که ا…
#   — رضا یزدانی  | score: 0.841 | row: 1230 | sum: رضا یزدانی، ورزشکار کشتی، در تاریخ 3 شهریور 1363 (در 40 سال) متولد شده است، قد ایشان 1، 72…
#   — محسن یزدانی | score: 0.836 | row: 1997 | sum: محسن یزدانی، متولد 10 مرداد 1348 در تهران، ورزشکار و مربی بدن‌سازی است. او دارای مدرک MBA…
#   — پیمان یزدانیان | score: 0.829 | row: 443 | sum: پیمان یزدانیان، متولد 1347 در تهران، آهنگساز، نوازنده پیانو و سازنده موسیقی متن فیلم ایران…
#
# ————————————————————————————————————————————————————————————————————————————————————————————————————
# Q: علیرضا دبیر
#   — علیرضا دبیر | score: 0.874 | row: 3258 | sum: علیرضا دبیر در تاریخ 1977 - 09 - 16 در شهر تهران واقع در تهران به دنیا آمد. زمینه‌های فعال…
#   — علیرضا دبیر | score: 0.868 | row: 1685 | sum: علیرضا دبیر، ورزشکار کشتی، در تاریخ 25 شهریور 1356 (47 سال) در شهر ری متولد شده است، افتخا…
#   — علیرضا حیدری | score: 0.819 | row: 1683 | sum: علیرضا حیدری، متولد 14 اسفند 1354 در تهران، ایران، ورزشکار کشتی آزاد با قد 1، 86 متر است ک…
#   — علیرضا لرستانی | score: 0.818 | row: 1703 | sum: علیرضا لرستانی، متولد 15 بهمن 1342 در خرم‌آباد، لرستان، کشتی‌گیر ایرانی است. او در رشته‌ها…
#   — علیرضا منظمی | score: 0.817 | row: 1709 | sum: علیرضا منظمی، ورزشکار فوتبال، در تاریخ 23 آذر 138114 دسامبر 2002 (22 سال) در خرمشهر، ایران…
#
# ————————————————————————————————————————————————————————————————————————————————————————————————————
# Q: هادی ساعی
#   — هادی ساعی | score: 0.859 | row: 2546 | sum: هادی ساعی، متولد 20 خرداد 1355 در شهر ری، ایران، تکواندوکار با قد 1، 82 متر و وزن 79 کیلوگ…
#   — هادی ساعی بنه‌ کهل | score: 0.826 | row: 3261 | sum: هادی ساعی بنه کهل در تاریخ 1976 - 10 - 06 در شهر شهر ری واقع در تهران به دنیا آمد. زمینه‌ه…
#   — هادی محمدی | score: 0.820 | row: 2553 | sum: هادی محمدی، متولد 17 اسفند 1369 در محلات، ایران، مدافع میانی فوتبال با قد 1، 88 متر است. ا…
#   — زهرا ساعی | score: 0.819 | row: 3579 | sum: زهرا ساعی در تاریخ 1980 - 00 - 00 در شهر تبریز واقع در آذربایجان شرقی به دنیا آمد. زمینه‌ه…
#   — سید هادی حسینی خامنه | score: 0.816 | row: 3797 | sum: سید هادی حسینی خامنه که با نام‌های مستعار «سید هادی خامنه‌ای» نیز شناخته می‌شود، در تاریخ…
#
# ————————————————————————————————————————————————————————————————————————————————————————————————————
# Q: کیمیا علیزاده
#   — کیمیا علیزاده | score: 0.818 | row: 2750 | sum: کیمیا علیزاده، متولد 19 تیر 1377 در کرج، ایران، ورزشکار تکواندو با قد 1، 85 متر و وزن 57 ک…
#   — محمد علیزاده | score: 0.814 | row: 313 | sum: محمد علیزاده، متولد 23 دی 1360 در کرج، خواننده، ترانه‌سرا، آهنگساز و مجری ایرانی است که در…
#   — علی زند  | score: 0.803 | row: 1609 | sum: علی زند، ورزشکار کاراته، در تاریخ 4 خرداد 1378 (25 سال) در اراک متولد شده است، قد ایشان 17…
#   — علی حجت کاشانی | score: 0.802 | row: 1594 | sum: علی حجت کاشانی، ورزشکار فوتبال.
#   — علی مدنی  | score: 0.800 | row: 1637 | sum: علی مدنی، ورزشکار فوتبال.
#
# ————————————————————————————————————————————————————————————————————————————————————————————————————
# Q: سعید مولایی
#   — سعید ملایی | score: 0.842 | row: 1368 | sum: سعید ملایی، متولد 5 دی 1370 در تهران، ایران، ورزشکار جودو با قد 1، 75 متر و وزن 81 کیلوگرم…
#   — مهدیه مولایی | score: 0.820 | row: 2366 | sum: مهدیه مولایی، ورزشکار فوتبال، در تاریخ 29 ژانویه 1991 (34 سال) [2] در جیرفت متولد شده است.
#   — سعید محمدی | score: 0.818 | row: 309 | sum: سعید محمدی، متولد 11 فروردین 1337 در تهران، خواننده، آهنگ‌ساز، ترانه‌سرا و نوازنده گیتار ا…
#   — سعید احمدی  | score: 0.817 | row: 1343 | sum: سعید احمدی، ورزشکار کاراته، در تاریخ 10 مهر 1367 (در 36 سال) متولد شده است، قد ایشان 180 س…
#   — پرواز همای | score: 0.814 | row: 2990 | sum: پرواز همای، معروف به سعید جعفرزاده احمدسرگورابی، در 20 بهمن 1358 در احمدسرگوراب متولد شد.…
#
# ————————————————————————————————————————————————————————————————————————————————————————————————————
# Q: سردار آزمون
#   — سردار آزمون | score: 0.898 | row: 1331 | sum: سردار آزمون، ورزشکار فوتبال، در تاریخ 11 دی 1373 (30 سال) در گنبد کاووس، ایران متولد شده ا…
#   — مریم آزمون | score: 0.832 | row: 2236 | sum: مریم آزمون، ورزشکار فوتبال، در تاریخ 10 نوامبر 1973 (51 سال) [1] در رشت، ایران متولد شده ا…
#   — وزیر ورزش و جوانان | score: 0.825 | row: 2614 | sum: وزیر ورزش و جوانان، ورزشکار فوتبال.
#   — سجاد انوشیروانی | score: 0.813 | row: 1314 | sum: سجاد انوشیروانی، ورزشکار وزنه‌برداری.
#   — ایمان شوریابی | score: 0.812 | row: 795 | sum: ایمان شوریابی، ورزشکار فوتبال، در تاریخ 30 شهریور 1366 در گرمسار، ایران متولد شده است، قد…
#
# ————————————————————————————————————————————————————————————————————————————————————————————————————
# Q: مهدی طارمی
#   — مهدی طارمی | score: 0.872 | row: 2341 | sum: مهدی طارمی، ورزشکار فوتبال، در تاریخ 27 تیر 1371 (32 سال) در بوشهر، ایران متولد شده است، ق…
#   — یدالله طارمی | score: 0.817 | row: 2997 | sum: یدالله طارمی، شاعر دوره پهلوی و جمهوری اسلامی، در سال 1311 شمسی در شیراز زاده شد و در سال…
#   — مهدی ترکمان | score: 0.812 | row: 2318 | sum: مهدی ترکمان، ورزشکار فوتبال، در تاریخ 17 اسفند 1367 (36 سال) در کرج، ایران متولد شده است،…
#   — مهدی خدابخشی | score: 0.808 | row: 2326 | sum: مهدی خدابخشی، ورزشکار رزمی، در تاریخ 10 اردیبهشت 1374 در اسلام‌آباد غرب متولد شده است، قد…
#   — مهدی کرمی | score: 0.804 | row: 2362 | sum: مهدی کرمی، ورزشکار کشتی، در تاریخ 23 مهر 1377 در 15 اکتبر 1998 (متولد شده است، قد ایشان 1،…
#
# ————————————————————————————————————————————————————————————————————————————————————————————————————
# Q: علی دایی
#   — علی دایی | score: 0.865 | row: 1605 | sum: علی دایی، ورزشکار فوتبال، در تاریخ 1 فروردین 1348 (56 سال) در اردبیل متولد شده است، قد ایش…
#   — علی دانایی‌فرد | score: 0.824 | row: 1603 | sum: علی دانایی‌فرد، ورزشکار فوتبال، در تاریخ 2 مهر 1300 تهران، ایران متولد شده است، در تاریخ 1…
#   — علی دشتی  | score: 0.814 | row: 1607 | sum: علی دشتی، ورزشکار فوتبال، در تاریخ 29 دی 1372 (31 سال) در بوشهر، ایران متولد شده است، قد ا…
#   — علی زند وکیلی | score: 0.814 | row: 256 | sum: علی زند وکیلی، متولد 5 دی 1365 در شیراز، خواننده و آهنگساز است. او با آلبوم‌هایی مانند «رو…
#   — علی حجت کاشانی | score: 0.812 | row: 1594 | sum: علی حجت کاشانی، ورزشکار فوتبال.
#
# ————————————————————————————————————————————————————————————————————————————————————————————————————
# Q: الهه احمدی
#   — الهه احمدی | score: 0.857 | row: 672 | sum: الهه احمدی، ورزشکار تیراندازی، در تاریخ 31 مه 1982 (در 42 سال) متولد شده است، قد ایشان 1،…
#   — الهه راستگو | score: 0.817 | row: 3460 | sum: الهه راستگو در تاریخ 1962 - 01 - 01 در شهر ملایر واقع در همدان به دنیا آمد. زمینه‌های فعال…
#   — الهه منصوریان | score: 0.816 | row: 673 | sum: الهه منصوریان، ورزشکار رزمی، در تاریخ 30 شهریور 1370 در [متولد شده است، قد ایشان 1، 68 متر…
#   — مرضیه احمدی اسکویی | score: 0.812 | row: 3747 | sum: مرضیه احمدی اسکویی در تاریخ 1941 - 00 - 00 در شهر اسکو واقع در آذربایجان شرقی به دنیا آمد.…
#   — ترانه احمدی | score: 0.811 | row: 898 | sum: ترانه احمدی، ورزشکار اسکیت، در تاریخ 5 تیر 1381 در ایران متولد شده است، قد ایشان 1، 67 متر…
#
#
# ### Running fuzzy/variant queries
#
# ————————————————————————————————————————————————————————————————————————————————————————————————————
# Q: کشتي آزاد ايران
#   — مرتضی خوشبخت  | score: 0.826 | row: 2220 | sum: مرتضی خوشبخت، ورزشکار کشتی، در تاریخ 10 اردیبهشت 1359 (44 سال) در تهران متولد شده است، قد…
#   — امیر توکلیان | score: 0.825 | row: 699 | sum: امیر توکلیان، متولد 16 شهریور 1350 در مشهد، ایران، کشتی‌گیر آزاد با ملیت ایرانی است.
#   — رضا یزدانی  | score: 0.818 | row: 1230 | sum: رضا یزدانی، ورزشکار کشتی، در تاریخ 3 شهریور 1363 (در 40 سال) متولد شده است، قد ایشان 1، 72…
#   — احمد وفادار | score: 0.818 | row: 600 | sum: احمد وفادار، ورزشکار کشتی، در تاریخ 15 خردادماه سال 1306 در روستای متولد شده است، قد ایشان…
#   — حسین تهامی | score: 0.817 | row: 1014 | sum: حسین تهامی، متولد ایران، کشتی‌گیر آزاد با ملیت ایرانی بود. او در اسفند 1385 درگذشت.
#
# ————————————————————————————————————————————————————————————————————————————————————————————————————
# Q: قهرمان كشتی فرنگی ايران
#   — رضا یزدانی  | score: 0.845 | row: 1230 | sum: رضا یزدانی، ورزشکار کشتی، در تاریخ 3 شهریور 1363 (در 40 سال) متولد شده است، قد ایشان 1، 72…
#   — احمد وفادار | score: 0.845 | row: 600 | sum: احمد وفادار، ورزشکار کشتی، در تاریخ 15 خردادماه سال 1306 در روستای متولد شده است، قد ایشان…
#   — غلام‌رضا قصاب | score: 0.844 | row: 1749 | sum: غلام‌رضا قصاب، متولد 21 مارس 1956 در دزفول، کشتی‌گیر فرنگی ایرانی است که به مدت 8 سال در ا…
#   — امین میرزازاده | score: 0.843 | row: 761 | sum: امین میرزازاده، ملقب به تانک بختیاری، متولد 18 دی 1376 در گتوند، خوزستان، ایران، ورزشکار ک…
#   — امیررضا خادم | score: 0.834 | row: 742 | sum: امیررضا خادم، ورزشکار کشتی، در تاریخ امیررضا خادم ازغدی در 10 فوریه 1970 (متولد شده است، ا…
#
# ————————————————————————————————————————————————————————————————————————————————————————————————————
# Q: هادی ساعي
#   — هادی ساعی | score: 0.859 | row: 2546 | sum: هادی ساعی، متولد 20 خرداد 1355 در شهر ری، ایران، تکواندوکار با قد 1، 82 متر و وزن 79 کیلوگ…
#   — هادی ساعی بنه‌ کهل | score: 0.826 | row: 3261 | sum: هادی ساعی بنه کهل در تاریخ 1976 - 10 - 06 در شهر شهر ری واقع در تهران به دنیا آمد. زمینه‌ه…
#   — هادی محمدی | score: 0.820 | row: 2553 | sum: هادی محمدی، متولد 17 اسفند 1369 در محلات، ایران، مدافع میانی فوتبال با قد 1، 88 متر است. ا…
#   — زهرا ساعی | score: 0.819 | row: 3579 | sum: زهرا ساعی در تاریخ 1980 - 00 - 00 در شهر تبریز واقع در آذربایجان شرقی به دنیا آمد. زمینه‌ه…
#   — سید هادی حسینی خامنه | score: 0.816 | row: 3797 | sum: سید هادی حسینی خامنه که با نام‌های مستعار «سید هادی خامنه‌ای» نیز شناخته می‌شود، در تاریخ…
#
# ————————————————————————————————————————————————————————————————————————————————————————————————————
# Q: كيميا عليزاده
#   — کیمیا علیزاده | score: 0.818 | row: 2750 | sum: کیمیا علیزاده، متولد 19 تیر 1377 در کرج، ایران، ورزشکار تکواندو با قد 1، 85 متر و وزن 57 ک…
#   — محمد علیزاده | score: 0.814 | row: 313 | sum: محمد علیزاده، متولد 23 دی 1360 در کرج، خواننده، ترانه‌سرا، آهنگساز و مجری ایرانی است که در…
#   — علی زند  | score: 0.803 | row: 1609 | sum: علی زند، ورزشکار کاراته، در تاریخ 4 خرداد 1378 (25 سال) در اراک متولد شده است، قد ایشان 17…
#   — علی حجت کاشانی | score: 0.802 | row: 1594 | sum: علی حجت کاشانی، ورزشکار فوتبال.
#   — علی مدنی  | score: 0.800 | row: 1637 | sum: علی مدنی، ورزشکار فوتبال.
#
# ————————————————————————————————————————————————————————————————————————————————————————————————————
# Q: حسن یزدانی چهره
#   — حسن یزدانی | score: 0.845 | row: 1004 | sum: حسن یزدانی، ورزشکار کشتی، در تاریخ 5 دی 1373 (30 سال) در جویبار متولد شده است، قد ایشان 1،…
#   — رضا یزدانی  | score: 0.826 | row: 1230 | sum: رضا یزدانی، ورزشکار کشتی، در تاریخ 3 شهریور 1363 (در 40 سال) متولد شده است، قد ایشان 1، 72…
#   — رضا یزدانی | score: 0.823 | row: 324 | sum: رضا یزدانی، متولد 24 مهر 1352 در تهران، خواننده، آهنگساز، نوازنده و بازیگر ایرانی است که ا…
#   — سیاوش یزدانی | score: 0.814 | row: 1403 | sum: سیاوش یزدانی، ورزشکار فوتبال، در تاریخ 8 اسفند 1370 (33 سال) در مشهد، ایران متولد شده است،…
#   — رضا یزدان‌دوست | score: 0.811 | row: 1231 | sum: رضا یزدان‌دوست، ورزشکار فوتبال، در تاریخ 7 نوامبر 1991 (33 سال) در تراکتور متولد شده است،…
#
# ————————————————————————————————————————————————————————————————————————————————————————————————————
# Q: تختی قهرمان کشتی
#   — غلامرضا تختی | score: 0.875 | row: 1746 | sum: غلامرضا تختی، ورزشکار کشتی، در تاریخ 5 شهریور 1309 در تهران متولد شده است، در تاریخ 17 دی…
#   — مصطفی شهری فریمانی | score: 0.837 | row: 2275 | sum: مصطفی شهری فریمانی، ورزشکار کشتی، در تاریخ 18 دی 1369 (در 34 سال) متولد شده است، قد ایشان…
#   — حامد رشیدی | score: 0.835 | row: 966 | sum: حامد رشیدی، ورزشکار کشتی، در تاریخ کرمانشاه در، متولد شده است، افتخارات مدال طلا جام جهانی…
#   — ولی اکبر | score: 0.832 | row: 2618 | sum: ولی اکبر، ورزشکار کشتی، در تاریخ 1 اردیبهشت 1349 در شهرستان ری متولد شده است، وزن ایشان 76…
#   — محمد باقری تاج امیر | score: 0.830 | row: 2011 | sum: محمد باقری تاج امیر، ورزشکار کشتی، در تاریخ 2 مهر 1377 (26 سال) در دلفان متولد شده است، قد…
#
# ————————————————————————————————————————————————————————————————————————————————————————————————————
# Q: دبیر کشتی ایران
#   — علیرضا دبیر | score: 0.873 | row: 3258 | sum: علیرضا دبیر در تاریخ 1977 - 09 - 16 در شهر تهران واقع در تهران به دنیا آمد. زمینه‌های فعال…
#   — علیرضا دبیر | score: 0.859 | row: 1685 | sum: علیرضا دبیر، ورزشکار کشتی، در تاریخ 25 شهریور 1356 (47 سال) در شهر ری متولد شده است، افتخا…
#   — رسول خادم | score: 0.844 | row: 3256 | sum: رسول خادم در تاریخ 1972 - 03 - 18 در شهر مشهد واقع در خراسان رضوی به دنیا آمد. زمینه‌های ف…
#   — رضا یزدانی  | score: 0.833 | row: 1230 | sum: رضا یزدانی، ورزشکار کشتی، در تاریخ 3 شهریور 1363 (در 40 سال) متولد شده است، قد ایشان 1، 72…
#   — امیرحسین مقصودی | score: 0.831 | row: 739 | sum: امیرحسین مقصودی، متولد تهران، ایران، کشتی‌گیر آزاد با وزن 65 کیلوگرم است که زیر نظر رسول د…
#
# ————————————————————————————————————————————————————————————————————————————————————————————————————
# Q: بانوی تیراندازی ایران
#   — نجمه خدمتی | score: 0.838 | row: 2503 | sum: نجمه خدمتی، ورزشکار تیراندازی، در تاریخ 20 خرداد 1375 در 9 ژوئن 1996 (متولد شده است، قد ای…
#   — هانیه رستمیان | score: 0.829 | row: 2567 | sum: هانیه رستمیان، ورزشکار تیراندازی، در تاریخ 20 شهریور 1377 (26 سال) در [متولد شده است، قد ا…
#   — آرمینا صادقیان | score: 0.828 | row: 498 | sum: آرمینا صادقیان، ورزشکار تیراندازی، در تاریخ 2 بهمن 1380 در 22 ژانویه 2002 (متولد شده است،…
#   — زهرا دهقان | score: 0.825 | row: 1261 | sum: زهرا دهقان، ورزشکار تیراندازی، در تاریخ 22 بهمن 1366 در شیراز متولد شده است، افتخار مدال ن…
#   — الهه احمدی | score: 0.825 | row: 672 | sum: الهه احمدی، ورزشکار تیراندازی، در تاریخ 31 مه 1982 (در 42 سال) متولد شده است، قد ایشان 1،…
#
# ————————————————————————————————————————————————————————————————————————————————————————————————————
# Q: وزنه بردار طلایی ایران
#   — حسین سلطانی  | score: 0.853 | row: 1030 | sum: حسین سلطانی، ورزشکار وزنه‌برداری، در تاریخ 2 دسامبر 1999 (در 25 سال) متولد شده است، وزن ای…
#   — علیرضا یوسفی | score: 0.849 | row: 1723 | sum: علیرضا یوسفی، ورزشکار وزنه‌برداری، در تاریخ 27 اوت 2003 (در 21 سال) متولد شده است، وزن ایش…
#   — محمدرضا براری | score: 0.848 | row: 2139 | sum: محمدرضا براری، ورزشکار وزنه‌برداری، در تاریخ ساری در 11 فروردین 1367 (متولد شده است، وزن ا…
#   — سجاد انوشیروانی | score: 0.847 | row: 1314 | sum: سجاد انوشیروانی، ورزشکار وزنه‌برداری.
#   — علی صفاسنبلی | score: 0.846 | row: 1622 | sum: علی صفاسنبلی، ورزشکار وزنه‌برداری، در تاریخ 29 آبان 1311 در 1957 تهران متولد شده است، قد ا…
#
# ————————————————————————————————————————————————————————————————————————————————————————————————————
# Q: مدال‌آور پارالمپیک ایران
#   — ساره جوانمردی | score: 0.834 | row: 1289 | sum: ساره جوانمردی، ورزشکار تیراندازی، در تاریخ 17 آذر 1363 (40 سال) در شیراز متولد شده است، اف…
#   — حامد صلحی‌پور | score: 0.831 | row: 967 | sum: حامد صلحی‌پور، ورزشکار وزنه‌برداری، در تاریخ 1 خرداد 1368 (35 سال) در تهران متولد شده است،…
#   — ذبیح‌الله پورشیب | score: 0.831 | row: 1153 | sum: ذبیح‌الله پورشیب، ورزشکار کاراته، در تاریخ 27 تیر 1367 (در 37 سال) متولد شده است، قد ایشان…
#   — علی پیروزخواه | score: 0.827 | row: 1661 | sum: علی پیروزخواه، ورزشکار فوتبال، در تاریخ 6 مه 1988 (در 36 سال) متولد شده است، قد ایشان 1، 8…
#   — مجتبی عابدینی | score: 0.825 | row: 1935 | sum: مجتبی عابدینی، ورزشکار رزمی، در تاریخ 11 اوت 1984 (در 40 سال) متولد شده است، قد ایشان 1، 7…
#
# Logs saved to: rag_out/search_logs.jsonl

# %%
ARABIC_TO_PERSIAN = str.maketrans({
    "ي":"ی","ك":"ک","ة":"ه","ۀ":"ه","ؤ":"و","إ":"ا","أ":"ا","ٱ":"ا","ى":"ی"
})
# Eastern (Persian/Arabic) digits -> ASCII 0-9
EASTERN_DIGITS = str.maketrans({
    "۰":"0","۱":"1","۲":"2","۳":"3","۴":"4","۵":"5","۶":"6","۷":"7","۸":"8","۹":"9",
    "٠":"0","١":"1","٢":"2","٣":"3","٤":"4","٥":"5","٦":"6","٧":"7","٨":"8","٩":"9",
})

# %%
import unicodedata

def normalize_query_min(s: str) -> str:
    if not isinstance(s, str):
        s = "" if s is None else str(s)
    s = s.translate(ARABIC_TO_PERSIAN)   # ي/ك/ة/… → ی/ک/ه/…
    s = unicodedata.normalize("NFKC", s) # standard unicode form
    s = s.translate(EASTERN_DIGITS)      # ۱۲۳۴۵ → 12345
    return s

USE_QUERY_NORM = True  # its optional, if you want to disable it, change it to False

# %%
MCQ_JSON = Path("mcq_questions_90.json")

with MCQ_JSON.open("r", encoding="utf-8") as f:
    mcq = json.load(f)
print(f"Loaded {len(mcq)} MCQs from {MCQ_JSON.name}")
# Out:
# Loaded 90 MCQs from mcq_questions_90.json

# %%
EVAL_REPORT_JSON  = OUT_DIR / "eval_mcq_report.json"   # summary of results
EVAL_DETAILS_JSONL= OUT_DIR / "eval_mcq_details.jsonl" # log for each question

# %%
try:
    docs  # noqa
except NameError:
    docs = [json.loads(line) for line in DOCS_MAP.open("r", encoding="utf-8")]
    print("Loaded docs for eval:", len(docs))

# %%
if 'ARABIC_TO_PERSIAN' not in globals():
    ARABIC_TO_PERSIAN = str.maketrans({"ي":"ی","ك":"ک","ة":"ه","ۀ":"ه","ؤ":"و","إ":"ا","أ":"ا","ٱ":"ا","ى":"ی"})
if 'EASTERN_DIGITS' not in globals():
    EASTERN_DIGITS = str.maketrans({
        "۰":"0","۱":"1","۲":"2","۳":"3","۴":"4","۵":"5","۶":"6","۷":"7","۸":"8","۹":"9",
        "٠":"0","١":"1","٢":"2","٣":"3","٤":"4","٥":"5","٦":"6","٧":"7","٨":"8","٩":"9",
    })

if 'normalize_query_min' not in globals():
    def normalize_query_min(s: str) -> str:
        if not isinstance(s, str):
            s = "" if s is None else str(s)
        s = s.translate(ARABIC_TO_PERSIAN)
        s = unicodedata.normalize("NFKC", s)
        s = s.translate(EASTERN_DIGITS)
        return s


if 'normalize_query_min' not in globals():
    def normalize_query_min(s: str) -> str:
        if not isinstance(s, str):
            s = "" if s is None else str(s)
        s = s.translate(ARABIC_TO_PERSIAN)
        s = unicodedata.normalize("NFKC", s)
        s = s.translate(EASTERN_DIGITS)
        return s

if 'normalize_name_field' not in globals():
    def normalize_name_field(x):
        if isinstance(x, list):
            for v in x:
                if isinstance(v, str) and v.strip():
                    return v
            return ""
        if isinstance(x, str):
            return x
        return "" if x is None else str(x)

if 'normalize_text_field' not in globals():
    def normalize_text_field(x):
        if isinstance(x, str):
            return x
        if isinstance(x, list):
            parts = [v.strip() for v in x if isinstance(v, str) and v.strip()]
            return " | ".join(parts)
        if isinstance(x, dict):
            parts = []
            for v in x.values():
                s = normalize_text_field(v)
                if s:
                    parts.append(s)
            return " | ".join(parts)
        return "" if x is None else str(x)

if 'normalize_text' not in globals():
    _SP_RE = re.compile(r"\s+")
    def normalize_text(s: str) -> str:
        s = normalize_query_min(s)
        s = s.casefold()
        s = _SP_RE.sub(" ", s).strip()
        return s

# --- precompute normalized names for entity matching ---
doc_norm_names = [(i, normalize_text(normalize_name_field(d.get("name")))) for i, d in enumerate(docs)]
name_set = {n for _, n in doc_norm_names if n}

# %% [markdown]
# # Load model and embeddings and use them for **Text questions set (Retrieval phase)**

# %%
def find_target_doc_indices(question_norm: str):
    """
    Match docs whose normalized name is a substring of the normalized question.
    """
    matches = []
    for i, nname in doc_norm_names:
        if nname and nname in question_norm:
            matches.append((i, len(nname)))
    matches.sort(key=lambda x: x[1], reverse=True)  # longest first
    return [i for i, _ in matches]

# %%
def hits_at_k(hits_list, ks=(1,3,5,10)):
    out = {}
    n = len(hits_list)
    if n == 0:
        return {k: 0.0 for k in ks}
    for k in ks:
        out[k] = float(np.mean([1.0 if any(h[:k]) else 0.0 for h in hits_list]))
    return out

# %%
# --- helper to map normalized names -> doc indices, and select targets ---
from collections import defaultdict

def _ensure_name_index():
    global doc_norm_names, name_norm_to_indices
    if 'doc_norm_names' not in globals():
        doc_norm_names = [(i, normalize_text(normalize_name_field(d.get("name","")))) for i, d in enumerate(docs)]
    if 'name_norm_to_indices' not in globals():
        name_norm_to_indices = defaultdict(list)
        for i, n in doc_norm_names:
            if n:
                name_norm_to_indices[n].append(i)

def get_target_indices(q_norm: str, ans_norm: str):
    """
    1) if the answer is a name in docs, get that target (answer_name)
    2) else if, predict the name from question (question_heuristic)
    3) else, none
    """
    _ensure_name_index()
    if ans_norm in name_norm_to_indices:
        return name_norm_to_indices[ans_norm], "answer_name"

    matches = []
    for i, nname in doc_norm_names:
        if nname and nname in q_norm:
            matches.append((i, len(nname)))
    matches.sort(key=lambda x: x[1], reverse=True)
    if matches:
        return [i for i, _ in matches], "question_heuristic"
    return [], "none"

# %%
# ===================== MCQ retrieval evaluation (updated) =====================
from pathlib import Path
import json, numpy as np
from datetime import datetime

try:
    OUT_DIR
except NameError:
    OUT_DIR = Path("rag_out")

EVAL_REPORT_JSON   = OUT_DIR / "eval_mcq_report.json"
EVAL_DETAILS_JSONL = OUT_DIR / "eval_mcq_details.jsonl"

def evaluate_mcq(mcq, k_values=(1,3,5,10)):
    entity_hits_lists = []
    answer_hits_lists = []
    skipped_no_entity = 0

    maxk = max(k_values)

    def answer_in_docs(ans_norm: str, docs_list):
        joined = " || ".join([
            normalize_text(normalize_name_field(d.get("name"))) + " | " +
            normalize_text(normalize_text_field(d.get("summary")))
            for d in docs_list
        ])
        return bool(ans_norm and ans_norm in joined)

    details_f = EVAL_DETAILS_JSONL.open("a", encoding="utf-8")

    for ex in mcq:
        q = ex.get("question","")
        ans = ex.get("answer","") or ""
        q_norm   = normalize_text(q)
        ans_norm = normalize_text(ans)

        try:
            retrieved = search(q, k=maxk) or []
        except Exception as e:
            print("search() error; skipping:", e)
            retrieved = []

        # find target better
        target_idxs, target_source = get_target_indices(q_norm, ans_norm)

        # Entity Hit@k
        if not target_idxs:
            entity_hits_lists.append([False]*maxk)
            skipped_no_entity += 1
            hit_bools_entity = [False]*maxk
            target_names_norm = []
        else:
            target_names_norm = [normalize_text(normalize_name_field(docs[i].get("name",""))) for i in target_idxs]
            hit_bools_entity = []
            for cut in range(1, maxk+1):
                top = retrieved[:cut]
                top_norm_names = {normalize_text(normalize_name_field(d.get("name"))) for d in top}
                hit_bools_entity.append(any(tn in top_norm_names for tn in target_names_norm))
            entity_hits_lists.append(hit_bools_entity)

        # Answer Hit@k (string containment)
        if not retrieved:
            hit_bools_answer = [False]*maxk
        else:
            hit_bools_answer = []
            for cut in range(1, maxk+1):
                hit_bools_answer.append(answer_in_docs(ans_norm, retrieved[:cut]))
        answer_hits_lists.append(hit_bools_answer)

        details_f.write(json.dumps({
            "ts": datetime.now().isoformat(timespec="seconds"),
            "question": q,
            "answer": ans,
            "answer_norm": ans_norm,
            "target_source": target_source,
            "target_doc_indices": target_idxs,
            "target_names_norm": target_names_norm,
            "entity_hit_bools": hit_bools_entity,
            "answer_hit_bools": hit_bools_answer,
            "retrieved": [
                {"row": int(r.get("_row",-1)), "name": r.get("name"), "score": float(r.get("_score",0.0))}
                for r in retrieved
            ]
        }, ensure_ascii=False) + "\n")

    details_f.close()

    # Aggregation
    def hits_at_k(hits_list, ks=(1,3,5,10)):
        out = {}
        n = len(hits_list)
        if n == 0:
            return {k: 0.0 for k in ks}
        for k in ks:
            out[k] = float(np.mean([1.0 if any(h[:k]) else 0.0 for h in hits_list]))
        return out

    entity_scores = hits_at_k(entity_hits_lists, ks=k_values)
    answer_scores = hits_at_k(answer_hits_lists, ks=k_values)

    report = {
        "timestamp": datetime.now().isoformat(timespec="seconds"),
        "num_questions": len(mcq),
        "entity_detection_skipped": int(skipped_no_entity),
        "entity_hit_at_k": {f"hit@{k}": round(entity_scores[k], 3) for k in k_values},
        "answer_hit_at_k": {f"hit@{k}": round(answer_scores[k], 3) for k in k_values},
        "k_values": list(k_values),
        "index_path": str((OUT_DIR / "faiss_text.idx").resolve()),
        "embeds_path": str((OUT_DIR / "text_embeds.npy").resolve()),
    }

    with EVAL_REPORT_JSON.open("w", encoding="utf-8") as f:
        json.dump(report, f, ensure_ascii=False, indent=2)

    return report

# %%
# ---- run eval ----

report = evaluate_mcq(mcq, k_values=(1,3,5,10))
print("\n" + "="*70)
print("MCQ RETRIEVAL EVALUATION (Hit@k)")
print("="*70)
print(f"Total questions                        : {report['num_questions']}")
print(f"Questions w/o detectable entity in Q   : {report['entity_detection_skipped']}")
print("-"*70)
print("Entity Hit@k")
for k, v in report["entity_hit_at_k"].items():
    print(f"  {k:<6}: {v:.3f}")
print("-"*70)
print("Answer-string Hit@k")
for k, v in report["answer_hit_at_k"].items():
    print(f"  {k:<6}: {v:.3f}")
print("="*70)
print("Saved summary to :", EVAL_REPORT_JSON)
print("Appended details to:", EVAL_DETAILS_JSONL)
# Out:
# ======================================================================
# MCQ RETRIEVAL EVALUATION (Hit@k)
# ======================================================================
# Total questions                        : 90
# Questions w/o detectable entity in Q   : 8
# ----------------------------------------------------------------------
# Entity Hit@k
#   hit@1 : 0.811
#   hit@3 : 0.844
#   hit@5 : 0.844
#   hit@10: 0.856
# ----------------------------------------------------------------------
# Answer-string Hit@k
#   hit@1 : 0.678
#   hit@3 : 0.711
#   hit@5 : 0.722
#   hit@10: 0.744
# ======================================================================
# Saved summary to : rag_out/eval_mcq_report.json
# Appended details to: rag_out/eval_mcq_details.jsonl

# %%
def show_examples(mcq_subset, n=5, k=3):
    shown = 0
    for ex in mcq_subset:
        if shown >= n: break
        q = ex.get("question", "")
        ans = ex.get("answer", "")
        hits = search(q, k=k) or []
        names = [d.get("name","") for d in hits]
        scores = [f"{d.get('_score',0.0):.3f}" for d in hits]
        print("\nQ:", q)
        print("A:", ans)
        print(f"Top-{k}:", list(zip(names, scores)))
        shown += 1

# change the mcq[:] and n=i based on need
show_examples(mcq[70:], n=15, k=3)
# Out:
# Q: کدام بازیگر برای بازی در «ناخدا خورشید» سیمرغ بلورین بهترین بازیگر نقش اول مرد را از جشنواره فیلم فجر دریافت کرد؟
# A: داریوش ارجمند
# Top-3: [('داریوش ارجمند', '0.872'), ('رضا عطاران', '0.845'), ('نوید محمدزاده', '0.843')]
#
# Q: مهران مدیری متولد چه سالی است؟
# A: 1346
# Top-3: [('مهران مدیری', '0.901'), ('مهران قاسمی', '0.842'), ('مهران امیری', '0.833')]
#
# Q: رعنا آزادیور در چه فیلم هایی بازی کرده است؟
# A: درباه الی و زخم کاری
# Top-3: [('رعنا آزادی\u200cور', '0.873'), ('زهرا داوودنژاد', '0.803'), ('افسانه چهره\u200cآزاد', '0.801')]
#
# Q: کدام بازیگر زن برنده جایزه امی برای «خانه صدام» (1387) شده است؟
# A: شهره آغداشلو
# Top-3: [('شهره آغداشلو', '0.830'), ('لاله اسکندری', '0.819'), ('پانته\u200cآ پناهی\u200cها', '0.818')]
#
# Q: کدام بازیگر برای «رگ خواب» سیمرغ بلورین بهترین بازیگر زن را از جشنواره فیلم فجر دریافت کرده است؟
# A: شهره آغداشلو
# Top-3: [('لیلا حاتمی', '0.852'), ('هنگامه قاضیانی', '0.830'), ('شبنم مقدمی', '0.829')]
#
# Q: کدام بازیگر برای «گیلانه» و «روسری آبی» جوایز بهترین بازیگر زن از جشنواره فیلم فجر دریافت کرده است؟
# A: فاطمه معتمدآریا
# Top-3: [('فاطمه معتمدآریا', '0.851'), ('نگار جواهریان', '0.830'), ('طناز طباطبایی', '0.823')]
#
# Q: علیرضا خمسه در چه فیلم هایی بازی کرده است؟
# A: بیست و ملاقات با جادوگر
# Top-3: [('علیرضا خمسه', '0.895'), ('امیرحسین رستمی', '0.810'), ('اکبر قدمی', '0.803')]
#
# Q: مهرداد صدیقیان از چه دهه ای فعالیت خود را آغاز کرده است؟
# A: 1380
# Top-3: [('مهرداد صدیقیان', '0.893'), ('مهرداد آسمانی', '0.815'), ('مهرداد بذرپاش', '0.814')]
#
# Q: ژاله صامتی برای بازی در چه فیلمی مورد توجه مخاطبان قرار گرفت؟
# A: زیرخاکی
# Top-3: [('ژاله صامتی', '0.895'), ('سعید پورصمیمی', '0.809'), ('لاله اسکندری', '0.806')]
#
# Q: کدام بازیگر برای بازی در «من ترانه 15 سال دارم» جایزه بهترین بازیگر زن را از بیستمین جشنواره فیلم فجر دریافت کرد؟
# A: ترانه علیدوستی
# Top-3: [('ترانه علیدوستی', '0.846'), ('طناز طباطبایی', '0.828'), ('مهناز افشار', '0.822')]
#
# Q: امیرحسین حسین آرمان متولد کجا است؟
# A: تهران
# Top-3: [('امیرحسین آرمان', '0.889'), ('امیرحسین حسین\u200cزاده', '0.846'), ('آرمان قاسمی', '0.841')]
#
# Q: انوشیروان ارجمند در چه سالی درگذشت؟
# A: 1393
# Top-3: [('انوشیروان ارجمند', '0.901'), ('انوشیروان روحانی', '0.821'), ('داریوش ارجمند', '0.800')]
#
# Q: آرامگاه صائب تبریزی در کجا قرار دارد؟
# A: اصفهان
# Top-3: [('صائب تبریزی', '0.855'), ('صابر همدانی', '0.816'), ('همام تبریزی', '0.810')]
#
# Q: شعر شب عشق از کدام ترانه سرا است؟
# A: لیلا کسری
# Top-3: [('نیلوفر لاری\u200cپور', '0.813'), ('حبیب محبیان', '0.810'), ('میرزاده عشقی', '0.808')]
#
# Q: لیلی جهان آرا در چه زمینه ای فعالیت داشته است؟
# A: مدیرعامل کانون پرورش فکری کودکان و نوجوانان
# Top-3: [('لیلی جهان\u200cآرا', '0.889'), ('لیلا برخورداری', '0.808'), ('لیلا زارع', '0.800')]

# %%
# index list -> normalized name (for homonym cases)
from collections import defaultdict

if 'name_norm_to_indices' not in globals():
    name_norm_to_indices = defaultdict(list)
    for i, d in enumerate(docs):
        n = normalize_text(normalize_name_field(d.get("name","")))
        if n:
            name_norm_to_indices[n].append(i)

# %%
def get_target_indices(q_norm: str, ans_norm: str):
    if ans_norm in name_norm_to_indices:
        return name_norm_to_indices[ans_norm], "answer_name"
    ti = find_target_doc_indices(q_norm)
    if ti:
        return ti, "question_heuristic"
    return [], "none"

# %%
# ================== Diagnose retrieval (updated) ==================
from datetime import datetime
import json, numpy as np

RETR_MISS_JSONL    = OUT_DIR / "retrieval_misses.jsonl"
RETR_SAMPLES_JSONL = OUT_DIR / "retrieval_samples.jsonl"

def diagnose_retrieval(mcq, k=5, max_show_hits=5, max_show_misses=8):
    def answer_in_docs(ans_norm: str, docs_list):
        joined = " || ".join([
            normalize_text(normalize_name_field(d.get("name"))) + " | " +
            normalize_text(normalize_text_field(d.get("summary")))
            for d in docs_list
        ])
        return bool(ans_norm and ans_norm in joined)

    no_entity_detected = 0
    entity_hit_cnt = 0
    answer_hit_cnt = 0
    both_hit_cnt = 0
    entity_hit_but_answer_miss = 0
    entity_miss_but_answer_hit = 0
    both_miss_cnt = 0

    first_rank_hits = []
    hit_scores = []
    miss_scores = []

    shown_hits = 0
    shown_misses = 0

    miss_f = RETR_MISS_JSONL.open("a", encoding="utf-8")
    samp_f = RETR_SAMPLES_JSONL.open("a", encoding="utf-8")

    print("\n" + "="*80)
    print(f"Diagnosing retrieval on {len(mcq)} examples (k={k})")
    print("="*80)

    for ex in mcq:
        q   = ex.get("question","")
        ans = ex.get("answer","") or ""
        q_norm   = normalize_text(q)
        ans_norm = normalize_text(ans)

        hits = search(q, k=k) or []
        top_names  = [normalize_text(normalize_name_field(h.get("name",""))) for h in hits]
        top_scores = [float(h.get("_score",0.0)) for h in hits]

        # ⬇️ جدید: تارگت از answer یا question
        target_idxs, target_source = get_target_indices(q_norm, ans_norm)
        target_names_norm = [normalize_text(normalize_name_field(docs[i].get("name",""))) for i in target_idxs]

        # Entity hit@k + first rank
        if not target_idxs:
            no_entity_detected += 1
            entity_hit = False
            first_rank = None
        else:
            entity_hit = False
            first_rank = None
            for rank, tn in enumerate(top_names, start=1):
                if tn in target_names_norm:
                    entity_hit = True
                    first_rank = rank
                    break

        # Answer hit@k
        answer_hit = answer_in_docs(ans_norm, hits)

        if entity_hit: entity_hit_cnt += 1
        if answer_hit: answer_hit_cnt += 1
        if entity_hit and answer_hit:
            both_hit_cnt += 1
        elif entity_hit and not answer_hit:
            entity_hit_but_answer_miss += 1
        elif (not entity_hit) and answer_hit:
            entity_miss_but_answer_hit += 1
        else:
            both_miss_cnt += 1

        if first_rank is not None:
            first_rank_hits.append(first_rank)
            if top_scores: hit_scores.append(top_scores[0])
        else:
            if top_scores: miss_scores.append(top_scores[0])

        def pretty_names_scores(hs):
            return [(h.get("name",""), f"{float(h.get('_score',0.0)):.3f}") for h in hs]

        if entity_hit and shown_hits < max_show_hits:
            print("\n✅ HIT")
            print("Q:", q)
            print("A:", ans)
            print(f"Target source: {target_source}")
            print("Targets (norm):", target_names_norm[:3] if target_names_norm else [])
            print(f"First target rank: {first_rank}")
            print(f"Top-{k}:", pretty_names_scores(hits))
            shown_hits += 1
            samp_f.write(json.dumps({
                "ts": datetime.now().isoformat(timespec="seconds"),
                "kind": "HIT",
                "q": q, "a": ans,
                "target_source": target_source,
                "first_rank": first_rank,
                "top": [{"name": h.get("name"), "score": float(h.get("_score",0.0))} for h in hits]
            }, ensure_ascii=False) + "\n")

        if (not entity_hit) and shown_misses < max_show_misses:
            print("\n❌ MISS")
            print("Q:", q)
            print("A:", ans)
            print(f"Target source: {target_source}")
            print("Targets (norm):", target_names_norm[:3] if target_names_norm else [])
            print(f"Top-{k}:", pretty_names_scores(hits))
            shown_misses += 1
            miss_f.write(json.dumps({
                "ts": datetime.now().isoformat(timespec="seconds"),
                "q": q, "a": ans,
                "target_source": target_source,
                "targets_norm": target_names_norm,
                "top": [{"name": h.get("name"), "score": float(h.get('_score',0.0))} for h in hits]
            }, ensure_ascii=False) + "\n")

    miss_f.close()
    samp_f.close()

    total = len(mcq)
    fr_mean = (np.mean(first_rank_hits) if first_rank_hits else float('nan'))
    fr_median = (np.median(first_rank_hits) if first_rank_hits else float('nan'))
    mean_hit_score = (np.mean(hit_scores) if hit_scores else float('nan'))
    mean_miss_score = (np.mean(miss_scores) if miss_scores else float('nan'))

    print("\n" + "-"*80)
    print("Summary")
    print("-"*80)
    print(f"Total examples                  : {total}")
    print(f"No entity detected in question  : {no_entity_detected}")
    print(f"Entity hit@{k}                  : {entity_hit_cnt}")
    print(f"Answer  hit@{k}                 : {answer_hit_cnt}")
    print(f"Both entity & answer hit        : {both_hit_cnt}")
    print(f"Entity hit, answer miss         : {entity_hit_but_answer_miss}")
    print(f"Entity miss, answer hit         : {entity_miss_but_answer_hit}")
    print(f"Both miss                       : {both_miss_cnt}")
    print(f"First-target rank (mean/med)    : {fr_mean:.2f} / {fr_median:.2f}")
    print(f"Top-1 score (mean, hits/misses) : {mean_hit_score:.3f} / {mean_miss_score:.3f}")
    print("-"*80)
    print("Saved misses to     :", RETR_MISS_JSONL)
    print("Saved printed cases :", RETR_SAMPLES_JSONL)

# %%
report = evaluate_mcq(mcq, k_values=(1,3,5,10))
print("\n=== SUMMARY ===")
for k, v in report["entity_hit_at_k"].items():
    print("Entity", k, ":", v)
for k, v in report["answer_hit_at_k"].items():
    print("Answer ", k, ":", v)
print("Saved summary to :", (OUT_DIR / "eval_mcq_report.json"))
print("Details appended :", (OUT_DIR / "eval_mcq_details.jsonl"))
# Out:
# === SUMMARY ===
# Entity hit@1 : 0.811
# Entity hit@3 : 0.844
# Entity hit@5 : 0.844
# Entity hit@10 : 0.856
# Answer  hit@1 : 0.678
# Answer  hit@3 : 0.711
# Answer  hit@5 : 0.722
# Answer  hit@10 : 0.744
# Saved summary to : rag_out/eval_mcq_report.json
# Details appended : rag_out/eval_mcq_details.jsonl

# %%
diagnose_retrieval(mcq, k=5, max_show_hits=5, max_show_misses=5)
# Out:
# ================================================================================
# Diagnosing retrieval on 90 examples (k=5)
# ================================================================================
#
# ✅ HIT
# Q: حبیب‌الله بلور در کدام رشته ورزشی فعالیت داشت؟
# A: کشتی
# Target source: question_heuristic
# Targets (norm): ['حبیب\u200cالله بلور', 'حبیب\u200cالله بلور']
# First target rank: 1
# Top-5: [('حبیب\u200cالله بلور', '0.879'), ('حبیب\u200cالله بلور', '0.863'), ('حبیب\u200cالله اخلاقی', '0.816'), ('محمد بلبلی', '0.814'), ('حبیب\u200cالله ایگدر', '0.806')]
#
# ✅ HIT
# Q: بهرنگ صفری در چه سالی متولد شده است؟
# A: ۱۳۶۳
# Target source: question_heuristic
# Targets (norm): ['بهرنگ صفری']
# First target rank: 1
# Top-5: [('بهرنگ صفری', '0.896'), ('سعید صفری', '0.827'), ('شکوفه صفری', '0.819'), ('بهشاد مختاری', '0.818'), ('عطاالله صفرپور', '0.815')]
#
# ✅ HIT
# Q: عبدالله موحد چند مدال جهانی کسب کرده است؟
# A: ۵
# Target source: question_heuristic
# Targets (norm): ['عبدالله موحد']
# First target rank: 1
# Top-5: [('عبدالله موحد', '0.902'), ('علی\u200cاکبر موسوی موحدی', '0.811'), ('بهادر مولایی', '0.809'), ('وحید جدی', '0.808'), ('محمد باقری معتمد', '0.805')]
#
# ✅ HIT
# Q: لوون کورکچیان مدال طلای خود را در کدام رقابت کسب کرده است؟
# A: بازی‌های آسیایی ۱۹۵۱ دهلی نو
# Target source: question_heuristic
# Targets (norm): ['لوون کورکچیان']
# First target rank: 1
# Top-5: [('لوون کورکچیان', '0.876'), ('ساره جوانمردی', '0.812'), ('علی اشکوریان', '0.806'), ('الیاس علی\u200cاکبری', '0.806'), ('لوون پاچاجیان', '0.804')]
#
# ✅ HIT
# Q: علیرضا حقی در چه ماهی متولد شده است؟
# A: فوریهٔ ۱۹۷۹
# Target source: question_heuristic
# Targets (norm): ['علیرضا حقی']
# First target rank: 1
# Top-5: [('علیرضا حقی', '0.876'), ('علیرضا محمدی', '0.839'), ('علیرضا حقیقی', '0.835'), ('مجتبی حق\u200cدوست', '0.835'), ('علیرضا لرستانی', '0.834')]
#
# ❌ MISS
# Q: کدام بازیگر در فیلم من و دبورا بازی کرده است؟
# A: مریلا زارعی
# Target source: answer_name
# Targets (norm): ['مریلا زارعی']
# Top-5: [('زهرا داوودنژاد', '0.793'), ('میترا حجار', '0.785'), ('ژاله علو', '0.784'), ('حمید منوچهری', '0.784'), ('صابر ابر', '0.781')]
#
# ❌ MISS
# Q: کدام یک از آثار احمدشاملو است؟
# A: ترانه شرقی
# Target source: none
# Targets (norm): []
# Top-5: [('احمد آقالو', '0.795'), ('محمدعلی سپانلو', '0.790'), ('احمد کریمی حکاک', '0.783'), ('مسعود امینی', '0.777'), ('احمد آزاد', '0.777')]
#
# ❌ MISS
# Q: شاعر معروف به تاج الشعرا در ابتدا در کجا دفن شد؟
# A: مسجد جامع سامان
# Target source: none
# Targets (norm): []
# Top-5: [('فرخی یزدی', '0.839'), ('محمد فرخی یزدی', '0.835'), ('جیحون یزدی', '0.832'), ('محمد بن علی سمرقندی', '0.831'), ('عمان سامانی', '0.829')]
#
# ❌ MISS
# Q: مفتاح الفتاح از چه کسی منتشر شده است؟
# A: شیخ بهایی
# Target source: answer_name
# Targets (norm): ['شیخ بهایی']
# Top-5: [('سید ابراهیم نبوی', '0.790'), ('احسان فتاحیان', '0.776'), ('وحید قزوینی', '0.772'), ('خواجه عبدالله انصاری', '0.769'), ('سید محمود علایی طالقانی', '0.769')]
#
# ❌ MISS
# Q: جمشید هاشمپور در چه دهه ای فعالیت خود را آغاز کرده است؟
# A: 1360
# Target source: none
# Targets (norm): []
# Top-5: [('جمشید هاشم\u200cپور', '0.876'), ('جمشید جمشیدیان', '0.811'), ('جمشید آموزگار', '0.806'), ('پژمان جمشیدی', '0.804'), ('جمشید لایق', '0.801')]
#
# --------------------------------------------------------------------------------
# Summary
# --------------------------------------------------------------------------------
# Total examples                  : 90
# No entity detected in question  : 8
# Entity hit@5                  : 76
# Answer  hit@5                 : 65
# Both entity & answer hit        : 60
# Entity hit, answer miss         : 16
# Entity miss, answer hit         : 5
# Both miss                       : 9
# First-target rank (mean/med)    : 1.04 / 1.00
# Top-1 score (mean, hits/misses) : 0.882 / 0.836
# --------------------------------------------------------------------------------
# Saved misses to     : rag_out/retrieval_misses.jsonl
# Saved printed cases : rag_out/retrieval_samples.jsonl

# %%
# printing samples with their relative top_3

import random
sample_idxs = random.sample(range(len(mcq)), k=min(5, len(mcq)))
sample = [mcq[i] for i in sample_idxs]
show_examples(sample, n=len(sample), k=3)
# Out:
# Q: حسن روحانی در کجا متولد شده است؟
# A: سمنان
# Top-3: [('حسن روحانی', '0.908'), ('حسن روحانی ', '0.884'), ('فؤاد روحانی', '0.847')]
#
# Q: کدام فرد برای بازی در فیلم سنتوری جایزه بهترین بازیگر مرد را در جشنواره فجر دریافت کرده است؟
# A: بهرام رادان
# Top-3: [('بهرام رادان', '0.829'), ('سیامک انصاری', '0.823'), ('آرش مجیدی', '0.816')]
#
# Q: علی مرادی در چه رشته‌ای ورزشکار است؟
# A: وزنه‌برداری
# Top-3: [('امیر مرادی', '0.884'), ('علی مرادی ', '0.879'), ('مراد محمدی', '0.863')]
#
# Q: ناصر حجازی در کدام تیم ها بازی کرده است؟
# A: استقلال و منچستر یونایتد
# Top-3: [('ناصر حجازی', '0.901'), ('آتیلا حجازی', '0.844'), ('احمد نوراللهی', '0.819')]
#
# Q: مفتاح الفتاح از چه کسی منتشر شده است؟
# A: شیخ بهایی
# Top-3: [('سید ابراهیم نبوی', '0.790'), ('احسان فتاحیان', '0.776'), ('وحید قزوینی', '0.772')]

# %%
# ===================== Text-only recall & MCQ (replacement for image parts) =====================

OUT_DIR = OUT_DIR if 'OUT_DIR' in globals() else Path("rag_out")
TEXT_EMB_NPY = OUT_DIR / "text_embeds.npy"
TEXT_IDS_NPY = OUT_DIR / "text_ids.npy"
TEXT_MCQ_JSON = OUT_DIR / "mcq_questions_90.json" # MCQ

# docs
try:
    docs  # noqa
except NameError:
    DOCS_MAP = OUT_DIR / "docs.jsonl"
    docs = [json.loads(line) for line in DOCS_MAP.open("r", encoding="utf-8")]
# text embeddings
text_vecs = np.load(TEXT_EMB_NPY) if TEXT_EMB_NPY.exists() else None
text_ids  = np.load(TEXT_IDS_NPY) if TEXT_IDS_NPY.exists() else np.arange(len(docs))
assert text_vecs is not None and text_vecs.shape[0] == len(docs), "text_embeds.npy is not matched with docs"

# %%
# ------------- Part A: Text -> Text Recall@K  -------------
def recall_at_k_tp(pos_list, top_lists, ks=(1,3,5,10)):
    out = {}
    N = len(pos_list)
    for k in ks:
        hits = 0
        for pos, top in zip(pos_list, top_lists):
            hit = (pos in set(top[:min(k, len(top))]))
            hits += 1 if hit else 0
        out[k] = hits / max(1, N)
    return out

# candidates = name of each doc
def _get_name(i):
    return normalize_name_field(docs[i].get("name","")).strip()

name_candidates = [i for i in range(len(docs)) if _get_name(i)]

# for each docs, we get the name of it, and search if top_k is it or not.
pos_list = []
top_lists = []
for doc_i in name_candidates:
    name = _get_name(doc_i)
    if not name:
        continue
    q_e = text_model.encode(f"query: {name}", convert_to_numpy=True, normalize_embeddings=True).astype("float32")
    D, I = knn(text_index, q_e, k=20, metric="ip")
    pos_list.append(doc_i)
    top_lists.append(I)

rec_text2text = recall_at_k_tp(pos_list, top_lists, ks=(1,3,5,10))
print("\n[Text -> Text Recall@K]  (query = person name)")
for k,v in rec_text2text.items():
    print(f"  R@{k}: {v:.3f}")
# Out:
# [Text -> Text Recall@K]  (query = person name)
#   R@1: 0.973
#   R@3: 0.998
#   R@5: 1.000
#   R@10: 1.000

# %%
# ------------- Part B: MCQ textual -------------
# idea: for each doc, extract name/summary from 3 nearest neighbors
random.seed(42)

def hard_distractors(correct_i, n=3, pool_nn=50):
    # nearest neighbors for embeddings
    q = text_vecs[correct_i]
    D, I = knn(text_index, q, k=min(pool_nn+1, len(docs)), metric="ip")
    neighs = [int(j) for j in I if int(j) != correct_i]
    # if it was lower than n, fill it with some random samples!! TODO: use better idea maybe
    if len(neighs) < n:
        others = [j for j in range(len(docs)) if j != correct_i]
        extra = random.sample(others, k=min(n - len(neighs), len(others)))
        neighs.extend(extra)

    return neighs[:n]

def _get_summary(i):
    x = docs[i].get("summary", "")
    if isinstance(x, str):
        return x

    return normalize_text_field(x)

mcq_items = []
for doc_i in name_candidates:
    name = _get_name(doc_i)
    summ = _get_summary(doc_i)
    if not name or not summ:
        continue

    ds_idx = hard_distractors(doc_i, n=3, pool_nn=50)
    opts = [name] + [_get_name(j) for j in ds_idx if _get_name(j)]

    pool = [i for i in name_candidates if i != doc_i and _get_name(i)]
    while len(opts) < 4 and pool:
        j = random.choice(pool); pool.remove(j)
        if _get_name(j) not in opts:
            opts.append(_get_name(j))
    if len(opts) < 4:
        continue
    random.shuffle(opts)
    mcq_items.append({
        "question": "این توضیح مربوط به کدام شخصیت است؟",
        "context": summ,           # summary, for testing retrieval
        "options": opts,           # just names
        "answer": name,            # correct name
        "row": int(doc_i),         # indexing for better search
        "doc_id": docs[doc_i].get("doc_id", doc_i),
    })

with (TEXT_MCQ_JSON).open("w", encoding="utf-8") as f:
    json.dump(mcq_items, f, ensure_ascii=False, indent=2)
print(f"\n[Text-MCQ] built {len(mcq_items)} items → {TEXT_MCQ_JSON.name}")

# ------------- Part C: Eval MCQ (classification) -------------
# strategy: q = encode("query: <context>")   ،  candidates = encode("passage: <name>")
# chooses option with highest similarity

correct = 0
total = 0
for it in mcq_items:
    ctx = it["context"]
    opts = it["options"]
    ans  = it["answer"]
    if not ctx or not opts:
        continue
    q_e = text_model.encode(f"query: {ctx}", convert_to_numpy=True, normalize_embeddings=True).astype("float32")
    opt_texts = [f"passage: {o}" for o in opts]
    o_e = text_model.encode(opt_texts, convert_to_numpy=True, normalize_embeddings=True).astype("float32")  # (m, d)

    sims = (o_e @ q_e.reshape(-1,1)).squeeze(1)  # (m,)
    pred = opts[int(np.argmax(sims))]
    correct += 1 if pred == ans else 0
    total   += 1

acc = correct / max(1, total)
print(f"[Text-MCQ Accuracy] {correct}/{total} = {acc:.3f}")
# Out:
# [Text-MCQ] built 4092 items → mcq_questions_90.json
# [Text-MCQ Accuracy] 3925/4092 = 0.959

# %%
# --- Build Top-3 results CSV for the MCQ set (text-only search) ---

# 1) Load MCQ if needed
try:
    mcq  # noqa
except NameError:
    BASE = Path(".") if 'BASE' not in globals() else BASE
    cand = [BASE / "mcq_question_90.json", BASE / "mcq_questions_90.json"]
    MCQ_JSON = next((p for p in cand if p.exists()), None)
    assert MCQ_JSON is not None, "MCQ file not found (mcq_question_90.json / mcq_questions_90.json)."
    with MCQ_JSON.open("r", encoding="utf-8") as f:
        mcq = json.load(f)
    print(f"Loaded {len(mcq)} MCQs from {MCQ_JSON.name}")

OUT_CSV = OUT_DIR / "text_mcq_top3_results.csv"

# %%
import pandas as pd

# %%
# 2) Rank-weighted presence scoring of options inside retrieved docs

def option_scores_from_docs(question, options, retrieved_docs, use_top_m_docs=5):
    joins, weights = [], []
    for rank, d in enumerate(retrieved_docs[:use_top_m_docs], start=1):
        joined = normalize_text(
            (normalize_name_field(d.get("name","")) or "") + " | " +
            (normalize_text_field(d.get("summary","")) or "")
        )
        joins.append(joined)
        weights.append(1.0 / rank)  # 1, 1/2, 1/3, ...

    scores = {opt: 0.0 for opt in options}
    if not joins:
        return scores

    for opt in options:
        onorm = normalize_text(str(opt))
        if not onorm:
            continue
        s = 0.0
        for w, jt in zip(weights, joins):
            if onorm in jt:
                s += w
        scores[opt] = float(s)
    return scores

# 3) Build rows
rows = []
for ex in mcq:
    q    = ex.get("question", "")
    opts = list(ex.get("options", []))
    gold = ex.get("answer", "")

    # Text-only retrieval
    hits = search(q, k=5) or []

    # Top-3 retrieved doc names
    top3_names = [d.get("name","") for d in hits[:3]]
    top1_doc   = hits[0] if hits else {}
    top1_name  = top1_doc.get("name","")
    top1_idx   = top1_doc.get("_row", "")  # comes from textual search

    # Score each option by rank-weighted presence in retrieved docs
    scores = option_scores_from_docs(q, opts, hits, use_top_m_docs=5)

    # Sort options by score (stable)
    sorted_opts = sorted(range(len(opts)), key=lambda i: (-scores.get(opts[i], 0.0), i))
    top3_idx    = sorted_opts[:3]
    top3_opts   = [opts[i] for i in top3_idx]
    top3_scores = [round(float(scores.get(opts[i], 0.0)), 6) for i in top3_idx]

    pred_answer = top3_opts[0] if top3_opts else (opts[0] if opts else "")
    pred_score  = float(scores.get(pred_answer, 0.0))
    is_correct  = 1 if pred_answer == gold else 0
    hit_at_3    = 1 if gold in top3_opts else 0

    rows.append({
        "question": q,
        "gold_answer": gold,
        "pred_answer": pred_answer,
        "pred_score": pred_score,
        "is_correct": is_correct,
        "hit_at_3": hit_at_3,
        "top3_options": json.dumps(top3_opts, ensure_ascii=False),
        "top3_scores": json.dumps(top3_scores, ensure_ascii=False),
        "top3_names": json.dumps(top3_names, ensure_ascii=False),
        "top1_catalog_idx": top1_idx,
        "top1_name": top1_name,
    })

# 4) Save CSV + quick metrics
df = pd.DataFrame(rows, columns=[
    "question","gold_answer","pred_answer","pred_score","is_correct","hit_at_3",
    "top3_options","top3_scores","top3_names","top1_catalog_idx","top1_name"
])
df.to_csv(OUT_CSV, index=False, encoding="utf-8")
print(f"Saved CSV --> {OUT_CSV}")
print(f"Accuracy: {df['is_correct'].mean():.3f} | Hit@3: {df['hit_at_3'].mean():.3f}")
# Out:
# Saved CSV --> rag_out/text_mcq_top3_results.csv
# Accuracy: 0.822 | Hit@3: 0.978

# %%
# visualizing dataframe
try:
    display(df.sample(10))
except Exception:
    print(df.head(10).to_string(index=False))
# Out:
#                                              question   gold_answer  \
# 26            پوریا امینی در چه استانی متولد شده است؟      گیلانغرب
# 7                    وزن محمد جمشیدی چند کیلوگرم است؟            ۸۰
# 87          گوهر خیراندیش در چه سریالی ضور داشته است؟   میوه ممنوعه
# 13                مهتاب رحمانی ورزشکار کدام رشته است؟       والیبال
# 16   عبدالواحد خنجی در کدام شهر و کشور متولد شده است؟   منامه بحرین
# 69                 کارگردان مغزهای کوچک زنگ زده کیست؟     هومن سیدی
# 10              الهام فلاح در چه رشته‌ای فعالیت دارد؟       والیبال
# 58                 اولین زن ایرانی در فضا چه کسی است؟  انوشه انصاری
# 8               مجتبی گلیج در کدام شهر متولد شده است؟        تنکابن
# 20  وحید گل‌خندان در جام جهانی ریودوژانیرو ۲۰۲۲ کد...          نقره
#
#                 pred_answer  pred_score  is_correct  hit_at_3  \
# 26                 گیلانغرب    1.000000           1         1
# 7                        ۸۰    1.000000           1         1
# 87              میوه ممنوعه    1.000000           1         1
# 13                  والیبال    1.000000           1         1
# 16  سیستان و بلوچستان ایران    0.000000           0         1
# 69                هومن سیدی    1.000000           1         1
# 10                  والیبال    1.000000           1         1
# 58             انوشه انصاری    1.000000           1         1
# 8                    تنکابن    1.000000           1         1
# 20                     نقره    2.283333           1         1
#
#                                          top3_options  \
# 26                      ["گیلانغرب", "تهران", "مشهد"]
# 7                                 ["۸۰", "۷۰", "۱۰۰"]
# 87             ["میوه ممنوعه", "دودکش", "لونه زنبور"]
# 13                      ["والیبال", "کشتی", "کاراته"]
# 16  ["سیستان و بلوچستان ایران", "منامه بحرین", "بغ...
# 69        ["هومن سیدی", "سیامک انصاری", "رضا عطاران"]
# 10                    ["والیبال", "فوتبال", "کاراته"]
# 58     ["انوشه انصاری", "زهرا رهنورد", "جمیله کدیور"]
# 8                          ["تنکابن", "تهران", "رشت"]
# 20                            ["نقره", "برنز", "طلا"]
#
#                        top3_scores  \
# 26                 [1.0, 0.5, 0.0]
# 7                  [1.0, 0.0, 0.0]
# 87                 [1.0, 0.0, 0.0]
# 13                 [1.0, 0.2, 0.0]
# 16                 [0.0, 0.0, 0.0]
# 69                 [1.0, 0.0, 0.0]
# 10                 [1.0, 0.2, 0.0]
# 58                 [1.0, 0.0, 0.0]
# 8                  [1.0, 0.5, 0.0]
# 20  [2.283333, 2.283333, 1.283333]
#
#                                            top3_names  top1_catalog_idx  \
# 26      ["پوریا امینی", "فاطمه امینی ", "شیوا امینی"]              2662
# 7     ["محمد جمشیدی ", "بهروز جمشیدی", "محمد شهریان"]              2018
# 87  ["گوهر خیراندیش", "غلامرضا نیکخواه", "سیاوش مف...               368
# 13  ["مهتاب رحمانی", "بختیار رحمانی", "رحمان رضایی "]              2305
# 16  ["عبدالواحد خنجی", "عبدالمجید ریگی", "سید محمد...              1552
# 69  ["هومن سیدی", "شهرام شاه‌حسینی", "کیکاووس یاکی...                 7
# 10  ["الهام فلاح", "مازیار فلاحی", "الهام امین‌زاده"]               670
# 58  ["انوشه انصاری", "اسفند فَرُّخ‌روی پارسا", "مر...              3023
# 8   ["مجتبی گلیج", "مجتبی حق‌دوست", "محمدعلی زلفی‌...              1943
# 20     ["وحید گل‌خندان", "جواد فروغی", "سجاد مردانی"]              2610
#
#          top1_name
# 26     پوریا امینی
# 7     محمد جمشیدی
# 87   گوهر خیراندیش
# 13    مهتاب رحمانی
# 16  عبدالواحد خنجی
# 69       هومن سیدی
# 10      الهام فلاح
# 58    انوشه انصاری
# 8       مجتبی گلیج
# 20   وحید گل‌خندان

# %% [markdown]
# # Generative phase for Text questions set

# %%
import os, json, re, unicodedata, ast, glob
from pathlib import Path
from typing import List, Dict, Any
import pandas as pd
from tqdm import tqdm
from openai import OpenAI

# %%
# --- Paths ---
BASE    = Path("./questions") if 'BASE' not in globals() else BASE
OUT_DIR = Path(".")
OUT_DIR.mkdir(parents=True, exist_ok=True)

QUESTIONS_JSON_CANDIDATES = [
    BASE / "mcq_question_90.json",
    BASE / "mcq_questions_90.json",
]
QUESTIONS_JSON = next((p for p in QUESTIONS_JSON_CANDIDATES if p.exists()), QUESTIONS_JSON_CANDIDATES[-1])

RETR_CSV = OUT_DIR / "text_mcq_top3_results.csv" # created in retrieval phase
OUT_CSV  = OUT_DIR / "Text_set_generative_outputs.csv"

print("Inputs exist:",
      QUESTIONS_JSON.exists(), RETR_CSV.exists())
# Out:
# Inputs exist: True True

# %%
GAPGPT_API_KEY = "sk-edJCkETfD1tsYS7ebz3e8SWwvEphI1TIX7kTWnDK8NYSydbb"
client = OpenAI(base_url="https://api.gapgpt.app/v1", api_key=GAPGPT_API_KEY)
MODEL  = "gpt-4o-mini"

# %%
try:
    _resp = client.chat.completions.create(
        model=MODEL,
        messages=[{"role": "user", "content": "ping"}],
        temperature=0
    )
    print("LLM ping ok:", bool(_resp.choices[0].message.content))
except Exception as e:
    raise RuntimeError(f"LLM health-check failed: {e}")
# Out:
# LLM ping ok: True

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "user", "content": "خداحافظ"}
    ]
)

print(response.choices[0].message.content)
# Out:
# خداحافظ! اگر به کمک یا سوالی نیاز داشتید، همیشه در اینجا هستم. مراقب خودتان باشید!

# %%
if 'ARABIC_TO_PERSIAN' not in globals():
    ARABIC_TO_PERSIAN = str.maketrans({"ي":"ی","ك":"ک","ة":"ه","ۀ":"ه","ؤ":"و","إ":"ا","أ":"ا","ٱ":"ا","ى":"ی"})
if 'EASTERN_DIGITS' not in globals():
    EASTERN_DIGITS = str.maketrans({
        "۰":"0","۱":"1","۲":"2","۳":"3","۴":"4","۵":"5","۶":"6","۷":"7","۸":"8","۹":"9",
        "٠":"0","١":"1","٢":"2","٣":"3","٤":"4","٥":"5","٦":"6","٧":"7","٨":"8","٩":"9",
    })

import re, unicodedata
if 'PUNCT_RE' not in globals():
    PUNCT_RE = re.compile(r"[\u200c\u200f\u202a-\u202e\s\-\_]+")
if 'normalize_text' not in globals():
    def normalize_text(s: str) -> str:
        if not isinstance(s, str):
            s = "" if s is None else str(s)
        s = s.translate(ARABIC_TO_PERSIAN)
        s = unicodedata.normalize("NFKC", s)
        s = s.translate(EASTERN_DIGITS)
        s = PUNCT_RE.sub(" ", s).strip().casefold()
        return s

# %%
questions: List[Dict[str, Any]] = json.loads(QUESTIONS_JSON.read_text(encoding="utf-8"))
retr_df: pd.DataFrame = pd.read_csv(RETR_CSV)

DOCS_MAP = OUT_DIR / "docs.jsonl"
docs = [json.loads(line) for line in DOCS_MAP.open("r", encoding="utf-8")]

# %%
def normalize_name_field(x):
    if isinstance(x, list):
        for v in x:
            if isinstance(v, str) and v.strip():
                return v
        return ""
    if isinstance(x, str):
        return x
    return "" if x is None else str(x)

def normalize_text_field(x):
    if isinstance(x, str):
        return x
    if isinstance(x, list):
        parts = [v.strip() for v in x if isinstance(v, str) and v.strip()]
        return " | ".join(parts)
    if isinstance(x, dict):
        parts = []
        for v in x.values():
            s = normalize_text_field(v)
            if s:
                parts.append(s)
        return " | ".join(parts)
    return "" if x is None else str(x)

# map: retrieval row -> question
q2retr = {row["question"]: row for _, row in retr_df.iterrows()}

# %%
# map : name -> summary
# from docs.jsonl we save the longest non-empty
name2summary: Dict[str, str] = {}
for r in docs:
    nm = normalize_name_field(r.get("name","")).strip()
    if not nm:
        continue
    summ = normalize_text_field(r.get("summary","")).strip()
    if summ:
        prev = name2summary.get(nm, "")
        if len(summ) > len(prev):
            name2summary[nm] = summ

# %%
def get_top3_names(row) -> List[str]:
    v = row.get("top3_names", "[]")
    if isinstance(v, str):
        try:
            return list(ast.literal_eval(v))
        except Exception:
            try:
                return json.loads(v)
            except Exception:
                return []
    if isinstance(v, list):
        return v
    return []

# %%
def build_contexts_for_question(qtext: str) -> List[Dict[str,str]]:
    row = q2retr.get(qtext)
    if row is None:
        return []
    names = get_top3_names(row)
    ctxs = []
    for nm in names[:3]:
        summ = name2summary.get(nm, "")
        ctxs.append({"name": nm, "summary": summ})
    return ctxs

# %%
def trim(s: str, max_chars: int = 1400) -> str:
    s = s.strip()
    return s if len(s) <= max_chars else (s[:max_chars] + "…")

# %% [markdown]
# ### Prompt Engineering here

# %%
def build_prompt_persian(question: str, options: List[str], ctxs: List[Dict[str, str]]) -> List[Dict[str, str]]:
    """
    input:
      - question: user question (as str)
      - options : list of options (for mcq)
      - ctxs    : retrieval output (top_k) in format: [{ "name": ..., "summary": ... }, ...]
    output:
      - model using ctx for generating answers.
    """
    k = max(1, len(ctxs))

    # defining task to only work with Top_K
    task = (
        "تو یک مولد پاسخ مبتنی بر RAG هستی. فقط و فقط از اسناد بازیابی‌شده زیر استفاده کن و اگر پاسخ در آن‌ها نبود، "
        "declare کن که «نمی‌دانم».\n"
        "گام‌ها:\n"
        "1) اگر از متن‌ها می‌توان شخص/موجود مرتبط را تشخیص داد، نام او را به‌صورت کامل در target_name بنویس؛ در غیر این صورت خالی بگذار.\n"
        "2) از بین گزینه‌ها دقیقاً یکی را به‌عنوان predicted_option برگزین؛ اگر هیچ گزینه‌ای با شواهد جور نبود، predicted_option را خالی بگذار.\n"
        "3) evidence_span باید تکه‌ای از خود متنِ یکی از منابع باشد (نقل‌قول مستقیم) که دلیل انتخاب را نشان می‌دهد.\n\n"
        "خروجی باید فقط یک JSON با کلیدهای زیر باشد و هیچ متن اضافه‌ای ننویس:\n"
        "{\n"
        '  "target_name": "نام کامل یا خالی",\n'
        '  "predicted_option": "یکی از گزینه‌ها یا خالی",\n'
        '  "evidence_span": "نقل‌قول مستقیم از یکی از منابع با امکان اشاره به شمارهٔ منبع مثل [1]"\n'
        "}\n"
        "تأکید: اگر پاسخ در منابع نیست، predicted_option را خالی بگذار و evidence_span را «نمی‌دانم» بنویس."
    )

    # question/answer block
    q_block = "سؤال:\n" + question.strip()
    if options:
        q_block += "\n\nگزینه‌ها:\n" + "\n".join([f"- {o}" for o in options])

    # labeling blocks [1...k] on retrieval outputs (name + summary)
    def _trim(s: str, n: int = 1400) -> str:
        s = (s or "").strip()
        return s if len(s) <= n else (s[:n] + "…")

    ctx_lines = []
    for i, c in enumerate(ctxs, start=1):
        nm = (c.get("name") or "").strip()
        sm = _trim((c.get("summary") or "").strip())
        header = f"[{i}] نام: {nm}" if nm else f"[{i}]"
        body = sm if sm else "—"
        ctx_lines.append(f"{header}\n{body}")
    ctx_block = "\n\n".join(ctx_lines) if ctx_lines else "هیچ متنی موجود نیست."

    # user msg: question + options + retrieval output
    user_content = (
        f"{task}\n\n"
        f"{q_block}\n\n"
        f"---\nاسناد بازیابی‌شده (top-{k}):\n{ctx_block}\n\n"
        "فقط JSON پاسخ بده."
    )

    # System: forced to return JSON
    return [
        {"role": "system", "content": "You are a helpful assistant. Answer ONLY in JSON."},
        {"role": "user", "content": user_content}
    ]

# %%
def call_model(messages: List[Dict[str,str]]) -> Dict[str,Any]:
    try:
        resp = client.chat.completions.create(
            model=MODEL,
            messages=messages,
            temperature=0,
            response_format={"type":"json_object"}
        )
        txt = resp.choices[0].message.content
    except Exception:
        resp = client.chat.completions.create(model=MODEL, messages=messages, temperature=0)
        txt = resp.choices[0].message.content

    txt = (txt or "").strip()
    if txt.startswith("```"):
        txt = re.sub(r"^```(?:json)?\s*|\s*```$", "", txt, flags=re.DOTALL)

    try:
        obj = json.loads(txt)
    except Exception:
        m = re.search(r"\{.*\}", txt, flags=re.DOTALL)
        obj = json.loads(m.group(0)) if m else {"target_name":"","predicted_option":"","evidence_span":txt}
    obj.setdefault("target_name","")
    obj.setdefault("predicted_option","")
    obj.setdefault("evidence_span","")
    return obj

# %%
import random

QUESTION_LIMIT = 30
N = min(QUESTION_LIMIT, len(questions))

seed = None
if seed is not None:
    random.seed(seed)

subset = random.sample(questions, k=N)

# %%
# run on few samples, just to test and optimizing resources (API)

OUT_CSV = OUT_DIR / "Text_set_generative_outputs.csv"
out_rows = []
for ex in tqdm(subset, desc=f"Generating (first {QUESTION_LIMIT})"):
    question = ex.get("question","").strip()
    options  = list(ex.get("options", []))
    ctxs     = build_contexts_for_question(question) or [{"name":"", "summary":""}]

    messages = build_prompt_persian(question, options, ctxs)
    result   = call_model(messages)

    target_name      = str(result.get("target_name","")).strip()
    predicted_option = str(result.get("predicted_option","")).strip()
    evidence_span    = str(result.get("evidence_span","")).strip()

    # assuring to being (predicted_option) in (options) by normalizing match
    if predicted_option not in options:
        opts_norm = [normalize_text(o) for o in options]
        po_norm   = normalize_text(predicted_option)
        if po_norm in opts_norm:
            predicted_option = options[opts_norm.index(po_norm)]

    out_rows.append({
        "question": question,
        "target_name": target_name,
        "predicted_option": predicted_option,
        "evidence_span": evidence_span
    })
# Out:
# Generating (first 3): 100%|██████████| 3/3 [00:05<00:00,  1.73s/it]

# %%
pd.DataFrame(out_rows).to_csv(OUT_CSV, index=False, encoding="utf-8")
print("Saved generative outputs -> ", OUT_CSV)
# Out:
# Saved generative outputs ->  Text_set_generative_outputs.csv

# %%
# --- Run on (subset) and log rich, monitorable outputs (with evidence text) ---
from tqdm import tqdm
import pandas as pd
import json

OUT_CSV = OUT_DIR / "Text_set_generative_outputs.csv"

def _locate_evidence_ctx(evidence: str, ctxs: list):
    """
    outputs:
      - idx: index of ctx (1..k) if found
      - src_name: ctx name
      - src_summary: summary of that ctx for double-checking
    """
    ev = (evidence or "").strip()
    if not ev:
        return "", "", ""

    for idx, c in enumerate(ctxs, start=1):
        summ = (c.get("summary") or "")
        if ev and ev in summ:
            return idx, (c.get("name") or ""), summ

    evn = normalize_text(ev)
    for idx, c in enumerate(ctxs, start=1):
        sn = normalize_text(c.get("summary", ""))
        if evn and evn in sn:
            return idx, (c.get("name") or ""), (c.get("summary") or "")

    return "", "", ""

rows = []
for ex in tqdm(questions, desc=f"Generating answers of ({len(questions)} questions)"):
    question = ex.get("question","").strip()
    options  = list(ex.get("options", []))
    gold     = ex.get("answer","")

    ctxs = build_contexts_for_question(question) or [{"name":"", "summary":""}]
    messages = build_prompt_persian(question, options, ctxs)
    result   = call_model(messages)

    target_name      = str(result.get("target_name","")).strip()
    predicted_option = str(result.get("predicted_option","")).strip()
    evidence_span    = str(result.get("evidence_span","")).strip()

    # align (predicted_option) with (options)
    if predicted_option and predicted_option not in options:
        opts_norm = [normalize_text(o) for o in options]
        po_norm   = normalize_text(predicted_option)
        if po_norm in opts_norm:
            predicted_option = options[opts_norm.index(po_norm)]

    ev_ctx_idx, ev_src_name, ev_src_summary = _locate_evidence_ctx(evidence_span, ctxs)
    ctx_names  = [c.get("name","") for c in ctxs]

    rows.append({
        "question": question,
        "options": json.dumps(options, ensure_ascii=False),
        "gold_answer": gold,
        "predicted_option": predicted_option,
        "is_correct": int(predicted_option == gold) if gold else "",
        "target_name": target_name,
        "evidence_ctx_idx": ev_ctx_idx,                    # evidences are in what ctx [1 ... k]
        "evidence_span": evidence_span,                    # selected text by model
        "evidence_source_name": ev_src_name,               # source name (evidence comes from)
        "evidence_source_summary": ev_src_summary,         # all the context for debugging
        "ctx_names": json.dumps(ctx_names, ensure_ascii=False),
    })

df = pd.DataFrame(rows, columns=[
    "question","options","gold_answer","predicted_option","is_correct",
    "target_name","evidence_ctx_idx","evidence_span","evidence_source_name",
    "evidence_source_summary","ctx_names"
])

df.to_csv(OUT_CSV, index=False, encoding="utf-8")
print(f"Saved generative outputs → {OUT_CSV}")
# Out:
# Generating answers of (90 questions): 100%|██████████| 90/90 [02:44<00:00,  1.82s/it]
# Saved generative outputs → Text_set_generative_outputs.csv

# %%
import pandas as pd

pd.set_option("display.max_rows", None)        
pd.set_option("display.max_columns", None)     
pd.set_option("display.max_colwidth", None)    
pd.set_option("display.width", 0)

# %%
try:
    display(
        df[[
            "question","options","gold_answer","predicted_option","is_correct",
            "evidence_ctx_idx","evidence_source_name","evidence_span"
        ]].sample(n=len(df), random_state=None).reset_index(drop=True)
    )
except Exception:
    print(df.head(10).to_string(index=False))
# Out:
#                                                                                                              question  \
# 0                                           ایوان مارکوویچ هافبک ذوب‌آهن در فوتبال فعالیت خود را با چه تیمی آغاز کرد؟
# 1   کدام بازیگر برای بازی در «ناخدا خورشید» سیمرغ بلورین بهترین بازیگر نقش اول مرد را از جشنواره فیلم فجر دریافت کرد؟
# 2                                                                                بهرنگ صفری در چه سالی متولد شده است؟
# 3                                                                             اولین زن برنده ی مدال فیلدر چه کسی است؟
# 4                        کدام بازیگر در سال 1396 برنده سیمرغ بلورین بهترین بازیگر نقش مکمل زن در جشنواره فیلم فجر شد؟
# 5                                                                           گلنوش خسروی در کدام شهر به متولد شده است؟
# 6                                                                                  کارگردان مغزهای کوچک زنگ زده کیست؟
# 7                                                                          هاجر صفرزاده در کدام رقابت مدال گرفته است؟
# 8                                                                        شجاع خلیل‌زاده در کدام تیم‌ها بازی کرده است؟
# 9                                                                                       دایره المعارف شیطان اثر کیست؟
# 10                                             وحید گل‌خندان در جام جهانی ریودوژانیرو ۲۰۲۲ کدام مدال را کسب کرده است؟
# 11                                                                         قد میربابک موسوی، ورزشکار والیبال چند است؟
# 12                                                                        امیرعلی صادقی در کدام تیم‌ها بازی کرده است؟
# 13                                                                                 اولین زن ایرانی در فضا چه کسی است؟
# 14                                                                         فرنوش شیخی در کدام رشته ورزشی فعالیت دارد؟
# 15                                                                                مهتاب رحمانی ورزشکار کدام رشته است؟
# 16                                                                                  مجید ترکان ورزشکار کدام رشته است؟
# 17                                                                            روزبه بمانی در چه حیطه ای فعالیت میکند؟
# 18                                                                                  ایرج میرزرا به چه نامی معروف بود؟
# 19                                                                               رضا نوروزی در چه شهری متولد شده است؟
# 20                                                                                   حسن روحانی در کجا متولد شده است؟
# 21                                                                              بهتاش فریبا در چه شهری متولد شده است؟
# 22                                                                             الهام حسینی در چه رشته‌ای فعالیت دارد؟
# 23                                                                                انوشیروان ارجمند در چه سالی درگذشت؟
# 24                                                                                 امیرحسین حسین آرمان متولد کجا است؟
# 25                                                                          گوهر خیراندیش در چه سریالی ضور داشته است؟
# 26                                                                        رعنا آزادیور در چه فیلم هایی بازی کرده است؟
# 27                                                         لوون کورکچیان مدال طلای خود را در کدام رقابت کسب کرده است؟
# 28                                                                             صمد پورسیدی در چه رشته‌ای فعالیت دارد؟
# 29                                                                         علیرضا خمسه در چه فیلم هایی بازی کرده است؟
# 30                                             کدام فرد برای کارگردانی فیلم خوابم میآید سیمرغ بلورین دریافت کرده است؟
# 31                                                                             کدام شاعر به پدر شعر انقلاب معروف است؟
# 32                                                                      رضا افتخاری در کدام رشته ورزشی شناخته می‌شود؟
# 33                                                   علی پاکدامن در جام جهانی گرجستان ۲۰۲۴ کدام مدال را کسب کرده است؟
# 34                                                            جمشید هاشمپور در چه دهه ای فعالیت خود را آغاز کرده است؟
# 35                                                                               سید ابراهیم رئیسی در چه سالی درگذشت؟
# 36                       کدام فرد برای بازی در فیلم سنتوری جایزه بهترین بازیگر مرد را در جشنواره فجر دریافت کرده است؟
# 37                                                                           ناصر حجازی در کدام تیم ها بازی کرده است؟
# 38                                                                                  سهراب سپهری در کجا متولد شده است؟
# 39                                                                                  شعر شب عشق از کدام ترانه سرا است؟
# 40                                                                             یوسف وکیا بازیکن کدام تیم‌ها بوده است؟
# 41                                                                     حبیب‌الله بلور در کدام رشته ورزشی فعالیت داشت؟
# 42                                                                   شاعر معروف به تاج الشعرا در ابتدا در کجا دفن شد؟
# 43                                                                                   کدام یک از آثار فروغ فرخزاد است؟
# 44                   کدام بازیگر برای «رگ خواب» سیمرغ بلورین بهترین بازیگر زن را از جشنواره فیلم فجر دریافت کرده است؟
# 45                                                                        کریم انصاری‌فرد در کدام کشور متولد شده است؟
# 46                                                                              مفتاح الفتاح از چه کسی منتشر شده است؟
# 47                                                                      کدام بازیگر در فیلم من و دبورا بازی کرده است؟
# 48                                                                                     مهران مدیری متولد چه سالی است؟
# 49                                                                              مجتبی گلیج در کدام شهر متولد شده است؟
# 50                                                                         زوونیمیر سولدو در کدام کشور متولد شده است؟
# 51                                                                                        پدر فیزیک ایران چه کسی است؟
# 52                                                                           حسین مهربان بازیکن کدام تیم‌ها بوده است؟
# 53                                                                             وحید سرلک در چه رشته‌ای شناخته می‌شود؟
# 54                                                                             محسن تنابنده در چه سالی متولد شده است؟
# 55                                                                   عبدالواحد خنجی در کدام شهر و کشور متولد شده است؟
# 56                                                      ژاله صامتی برای بازی در چه فیلمی مورد توجه مخاطبان قرار گرفت؟
# 57                                                                              الهام فلاح در چه رشته‌ای فعالیت دارد؟
# 58                                                         زینب گیوه بازیکن والیبال ایرانی در کدام پست فعالیت می‌کند؟
# 59                                                                                  کدام شاعر معروف به نیمای غزل است؟
# 60                                                                    علی دایی در کدام تیم‌های اروپایی بازی کرده است؟
# 61                                                                                   بیژن طاهری بازیکن کدام رشته است؟
# 62                                                                               محراب شاهرخی در چه سالی درگذشته است؟
# 63                                                                             هاروتیون آبراهامیان اهل کدام کشور است؟
# 64                                                                              آرامگاه صائب تبریزی در کجا قرار دارد؟
# 65                                                                                             پدر ادبیات تاجیک کیست؟
# 66                                                                       جمشید نصیری در کدام شهر ایران متولد شده است؟
# 67                                                                                   وزن محمد جمشیدی چند کیلوگرم است؟
# 68                                                                               رضا مؤمنی در کدام شهر متولد شده است؟
# 69                                                                            پوریا امینی در چه استانی متولد شده است؟
# 70                                                           مهرداد صدیقیان از چه دهه ای فعالیت خود را آغاز کرده است؟
# 71                                                                               علی مرادی در چه رشته‌ای ورزشکار است؟
# 72                                                                               حسن حبیبی در کدام شهر متولد شده است؟
# 73                کدام بازیگر برای «گیلانه» و «روسری آبی» جوایز بهترین بازیگر زن از جشنواره فیلم فجر دریافت کرده است؟
# 74                                                                            مهدی خدابخشی در چه رشته‌ای فعالیت دارد؟
# 75                                                                           عزت‌الله اکبری در چه سالی متولد شده است؟
# 76                                                              پژمان جمشیدی از چه سالی به عنوان بازیگر فعالیت میکند؟
# 77                                                                                            قد ایمان موسوی چند است؟
# 78                                                                          مهدی تیکدری سالاری در کدام رشته فعال است؟
# 79                                       نامزد بهترین بازیگر نقش اول زن در جشنواره فیلم فجر برای «سعادت‌آباد» که بود؟
# 80                                                                                     کدام یک از آثار احمدشاملو است؟
# 81                                                                                سارا شیربیگی ورزشکار کدام رشته است؟
# 82                                                    کدام بازیگر زن برنده جایزه امی برای «خانه صدام» (1387) شده است؟
# 83                                                                     لیلی جهان آرا در چه زمینه ای فعالیت داشته است؟
# 84                                                                               علیرضا حقی در چه ماهی متولد شده است؟
# 85                                                         عباس زندی در کدام رشته ورزشی مدال‌های متعددی کسب کرده است؟
# 86                                                                          عبدالله موحد چند مدال جهانی کسب کرده است؟
# 87  کدام بازیگر برای بازی در «من ترانه 15 سال دارم» جایزه بهترین بازیگر زن را از بیستمین جشنواره فیلم فجر دریافت کرد؟
# 88                                                                                   کدام آلبوم برای امید حاجیلی است؟
# 89                                                                                 رضا علی‌پور ورزشکار کدام رشته است؟
#
#                                                                                                       options  \
# 0                                             ["دینامو زاگرب", "بایرن مونیخ", "کوپنهاگن", "ستاره سرخ بلگراد"]
# 1                                             ["مهران مدیری", "پرویز پرستویی", "داریوش ارجمند", "رضا عطاران"]
# 2                                                                            ["۱۳۵۹", "۱۳۷۱", "۱۳۷۷", "۱۳۶۳"]
# 3                                            ["مریم میرزاخانی", "انوشه انصاری", "نادیا مفتونی", "هاله افشار"]
# 4                                             ["سحر دولتشاهی", "نسرین مقانلو", "فرزانه کابلی", "باران کوثری"]
# 5                                                                       ["ارومیه", "تهران", "اصفهان", "مشهد"]
# 6                                                  ["سیامک انصاری", "هومن سیدی", "رضا عطاران", "مهران مدیری"]
# 7                    ["پارالمپیک پاریس ۲۰۲۴", "المپیک ریو ۲۰۱۶", "بازی‌های آسیایی ۲۰۱۸", "المپیک توکیو ۲۰۲۰"]
# 8                           ["پرسپولیس و الریان", "سپاهان و استقلال", "ذوب‌آهن و ملوان", "فجر سپاسی و سایپا"]
# 9                                              ["ابراهیم نبوی", "نیما یوشیج", "پروین اعتصامی", "سهراب سپهری"]
# 10                                                                         ["طلا", "نقره", "برنز", "هیچکدام"]
# 11                                                                           ["۱٫۹۴", "۱٫۸۸", "۲٫۰۰", "۲٫۰۸"]
# 12                             ["پرسپولیس و سپاهان", "سایپا و استقلال", "ذوب‌آهن و تراکتور", "پیکان و نساجی"]
# 13                                               ["زهرا رهنورد", "انوشه انصاری", "جمیله کدیور", "زهرا شجاعی"]
# 14                                                                   ["تکواندو", "والیبال", "فوتبال", "کشتی"]
# 15                                                                       ["کاراته", "کشتی", "شنا", "والیبال"]
# 16                                                                   ["فوتبال", "والیبال", "بسکتبال", "کشتی"]
# 17                                                                ["خوانندگی", "ورزش", "بازیگری", "نوازندگی"]
# 18                                                      ["نیمای غزل", "جلال الممالک", "سرمست", "شاعر انقلاب"]
# 19                                                                       ["ایذه", "اهواز", "تهران", "اصفهان"]
# 20                                                                         ["تهران", "یزد", "سمنان", "کرمان"]
# 21                                                                       ["تبریز", "تهران", "اصفهان", "مشهد"]
# 22                                                             ["وزنه‌برداری", "کاراته", "فوتبال", "والیبال"]
# 23                                                                           ["1393", "1389", "1390", "1391"]
# 24                                                                   ["تهران", "اصفهان", "بوشهر", "مازندران"]
# 25                                                         ["میوه ممنوعه", "دودکش", "لونه زنبور", "زخم کاری"]
# 26          ["درباه الی و زخم کاری", "راز بهشت و آخرین خیال", "تنهایی لیلا و عصر پاییزی", "سایه روشن و حلقه"]
# 27         ["المپیک ۱۹۵۲ هلسینکی", "بازی‌های آسیایی ۱۹۵۱ دهلی نو", "قهرمانی جهان ۱۹۵۴", "قهرمانی اروپا ۱۹۵۰"]
# 28                                                              ["دوچرخه‌سواری", "فوتبال", "کشتی", "والیبال"]
# 29       ["بیست و ملاقات با جادوگر", "راز بهشت و آخرین خیال", "تنهایی لیلا و عصر پاییزی", "سایه روشن و حلقه"]
# 30                                              ["عباس غزالی", "رضا عطاران", "فریبرز عربنیا", "کامشاد کوشان"]
# 31                                            ["حمید سبزواری", "پروین اعتصامی", "خاقانی شروانی", "حمید مصدق"]
# 32                                                                    ["کشتی", "فوتبال", "والیبال", "کاراته"]
# 33                                                                         ["طلا", "نقره", "برنز", "هیچکدام"]
# 34                                                                           ["1360", "1350", "1380", "1370"]
# 35                                                                           ["1403", "1400", "1398", "1397"]
# 36                                                   ["رضا بابک", "مصطفی زمانی", "حسن جوهرچی", "بهرام رادان"]
# 37         ["استقلال و منچستر یونایتد", "سپاهان و رئال مادرید", "پاس و بارسلونا", "بانک تجارت و بایرن مونیخ"]
# 38                                                                         ["تهران", "قم", "اضفهان", "زنجان"]
# 39                                           ["لیلا کسری", "فروغ فرخزاد", "پرورین اعتصامی", "لیلا برخورداری"]
# 40                    ["فولاد و نفت مسجدسلیمان", "استقلال و پرسپولیس", "سپاهان و تراکتور", "ذوب‌آهن و ملوان"]
# 41                                                               ["فوتبال", "کشتی", "وزنه‌برداری", "بسکتبال"]
# 42                                                                 ["مسجد جامع سامان", "نجف", "عمان", "عراق"]
# 43                                                     ["تولدی دیگر", "میخک نقره ای", "رند و زاهد", "پریشان"]
# 44                                               ["شهره آغداشلو", "مهناز افشار", "الهام حمیدی", "لیلا حاتمی"]
# 45                                                                       ["ایران", "ترکیه", "آلمان", "یونان"]
# 46                                                    ["شیخ بهایی", "خوارزمی", "ابن سینا", "ابوریحان بیرونی"]
# 47                                                ["مریلا زارعی", "هومن سیدی", "پرستو صالحی", "سیامک انصاری"]
# 48                                                                           ["1354", "1346", "1344", "1357"]
# 49                                                                        ["رشت", "تهران", "تبریز", "تنکابن"]
# 50                                                                     ["کرواسی", "ایران", "آلمان", "لهستان"]
# 51                                            ["مراد فرهادپور", "محمود حسابی", "مجید شهریاری", "مسلم بهادری"]
# 52                     ["پدیده و فجر سپاسی", "سپاهان و تراکتور", "استقلال و پرسپولیس", "ذوب‌آهن و نفت تهران"]
# 53                                                                      ["رزمی", "کشتی", "فوتبال", "والیبال"]
# 54                                                                           ["1354", "1357", "1347", "1349"]
# 55                                     ["سیستان و بلوچستان ایران", "منامه بحرین", "بغداد عراق", "محرق بحرین"]
# 56                                                                   ["پوست شیر", "زیرخاکی", "تگزاس", "جوکر"]
# 57                                                               ["فوتبال", "کاراته", "تیراندازی", "والیبال"]
# 58                                               ["پاسور", "دریافت‌کننده قدرتی", "لیبرو", "آبشارزننده سرعتی"]
# 59                                                     ["سیمین بهبهانی", "نیما یوشیج", "سعدی", "شهیار قنبری"]
# 60               ["بایرن مونیخ و هرتابرلین", "رئال مادرید و بارسلونا", "آژاکس و پی‌اس‌وی", "یوونتوس و میلان"]
# 61                                                                   ["کشتی", "فوتبال", "والیبال", "تکواندو"]
# 62                                                                           ["۱۳۸۳", "۱۴۰۰", "۱۳۶۹", "۱۳۷۱"]
# 63                                                                  ["ایران", "ارمنستان", "ترکیه", "گرجستان"]
# 64                                                                         ["اصفهان", "کرمان", "تهران", "قم"]
# 65                                                                       ["رودکی", "فردوسی", "سعدی", "سنایی"]
# 66                                                                      ["تهران", "مشهد", "خرمشهر", "اصفهان"]
# 67                                                                                  ["۷۰", "۱۰۰", "۸۰", "۹۵"]
# 68                                                                     ["تهران", "قائمشهر", "مشهد", "اصفهان"]
# 69                                                                       ["گیلانغرب", "تهران", "مشهد", "رشت"]
# 70                                                                           ["1390", "1380", "1370", "1400"]
# 71                                                              ["وزنه‌برداری", "کشتی", "والیبال", "بسکتبال"]
# 72                                                                      ["شیراز", "کرمان", "تبریز", "اصفهان"]
# 73                                           ["شهره آغداشلو", "فاطمه معتمدآریا", "الهام حمیدی", "لیلا حاتمی"]
# 74                                                                      ["رزمی", "کشتی", "والیبال", "فوتبال"]
# 75                                                                           ["۱۳۷۱", "۱۳۶۱", "۱۳۵۱", "۱۳۴۱"]
# 76                                                                           ["1392", "1380", "1382", "1390"]
# 77                                                                           ["۱/۸۴", "۱/۶۵", "۱/۹۴", "۱/۷۲"]
# 78                                                                      ["فوتبال", "کشتی", "والیبال", "رزمی"]
# 79                                              ["باران کوثری", "مهناز افشار", "فرزانه کابلی", "مریلا زارعی"]
# 80                                                  ["ترانه شرقی", "دیوار کافه", "روز شمار یک عشق", "گلستان"]
# 81                                                                    ["فوتسال", "فوتبال", "کشتی", "والیبال"]
# 82                                               ["شهره آغداشلو", "مهناز افشار", "الهام حمیدی", "لیلا حاتمی"]
# 83  ["مدیرعامل کانون پرورش فکری کودکان و نوجوانان", "ریاست جمهوری", "ریاست فدراسیون فوتبال", "نمایندگی مجلس"]
# 84                                                  ["مارس ۱۹۸۲", "فوریهٔ ۱۹۷۹", "ژانویه ۱۹۸۸", "اکتبر ۱۹۶۹"]
# 85                                                                    ["کشتی", "فوتبال", "والیبال", "کاراته"]
# 86                                                                                       ["۴", "۳", "۵", "۲"]
# 87                                         ["ترانه علیدوستی", "فاطمه معتمدآریا", "الهام حمیدی", "لیلا حاتمی"]
# 88                                                                    ["آلگرو", "غوغا", "کازابلانکا", "مثلث"]
# 89                                                                ["قایقرانی", "کاراته", "کشتی", "سنگ‌نوردی"]
#
#                                     gold_answer  \
# 0                              ستاره سرخ بلگراد
# 1                                 داریوش ارجمند
# 2                                          ۱۳۶۳
# 3                                مریم میرزاخانی
# 4                                  سحر دولتشاهی
# 5                                        اصفهان
# 6                                     هومن سیدی
# 7                          پارالمپیک پاریس ۲۰۲۴
# 8                             پرسپولیس و الریان
# 9                                  ابراهیم نبوی
# 10                                         نقره
# 11                                         ۱٫۹۴
# 12                              سایپا و استقلال
# 13                                 انوشه انصاری
# 14                                      والیبال
# 15                                      والیبال
# 16                                         کشتی
# 17                                     خوانندگی
# 18                                 جلال الممالک
# 19                                         ایذه
# 20                                        سمنان
# 21                                        تهران
# 22                                  وزنه‌برداری
# 23                                         1393
# 24                                        تهران
# 25                                  میوه ممنوعه
# 26                         درباه الی و زخم کاری
# 27                 بازی‌های آسیایی ۱۹۵۱ دهلی نو
# 28                                 دوچرخه‌سواری
# 29                      بیست و ملاقات با جادوگر
# 30                                   رضا عطاران
# 31                                 حمید سبزواری
# 32                                       فوتبال
# 33                                         نقره
# 34                                         1360
# 35                                         1403
# 36                                  بهرام رادان
# 37                     استقلال و منچستر یونایتد
# 38                                           قم
# 39                                    لیلا کسری
# 40                       فولاد و نفت مسجدسلیمان
# 41                                         کشتی
# 42                              مسجد جامع سامان
# 43                                   تولدی دیگر
# 44                                 شهره آغداشلو
# 45                                        ایران
# 46                                    شیخ بهایی
# 47                                  مریلا زارعی
# 48                                         1346
# 49                                       تنکابن
# 50                                       کرواسی
# 51                                  محمود حسابی
# 52                            پدیده و فجر سپاسی
# 53                                         رزمی
# 54                                         1354
# 55                                  منامه بحرین
# 56                                      زیرخاکی
# 57                                      والیبال
# 58                           دریافت‌کننده قدرتی
# 59                                سیمین بهبهانی
# 60                      بایرن مونیخ و هرتابرلین
# 61                                       فوتبال
# 62                                         ۱۳۷۱
# 63                                     ارمنستان
# 64                                       اصفهان
# 65                                        رودکی
# 66                                       خرمشهر
# 67                                           ۸۰
# 68                                      قائمشهر
# 69                                     گیلانغرب
# 70                                         1380
# 71                                  وزنه‌برداری
# 72                                        کرمان
# 73                              فاطمه معتمدآریا
# 74                                         رزمی
# 75                                         ۱۳۷۱
# 76                                         1392
# 77                                         ۱/۸۴
# 78                                       فوتبال
# 79                                  مهناز افشار
# 80                                   ترانه شرقی
# 81                                       فوتسال
# 82                                 شهره آغداشلو
# 83  مدیرعامل کانون پرورش فکری کودکان و نوجوانان
# 84                                  فوریهٔ ۱۹۷۹
# 85                                         کشتی
# 86                                            ۵
# 87                               ترانه علیدوستی
# 88                                        آلگرو
# 89                                    سنگ‌نوردی
#
#                                predicted_option  is_correct evidence_ctx_idx  \
# 0                              ستاره سرخ بلگراد           1
# 1                                 داریوش ارجمند           1                1
# 2                                          ۱۳۶۳           1                1
# 3                                مریم میرزاخانی           1
# 4                                  سحر دولتشاهی           1                2
# 5                                        اصفهان           1                1
# 6                                     هومن سیدی           1                1
# 7                          پارالمپیک پاریس ۲۰۲۴           1                1
# 8                             پرسپولیس و الریان           1
# 9                                                         0
# 10                                         نقره           1                1
# 11                                         ۱٫۹۴           1                1
# 12                              سایپا و استقلال           1
# 13                                 انوشه انصاری           1
# 14                                      والیبال           1                1
# 15                                      والیبال           1                1
# 16                                         کشتی           1                1
# 17                                     خوانندگی           1                1
# 18                                 جلال الممالک           1                1
# 19                                         ایذه           1                1
# 20                                        سمنان           1
# 21                                        تهران           1                1
# 22                                  وزنه‌برداری           1                1
# 23                                         1393           1
# 24                                        تهران           1
# 25                                  میوه ممنوعه           1
# 26                         درباه الی و زخم کاری           1
# 27                 بازی‌های آسیایی ۱۹۵۱ دهلی نو           1                1
# 28                                 دوچرخه‌سواری           1                1
# 29                      بیست و ملاقات با جادوگر           1
# 30                                   رضا عطاران           1                1
# 31                                 حمید سبزواری           1                1
# 32                                       فوتبال           1                1
# 33                                         نقره           1                1
# 34                                         1360           1
# 35                                         1403           1
# 36                                  بهرام رادان           1
# 37                     استقلال و منچستر یونایتد           1                1
# 38                                     نمی‌دانم           0
# 39                                                        0
# 40                       فولاد و نفت مسجدسلیمان           1                1
# 41                                         کشتی           1
# 42                                                        0
# 43                                   تولدی دیگر           1
# 44                                   لیلا حاتمی           0                1
# 45                                        ایران           1
# 46                                                        0
# 47                                                        0
# 48                                         1346           1                1
# 49                                       تنکابن           1
# 50                                       کرواسی           1                1
# 51                                  محمود حسابی           1
# 52                            پدیده و فجر سپاسی           1                1
# 53                                         رزمی           1                1
# 54                                         1354           1                1
# 55                                  مناحه بحرین           0                1
# 56                                      زیرخاکی           1                1
# 57                                      والیبال           1                1
# 58                           دریافت‌کننده قدرتی           1
# 59                                سیمین بهبهانی           1                2
# 60                      بایرن مونیخ و هرتابرلین           1
# 61                                       فوتبال           1                1
# 62                                         ۱۳۷۱           1
# 63                                     ارمنستان           1                1
# 64                                       اصفهان           1                1
# 65                                        رودکی           1
# 66                                       خرمشهر           1                1
# 67                                                        0
# 68                                      قائمشهر           1                1
# 69                                     گیلانغرب           1                1
# 70                                         1380           1
# 71                                                        0
# 72                                         خالی           0
# 73                              فاطمه معتمدآریا           1                1
# 74                                         رزمی           1                1
# 75                                         ۱۳۷۱           1
# 76                                         1392           1                1
# 77                                         ۱/۸۴           1                1
# 78                                       فوتبال           1                1
# 79                                  مهناز افشار           1                1
# 80                                   ترانه شرقی           1
# 81                                       فوتسال           1                1
# 82                                 شهره آغداشلو           1
# 83  مدیرعامل کانون پرورش فکری کودکان و نوجوانان           1
# 84                                  فوریهٔ ۱۹۷۹           1                1
# 85                                         کشتی           1                1
# 86                                            ۵           1
# 87                               ترانه علیدوستی           1                1
# 88                                        آلگرو           1
# 89                                    سنگ‌نوردی           1                1
#
#    evidence_source_name  \
# 0
# 1         داریوش ارجمند
# 2            بهرنگ صفری
# 3
# 4          سحر دولتشاهی
# 5           گلنوش خسروی
# 6             هومن سیدی
# 7          هاجر صفرزاده
# 8
# 9
# 10        وحید گل‌خندان
# 11        میربابک موسوی
# 12
# 13
# 14           فرنوش شیخی
# 15         مهتاب رحمانی
# 16           مجید ترکان
# 17          روزبه بمانی
# 18           ایرج میرزا
# 19           رضا نوروزی
# 20
# 21          بهتاش فریبا
# 22          الهام حسینی
# 23
# 24
# 25
# 26
# 27        لوون کورکچیان
# 28          صمد پورسیدی
# 29
# 30           رضا عطاران
# 31         حمید سبزواری
# 32          رضا افتخاری
# 33          علی پاکدامن
# 34
# 35
# 36
# 37           ناصر حجازی
# 38
# 39
# 40            یوسف وکیا
# 41
# 42
# 43
# 44           لیلا حاتمی
# 45
# 46
# 47
# 48          مهران مدیری
# 49
# 50       زوونیمیر سولدو
# 51
# 52          حسین مهربان
# 53            وحید سرلک
# 54         محسن تنابنده
# 55       عبدالواحد خنجی
# 56           ژاله صامتی
# 57           الهام فلاح
# 58
# 59        سیمین بهبهانی
# 60
# 61           بیژن طاهری
# 62
# 63  هاروتیون آبراهامیان
# 64          صائب تبریزی
# 65
# 66          جمشید نصیری
# 67
# 68            رضا مؤمنی
# 69          پوریا امینی
# 70
# 71
# 72
# 73      فاطمه معتمدآریا
# 74         مهدی خدابخشی
# 75
# 76         پژمان جمشیدی
# 77          ایمان موسوی
# 78          مهدی تیکدری
# 79          مهناز افشار
# 80
# 81         سارا شیربیگی
# 82
# 83
# 84           علیرضا حقی
# 85            عباس زندی
# 86
# 87       ترانه علیدوستی
# 88
# 89          رضا علی‌پور
#
#                                                                                                                                                                                                                                 evidence_span
# 0                                                                                                                                                                         مارکوویچ فعالیت خود را از سال 2003 با ستاره‌سرخ بلگراد آغاز کرد [1]
# 1                                                                                                                                ارجمند برای بازی در «ناخدا خورشید» سیمرغ بلورین بهترین بازیگر نقش اول مرد را از جشنواره فیلم فجر دریافت کرد.
# 2                                                                                                                        بهرنگ صفری، ورزشکار فوتبال، در تاریخ 20 بهمن 1363 (سن:40 سال) در تهران، ایران متولد شده است، قد ایشان 1، 84 متر است.
# 3                                                                                                                                                                                            او در سال 1393 اولین زن برنده مدال فیلدز شد. [1]
# 4                                                                                                               دولتشاهی در سال 1396 برنده سیمرغ بلورین بهترین بازیگر نقش مکمل زن در جشنواره فیلم فجر برای «چهارراه استانبول» و «عرق سرد» شد.
# 5                                                                                                                                   گلنوش خسروی، ورزشکار فوتبال، در تاریخ 12 می‌ 200122 اردیبهشت 1380 (24 سال) در اصفهان، ایران متولد شده است
# 6                                                                                                                                                                     سیدی برای کارگردانی «مغزهای کوچک زنگ‌زده» جوایز متعددی دریافت کرده است.
# 7                                                                                                                                                                                                     مدال نقره بازی‌های پارالمپیک پاریس 2024
# 8                                                                                                           شجاع خلیل‌زاده... در تیم‌های مس رفسنجان، مس کرمان، سپاهان، ←تراکتور (قرضی)، پرسپولیس، الریان، الاهلی قطر و تراکتور بازی کرده است.
# 9                                                                                                                                                                                                                                    نمی‌دانم
# 10                                                                                                                                                                                                       مدال نقره جام جهانی ریودوژانیرو 2022
# 11                                                                                                                                                               قد ایشان 1، 94 m (6 ft 41 ⁄ 2 in) است و وزن ایشان 90 کیلوگرم (200 پوند) است.
# 12                                                                                                                                         او با شماره 99 برای استقلال بازی می‌کند و افتخاراتی نظیر قهرمانی لیگ برتر (01 - 1400) را دارد. [1]
# 13        انوشه انصاری، متولد 21 مهر 1345 در مشهد، مهندس، کارآفرین و اولین زن ایرانی در فضا است. او در 27 شهریور 1385 به ایستگاه فضایی بین‌المللی سفر کرد، سیستم‌های پرودیا را تاسیس کرد و در سال 1395 جایزه پیشگام فضایی را دریافت نمود. [1]
# 14                                                                                                                                                                                     فرنوش شیخی، ورزشکار والیبال، در تاریخ 23 اردیبهشت 1369
# 15                                                                                                                          مهتاب رحمانی، ورزشکار والیبال، در تاریخ 3 شهریور 1371 (32 سال) کرمانشاه در تیم ملی بزرگسالان ایران متولد شده است،
# 16                                                                                                                                                                   مجید ترکان، ورزشکار کشتی، در تاریخ 21 آذر 1344 (در 60 سال) متولد شده است
# 17                                                                                                                           روزبه بمانی، متولد 7 قوس 1358 در تهران، شاعر، ترانه‌سرا، خواننده و بازیگر ایرانی است که از دهه 1370 فعالیت دارد.
# 18                                                                                                                      ایرج میرزا، معروف به جلال‌الممالک یا فخرالشعرا، در سال 1252 یا 1253 خورشیدی در تبریز، استان آذربایجان شرقی، متولد شد.
# 19                                                                                                                             رضا نوروزی، ورزشکار فوتبال، در تاریخ 30 شهریور 1361 (42 سال) در ایذه، ایران متولد شده است، قد ایشان 1، 89 است.
# 20                                                                                                                                                              حسن روحانی در تاریخ 1948 - 12 - 11 در شهر سرخه واقع در سمنان به دنیا آمد. [1]
# 21                                                                                                                                                 بهتاش فریبا، ورزشکار فوتبال، در تاریخ 22 بهمن 1334 (69 سال) در تهران، ایران متولد شده است.
# 22                                                                                                                 الهام حسینی، ورزشکار وزنه‌برداری، در تاریخ 16 سپتامبر 1988 (در 36 سال) متولد شده است، وزن ایشان 87 کیلوگرم (192 پوند) است.
# 23                                                                                                                                                                                                     او در 23 آذر 1393 در تهران درگذشت. [1]
# 24                                                                                                                             امیرحسین آرمان، متولد 14 آبان 1361 در تهران، بازیگر ایرانی است که از دهه 1380 فعالیت خود را آغاز کرده است. [1]
# 25                                                                                                                                                                           او در سریال‌هایی مانند «میوه ممنوعه» در سال 1386 حضور داشته است.
# 26                                 او در فیلم‌هایی مانند «مارمولک» در سال 1382، «درباره الی» در سال 1387، ... آزادی‌ور در مجموعه‌های نمایش خانگی مانند «زخم کاری» در سال 1400 حضور داشته و برای بازی در «درباره الی» مورد توجه قرار گرفت. [1]
# 27                                                                                                                                                                              افتخار مدال طلا بازی‌های آسیایی 1951 دهلی‌نو را کسب کرده است.
# 28                                                                                                                                                     صمد پورسیدی، ورزشکار دوچرخه‌سواری، در تاریخ 23 مهر 1364 (سن: در 39 سال) متولد شده است.
# 29                                                                                          او در فیلم‌هایی چون «مرگ یزدگرد» (1360)، «آپارتمان شماره 13» (1369)، «بیست» (1387) و مجموعه «پایتخت» (1389) بازی کرد و برنده سیمرغ بلورین شد. [1]
# 30                                                          او برای بازی در «طبقه هساث» و «روشن» در سال‌های 1392 و 1399 سیمرغ بلورین بهترین بازیگر مرد و برای کارگردانی «خوابم می‌آد» در سال 1390 سیمرغ بلورین بهترین کارگردان را دریافت کرد.
# 31                                                                                                                                   حمید سبزواری، معروف به شاعر انقلاب و پدر شعر انقلاب، در سال 1304 در سبزوار، استان خراسان رضوی، متولد شد.
# 32                                                                                                                                                                                                               رضا افتخاری، ورزشکار فوتبال.
# 33                                                                                                                                                                                          مدال نقره جام جهانی گرجستان 2024 را کسب کرده است.
# 34                                                                                                                                                                                 جمشید هاشم‌پور... از دهه 1360 فعالیت خود را آغاز کرده است.
# 35                                                                                                                                           او در دوره 1400 - 1403 فعالیت و زیست کرده است. در نهایت در تاریخ 1403 - 05 - 04 از دنیا رفت. [1]
# 36                                                                                                                                   رادان ... برای بازی در «سنتوری» جایزه بهترین بازیگر مرد را از بیست و پنجمین جشنواره فیلم فجر دریافت کرد.
# 37                                                                                                                                                         در تیم‌های نادر تهران، تاج، شهباز، استقلال، محمدان و منچستر یونایتد بازی کرده است.
# 38                                                                                                                                                                                                                                   نمی‌دانم
# 39                                                                                                                                                                                                                                   نمی‌دانم
# 40                                                                                                                  در تیم‌های فولاد، نفت مسجدسلیمان، گل‌گهر، پدیده، خیبر خرم‌آباد، فجر سپاسی، صنعت نفت آبادان و بعثت کرمانشاه بازی کرده است.
# 41                                                                                                                   حبیب‌الله بلور، ... مربی کشتی، مدیر ورزشی و بازیگر سینمای ایرانی بود. ... بلور همچنین کتاب «فن و بند کشتی» را تالیف کرد.
# 42                                                                                                                                                                                                                                   نمی‌دانم
# 43                                                                                                                                                                                                 او تولدی دیگر و ایمان بیاوریم را سرود. [1]
# 44                                                                                                                                                      حاتمی برای «رگ خواب» سیمرغ بلورین بهترین بازیگر زن را از جشنواره فیلم فجر دریافت کرد.
# 45                                                                                                                                                   کریم انصاری‌فرد، ورزشکار فوتبال، در تاریخ 14 فروردین 1369 در اردبیل، ایران متولد شده است
# 46                                                                                                                                                                                                                                   نمی‌دانم
# 47                                                                                                                                                                                                                                   نمی‌دانم
# 48                                                                                                                                                                                                مهران مدیری، متولد 29 فروردین 1346 در تهران
# 49                                                                                                                                                                     مجتبی گلیج، ورزشکار کشتی، در تاریخ 3 بهمن 1375 در تنکابن متولد شده است
# 50                                                                                                                                                              زوونیمیر سولدو، ورزشکار فوتبال، در تاریخ 2 نوامبر 1967 (57 سال) متولد شده است
# 51                                                                                                                       محمود حسابی، معروف به پدر فیزیک ایران، در 3 اسفند 1281 شمسی در تهران متولد شد و در 12 شهریور 1371 در ژنو درگذشت. [1]
# 52                                                                                             حسین مهربان، ورزشکار فوتبال، در تاریخ 12 مه 1996 در مشهد، ایران متولد شده است، در تیم‌های پدیده، فجر سپاسی، مس رفسنجان و هوادار بازی کرده است.
# 53                                                                                                                                                                       وحید سرلک، ورزشکار رزمی، در تاریخ 30 دی 1359 در ایران متولد شده است.
# 54                                                                                                                                                                                               محسن تنابنده، متولد 26 فروردین 1354 در تهران
# 55                                                                                                                       عبدالواحد خنجی، ورزشکار دوچرخه‌سواری، در تاریخ 17 بهمن 1307 در منامه متولد شده است، در تاریخ 18 دی 1376 درگذشته است.
# 56                                                                                                                                                                                     او برای بازی در «زیرخاکی» مورد توجه مخاطبان قرار گرفت.
# 57                                                                                                                              الهام فلاح، ورزشکار والیبال، در تاریخ 25 فروردین 1373 (31 سال) شیراز در تیم ملی بزرگسالان ایران متولد شده است
# 58                                                                                                                                                                                  زینب گیوه... در پست دریافت‌کننده قدرتی فعالیت می‌کند. [1]
# 59                                                                                                                                                         سیمین بهبهانی، معروف به سیمین خلیلی و نیمای غزل، در 28 تیر 1306 در تهران متولد شد.
# 60                                                                                                                                                                                   در تیم‌های ... بایرن‌مونیخ، هرتابرلین ... بازی کرده است.
# 61                                                                                                                                             بیژن طاهری، ورزشکار فوتبال، در تاریخ 1 فروردین 1340 (سن:64 سال) در تهران، ایران متولد شده است.
# 62                                                                                                                                                           محراب شاهرخی، ورزشکار فوتبال، در تاریخ 12 بهمن 1371 درگذشته است، قد ایشان - است.
# 63                                                                                                                                     هاروتیون آبراهامیان، ورزشکار فوتبال، در تاریخ 4 دسامبر 1969 (55 سال) در ایروان، ارمنستان متولد شده است
# 64                                                                                                                                                          صائب در سال 1087 هجری قمری در اصفهان درگذشت و آرامگاهش نیز در همان شهر قرار دارد.
# 65                                                                                                                                                                                                                                   نمی‌دانم
# 66                                               جمشید نصیری، ورزشکار فوتبال، در تاریخ 23 فوریه 1959 (66 سال) در بندر خرمشهر، ایران متولد شده است، در تیم‌های Rastakhiz Khorramshahr، East Bengal، Mohammedan SC و East Bengal بازی کرده است.
# 67                                                                                                                                                                                                                                   نمی‌دانم
# 68                                                                                                                                                                               رضا مومنی، ورزشکار کشتی، در تاریخ قائمشهر در، متولد شده است.
# 69                                                                                                                  پوریا امینی، ورزشکار فوتبال، در تاریخ 8 اسفند 1373 (30 سال) در گیلانغرب، ایران متولد شده است، قد ایشان 181 سانتی‌متر است.
# 70                                                                                                                                                                          مهرداد صدیقیان... که از دهه 1380 فعالیت خود را آغاز کرده است. [1]
# 71                                                                                                                                                                                                                                   نمی‌دانم
# 72                                                                                                                                                                                                                                   نمی‌دانم
# 73                                                                                                                                               معتمدآریا برای «گیلانه» و «روسری آبی» جوایز بهترین بازیگر زن از جشنواره فیلم فجر دریافت کرد.
# 74                                                                                                                                                      مهدی خدابخشی، ورزشکار رزمی، در تاریخ 10 اردیبهشت 1374 در اسلام‌آباد غرب متولد شده است
# 75                                                                                                          عزت‌الله اکبری، متولد 20 آبان 1371 در جویبار، مازندران، ایران، کشتی‌گیر آزاد در دسته‌های 74 و 79 کیلوگرم با قد 1، 86 متر است. [1]
# 76                                                                                                                                                                                                 از سال 1392 به عنوان بازیگر فعالیت می‌کند.
# 77                                                                                                                                                                                         قد ایشان 1 / 84 است، در تیم سال‌های بازی کرده است.
# 78                                                                                                                                                   مهدی تیکدری، ورزشکار فوتبال، در تاریخ 23 تیر 1375 (28 سال) در کرمان، ایران متولد شده است
# 79                                                                                                                                                 افشار در سال 1390 نامزد بهترین بازیگر نقش اول زن در جشنواره فیلم فجر برای «سعادت‌آباد» شد.
# 80                                                                                                                                                                                                                                   نمی‌دانم
# 81                                                                                                  سارا شیربیگی، ورزشکار فوتسال، در تاریخ 15 مرداد 1370 در فوتسال زنان ایران متولد شده است، در تیم‌های سپیدرود رشت و نصرفردیس بازی کرده است.
# 82                                                                              آغداشلو در مجموعه‌های تلویزیونی مانند «24» (1384)، «خانه صدام» (1387) و «گستره» (1394) نقش‌آفرینی کرده و ... برنده جایزه امی برای «خانه صدام» (1387) شده است.
# 83  زمینه‌های فعالیت او شامل مدیر آموزشی و مدرس دانشگاه و مدیرعامل کانون پرورش فکری کودکان و نوجوانان و رئیس کتابخانه‌ی دانشگاه ملی و رئیس کتابخانه‌ی شرکت ملی نفت ایران و استادیار کتابداری دانشگاه تهران و عضو شورای آموزش کشور می‌شود. [1]
# 84                                                                                                      علیرضا حقی، ورزشکار دوچرخه‌سواری، در تاریخ 8 فوریه 1979 (در 46 سال) متولد شده است، قد ایشان 1، 80 متر است و وزن ایشان 76 کیلوگرم است.
# 85                                                                                                                                                                  عباس زندی، متولد 1310 در سنگلج، تهران، ایران، ورزشکار کشتی آزاد و پهلوانی
# 86                                                                                                                                                                       او 5 مدال جهانی، 2 مدال منطقه‌ای، و یک مدال المپیک کسب کرده است. [1]
# 87                                                           علیدوستی در مجموعه‌های نمایش خانگی مانند «شهرزاد» در سال 1394 حضور داشته و برای بازی در «من ترانه 15 سال دارم» جایزه بهترین بازیگر زن را از بیستمین جشنواره فیلم فجر دریافت کرد.
# 88                                                                                                                                                            او آلبوم‌های «آلگرو» (1387)، «حاجیلیتو» (1395) و «ترومپت» (1400) منتشر کرد. [1]
# 89                                                                                                                                                         رضا علی‌پور، ورزشکار سنگ‌نورد، در تاریخ 9 اردیبهشت 1373 (در 31 سال) متولد شده است.

# %%
for r in rows:
    print("\n" + "—"*90)
    print("سؤال:", r["question"])
    print("نام انتخاب‌شده:", r["target_name"])
    print("گزینهٔ پیش‌بینی‌شده:", r["predicted_option"])
    print("شاهد (بخش استخراج‌شده):")
    print(r["evidence_span"] if r["evidence_span"] else "—")
# Out:
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: حبیب‌الله بلور در کدام رشته ورزشی فعالیت داشت؟
# نام انتخاب‌شده: حبیب‌الله بلور
# گزینهٔ پیش‌بینی‌شده: کشتی
# شاهد (بخش استخراج‌شده):
# حبیب‌الله بلور، ... مربی کشتی، مدیر ورزشی و بازیگر سینمای ایرانی بود. ... بلور همچنین کتاب «فن و بند کشتی» را تالیف کرد.
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: بهرنگ صفری در چه سالی متولد شده است؟
# نام انتخاب‌شده: بهرنگ صفری
# گزینهٔ پیش‌بینی‌شده: ۱۳۶۳
# شاهد (بخش استخراج‌شده):
# بهرنگ صفری، ورزشکار فوتبال، در تاریخ 20 بهمن 1363 (سن:40 سال) در تهران، ایران متولد شده است، قد ایشان 1، 84 متر است.
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: عبدالله موحد چند مدال جهانی کسب کرده است؟
# نام انتخاب‌شده: عبدالله موحد
# گزینهٔ پیش‌بینی‌شده: ۵
# شاهد (بخش استخراج‌شده):
# او 5 مدال جهانی، 2 مدال منطقه‌ای، و یک مدال المپیک کسب کرده است. [1]
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: لوون کورکچیان مدال طلای خود را در کدام رقابت کسب کرده است؟
# نام انتخاب‌شده: لوون کورکچیان
# گزینهٔ پیش‌بینی‌شده: بازی‌های آسیایی ۱۹۵۱ دهلی نو
# شاهد (بخش استخراج‌شده):
# افتخار مدال طلا بازی‌های آسیایی 1951 دهلی‌نو را کسب کرده است.
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: علیرضا حقی در چه ماهی متولد شده است؟
# نام انتخاب‌شده: علیرضا حقی
# گزینهٔ پیش‌بینی‌شده: فوریهٔ ۱۹۷۹
# شاهد (بخش استخراج‌شده):
# علیرضا حقی، ورزشکار دوچرخه‌سواری، در تاریخ 8 فوریه 1979 (در 46 سال) متولد شده است، قد ایشان 1، 80 متر است و وزن ایشان 76 کیلوگرم است.
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: زوونیمیر سولدو در کدام کشور متولد شده است؟
# نام انتخاب‌شده: زوونیمیر سولدو
# گزینهٔ پیش‌بینی‌شده: کرواسی
# شاهد (بخش استخراج‌شده):
# زوونیمیر سولدو، ورزشکار فوتبال، در تاریخ 2 نوامبر 1967 (57 سال) متولد شده است
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: محراب شاهرخی در چه سالی درگذشته است؟
# نام انتخاب‌شده: محراب شاهرخی
# گزینهٔ پیش‌بینی‌شده: ۱۳۷۱
# شاهد (بخش استخراج‌شده):
# محراب شاهرخی، ورزشکار فوتبال، در تاریخ 12 بهمن 1371 درگذشته است، قد ایشان - است.
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: وزن محمد جمشیدی چند کیلوگرم است؟
# نام انتخاب‌شده: محمد جمشیدی
# گزینهٔ پیش‌بینی‌شده:
# شاهد (بخش استخراج‌شده):
# نمی‌دانم
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: مجتبی گلیج در کدام شهر متولد شده است؟
# نام انتخاب‌شده: مجتبی گلیج
# گزینهٔ پیش‌بینی‌شده: تنکابن
# شاهد (بخش استخراج‌شده):
# مجتبی گلیج، ورزشکار کشتی، در تاریخ 3 بهمن 1375 در تنکابن متولد شده است
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: قد ایمان موسوی چند است؟
# نام انتخاب‌شده: ایمان موسوی
# گزینهٔ پیش‌بینی‌شده: ۱/۸۴
# شاهد (بخش استخراج‌شده):
# قد ایشان 1 / 84 است، در تیم سال‌های بازی کرده است.
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: الهام فلاح در چه رشته‌ای فعالیت دارد؟
# نام انتخاب‌شده: الهام فلاح
# گزینهٔ پیش‌بینی‌شده: والیبال
# شاهد (بخش استخراج‌شده):
# الهام فلاح، ورزشکار والیبال، در تاریخ 25 فروردین 1373 (31 سال) شیراز در تیم ملی بزرگسالان ایران متولد شده است
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: ناصر حجازی در کدام تیم ها بازی کرده است؟
# نام انتخاب‌شده: ناصر حجازی
# گزینهٔ پیش‌بینی‌شده: استقلال و منچستر یونایتد
# شاهد (بخش استخراج‌شده):
# در تیم‌های نادر تهران، تاج، شهباز، استقلال، محمدان و منچستر یونایتد بازی کرده است.
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: امیرعلی صادقی در کدام تیم‌ها بازی کرده است؟
# نام انتخاب‌شده: امیرعلی صادقی
# گزینهٔ پیش‌بینی‌شده: سایپا و استقلال
# شاهد (بخش استخراج‌شده):
# او با شماره 99 برای استقلال بازی می‌کند و افتخاراتی نظیر قهرمانی لیگ برتر (01 - 1400) را دارد. [1]
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: مهتاب رحمانی ورزشکار کدام رشته است؟
# نام انتخاب‌شده: مهتاب رحمانی
# گزینهٔ پیش‌بینی‌شده: والیبال
# شاهد (بخش استخراج‌شده):
# مهتاب رحمانی، ورزشکار والیبال، در تاریخ 3 شهریور 1371 (32 سال) کرمانشاه در تیم ملی بزرگسالان ایران متولد شده است،
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: بهتاش فریبا در چه شهری متولد شده است؟
# نام انتخاب‌شده: بهتاش فریبا
# گزینهٔ پیش‌بینی‌شده: تهران
# شاهد (بخش استخراج‌شده):
# بهتاش فریبا، ورزشکار فوتبال، در تاریخ 22 بهمن 1334 (69 سال) در تهران، ایران متولد شده است.
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: صمد پورسیدی در چه رشته‌ای فعالیت دارد؟
# نام انتخاب‌شده: صمد پورسیدی
# گزینهٔ پیش‌بینی‌شده: دوچرخه‌سواری
# شاهد (بخش استخراج‌شده):
# صمد پورسیدی، ورزشکار دوچرخه‌سواری، در تاریخ 23 مهر 1364 (سن: در 39 سال) متولد شده است.
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: عبدالواحد خنجی در کدام شهر و کشور متولد شده است؟
# نام انتخاب‌شده: عبدالواحد خنجی
# گزینهٔ پیش‌بینی‌شده: مناحه بحرین
# شاهد (بخش استخراج‌شده):
# عبدالواحد خنجی، ورزشکار دوچرخه‌سواری، در تاریخ 17 بهمن 1307 در منامه متولد شده است، در تاریخ 18 دی 1376 درگذشته است.
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: بیژن طاهری بازیکن کدام رشته است؟
# نام انتخاب‌شده: بیژن طاهری
# گزینهٔ پیش‌بینی‌شده: فوتبال
# شاهد (بخش استخراج‌شده):
# بیژن طاهری، ورزشکار فوتبال، در تاریخ 1 فروردین 1340 (سن:64 سال) در تهران، ایران متولد شده است.
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: علی مرادی در چه رشته‌ای ورزشکار است؟
# نام انتخاب‌شده: علی مرادی
# گزینهٔ پیش‌بینی‌شده:
# شاهد (بخش استخراج‌شده):
# نمی‌دانم
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: رضا علی‌پور ورزشکار کدام رشته است؟
# نام انتخاب‌شده: رضا علی‌پور
# گزینهٔ پیش‌بینی‌شده: سنگ‌نوردی
# شاهد (بخش استخراج‌شده):
# رضا علی‌پور، ورزشکار سنگ‌نورد، در تاریخ 9 اردیبهشت 1373 (در 31 سال) متولد شده است.
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: وحید گل‌خندان در جام جهانی ریودوژانیرو ۲۰۲۲ کدام مدال را کسب کرده است؟
# نام انتخاب‌شده: وحید گل‌خندان
# گزینهٔ پیش‌بینی‌شده: نقره
# شاهد (بخش استخراج‌شده):
# مدال نقره جام جهانی ریودوژانیرو 2022
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: وحید سرلک در چه رشته‌ای شناخته می‌شود؟
# نام انتخاب‌شده: وحید سرلک
# گزینهٔ پیش‌بینی‌شده: رزمی
# شاهد (بخش استخراج‌شده):
# وحید سرلک، ورزشکار رزمی، در تاریخ 30 دی 1359 در ایران متولد شده است.
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: یوسف وکیا بازیکن کدام تیم‌ها بوده است؟
# نام انتخاب‌شده: یوسف وکیا
# گزینهٔ پیش‌بینی‌شده: فولاد و نفت مسجدسلیمان
# شاهد (بخش استخراج‌شده):
# در تیم‌های فولاد، نفت مسجدسلیمان، گل‌گهر، پدیده، خیبر خرم‌آباد، فجر سپاسی، صنعت نفت آبادان و بعثت کرمانشاه بازی کرده است.
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: هاروتیون آبراهامیان اهل کدام کشور است؟
# نام انتخاب‌شده: هاروتیون آبراهامیان
# گزینهٔ پیش‌بینی‌شده: ارمنستان
# شاهد (بخش استخراج‌شده):
# هاروتیون آبراهامیان، ورزشکار فوتبال، در تاریخ 4 دسامبر 1969 (55 سال) در ایروان، ارمنستان متولد شده است
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: جمشید نصیری در کدام شهر ایران متولد شده است؟
# نام انتخاب‌شده: جمشید نصیری
# گزینهٔ پیش‌بینی‌شده: خرمشهر
# شاهد (بخش استخراج‌شده):
# جمشید نصیری، ورزشکار فوتبال، در تاریخ 23 فوریه 1959 (66 سال) در بندر خرمشهر، ایران متولد شده است، در تیم‌های Rastakhiz Khorramshahr، East Bengal، Mohammedan SC و East Bengal بازی کرده است.
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: رضا افتخاری در کدام رشته ورزشی شناخته می‌شود؟
# نام انتخاب‌شده: رضا افتخاری
# گزینهٔ پیش‌بینی‌شده: فوتبال
# شاهد (بخش استخراج‌شده):
# رضا افتخاری، ورزشکار فوتبال.
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: پوریا امینی در چه استانی متولد شده است؟
# نام انتخاب‌شده: پوریا امینی
# گزینهٔ پیش‌بینی‌شده: گیلانغرب
# شاهد (بخش استخراج‌شده):
# پوریا امینی، ورزشکار فوتبال، در تاریخ 8 اسفند 1373 (30 سال) در گیلانغرب، ایران متولد شده است، قد ایشان 181 سانتی‌متر است.
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: حسن حبیبی در کدام شهر متولد شده است؟
# نام انتخاب‌شده: حسن ابراهیم حبیبی
# گزینهٔ پیش‌بینی‌شده: خالی
# شاهد (بخش استخراج‌شده):
# نمی‌دانم
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: زینب گیوه بازیکن والیبال ایرانی در کدام پست فعالیت می‌کند؟
# نام انتخاب‌شده: زینب گیوه
# گزینهٔ پیش‌بینی‌شده: دریافت‌کننده قدرتی
# شاهد (بخش استخراج‌شده):
# زینب گیوه... در پست دریافت‌کننده قدرتی فعالیت می‌کند. [1]
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: حسین مهربان بازیکن کدام تیم‌ها بوده است؟
# نام انتخاب‌شده: حسین مهربان
# گزینهٔ پیش‌بینی‌شده: پدیده و فجر سپاسی
# شاهد (بخش استخراج‌شده):
# حسین مهربان، ورزشکار فوتبال، در تاریخ 12 مه 1996 در مشهد، ایران متولد شده است، در تیم‌های پدیده، فجر سپاسی، مس رفسنجان و هوادار بازی کرده است.
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: علی پاکدامن در جام جهانی گرجستان ۲۰۲۴ کدام مدال را کسب کرده است؟
# نام انتخاب‌شده: علی پاکدامن
# گزینهٔ پیش‌بینی‌شده: نقره
# شاهد (بخش استخراج‌شده):
# مدال نقره جام جهانی گرجستان 2024 را کسب کرده است.
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: الهام حسینی در چه رشته‌ای فعالیت دارد؟
# نام انتخاب‌شده: الهام حسینی
# گزینهٔ پیش‌بینی‌شده: وزنه‌برداری
# شاهد (بخش استخراج‌شده):
# الهام حسینی، ورزشکار وزنه‌برداری، در تاریخ 16 سپتامبر 1988 (در 36 سال) متولد شده است، وزن ایشان 87 کیلوگرم (192 پوند) است.
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: رضا مؤمنی در کدام شهر متولد شده است؟
# نام انتخاب‌شده: رضا مؤمنی
# گزینهٔ پیش‌بینی‌شده: قائمشهر
# شاهد (بخش استخراج‌شده):
# رضا مومنی، ورزشکار کشتی، در تاریخ قائمشهر در، متولد شده است.
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: رضا نوروزی در چه شهری متولد شده است؟
# نام انتخاب‌شده: رضا نوروزی
# گزینهٔ پیش‌بینی‌شده: ایذه
# شاهد (بخش استخراج‌شده):
# رضا نوروزی، ورزشکار فوتبال، در تاریخ 30 شهریور 1361 (42 سال) در ایذه، ایران متولد شده است، قد ایشان 1، 89 است.
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: مجید ترکان ورزشکار کدام رشته است؟
# نام انتخاب‌شده: مجید ترکان
# گزینهٔ پیش‌بینی‌شده: کشتی
# شاهد (بخش استخراج‌شده):
# مجید ترکان، ورزشکار کشتی، در تاریخ 21 آذر 1344 (در 60 سال) متولد شده است
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: ایوان مارکوویچ هافبک ذوب‌آهن در فوتبال فعالیت خود را با چه تیمی آغاز کرد؟
# نام انتخاب‌شده: ایوان مارکوویچ
# گزینهٔ پیش‌بینی‌شده: ستاره سرخ بلگراد
# شاهد (بخش استخراج‌شده):
# مارکوویچ فعالیت خود را از سال 2003 با ستاره‌سرخ بلگراد آغاز کرد [1]
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: گلنوش خسروی در کدام شهر به متولد شده است؟
# نام انتخاب‌شده: گلنوش خسروی
# گزینهٔ پیش‌بینی‌شده: اصفهان
# شاهد (بخش استخراج‌شده):
# گلنوش خسروی، ورزشکار فوتبال، در تاریخ 12 می‌ 200122 اردیبهشت 1380 (24 سال) در اصفهان، ایران متولد شده است
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: فرنوش شیخی در کدام رشته ورزشی فعالیت دارد؟
# نام انتخاب‌شده: فرنوش شیخی
# گزینهٔ پیش‌بینی‌شده: والیبال
# شاهد (بخش استخراج‌شده):
# فرنوش شیخی، ورزشکار والیبال، در تاریخ 23 اردیبهشت 1369
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: سارا شیربیگی ورزشکار کدام رشته است؟
# نام انتخاب‌شده: سارا شیربیگی
# گزینهٔ پیش‌بینی‌شده: فوتسال
# شاهد (بخش استخراج‌شده):
# سارا شیربیگی، ورزشکار فوتسال، در تاریخ 15 مرداد 1370 در فوتسال زنان ایران متولد شده است، در تیم‌های سپیدرود رشت و نصرفردیس بازی کرده است.
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: هاجر صفرزاده در کدام رقابت مدال گرفته است؟
# نام انتخاب‌شده: هاجر صفرزاده
# گزینهٔ پیش‌بینی‌شده: پارالمپیک پاریس ۲۰۲۴
# شاهد (بخش استخراج‌شده):
# مدال نقره بازی‌های پارالمپیک پاریس 2024
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: مهدی تیکدری سالاری در کدام رشته فعال است؟
# نام انتخاب‌شده: مهدی تیکدری سالاری
# گزینهٔ پیش‌بینی‌شده: فوتبال
# شاهد (بخش استخراج‌شده):
# مهدی تیکدری، ورزشکار فوتبال، در تاریخ 23 تیر 1375 (28 سال) در کرمان، ایران متولد شده است
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: شجاع خلیل‌زاده در کدام تیم‌ها بازی کرده است؟
# نام انتخاب‌شده: شجاع خلیل‌زاده
# گزینهٔ پیش‌بینی‌شده: پرسپولیس و الریان
# شاهد (بخش استخراج‌شده):
# شجاع خلیل‌زاده... در تیم‌های مس رفسنجان، مس کرمان، سپاهان، ←تراکتور (قرضی)، پرسپولیس، الریان، الاهلی قطر و تراکتور بازی کرده است.
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: مهدی خدابخشی در چه رشته‌ای فعالیت دارد؟
# نام انتخاب‌شده: مهدی خدابخشی
# گزینهٔ پیش‌بینی‌شده: رزمی
# شاهد (بخش استخراج‌شده):
# مهدی خدابخشی، ورزشکار رزمی، در تاریخ 10 اردیبهشت 1374 در اسلام‌آباد غرب متولد شده است
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: علی دایی در کدام تیم‌های اروپایی بازی کرده است؟
# نام انتخاب‌شده: علی دایی
# گزینهٔ پیش‌بینی‌شده: بایرن مونیخ و هرتابرلین
# شاهد (بخش استخراج‌شده):
# در تیم‌های ... بایرن‌مونیخ، هرتابرلین ... بازی کرده است.
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: عباس زندی در کدام رشته ورزشی مدال‌های متعددی کسب کرده است؟
# نام انتخاب‌شده: عباس زندی
# گزینهٔ پیش‌بینی‌شده: کشتی
# شاهد (بخش استخراج‌شده):
# عباس زندی، متولد 1310 در سنگلج، تهران، ایران، ورزشکار کشتی آزاد و پهلوانی
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: عزت‌الله اکبری در چه سالی متولد شده است؟
# نام انتخاب‌شده: عزت‌الله اکبری
# گزینهٔ پیش‌بینی‌شده: ۱۳۷۱
# شاهد (بخش استخراج‌شده):
# عزت‌الله اکبری، متولد 20 آبان 1371 در جویبار، مازندران، ایران، کشتی‌گیر آزاد در دسته‌های 74 و 79 کیلوگرم با قد 1، 86 متر است. [1]
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: قد میربابک موسوی، ورزشکار والیبال چند است؟
# نام انتخاب‌شده: میربابک موسوی
# گزینهٔ پیش‌بینی‌شده: ۱٫۹۴
# شاهد (بخش استخراج‌شده):
# قد ایشان 1، 94 m (6 ft 41 ⁄ 2 in) است و وزن ایشان 90 کیلوگرم (200 پوند) است.
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: کریم انصاری‌فرد در کدام کشور متولد شده است؟
# نام انتخاب‌شده: کریم انصاری‌فرد
# گزینهٔ پیش‌بینی‌شده: ایران
# شاهد (بخش استخراج‌شده):
# کریم انصاری‌فرد، ورزشکار فوتبال، در تاریخ 14 فروردین 1369 در اردبیل، ایران متولد شده است
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: کدام بازیگر در فیلم من و دبورا بازی کرده است؟
# نام انتخاب‌شده:
# گزینهٔ پیش‌بینی‌شده:
# شاهد (بخش استخراج‌شده):
# نمی‌دانم
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: کدام فرد برای کارگردانی فیلم خوابم میآید سیمرغ بلورین دریافت کرده است؟
# نام انتخاب‌شده: رضا عطاران
# گزینهٔ پیش‌بینی‌شده: رضا عطاران
# شاهد (بخش استخراج‌شده):
# او برای بازی در «طبقه هساث» و «روشن» در سال‌های 1392 و 1399 سیمرغ بلورین بهترین بازیگر مرد و برای کارگردانی «خوابم می‌آد» در سال 1390 سیمرغ بلورین بهترین کارگردان را دریافت کرد.
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: کدام فرد برای بازی در فیلم سنتوری جایزه بهترین بازیگر مرد را در جشنواره فجر دریافت کرده است؟
# نام انتخاب‌شده: بهرام رادان
# گزینهٔ پیش‌بینی‌شده: بهرام رادان
# شاهد (بخش استخراج‌شده):
# رادان ... برای بازی در «سنتوری» جایزه بهترین بازیگر مرد را از بیست و پنجمین جشنواره فیلم فجر دریافت کرد.
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: محسن تنابنده در چه سالی متولد شده است؟
# نام انتخاب‌شده: محسن تنابنده
# گزینهٔ پیش‌بینی‌شده: 1354
# شاهد (بخش استخراج‌شده):
# محسن تنابنده، متولد 26 فروردین 1354 در تهران
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: کدام یک از آثار احمدشاملو است؟
# نام انتخاب‌شده: احمد شاملو
# گزینهٔ پیش‌بینی‌شده: ترانه شرقی
# شاهد (بخش استخراج‌شده):
# نمی‌دانم
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: روزبه بمانی در چه حیطه ای فعالیت میکند؟
# نام انتخاب‌شده: روزبه بمانی
# گزینهٔ پیش‌بینی‌شده: خوانندگی
# شاهد (بخش استخراج‌شده):
# روزبه بمانی، متولد 7 قوس 1358 در تهران، شاعر، ترانه‌سرا، خواننده و بازیگر ایرانی است که از دهه 1370 فعالیت دارد.
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: سهراب سپهری در کجا متولد شده است؟
# نام انتخاب‌شده: سهراب سپهری
# گزینهٔ پیش‌بینی‌شده: نمی‌دانم
# شاهد (بخش استخراج‌شده):
# نمی‌دانم
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: کدام شاعر معروف به نیمای غزل است؟
# نام انتخاب‌شده: سیمین بهبهانی
# گزینهٔ پیش‌بینی‌شده: سیمین بهبهانی
# شاهد (بخش استخراج‌شده):
# سیمین بهبهانی، معروف به سیمین خلیلی و نیمای غزل، در 28 تیر 1306 در تهران متولد شد.
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: شاعر معروف به تاج الشعرا در ابتدا در کجا دفن شد؟
# نام انتخاب‌شده: محمد فرخی یزدی
# گزینهٔ پیش‌بینی‌شده:
# شاهد (بخش استخراج‌شده):
# نمی‌دانم
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: کدام یک از آثار فروغ فرخزاد است؟
# نام انتخاب‌شده: فروغ فرخزاد
# گزینهٔ پیش‌بینی‌شده: تولدی دیگر
# شاهد (بخش استخراج‌شده):
# او تولدی دیگر و ایمان بیاوریم را سرود. [1]
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: اولین زن ایرانی در فضا چه کسی است؟
# نام انتخاب‌شده: انوشه انصاری
# گزینهٔ پیش‌بینی‌شده: انوشه انصاری
# شاهد (بخش استخراج‌شده):
# انوشه انصاری، متولد 21 مهر 1345 در مشهد، مهندس، کارآفرین و اولین زن ایرانی در فضا است. او در 27 شهریور 1385 به ایستگاه فضایی بین‌المللی سفر کرد، سیستم‌های پرودیا را تاسیس کرد و در سال 1395 جایزه پیشگام فضایی را دریافت نمود. [1]
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: مفتاح الفتاح از چه کسی منتشر شده است؟
# نام انتخاب‌شده:
# گزینهٔ پیش‌بینی‌شده:
# شاهد (بخش استخراج‌شده):
# نمی‌دانم
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: پدر فیزیک ایران چه کسی است؟
# نام انتخاب‌شده: محمود حسابی
# گزینهٔ پیش‌بینی‌شده: محمود حسابی
# شاهد (بخش استخراج‌شده):
# محمود حسابی، معروف به پدر فیزیک ایران، در 3 اسفند 1281 شمسی در تهران متولد شد و در 12 شهریور 1371 در ژنو درگذشت. [1]
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: اولین زن برنده ی مدال فیلدر چه کسی است؟
# نام انتخاب‌شده: مریم میرزاخانی
# گزینهٔ پیش‌بینی‌شده: مریم میرزاخانی
# شاهد (بخش استخراج‌شده):
# او در سال 1393 اولین زن برنده مدال فیلدز شد. [1]
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: جمشید هاشمپور در چه دهه ای فعالیت خود را آغاز کرده است؟
# نام انتخاب‌شده: جمشید هاشم‌پور
# گزینهٔ پیش‌بینی‌شده: 1360
# شاهد (بخش استخراج‌شده):
# جمشید هاشم‌پور... از دهه 1360 فعالیت خود را آغاز کرده است.
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: کدام بازیگر در سال 1396 برنده سیمرغ بلورین بهترین بازیگر نقش مکمل زن در جشنواره فیلم فجر شد؟
# نام انتخاب‌شده: سحر دولتشاهی
# گزینهٔ پیش‌بینی‌شده: سحر دولتشاهی
# شاهد (بخش استخراج‌شده):
# دولتشاهی در سال 1396 برنده سیمرغ بلورین بهترین بازیگر نقش مکمل زن در جشنواره فیلم فجر برای «چهارراه استانبول» و «عرق سرد» شد.
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: نامزد بهترین بازیگر نقش اول زن در جشنواره فیلم فجر برای «سعادت‌آباد» که بود؟
# نام انتخاب‌شده: مهناز افشار
# گزینهٔ پیش‌بینی‌شده: مهناز افشار
# شاهد (بخش استخراج‌شده):
# افشار در سال 1390 نامزد بهترین بازیگر نقش اول زن در جشنواره فیلم فجر برای «سعادت‌آباد» شد.
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: دایره المعارف شیطان اثر کیست؟
# نام انتخاب‌شده:
# گزینهٔ پیش‌بینی‌شده:
# شاهد (بخش استخراج‌شده):
# نمی‌دانم
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: ایرج میرزرا به چه نامی معروف بود؟
# نام انتخاب‌شده: ایرج میرزا
# گزینهٔ پیش‌بینی‌شده: جلال الممالک
# شاهد (بخش استخراج‌شده):
# ایرج میرزا، معروف به جلال‌الممالک یا فخرالشعرا، در سال 1252 یا 1253 خورشیدی در تبریز، استان آذربایجان شرقی، متولد شد.
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: کدام شاعر به پدر شعر انقلاب معروف است؟
# نام انتخاب‌شده: حمید سبزواری
# گزینهٔ پیش‌بینی‌شده: حمید سبزواری
# شاهد (بخش استخراج‌شده):
# حمید سبزواری، معروف به شاعر انقلاب و پدر شعر انقلاب، در سال 1304 در سبزوار، استان خراسان رضوی، متولد شد.
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: پدر ادبیات تاجیک کیست؟
# نام انتخاب‌شده: خالی
# گزینهٔ پیش‌بینی‌شده: رودکی
# شاهد (بخش استخراج‌شده):
# نمی‌دانم
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: کارگردان مغزهای کوچک زنگ زده کیست؟
# نام انتخاب‌شده: هومن سیدی
# گزینهٔ پیش‌بینی‌شده: هومن سیدی
# شاهد (بخش استخراج‌شده):
# سیدی برای کارگردانی «مغزهای کوچک زنگ‌زده» جوایز متعددی دریافت کرده است.
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: کدام بازیگر برای بازی در «ناخدا خورشید» سیمرغ بلورین بهترین بازیگر نقش اول مرد را از جشنواره فیلم فجر دریافت کرد؟
# نام انتخاب‌شده: داریوش ارجمند
# گزینهٔ پیش‌بینی‌شده: داریوش ارجمند
# شاهد (بخش استخراج‌شده):
# ارجمند برای بازی در «ناخدا خورشید» سیمرغ بلورین بهترین بازیگر نقش اول مرد را از جشنواره فیلم فجر دریافت کرد.
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: مهران مدیری متولد چه سالی است؟
# نام انتخاب‌شده: مهران مدیری
# گزینهٔ پیش‌بینی‌شده: 1346
# شاهد (بخش استخراج‌شده):
# مهران مدیری، متولد 29 فروردین 1346 در تهران
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: رعنا آزادیور در چه فیلم هایی بازی کرده است؟
# نام انتخاب‌شده: رعنا آزادی‌ور
# گزینهٔ پیش‌بینی‌شده: درباه الی و زخم کاری
# شاهد (بخش استخراج‌شده):
# او در فیلم‌هایی مانند «مارمولک» در سال 1382، «درباره الی» در سال 1387، ... آزادی‌ور در مجموعه‌های نمایش خانگی مانند «زخم کاری» در سال 1400 حضور داشته و برای بازی در «درباره الی» مورد توجه قرار گرفت. [1]
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: کدام بازیگر زن برنده جایزه امی برای «خانه صدام» (1387) شده است؟
# نام انتخاب‌شده: شهره آغداشلو
# گزینهٔ پیش‌بینی‌شده: شهره آغداشلو
# شاهد (بخش استخراج‌شده):
# آغداشلو در مجموعه‌های تلویزیونی مانند «24» (1384)، «خانه صدام» (1387) و «گستره» (1394) نقش‌آفرینی کرده و ... برنده جایزه امی برای «خانه صدام» (1387) شده است.
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: کدام بازیگر برای «رگ خواب» سیمرغ بلورین بهترین بازیگر زن را از جشنواره فیلم فجر دریافت کرده است؟
# نام انتخاب‌شده: لیلا حاتمی
# گزینهٔ پیش‌بینی‌شده: لیلا حاتمی
# شاهد (بخش استخراج‌شده):
# حاتمی برای «رگ خواب» سیمرغ بلورین بهترین بازیگر زن را از جشنواره فیلم فجر دریافت کرد.
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: کدام بازیگر برای «گیلانه» و «روسری آبی» جوایز بهترین بازیگر زن از جشنواره فیلم فجر دریافت کرده است؟
# نام انتخاب‌شده: فاطمه معتمدآریا
# گزینهٔ پیش‌بینی‌شده: فاطمه معتمدآریا
# شاهد (بخش استخراج‌شده):
# معتمدآریا برای «گیلانه» و «روسری آبی» جوایز بهترین بازیگر زن از جشنواره فیلم فجر دریافت کرد.
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: علیرضا خمسه در چه فیلم هایی بازی کرده است؟
# نام انتخاب‌شده: علیرضا خمسه
# گزینهٔ پیش‌بینی‌شده: بیست و ملاقات با جادوگر
# شاهد (بخش استخراج‌شده):
# او در فیلم‌هایی چون «مرگ یزدگرد» (1360)، «آپارتمان شماره 13» (1369)، «بیست» (1387) و مجموعه «پایتخت» (1389) بازی کرد و برنده سیمرغ بلورین شد. [1]
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: مهرداد صدیقیان از چه دهه ای فعالیت خود را آغاز کرده است؟
# نام انتخاب‌شده: مهرداد صدیقیان
# گزینهٔ پیش‌بینی‌شده: 1380
# شاهد (بخش استخراج‌شده):
# مهرداد صدیقیان... که از دهه 1380 فعالیت خود را آغاز کرده است. [1]
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: ژاله صامتی برای بازی در چه فیلمی مورد توجه مخاطبان قرار گرفت؟
# نام انتخاب‌شده: ژاله صامتی
# گزینهٔ پیش‌بینی‌شده: زیرخاکی
# شاهد (بخش استخراج‌شده):
# او برای بازی در «زیرخاکی» مورد توجه مخاطبان قرار گرفت.
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: کدام بازیگر برای بازی در «من ترانه 15 سال دارم» جایزه بهترین بازیگر زن را از بیستمین جشنواره فیلم فجر دریافت کرد؟
# نام انتخاب‌شده: ترانه علیدوستی
# گزینهٔ پیش‌بینی‌شده: ترانه علیدوستی
# شاهد (بخش استخراج‌شده):
# علیدوستی در مجموعه‌های نمایش خانگی مانند «شهرزاد» در سال 1394 حضور داشته و برای بازی در «من ترانه 15 سال دارم» جایزه بهترین بازیگر زن را از بیستمین جشنواره فیلم فجر دریافت کرد.
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: امیرحسین حسین آرمان متولد کجا است؟
# نام انتخاب‌شده: امیرحسین حسین آرمان
# گزینهٔ پیش‌بینی‌شده: تهران
# شاهد (بخش استخراج‌شده):
# امیرحسین آرمان، متولد 14 آبان 1361 در تهران، بازیگر ایرانی است که از دهه 1380 فعالیت خود را آغاز کرده است. [1]
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: انوشیروان ارجمند در چه سالی درگذشت؟
# نام انتخاب‌شده: انوشیروان ارجمند
# گزینهٔ پیش‌بینی‌شده: 1393
# شاهد (بخش استخراج‌شده):
# او در 23 آذر 1393 در تهران درگذشت. [1]
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: آرامگاه صائب تبریزی در کجا قرار دارد؟
# نام انتخاب‌شده: صائب تبریزی
# گزینهٔ پیش‌بینی‌شده: اصفهان
# شاهد (بخش استخراج‌شده):
# صائب در سال 1087 هجری قمری در اصفهان درگذشت و آرامگاهش نیز در همان شهر قرار دارد.
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: شعر شب عشق از کدام ترانه سرا است؟
# نام انتخاب‌شده:
# گزینهٔ پیش‌بینی‌شده:
# شاهد (بخش استخراج‌شده):
# نمی‌دانم
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: لیلی جهان آرا در چه زمینه ای فعالیت داشته است؟
# نام انتخاب‌شده: لیلی جهان‌آرا
# گزینهٔ پیش‌بینی‌شده: مدیرعامل کانون پرورش فکری کودکان و نوجوانان
# شاهد (بخش استخراج‌شده):
# زمینه‌های فعالیت او شامل مدیر آموزشی و مدرس دانشگاه و مدیرعامل کانون پرورش فکری کودکان و نوجوانان و رئیس کتابخانه‌ی دانشگاه ملی و رئیس کتابخانه‌ی شرکت ملی نفت ایران و استادیار کتابداری دانشگاه تهران و عضو شورای آموزش کشور می‌شود. [1]
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: سید ابراهیم رئیسی در چه سالی درگذشت؟
# نام انتخاب‌شده: سید ابراهیم رئیسی
# گزینهٔ پیش‌بینی‌شده: 1403
# شاهد (بخش استخراج‌شده):
# او در دوره 1400 - 1403 فعالیت و زیست کرده است. در نهایت در تاریخ 1403 - 05 - 04 از دنیا رفت. [1]
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: حسن روحانی در کجا متولد شده است؟
# نام انتخاب‌شده: حسن روحانی
# گزینهٔ پیش‌بینی‌شده: سمنان
# شاهد (بخش استخراج‌شده):
# حسن روحانی در تاریخ 1948 - 12 - 11 در شهر سرخه واقع در سمنان به دنیا آمد. [1]
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: گوهر خیراندیش در چه سریالی ضور داشته است؟
# نام انتخاب‌شده: گوهر خیراندیش
# گزینهٔ پیش‌بینی‌شده: میوه ممنوعه
# شاهد (بخش استخراج‌شده):
# او در سریال‌هایی مانند «میوه ممنوعه» در سال 1386 حضور داشته است.
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: پژمان جمشیدی از چه سالی به عنوان بازیگر فعالیت میکند؟
# نام انتخاب‌شده: پژمان جمشیدی
# گزینهٔ پیش‌بینی‌شده: 1392
# شاهد (بخش استخراج‌شده):
# از سال 1392 به عنوان بازیگر فعالیت می‌کند.
#
# ——————————————————————————————————————————————————————————————————————————————————————————
# سؤال: کدام آلبوم برای امید حاجیلی است؟
# نام انتخاب‌شده: امید حاجیلی
# گزینهٔ پیش‌بینی‌شده: آلگرو
# شاهد (بخش استخراج‌شده):
# او آلبوم‌های «آلگرو» (1387)، «حاجیلیتو» (1395) و «ترومپت» (1400) منتشر کرد. [1]

# %% [markdown]
# # Evaluation Metrics here

# %%
# ====== Generative evaluation metrics (drop-in) ======
import json
import numpy as np
import pandas as pd
from pathlib import Path

METRICS_JSON = OUT_DIR / "generative_metrics_summary.json"

# %%
# Helpers
def _norm_fn():
    if "normalize_text" in globals():
        return normalize_text
    import re, unicodedata
    ARABIC_TO_PERSIAN = str.maketrans({"ي":"ی","ك":"ک","ة":"ه","ۀ":"ه","ؤ":"و","إ":"ا","أ":"ا","ٱ":"ا","ى":"ی"})
    EASTERN_DIGITS = str.maketrans({"۰":"0","۱":"1","۲":"2","۳":"3","۴":"4","۵":"5","۶":"6","۷":"7","۸":"8","۹":"9",
                                    "٠":"0","١":"1","٢":"2","٣":"3","٤":"4","٥":"5","٦":"6","٧":"7","٨":"8","٩":"9"})
    PUNCT_RE = re.compile(r"[\u200c\u200f\u202a-\u202e\s\-\_]+")
    def _n(s: str) -> str:
        if not isinstance(s, str):
            s = "" if s is None else str(s)
        s = s.translate(ARABIC_TO_PERSIAN)
        s = unicodedata.normalize("NFKC", s)
        s = s.translate(EASTERN_DIGITS)
        s = PUNCT_RE.sub(" ", s).strip().casefold()
        return s
    return _n

NORM = _norm_fn()

def _as_list(x):
    if isinstance(x, list): return x
    if isinstance(x, str):
        try:
            return json.loads(x)
        except Exception:
            try:
                import ast
                return list(ast.literal_eval(x))
            except Exception:
                return [x]
    return []

def _nonempty(s):
    return bool(str(s).strip())

def _appears(haystack, needle):
    return NORM(needle) in NORM(haystack)

# Robust columns
df_eval = df.copy()
if "is_correct" in df_eval.columns:
    df_eval["is_correct"] = pd.to_numeric(df_eval["is_correct"], errors="coerce")

df_eval["has_pred"] = df_eval["predicted_option"].apply(_nonempty)
df_eval["has_gold"] = df_eval["gold_answer"].apply(_nonempty)
df_eval["in_options"] = df_eval.apply(
    lambda r: any(NORM(r.get("predicted_option","")) == NORM(o) for o in _as_list(r.get("options","")) ) if _nonempty(r.get("predicted_option","")) else False,
    axis=1
)
df_eval["has_evidence_text"] = df_eval["evidence_span"].apply(_nonempty)
df_eval["evidence_located"] = df_eval["evidence_ctx_idx"].apply(_nonempty)

# %%
# Evidence–prediction/gold consistency (only where we have evidence located or text)
def _pred_supported(r):
    pred = r.get("predicted_option","")
    if not _nonempty(pred) or not _nonempty(r.get("evidence_span","")): 
        return np.nan
    src_name = r.get("evidence_source_name","")
    src_sum  = r.get("evidence_source_summary","")
    return bool(
        (NORM(pred) and NORM(pred) == NORM(src_name)) or
        _appears(src_sum, pred) or
        _appears(r.get("evidence_span",""), pred)
    )

def _gold_supported(r):
    gold = r.get("gold_answer","")
    if not _nonempty(gold) or not _nonempty(r.get("evidence_span","")): 
        return np.nan
    src_name = r.get("evidence_source_name","")
    src_sum  = r.get("evidence_source_summary","")
    return bool(
        (NORM(gold) and NORM(gold) == NORM(src_name)) or
        _appears(src_sum, gold) or
        _appears(r.get("evidence_span",""), gold)
    )

df_eval["pred_evidence_consistent"] = df_eval.apply(_pred_supported, axis=1)
df_eval["gold_evidence_consistent"] = df_eval.apply(_gold_supported, axis=1)

# %%
# Retrieval ceiling (if ctx_names exists)
if "ctx_names" in df_eval.columns:
    df_eval["ctx_names_list"] = df_eval["ctx_names"].apply(_as_list)
    df_eval["gold_in_ctx"] = df_eval.apply(
        lambda r: any(NORM(r.get("gold_answer","")) == NORM(x) for x in r.get("ctx_names_list", [])) if _nonempty(r.get("gold_answer","")) else np.nan,
        axis=1
    )
else:
    df_eval["gold_in_ctx"] = np.nan

# Buckets
mask_supported   = df_eval["evidence_located"] == True
mask_unsupported = df_eval["evidence_located"] == False
mask_with_gold   = df_eval["has_gold"] == True

def _mean(series):
    s = pd.to_numeric(series, errors="coerce").dropna()
    return float(s.mean()) if len(s) else float("nan")

report = {
    "n_rows": int(len(df_eval)),
    "top1_accuracy": _mean(df_eval["is_correct"]),
    "coverage_predicted": _mean(df_eval["has_pred"]),          # non-empty prediction rate
    "in_options_rate": _mean(df_eval["in_options"]),           # should be ~1.0
    "evidence_text_rate": _mean(df_eval["has_evidence_text"]),
    "evidence_located_rate": _mean(df_eval["evidence_located"]),
    "supported_accuracy": _mean(df_eval.loc[mask_supported, "is_correct"]),
    "unsupported_accuracy": _mean(df_eval.loc[mask_unsupported, "is_correct"]),
    "pred_evidence_consistency_rate": _mean(df_eval["pred_evidence_consistent"]),
    "gold_evidence_consistency_rate": _mean(df_eval.loc[mask_with_gold, "gold_evidence_consistent"]),
    "retrieval_ceiling_gold_in_ctx": _mean(df_eval["gold_in_ctx"]),  # if ctx_names not present -> NaN
}

# %%
print("\n" + "="*70)
print("GENERATIVE EVALUATION (MCQ)")
print("="*70)
print(f"Total rows                     : {report['n_rows']}")
print(f"Top-1 Accuracy                 : {report['top1_accuracy']:.3f}")
print(f"Coverage (predicted non-empty) : {report['coverage_predicted']:.3f}")
print(f"In-Options Rate                : {report['in_options_rate']:.3f}")
print(f"Evidence text present          : {report['evidence_text_rate']:.3f}")
print(f"Evidence located (ctx idx)     : {report['evidence_located_rate']:.3f}")
print(f"Accuracy | Supported (has ev.) : {report['supported_accuracy']:.3f}")
print(f"Accuracy | Unsupported         : {report['unsupported_accuracy']:.3f}")
print(f"Pred↔Evidence consistency      : {report['pred_evidence_consistency_rate']:.3f}")
print(f"Gold↔Evidence consistency      : {report['gold_evidence_consistency_rate']:.3f}")
if not np.isnan(report["retrieval_ceiling_gold_in_ctx"]):
    print(f"Retrieval ceiling (gold in ctx): {report['retrieval_ceiling_gold_in_ctx']:.3f}")
else:
    print(f"Retrieval ceiling (gold in ctx): N/A (ctx_names not in df)")
print("="*70)

# Optional: per-bucket table
bucket_table = pd.DataFrame([
    {
        "bucket": "ALL",
        "count": len(df_eval),
        "acc": _mean(df_eval["is_correct"]),
        "predicted%": _mean(df_eval["has_pred"]),
        "supported%": _mean(df_eval["evidence_located"]),
    },
    {
        "bucket": "SUPPORTED (has evidence)",
        "count": int(mask_supported.sum()),
        "acc": _mean(df_eval.loc[mask_supported, "is_correct"]),
        "predicted%": _mean(df_eval.loc[mask_supported, "has_pred"]),
        "pred-evidence consistency%": _mean(df_eval.loc[mask_supported, "pred_evidence_consistent"]),
    },
    {
        "bucket": "UNSUPPORTED (no evidence)",
        "count": int(mask_unsupported.sum()),
        "acc": _mean(df_eval.loc[mask_unsupported, "is_correct"]),
        "predicted%": _mean(df_eval.loc[mask_unsupported, "has_pred"]),
    },
])
try:
    display(bucket_table)
except Exception:
    print("\n" + bucket_table.to_string(index=False))

# Save summary
with METRICS_JSON.open("w", encoding="utf-8") as f:
    json.dump(report, f, ensure_ascii=False, indent=2)
print("Saved summary ->", METRICS_JSON)
# Out:
# ======================================================================
# GENERATIVE EVALUATION (MCQ)
# ======================================================================
# Total rows                     : 90
# Top-1 Accuracy                 : 0.878
# Coverage (predicted non-empty) : 0.922
# In-Options Rate                : 0.889
# Evidence text present          : 1.000
# Evidence located (ctx idx)     : 0.567
# Accuracy | Supported (has ev.) : 0.961
# Accuracy | Unsupported         : 0.769
# Pred↔Evidence consistency      : 0.747
# Gold↔Evidence consistency      : 0.667
# Retrieval ceiling (gold in ctx): 0.156
# ======================================================================
#                       bucket  count       acc  predicted%  supported%  \
# 0                        ALL     90  0.877778    0.922222    0.566667
# 1   SUPPORTED (has evidence)     51  0.960784    1.000000         NaN
# 2  UNSUPPORTED (no evidence)     39  0.769231    0.820513         NaN
#
#    pred-evidence consistency%
# 0                         NaN
# 1                    0.803922
# 2                         NaN
# Saved summary -> generative_metrics_summary.json

# %% [markdown]
# # Now we're gonna work on questions without option (no MCQ)

# %%
# put this at the very top of your notebook/script
import os, subprocess
from pathlib import Path

def get_repo_root():
    # Try git first
    try:
        root = subprocess.check_output(
            ["git", "rev-parse", "--show-toplevel"],
            stderr=subprocess.DEVNULL, text=True
        ).strip()
        return Path(root)
    except Exception:
        # Fallback: walk up until we see a marker (adjust markers if you like)
        p = Path.cwd()
        for q in [p, *p.parents]:
            if (q/".git").exists() or (q/"apps").exists() or (q/"artifacts").exists() or (q/"rag_out").exists():
                return q
        return p  # last resort

REPO_ROOT = get_repo_root().resolve()
os.chdir(REPO_ROOT)
print("CWD set to repo root:", REPO_ROOT)
# Out:
# CWD set to repo root: E:\Sharif\Term 6\Natural Language Processing\Mashahir_rag_2

# %%
# --- OpenQA input & output paths ---
from pathlib import Path
import json, os

OPENQA_JSON = Path("questions/uni_questions_110.json")
assert OPENQA_JSON.exists(), f"OpenQA file not found: {OPENQA_JSON}"

openqa = json.loads(OPENQA_JSON.read_text(encoding="utf-8"))
print(f"Loaded {len(openqa)} open-ended questions from {OPENQA_JSON}")

RUN_DIR_CANDS = [Path("artifacts/unimodal/runs"), Path("artifacts/notebooks/unimodal/runs")]
OUT_RUN_DIR = next((p for p in RUN_DIR_CANDS if p.exists()), RUN_DIR_CANDS[-1])
OUT_RUN_DIR.mkdir(parents=True, exist_ok=True)

OPENQA_OUT_CSV   = OUT_RUN_DIR / "openqa_outputs.csv"
OPENQA_METRICS   = OUT_RUN_DIR / "openqa_metrics_summary.json"
OPENQA_DETAILSJL = OUT_RUN_DIR / "openqa_details.jsonl"

print("Outputs ->", OPENQA_OUT_CSV, "|", OPENQA_METRICS)
# Out:
# Loaded 110 open-ended questions from questions\uni_questions_110.json
# Outputs -> artifacts\unimodal\runs\openqa_outputs.csv | artifacts\unimodal\runs\openqa_metrics_summary.json

# %% [markdown]
# # Kazem

# %%
from pathlib import Path
import json
from huggingface_hub import snapshot_download

# --- locate artifacts/ robustly (works no matter current working dir) ---
def find_upwards(dirname: str) -> Path:
    p = Path.cwd().resolve()
    while True:
        cand = p / dirname
        if cand.exists():
            return cand
        if p.parent == p:
            raise FileNotFoundError(f"Could not find '{dirname}' upwards from {Path.cwd()}")
        p = p.parent

ARTIFACTS_DIR = find_upwards("artifacts")

# --- project directories based on your tree ---
DATA_RAW        = ARTIFACTS_DIR / "data" / "raw"
DATA_PROCESSED  = ARTIFACTS_DIR / "data" / "processed"
UNIMODAL_DIR    = ARTIFACTS_DIR / "unimodal"
IDX_DIR         = UNIMODAL_DIR / "indexes"
EMB_DIR         = UNIMODAL_DIR / "embeddings"
REPORTS_DIR     = ARTIFACTS_DIR / "reports"
RUNS_DIR        = ARTIFACTS_DIR / "runs"
MODELS_DIR      = UNIMODAL_DIR / "m-e5-base"   # local cache for the encoder

# --- files you mentioned / we will write ---
JSON_IN   = DATA_RAW / "normalized_data_final.json"   # your input JSON (raw)
DOCS_MAP  = DATA_PROCESSED / "docs.jsonl"             # canonical docs map
TEXT_INDEX = IDX_DIR / "faiss_text.idx"               # faiss index file

# ensure dirs exist
for d in [DATA_PROCESSED, IDX_DIR, EMB_DIR, REPORTS_DIR, RUNS_DIR, MODELS_DIR]:
    d.mkdir(parents=True, exist_ok=True)

print("Artifacts root:", ARTIFACTS_DIR.resolve())
print("JSON exists:", JSON_IN.exists(), JSON_IN.resolve())
print("DOCS_MAP will be:", DOCS_MAP.resolve())
print("TEXT_INDEX will be:", TEXT_INDEX.resolve())

# --- download / cache the multilingual-e5 model into artifacts/unimodal/m-e5-base ---
E5_DIR = snapshot_download(
    repo_id="intfloat/multilingual-e5-base",
    local_dir=str(MODELS_DIR),
    local_dir_use_symlinks=False,
    resume_download=True,
)
print("E5 model at:", E5_DIR)

# --- load raw json and write docs.jsonl under artifacts/data/processed ---
with JSON_IN.open("r", encoding="utf-8") as f:
    records = json.load(f)
print(f"Loaded records: {len(records)}")

with DOCS_MAP.open("w", encoding="utf-8") as f:
    for r in records:
        f.write(json.dumps(r, ensure_ascii=False) + "\n")
print(f"Wrote {len(records)} lines to:", DOCS_MAP.resolve())
# Out:
# Artifacts root: E:\Sharif\Term 6\Natural Language Processing\Mashahir_rag_2\artifacts
# JSON exists: False E:\Sharif\Term 6\Natural Language Processing\Mashahir_rag_2\artifacts\data\raw\normalized_data_final.json
# DOCS_MAP will be: E:\Sharif\Term 6\Natural Language Processing\Mashahir_rag_2\artifacts\data\processed\docs.jsonl
# TEXT_INDEX will be: E:\Sharif\Term 6\Natural Language Processing\Mashahir_rag_2\artifacts\unimodal\indexes\faiss_text.idx
# C:\Users\danes\AppData\Roaming\Python\Python311\site-packages\huggingface_hub\file_download.py:982: UserWarning: `local_dir_use_symlinks` parameter is deprecated and will be ignored. The process to download files to a local folder has been updated and do not rely on symlinks anymore. You only need to pass a destination folder as`local_dir`.
# For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/download#download-files-to-local-folder.
#   warnings.warn(
# C:\Users\danes\AppData\Roaming\Python\Python311\site-packages\huggingface_hub\file_download.py:945: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Fetching 22 files:   0%|          | 0/22 [00:00<?, ?it/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# .gitattributes: 0.00B [00:00, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# config.json:   0%|          | 0.00/686 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# special_tokens_map.json:   0%|          | 0.00/280 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/418 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# openvino_model.xml: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model_O4.onnx:   0%|          | 0.00/555M [00:00<?, ?B/s]
# openvino_model.bin:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# model.onnx:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# model_qint8_avx512_vnni.onnx:   0%|          | 0.00/279M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# Error while downloading from https://huggingface.co/intfloat/multilingual-e5-base/resolve/835193815a3936a24a0ee7dc9e3d48c1fbb19c55/onnx/tokenizer.json: HTTPSConnectionPool(host='cas-bridge.xethub.hf.co', port=443): Read timed out.
# Trying to resume download...
# Error while downloading from https://huggingface.co/intfloat/multilingual-e5-base/resolve/835193815a3936a24a0ee7dc9e3d48c1fbb19c55/pytorch_model.bin: HTTPSConnectionPool(host='cas-bridge.xethub.hf.co', port=443): Read timed out.
# Trying to resume download...
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# Error while downloading from https://huggingface.co/intfloat/multilingual-e5-base/resolve/835193815a3936a24a0ee7dc9e3d48c1fbb19c55/onnx/sentencepiece.bpe.model: HTTPSConnectionPool(host='cas-bridge.xethub.hf.co', port=443): Read timed out.
# Trying to resume download...
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Error while downloading from https://huggingface.co/intfloat/multilingual-e5-base/resolve/835193815a3936a24a0ee7dc9e3d48c1fbb19c55/onnx/model_qint8_avx512_vnni.onnx: HTTPSConnectionPool(host='cas-bridge.xethub.hf.co', port=443): Read timed out.
# Trying to resume download...
# Error while downloading from https://huggingface.co/intfloat/multilingual-e5-base/resolve/835193815a3936a24a0ee7dc9e3d48c1fbb19c55/onnx/model.onnx: HTTPSConnectionPool(host='cas-bridge.xethub.hf.co', port=443): Read timed out.
# Trying to resume download...
# model_qint8_avx512_vnni.onnx:   0%|          | 0.00/279M [00:00<?, ?B/s]
# model.onnx:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# Error while downloading from https://huggingface.co/intfloat/multilingual-e5-base/resolve/835193815a3936a24a0ee7dc9e3d48c1fbb19c55/onnx/tokenizer.json: HTTPSConnectionPool(host='cas-bridge.xethub.hf.co', port=443): Read timed out.
# Trying to resume download...
# Error while downloading from https://huggingface.co/intfloat/multilingual-e5-base/resolve/835193815a3936a24a0ee7dc9e3d48c1fbb19c55/onnx/model_qint8_avx512_vnni.onnx: The operation did not complete (read) (_ssl.c:2580)
# Trying to resume download...
# model_qint8_avx512_vnni.onnx:   0%|          | 0.00/279M [00:00<?, ?B/s]
