# %% [markdown]
# # Merging same-category files

# %%
import json
from pathlib import Path
from typing import Any, Dict, List, Tuple

# %%
def normalize_name(name) -> str:
    """
    Normalize name to a comparable lowercase string.
    - If list: pick the first non-empty string.
    - If non-string: coerce to string.
    """
    if isinstance(name, list):
        for v in name:
            if isinstance(v, str) and v.strip():
                s = v
                break
        else:
            s = ""
    elif isinstance(name, str):
        s = name
    else:
        s = "" if name is None else str(name)
    return s.strip().casefold()

def is_empty(val: Any) -> bool:
    if val is None:
        return True
    if isinstance(val, str) and val.strip() == "":
        return True
    if isinstance(val, (list, tuple, set)) and len(val) == 0:
        return True
    if isinstance(val, dict) and len(val) == 0:
        return True
    return False

def as_image_dict(img: Any) -> Dict[str, Any]:
    """
    Normalize an image field to a dict:
    - dict -> dict
    - list/str/number -> {"_value": <that>}
    - None/empty -> {}
    """
    if isinstance(img, dict):
        return {k: v for k, v in img.items() if not is_empty(v)}
    if is_empty(img):
        return {}
    return {"_value": img}

def dedup_list(lst: List[Any]) -> List[Any]:
    seen = set()
    out = []
    for item in lst:
        key = json.dumps(item, sort_keys=True) if isinstance(item, (dict, list)) else item
        if key not in seen:
            seen.add(key)
            out.append(item)
    return out

def merge_values(v1: Any, v2: Any) -> Any:
    """Best-effort union for values under image keys."""
    if is_empty(v1):
        return v2
    if is_empty(v2):
        return v1

    if isinstance(v1, dict) and isinstance(v2, dict):
        return merge_dicts(v1, v2)

    if isinstance(v1, list) and isinstance(v2, list):
        return dedup_list(v1 + v2)

    if isinstance(v1, list) and not isinstance(v2, list):
        return dedup_list(v1 + [v2])

    if isinstance(v2, list) and not isinstance(v1, list):
        return dedup_list([v1] + v2)

    # scalars unequal -> keep both
    if v1 != v2:
        return dedup_list([v1, v2])

    return v1

def merge_dicts(d1: Dict[str, Any], d2: Dict[str, Any]) -> Dict[str, Any]:
    keys = set(d1) | set(d2)
    out = {}
    for k in keys:
        merged = merge_values(d1.get(k), d2.get(k))
        if not is_empty(merged):
            out[k] = merged
    return out

def merge_image(img1: Any, img2: Any) -> Dict[str, Any]:
    d1 = as_image_dict(img1)
    d2 = as_image_dict(img2)
    return merge_dicts(d1, d2)

def load_by_name(path: str) -> Tuple[Dict[str, dict], List[dict]]:
    with open(path, "r", encoding="utf-8") as f:
        data = json.load(f)
    index = {}
    for rec in data:
        if not isinstance(rec, dict):
            continue
        key = normalize_name(rec.get("name"))
        if key:
            index[key] = rec
    return index, data

def write_json(path: str, data: Any):
    with open(path, "w", encoding="utf-8") as f:
        json.dump(data, f, ensure_ascii=False, indent=2)

# %%
def merge_pair(file_a: str, file_b: str, out_path: str):
    a_idx, a_list = load_by_name(file_a)
    b_idx, b_list = load_by_name(file_b)

    a_keys = set(a_idx)
    b_keys = set(b_idx)
    dup_keys = sorted(a_keys & b_keys)
    only_a  = sorted(a_keys - b_keys)
    only_b  = sorted(b_keys - a_keys)

    merged_records = []

    # Build quick lookups to preserve original 'name' strings
    def original_name(key):
        return (a_idx.get(key) or b_idx.get(key)).get("name")

    # duplicates → keep only name + merged image
    dup_report = []
    both_img = a_only_img = b_only_img = neither_img = 0

    for k in dup_keys:
        ra = a_idx[k]
        rb = b_idx[k]
        img_a = ra.get("image")
        img_b = rb.get("image")

        has_a = not is_empty(as_image_dict(img_a))
        has_b = not is_empty(as_image_dict(img_b))
        if has_a and has_b:
            both_img += 1
        elif has_a and not has_b:
            a_only_img += 1
        elif has_b and not has_a:
            b_only_img += 1
        else:
            neither_img += 1

        merged_img = merge_image(img_a, img_b)
        added_keys = sorted(set(as_image_dict(img_b)) - set(as_image_dict(img_a)))

        merged_records.append({
            "name": ra.get("name") or rb.get("name"),
            "image": merged_img
        })

        dup_report.append({
            "name": ra.get("name") or rb.get("name"),
            "from_file_a": file_a,
            "from_file_b": file_b,
            "image_a_keys": sorted(list(as_image_dict(img_a).keys())),
            "image_b_keys": sorted(list(as_image_dict(img_b).keys())),
            "added_keys_from_b": added_keys,
            "merged_image_keys": sorted(list(merged_img.keys()))
        })

    # uniques → keep record as-is
    for k in only_a:
        merged_records.append(a_idx[k])
    for k in only_b:
        merged_records.append(b_idx[k])

    # Sort final output deterministically by normalized name
    merged_records.sort(key=lambda r: normalize_name(r.get("name")))

    # write output
    write_json(out_path, merged_records)

    # report
    report = {
        "pair": [file_a, file_b],
        "input_counts": {
            Path(file_a).name: len(a_list),
            Path(file_b).name: len(b_list),
        },
        "name_key_stats": {
            "duplicates": len(dup_keys),
            "only_in_" + Path(file_a).name: len(only_a),
            "only_in_" + Path(file_b).name: len(only_b),
        },
        "duplicate_image_breakdown": {
            "both_have_image": both_img,
            "only_first_has_image": a_only_img,
            "only_second_has_image": b_only_img,
            "neither_has_image": neither_img,
        },
        "output_count": len(merged_records),
        "duplicates_detail": dup_report,  # full per-duplicate info
    }

    # pretty print report
    print("\n" + "="*80)
    print(f"Merged: {file_a}  +  {file_b}  →  {out_path}")
    print("-"*80)
    print("Inputs:")
    for k, v in report["input_counts"].items():
        print(f"  {k}: {v}")
    print("Name-key stats:")
    for k, v in report["name_key_stats"].items():
        print(f"  {k}: {v}")
    print("Duplicate image breakdown:")
    for k, v in report["duplicate_image_breakdown"].items():
        print(f"  {k}: {v}")
    print(f"Output records: {report['output_count']}")
    print("-"*80)
    print("Duplicates detail (name | added_keys_from_second | merged_keys):")
    for row in report["duplicates_detail"]:
        print(f"  - {row['name']} | +{row['added_keys_from_b']} | merged={row['merged_image_keys']}")
    print("="*80 + "\n")

    # Also write JSON report next to the merged file (optional but handy)
    report_path = Path(out_path).with_suffix(".report.json")
    write_json(str(report_path), report)

    return report

# %%
poets_report = merge_pair("poets20.json",      "poets22.json",      "poets_merged.json")
scis_report  = merge_pair("scientists15.json", "scientists21.json", "scientists_merged.json")
# Out:
# ================================================================================
# Merged: poets20.json  +  poets22.json  →  poets_merged.json
# --------------------------------------------------------------------------------
# Inputs:
#   poets20.json: 284
#   poets22.json: 26
# Name-key stats:
#   duplicates: 9
#   only_in_poets20.json: 263
#   only_in_poets22.json: 17
# Duplicate image breakdown:
#   both_have_image: 9
#   only_first_has_image: 0
#   only_second_has_image: 0
#   neither_has_image: 0
# Output records: 289
# --------------------------------------------------------------------------------
# Duplicates detail (name | added_keys_from_second | merged_keys):
#   - احمد شاملو | +['adult'] | merged=['adult', 'tomb', 'young']
#   - جامی | +['adult'] | merged=['adult', 'tomb']
#   - خواجه عبدالله انصاری | +['adult'] | merged=['adult', 'young']
#   - رهی معیری | +[] | merged=['adult', 'tomb']
#   - عطار | +['adult'] | merged=['adult', 'tomb']
#   - قطران تبریزی | +['adult'] | merged=['adult', 'tomb']
#   - مولوی | +['adult'] | merged=['adult', 'tomb', 'young']
#   - وصال شیرازی | +['adult'] | merged=['adult', 'tomb']
#   - کمال خجندی | +[] | merged=['adult']
# ================================================================================
#
#
# ================================================================================
# Merged: scientists15.json  +  scientists21.json  →  scientists_merged.json
# --------------------------------------------------------------------------------
# Inputs:
#   scientists15.json: 46
#   scientists21.json: 198
# Name-key stats:
#   duplicates: 0
#   only_in_scientists15.json: 44
#   only_in_scientists21.json: 197
# Duplicate image breakdown:
#   both_have_image: 0
#   only_first_has_image: 0
#   only_second_has_image: 0
#   neither_has_image: 0
# Output records: 241
# --------------------------------------------------------------------------------
# Duplicates detail (name | added_keys_from_second | merged_keys):
# ================================================================================

# %% [markdown]
# # Merging narratives and add them to json as "summary"

# %%
import csv
import json
from pathlib import Path
from collections import defaultdict, Counter

# %%
POET_JSON_IN  = "poets_merged.json"
SCIS_JSON_IN  = "scientists_merged.json"
ART_MUSIC_JSON_IN = "art_music.json"
POET_JSON_OUT = "poets_merged_with_bios.json"
SCIS_JSON_OUT = "scientists_merged_with_bios.json"
ART_MUSIC_JSON_OUT = "art_music_with_bios.json"

POET_CSVS = ["poets_biography_1.csv", "poets_biography_2.csv"]
SCIS_CSVS = ["scientists_biography_1.csv", "scientists_biography_2.csv"]
ART_MUSIC_CSVS = ["art_music_biography.csv"]

# %%
def normalize_name(name: str) -> str:
    """Use exactly the same normalization you used for JSON merges."""
    return (name or "").strip().casefold()

def extract_name_from_bio(text: str):
    """
    Given a biography string like '{name} ، ...', return (name, biography_text).
    If '،' not found, returns (None, text) so caller can ignore that row.
    """
    if not isinstance(text, str):
        return None, text
    if "،" not in text:
        return None, text
    name = text.split("،", 1)[0].strip()
    return (name if name else None), text.strip()

def iter_bio_texts_from_csv(csv_path: str):
    """
    Read a CSV and yield biography strings. We:
      - prefer any cell that contains '،'
      - otherwise join non-empty cells (but then we require '،' in the final string)
    Rows without '،' are ignored.
    """
    with open(csv_path, "r", encoding="utf-8-sig", newline="") as f:
        rdr = csv.reader(f)
        for row in rdr:
            if not row:
                continue
            # Prefer the cell(s) that contain the Persian comma
            candidates = [c for c in row if isinstance(c, str) and "،" in c]
            if candidates:
                text = max(candidates, key=len).strip()
            else:
                text = " ".join([c for c in row if isinstance(c, str) and c.strip()]).strip()
            if "،" not in text or not text:
                continue
            yield text

def load_bios_grouped_by_name(csv_paths):
    """
    Build dict: normalized_name -> list of biography strings (order preserved).
    If same name appears multiple times across files, we keep all (first-file-first).
    """
    grouped = defaultdict(list)
    order_counter = Counter()
    for p in csv_paths:
        for text in iter_bio_texts_from_csv(p):
            name, bio = extract_name_from_bio(text)
            if not name:
                continue
            key = normalize_name(name)
            grouped[key].append(bio)
            order_counter[key] += 1
    return grouped, order_counter  # second value is how many bios per name (for diagnostics)

def index_json_by_name(json_path: str):
    """Load JSON array and return (records_list, index_by_normalized_name)."""
    with open(json_path, "r", encoding="utf-8") as f:
        data = json.load(f)
    index = {}
    for rec in data:
        nm = rec.get("name")
        if isinstance(nm, str) and nm.strip():
            index[normalize_name(nm)] = rec
    return data, index

def attach_bios(records, index_by_name, bios_by_name):
    """
    Attach biographies to the next available summary field per record:
    summary -> summary2 -> summary3. Stop after summary3.
    Returns a report dict with counts and unfound names.
    """
    added_summary = added_summary2 = added_summary3 = 0
    unfound = []
    skipped_extra = 0  # bios that we couldn't add because summary3 already existed

    for key, bio_list in bios_by_name.items():
        rec = index_by_name.get(key)
        if rec is None:
            unfound.append(key)
            continue

        for bio in bio_list:
            if "summary" not in rec or rec.get("summary") in (None, ""):
                rec["summary"] = bio
                added_summary += 1
            elif "summary2" not in rec or rec.get("summary2") in (None, ""):
                rec["summary2"] = bio
                added_summary2 += 1
            elif "summary3" not in rec or rec.get("summary3") in (None, ""):
                rec["summary3"] = bio
                added_summary3 += 1
            else:
                skipped_extra += 1
                # Do not add beyond summary3

    return {
        "added_summary": added_summary,
        "added_summary2": added_summary2,
        "added_summary3": added_summary3,
        "skipped_extra_bios": skipped_extra,
        "unfound_count": len(unfound),
        "unfound_names_sample": unfound[:20],  # preview a few
    }

def write_json(path: str, data):
    with open(path, "w", encoding="utf-8") as f:
        json.dump(data, f, ensure_ascii=False, indent=2)

def run_pipeline(kind: str, json_in: str, json_out: str, csvs: list):
    print("\n" + "="*88)
    print(f"{kind.upper()} — Merging narratives into JSON")
    print("="*88)

    # 1) Load and group biographies
    bios_by_name, dup_counter = load_bios_grouped_by_name(csvs)
    total_bio_rows = sum(dup_counter.values())
    multi_bio_names = {k: c for k, c in dup_counter.items() if c > 1}

    print(f"CSV inputs: {', '.join(csvs)}")
    print(f"Biographies parsed (rows with '،'): {total_bio_rows}")
    print(f"Unique names in CSVs: {len(bios_by_name)}")
    if multi_bio_names:
        print(f"Names with multiple bios: {len(multi_bio_names)} (first few: "
              f"{', '.join(list(multi_bio_names.keys())[:10])})")

    # 2) Load JSON + index by normalized name
    records, index_by_name = index_json_by_name(json_in)
    print(f"JSON input: {json_in} | records: {len(records)} | indexable by name: {len(index_by_name)}")

    # 3) Attach bios to summary fields
    rep = attach_bios(records, index_by_name, bios_by_name)

    # 4) Save output
    write_json(json_out, records)

    # 5) Report
    print("-"*88)
    print(f"Added summary fields:")
    print(f"  summary : {rep['added_summary']}")
    print(f"  summary2: {rep['added_summary2']}")
    print(f"  summary3: {rep['added_summary3']}")
    print(f"Skipped extra bios (already had summary3): {rep['skipped_extra_bios']}")
    print(f"Unfound narrative records: {rep['unfound_count']}")
    if rep["unfound_names_sample"]:
        print(f"Examples (normalized): {rep['unfound_names_sample']}")
    print(f"Output written to: {json_out}")
    print("="*88 + "\n")

# %%
run_pipeline("poets",      POET_JSON_IN, POET_JSON_OUT, POET_CSVS)
run_pipeline("scientists", SCIS_JSON_IN, SCIS_JSON_OUT, SCIS_CSVS)
run_pipeline("art_music",  ART_MUSIC_JSON_IN, ART_MUSIC_JSON_OUT, ART_MUSIC_CSVS)
# Out:
# ========================================================================================
# POETS — Merging narratives into JSON
# ========================================================================================
# CSV inputs: poets_biography_1.csv, poets_biography_2.csv
# Biographies parsed (rows with '،'): 733
# Unique names in CSVs: 645
# Names with multiple bios: 83 (first few: شاه نعمت‌الله ولی, مهدیه الهی قمشه‌ای, رودکی, شکوه قاسم‌نیا, عمعق بخاری, قاسم انوار, بابا فغانی شیرازی, ایرج میرزا, پروین اعتصامی, محمدتقی بهار)
# JSON input: poets_merged.json | records: 289 | indexable by name: 289
# ----------------------------------------------------------------------------------------
# Added summary fields:
#   summary : 209
#   summary2: 56
#   summary3: 4
# Skipped extra bios (already had summary3): 1
# Unfound narrative records: 436
# Examples (normalized): ['افضل\u200cالدین بدیل بن علی خاقانی شروانی', 'رکن\u200cالدین اوحدی مراغه\u200cای', 'محمد بن حسام\u200cالدین حسن بن شمس\u200cالدین محمد خوسفی', 'نورالدین عبدالرحمن ابن نظام\u200cالدین احمد ابن محمد', 'بهاءالدین محمد عاملی', 'ابوالحسن فراهانی در شهر فراهان متولد شد و در سال ۱۰۴۰ خورشیدی درگذشت. او در قرن یازدهم هجری به عنوان شاعر فعالیت می\u200cکرد و اثر برجسته\u200cاش', 'ملا فتح\u200cالله وفایی شوشتری', 'جهان\u200cملک خاتون در سده هشتم هجری به عنوان شاعری برجسته فعالیت می\u200cکرد و آثاری چون غزل', 'مهدیه الهی قمشه\u200cای', 'علی سعیدی در سال ۱۲۵۹ خورشیدی در شهر ساوه', 'سهیل محمودی در ۲۷ دی ۱۳۳۹ خورشیدی در شهر تهران متولد شد. او به عنوان شاعر', 'سلمان هراتی در ۱ فروردین ۱۳۳۸ خورشیدی در شهر تنکابن', 'فریاد شیری در سال ۱۳۵۰ خورشیدی در شهر صحنه متولد شد. او به عنوان شاعر', 'جهانبخش پازوکی در ۴ خرداد ۱۳۱۶ خورشیدی در شهر شیراز', 'لطیف پدرام در سال ۱۳۴۲ خورشیدی در استان بدخشان متولد شد. او به عنوان سیاستمدار', 'قنبرعلی تابش در ۱۰ آذر ۱۳۴۹ خورشیدی در شهر جاغوری', 'حسنیه عثمان در سال ۱۳۴۰ خورشیدی در شهر کابل متولد شد. او به عنوان شاعر', 'نادیه فضل در بهار ۱۳۴۵ خورشیدی در شهر کابل متولد شد. او به عنوان شاعر', 'ضیا قاری\u200cزاده در سال ۱۳۰۱ خورشیدی متولد شد. او به عنوان شاعر', 'یوسف کهزاد در سال ۱۳۱۳ خورشیدی در شهر کابل متولد شد. او به عنوان شاعر']
# Output written to: poets_merged_with_bios.json
# ========================================================================================
#
#
# ========================================================================================
# SCIENTISTS — Merging narratives into JSON
# ========================================================================================
# CSV inputs: scientists_biography_1.csv, scientists_biography_2.csv
# Biographies parsed (rows with '،'): 1004
# Unique names in CSVs: 900
# Names with multiple bios: 92 (first few: جواد حیات, امید کردستانی, محسن مصطفوی, کاوه پهلوان, تفتازانی, ابومحمد الحسن بن موسی النوبختی, ابویعقوب اسحاق بن احمد سجستانی, شهاب‌الدین سهروردی, نادیا مفتونی, رضا داوری اردکانی)
# JSON input: scientists_merged.json | records: 241 | indexable by name: 241
# ----------------------------------------------------------------------------------------
# Added summary fields:
#   summary : 132
#   summary2: 26
#   summary3: 4
# Skipped extra bios (already had summary3): 2
# Unfound narrative records: 768
# Examples (normalized): ['منوچهر اقبال', 'جواد حیات', 'جمال\u200cالدین مستغیمی', 'یاسمین مستوفی', 'فرخ\u200cرو پارسا', 'سکینه پری', 'غلامحسین ساعدی', 'کاظم سامی', 'بدر تیمورتاش', 'بهنام آزهنگ', 'مجید عزیزاده', 'عباس امانت', 'مهیار آ. اموزگار', 'نیما ارکانی\u200cحامد', 'رضا امراللهی', 'مهدی بهادری', 'حسین بهاروند', 'آصف بیات', 'علی جعفری', 'همایون کاظرونی']
# Output written to: scientists_merged_with_bios.json
# ========================================================================================
#
#
# ========================================================================================
# ART_MUSIC — Merging narratives into JSON
# ========================================================================================
# CSV inputs: art_music_biography.csv
# Biographies parsed (rows with '،'): 1859
# Unique names in CSVs: 706
# Names with multiple bios: 229 (first few: کامشاد کوشان, ایران دفتری, فتح‌الله منوچهری, چکامه چمن‌ماه, عباس غزالی, پیام نادری دهکردی, شهرام حقیقت‌دوست, ابراهیم فخار کاشانی, مه‌لقا باقری, سیامک انصاری)
# JSON input: art_music.json | records: 1338 | indexable by name: 1268
# ----------------------------------------------------------------------------------------
# Added summary fields:
#   summary : 470
#   summary2: 178
#   summary3: 149
# Skipped extra bios (already had summary3): 547
# Unfound narrative records: 236
# Examples (normalized): ['ابراهیم فخار کاشانی', 'امیرعلی نبویان', 'انوش معظمی', 'بهناز جعفری', 'پردیس احمدیه', 'پژمان بازغی', 'پیمان معادی', 'جواد عزتی', 'حامد بهداد', 'حسن معجونی', 'رامبد جوان', 'رویا تیموریان', 'رویا نونهالی', 'سپیده اعلایی', 'بهمن فرسی', 'امیرعباس گلاب', 'فرمان فتحعلیان', 'حمیدرضا طالب\u200cزاده', 'فتانه ولیدی', 'حمید فرخ\u200cنژاد']
# Output written to: art_music_with_bios.json
# ========================================================================================

# %%
FILES = [
    "poets_merged_with_bios.json",
    "scientists_merged_with_bios.json",
    "art_music_with_bios.json"
]

def filled(x):
    """True if a value is a non-empty, non-whitespace string."""
    return isinstance(x, str) and x.strip() != ""

def summarize_file(path: Path):
    with path.open("r", encoding="utf-8") as f:
        data = json.load(f)

    c_summary = c_summary2 = c_summary3 = c_without_any = 0

    for rec in data:
        s1 = filled(rec.get("summary"))
        s2 = filled(rec.get("summary2"))
        s3 = filled(rec.get("summary3"))

        if s1: c_summary += 1
        if s2: c_summary2 += 1
        if s3: c_summary3 += 1
        if not (s1 or s2 or s3):
            c_without_any += 1

    return {
        "file": path.name,
        "total": len(data),
        "summary": c_summary,
        "summary2": c_summary2,
        "summary3": c_summary3,
        "without_any_summary": c_without_any,
    }

reports = []
for fname in FILES:
    p = Path(fname)
    if p.exists():
        rep = summarize_file(p)
        reports.append(rep)
    else:
        print(f"⚠️  Skipping (not found): {fname}")

# Print per-file and totals
totals = {"total": 0, "summary": 0, "summary2": 0, "summary3": 0, "without_any_summary": 0}

for r in reports:
    print("\n" + "="*70)
    print(f"File: {r['file']}")
    print("-"*70)
    print(f"Total records:           {r['total']}")
    print(f"With summary:            {r['summary']}")
    print(f"With summary2:           {r['summary2']}")
    print(f"With summary3:           {r['summary3']}")
    print(f"Without any summary*:    {r['without_any_summary']}")
    print("="*70)

    for k in totals:
        totals[k] += r[k] if k in r else 0

if reports:
    print("\n" + "#"*70)
    print("AGGREGATE TOTALS (all processed files)")
    print("#"*70)
    print(f"Total records:           {totals['total']}")
    print(f"With summary:            {totals['summary']}")
    print(f"With summary2:           {totals['summary2']}")
    print(f"With summary3:           {totals['summary3']}")
    print(f"Without any summary*:    {totals['without_any_summary']}")
    print("#"*70)
else:
    print("No files processed.")
# Out:
# ======================================================================
# File: poets_merged_with_bios.json
# ----------------------------------------------------------------------
# Total records:           289
# With summary:            209
# With summary2:           56
# With summary3:           4
# Without any summary*:    80
# ======================================================================
#
# ======================================================================
# File: scientists_merged_with_bios.json
# ----------------------------------------------------------------------
# Total records:           241
# With summary:            132
# With summary2:           26
# With summary3:           4
# Without any summary*:    109
# ======================================================================
#
# ======================================================================
# File: art_music_with_bios.json
# ----------------------------------------------------------------------
# Total records:           1338
# With summary:            470
# With summary2:           178
# With summary3:           149
# Without any summary*:    868
# ======================================================================
#
# ######################################################################
# AGGREGATE TOTALS (all processed files)
# ######################################################################
# Total records:           1868
# With summary:            811
# With summary2:           260
# With summary3:           157
# Without any summary*:    1057
# ######################################################################

# %% [markdown]
# # Try to download images

# %%
import os
import re
import json
import time
import random
import urllib.request
import urllib.parse
from io import BytesIO
from PIL import Image
from pathlib import Path

# %%
INPUTS = [
    {
        "json_in":  "scientists_merged_with_bios.json",
        "json_out": "scientists_merged_with_bios_imaged.json",
        "img_dir":  "scientists_images",
    },
    {
        "json_in":  "poets_merged_with_bios.json",
        "json_out": "poets_merged_with_bios_imaged.json",
        "img_dir":  "poets_images",
    },
]

# %%
FIELDS_WHITELIST = None  # or set to a set of keys

# Polite UA
HEADERS = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/115.0.0.0 Safari/537.36"
    )
}

# %%
URL_RE = re.compile(r"^https?://", re.IGNORECASE)
GENERIC_URL_KEYS = {"url", "href", "src", "link"}
IMG_EXTS = {".jpg", ".jpeg", ".png", ".webp", ".gif", ".tif", ".tiff", ".bmp", ".svg"}

def sanitize_filename(s: str) -> str:
    s = (str(s) or "").strip()
    s = re.sub(r"\s+", "_", s)
    s = re.sub(r"[^\w\-.]+", "", s)
    return s or "image"

def http_open(url, timeout=35):
    req = urllib.request.Request(url, headers=HEADERS)
    return urllib.request.urlopen(req, timeout=timeout)

def is_direct_image_url(url: str) -> bool:
    u = urllib.parse.urlparse(url)
    ext = os.path.splitext(u.path)[1].lower()
    return (ext in IMG_EXTS) or ("upload.wikimedia.org" in u.netloc.lower())

def from_wikimedia_thumb_to_original(url: str) -> str:
    parts = urllib.parse.urlparse(url)
    path = parts.path
    if "/thumb/" in path:
        base, tail = path.split("/thumb/", 1)
        segs = tail.split("/")
        if len(segs) >= 2:
            orig_path = base + "/" + "/".join(segs[:-1])
            return urllib.parse.urlunparse(parts._replace(path=orig_path))
    return url

def read_text(url, timeout=35, encoding="utf-8"):
    with http_open(url, timeout) as resp:
        data = resp.read()
    try:
        return data.decode(encoding, errors="ignore")
    except Exception:
        return data.decode("utf-8", errors="ignore")

def wiki_api_request(base, params):
    qs = urllib.parse.urlencode(params)
    url = f"{base}?{qs}"
    try:
        txt = read_text(url)
        return json.loads(txt)
    except Exception:
        return {}

def parse_wiki_title(u):
    parsed = urllib.parse.urlparse(u)
    if "/wiki/" not in parsed.path:
        return parsed.netloc, None
    title = urllib.parse.unquote(parsed.path.split("/wiki/", 1)[1])
    return parsed.netloc, title

def to_canonical_file_title(title):
    if not title or ":" not in title:
        return None
    name = title.split(":", 1)[1]
    return "File:" + name

def resolve_wikipedia_article_image(article_url: str) -> str or None:
    host, title = parse_wiki_title(article_url)
    if not title:
        return None
    api_base = f"https://{host}/w/api.php"
    params = {
        "action": "query",
        "titles": title,
        "prop": "pageimages",
        "piprop": "original",
        "format": "json",
    }
    data = wiki_api_request(api_base, params)
    pages = (data.get("query") or {}).get("pages") or {}
    for _, pg in pages.items():
        orig = pg.get("original")
        if orig and orig.get("source"):
            return orig["source"]
    return None

# Common localized "File:" prefixes (handles fa: پرونده / فایل)
FILE_NS_PREFIXES = {"file", "پرونده", "فایل", "fichier", "datei", "archivo", "arquivo", "dosya", "файл", "ファイル", "文件", "檔案", "파일"}

def resolve_wiki_file_image(file_page_url: str) -> str or None:
    host, title = parse_wiki_title(file_page_url)
    if not title:
        return None
    prefix = title.split(":", 1)[0].lower()
    looks_file_ns = (":" in title) and (prefix in FILE_NS_PREFIXES or "." in title)
    if looks_file_ns:
        title = to_canonical_file_title(title) or title

    api_base = f"https://{host}/w/api.php"
    params = {
        "action": "query",
        "titles": title,
        "prop": "imageinfo",
        "iiprop": "url|mime",
        "format": "json",
    }
    data = wiki_api_request(api_base, params)
    pages = (data.get("query") or {}).get("pages") or {}
    for _, pg in pages.items():
        infos = pg.get("imageinfo") or []
        if infos and "url" in infos[0]:
            return infos[0]["url"]
    # Fallback via Special:FilePath (will redirect to the file)
    base_name = title.split(":", 1)[1] if ":" in title else title
    for host_try in (host, "commons.wikimedia.org"):
        c = f"https://{host_try}/wiki/Special:FilePath/{urllib.parse.quote(base_name)}"
        try:
            with http_open(c) as resp:
                ctype = (resp.headers.get("Content-Type") or "").lower()
                if ctype.startswith("image/"):
                    return c
        except Exception:
            pass
    return None

def resolve_og_image(page_url: str) -> str or None:
    try:
        html = read_text(page_url)
    except Exception:
        return None
    m = re.search(r'<meta\s+property=["\']og:image["\']\s+content=["\']([^"\']+)["\']', html, re.IGNORECASE)
    if m:
        img = m.group(1)
        if "upload.wikimedia.org" in img and "/thumb/" in img:
            img = from_wikimedia_thumb_to_original(img)
        return img
    return None

def basename_from_url(url: str) -> str:
    p = urllib.parse.urlparse(url)
    return os.path.basename(p.path)

def svg_to_png_thumbnail(file_name: str, prefer_host: str = "commons.wikimedia.org", width: int = 1200) -> str:
    quoted = urllib.parse.quote(file_name)
    return f"https://{prefer_host}/wiki/Special:FilePath/{quoted}?width={width}"

def resolve_to_direct_images(url: str) -> list:
    """
    Return a list of direct image URLs (best-effort).
    We will try them in order until one downloads successfully.
    """
    out = []
    if is_direct_image_url(url):
        ubase = basename_from_url(url).lower()
        if ubase.endswith(".svg"):
            out.append(svg_to_png_thumbnail(ubase))
        else:
            out.append(from_wikimedia_thumb_to_original(url))
        return out

    u = urllib.parse.urlparse(url)
    host = u.netloc.lower()
    path = u.path
    is_wikipedia = host.endswith(".wikipedia.org")
    is_commons   = (host == "commons.wikimedia.org")

    if (is_wikipedia or is_commons) and "/wiki/" in path:
        f = resolve_wiki_file_image(url)
        if f:
            if f.lower().endswith(".svg"):
                out.append(svg_to_png_thumbnail(basename_from_url(f)))
            else:
                out.append(f)
            return out
        a = resolve_wikipedia_article_image(url)
        if a:
            if a.lower().endswith(".svg"):
                out.append(svg_to_png_thumbnail(basename_from_url(a)))
            else:
                out.append(a)
            return out

    og = resolve_og_image(url)
    if og:
        if og.lower().endswith(".svg"):
            out.append(svg_to_png_thumbnail(basename_from_url(og)))
        else:
            out.append(og)
    return out

def download_image(url, image_path):
    try:
        with http_open(url, timeout=35) as resp:
            final_url = resp.geturl()
            ctype = (resp.headers.get("Content-Type") or "").lower()
            if not ctype.startswith("image/"):
                # try following redirect target explicitly once
                with http_open(final_url, timeout=35) as resp2:
                    ctype2 = (resp2.headers.get("Content-Type") or "").lower()
                    if not ctype2.startswith("image/"):
                        return False
                    data = resp2.read()
            else:
                data = resp.read()

        img = Image.open(BytesIO(data))
        if img.mode not in ("RGB", "L"):
            img = img.convert("RGB")
        elif img.mode == "L":
            img = img.convert("RGB")
        img.save(image_path, format="JPEG", quality=92)
        return True
    except Exception:
        return False

def iter_urls(obj):
    """Yield all URL-like strings found recursively in obj."""
    if obj is None:
        return
    if isinstance(obj, str):
        s = obj.strip()
        if URL_RE.match(s):
            yield s
        return
    if isinstance(obj, dict):
        for v in obj.values():
            yield from iter_urls(v)
    elif isinstance(obj, (list, tuple, set)):
        for v in obj:
            yield from iter_urls(v)

# %%
for pack in INPUTS:
    json_in  = Path(pack["json_in"])
    json_out = Path(pack["json_out"])
    img_dir  = Path(pack["img_dir"])
    if not json_in.exists():
        print(f"⚠️  Skipping (missing): {json_in}")
        continue

    img_dir.mkdir(parents=True, exist_ok=True)

    with json_in.open("r", encoding="utf-8") as f:
        records = json.load(f)

    downloaded_true = 0
    downloaded_false = 0

    print("\n" + "="*100)
    print(f"PROCESSING FILE: {json_in.name}")
    print("="*100)

    for idx, rec in enumerate(records):
        name = rec.get("name") or f"record_{idx}"
        name_safe = sanitize_filename(name)
        image_obj = rec.get("image")

        print(f"\n[{idx}] {name}")
        record_ok = False
        any_urls_found = False

        if isinstance(image_obj, dict) and image_obj:
            image_fields = list(image_obj.keys())
            if FIELDS_WHITELIST:
                image_fields = [k for k in image_fields if k in FIELDS_WHITELIST]

            if not image_fields:
                print("  ⚠️ image object present but no fields to check (whitelist filtered all).")

            for field in image_fields:
                field_val = image_obj.get(field)
                if field_val is None or (isinstance(field_val, (str, list, dict)) and not field_val):
                    print(f"  • {field}: ⚠️ field missing/empty")
                    continue

                urls = list(dict.fromkeys(iter_urls(field_val)))  # dedup in-order
                if not urls:
                    print(f"  • {field}: ⚠️ no URL found under this field")
                    continue

                any_urls_found = True
                print(f"  • {field}: ℹ️ found {len(urls)} URL(s) → resolving…")

                saved_this_field = False
                for url in urls:
                    candidates = resolve_to_direct_images(url)
                    if not candidates:
                        print(f"      - {url} → ℹ️ no direct image resolvable")
                        continue

                    print(f"      - {url} → ℹ️ resolved {len(candidates)} candidate(s)")
                    for cand in candidates:
                        filename = f"{idx}_{name_safe}_{sanitize_filename(field)}.jpg"
                        out_path = img_dir / filename
                        ok = download_image(cand, str(out_path))
                        if ok:
                            print(f"         ✅ download OK → {out_path.name}")
                            saved_this_field = True
                            record_ok = True
                            break
                        else:
                            print(f"         ❌ download FAILED for candidate")

                    if saved_this_field:
                        break

                if not saved_this_field:
                    print(f"  • {field}: ❌ URL extracted but download missed for all candidates")

                # polite delay between fields
                time.sleep(random.uniform(0.05, 0.2))

        else:
            print("  ⚠️ image object missing or empty")

        # per-record summary + flag
        rec["is_image_downloaded"] = bool(record_ok)
        if record_ok:
            print("  ▶︎ SUMMARY: ✅ Download COMPLETE for this record")
            downloaded_true += 1
        else:
            if any_urls_found:
                print("  ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed")
            else:
                print("  ▶︎ SUMMARY: ❌ URL missed (no usable URLs under any image fields)")
            downloaded_false += 1

        # small delay between records
        time.sleep(random.uniform(0.05, 0.25))

    # write updated JSON
    with json_out.open("w", encoding="utf-8") as f:
        json.dump(records, f, ensure_ascii=False, indent=2)

    total = len(records)
    print("\n" + "-"*100)
    print(f"FILE DONE: {json_in.name}")
    print(f"Images dir: {img_dir}")
    print(f"Output JSON: {json_out.name}")
    print(f"Total records:              {total}")
    print(f"is_image_downloaded = True: {downloaded_true}")
    print(f"is_image_downloaded = False:{downloaded_false}")
    print("-"*100)
# Out:
# ====================================================================================================
# PROCESSING FILE: scientists_merged_with_bios.json
# ====================================================================================================
#
# [0] Abbas Shafiee
#   • young: ℹ️ found 1 URL(s) → resolving…
#       - https://www.researchgate.net/profile/Abbas-Shafiee-3 → ℹ️ no direct image resolvable
#   • young: ❌ URL extracted but download missed for all candidates
#   • adult: ℹ️ found 1 URL(s) → resolving…
#       - https://www.researchgate.net/profile/Abbas-Shafiee-3 → ℹ️ no direct image resolvable
#   • adult: ❌ URL extracted but download missed for all candidates
#   • tomb: ℹ️ found 1 URL(s) → resolving…
#       - https://www.researchgate.net/profile/Abbas-Shafiee-3 → ℹ️ no direct image resolvable
#   • tomb: ❌ URL extracted but download missed for all candidates
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [1] Abdullah Ibn al-Muqaffa'
#   • young: ⚠️ field missing/empty
#   • adult: ⚠️ field missing/empty
#   • tomb: ⚠️ field missing/empty
#   ▶︎ SUMMARY: ❌ URL missed (no usable URLs under any image fields)
#
# [2] Abu Mansur al-Maturidi
#   • young: ⚠️ field missing/empty
#   • adult: ⚠️ field missing/empty
#   • tomb: ⚠️ no URL found under this field
#   ▶︎ SUMMARY: ❌ URL missed (no usable URLs under any image fields)
#
# [3] Abu Sa'id 'Ubayd Allah ibn Bakhtishu
#   • young: ⚠️ field missing/empty
#   • adult: ⚠️ field missing/empty
#   • tomb: ⚠️ field missing/empty
#   ▶︎ SUMMARY: ❌ URL missed (no usable URLs under any image fields)
#
# [4] Abu Zayd Ahmed ibn Sahl Balkhi
#   • young: ⚠️ field missing/empty
#   • adult: ⚠️ field missing/empty
#   • tomb: ⚠️ field missing/empty
#   ▶︎ SUMMARY: ❌ URL missed (no usable URLs under any image fields)
#
# [5] Abū Sulaimān al-Maqdisī
#   • young: ⚠️ field missing/empty
#   • adult: ⚠️ field missing/empty
#   • tomb: ⚠️ field missing/empty
#   ▶︎ SUMMARY: ❌ URL missed (no usable URLs under any image fields)
#
# [6] Ahmad Parsa
#   • young: ⚠️ field missing/empty
#   • adult: ⚠️ field missing/empty
#   • tomb: ⚠️ field missing/empty
#   ▶︎ SUMMARY: ❌ URL missed (no usable URLs under any image fields)
#
# [7] Al-Farghani
#   • young: ⚠️ field missing/empty
#   • adult: ⚠️ field missing/empty
#   • tomb: ⚠️ field missing/empty
#   ▶︎ SUMMARY: ❌ URL missed (no usable URLs under any image fields)
#
# [8] Al-Ramhormuzi
#   • young: ⚠️ field missing/empty
#   • adult: ⚠️ field missing/empty
#   • tomb: ⚠️ field missing/empty
#   ▶︎ SUMMARY: ❌ URL missed (no usable URLs under any image fields)
#
# [9] Ali Asghar Mosleh Fasaei
#   • young: ⚠️ field missing/empty
#   • adult: ⚠️ field missing/empty
#   • tomb: ⚠️ field missing/empty
#   ▶︎ SUMMARY: ❌ URL missed (no usable URLs under any image fields)
#
# [10] Ali Nobakht
#   • adult: ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/1/12/Dr._Ali_Nobakht_2016.jpg/800px-Dr._Ali_Nobakht_2016.jpg → ℹ️ resolved 1 candidate(s)
#          ✅ download OK → 10_Ali_Nobakht_adult.jpg
#   ▶︎ SUMMARY: ✅ Download COMPLETE for this record
#
# [11] Ali R. Rabi
#   • young: ⚠️ field missing/empty
#   • adult: ⚠️ field missing/empty
#   • tomb: ⚠️ field missing/empty
#   ▶︎ SUMMARY: ❌ URL missed (no usable URLs under any image fields)
#
# [12] Ali-Akbar Saboury
#   • young: ⚠️ field missing/empty
#   • adult: ⚠️ field missing/empty
#   • tomb: ⚠️ field missing/empty
#   ▶︎ SUMMARY: ❌ URL missed (no usable URLs under any image fields)
#
# [13] Alireza Yalda
#   • young: ⚠️ field missing/empty
#   • adult: ⚠️ field missing/empty
#   • tomb: ⚠️ field missing/empty
#   ▶︎ SUMMARY: ❌ URL missed (no usable URLs under any image fields)
#
# [14] Dariush Safvat
#   • young: ⚠️ field missing/empty
#   • adult: ⚠️ field missing/empty
#   • tomb: ⚠️ field missing/empty
#   ▶︎ SUMMARY: ❌ URL missed (no usable URLs under any image fields)
#
# [15] Emad Afroogh
#   • young: ⚠️ field missing/empty
#   • adult: ⚠️ field missing/empty
#   • tomb: ⚠️ field missing/empty
#   ▶︎ SUMMARY: ❌ URL missed (no usable URLs under any image fields)
#
# [16] Ezzatollah Negahban
#   • young: ⚠️ field missing/empty
#   • adult: ⚠️ field missing/empty
#   • tomb: ⚠️ field missing/empty
#   ▶︎ SUMMARY: ❌ URL missed (no usable URLs under any image fields)
#
# [17] Fazlallah Khunji Isfahani
#   • young: ⚠️ field missing/empty
#   • adult: ⚠️ field missing/empty
#   • tomb: ⚠️ field missing/empty
#   ▶︎ SUMMARY: ❌ URL missed (no usable URLs under any image fields)
#
# [18] Haleh Afshar
#   • young: ⚠️ field missing/empty
#   • adult: ⚠️ field missing/empty
#   • tomb: ⚠️ field missing/empty
#   ▶︎ SUMMARY: ❌ URL missed (no usable URLs under any image fields)
#
# [19] Hamdallah Mustawfi
#   • young: ⚠️ field missing/empty
#   • adult: ⚠️ field missing/empty
#   • tomb: ⚠️ no URL found under this field
#   ▶︎ SUMMARY: ❌ URL missed (no usable URLs under any image fields)
#
# [20] Hamidreza Pouretemad
#   • young: ⚠️ field missing/empty
#   • adult: ⚠️ field missing/empty
#   • tomb: ⚠️ field missing/empty
#   ▶︎ SUMMARY: ❌ URL missed (no usable URLs under any image fields)
#
# [21] Husayn ibn Muhammad ibn Ali al-Astarabadi
#   • young: ⚠️ field missing/empty
#   • adult: ⚠️ field missing/empty
#   • tomb: ⚠️ field missing/empty
#   ▶︎ SUMMARY: ❌ URL missed (no usable URLs under any image fields)
#
# [22] Jalal ad-Din Muḥammad Rūmī
#   • young: ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/e/e8/Rumi_by_Iranian_artist_Hossein_Behzad_30_September_1207.jpg/250px-Rumi_by_Iranian_artist_Hossein_Behzad_30_September_1207.jpg → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   • young: ❌ URL extracted but download missed for all candidates
#   • adult: ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/e/e8/Rumi_by_Iranian_artist_Hossein_Behzad_1957.jpg/250px-Rumi_by_Iranian_artist_Hossein_Behzad_1957.jpg → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   • adult: ❌ URL extracted but download missed for all candidates
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [23] Jamileh Alamolhoda
#   • young: ⚠️ field missing/empty
#   • adult: ⚠️ field missing/empty
#   • tomb: ⚠️ field missing/empty
#   ▶︎ SUMMARY: ❌ URL missed (no usable URLs under any image fields)
#
# [24] Kaave Lajevardi
#   • young: ⚠️ field missing/empty
#   • adult: ⚠️ field missing/empty
#   • tomb: ⚠️ field missing/empty
#   ▶︎ SUMMARY: ❌ URL missed (no usable URLs under any image fields)
#
# [25] Mahmud ibn Ilyas Shirazi
#   • young: ⚠️ field missing/empty
#   • adult: ⚠️ field missing/empty
#   • tomb: ⚠️ field missing/empty
#   ▶︎ SUMMARY: ❌ URL missed (no usable URLs under any image fields)
#
# [26] Masoud Ahmadzadeh
#   • young: ⚠️ field missing/empty
#   • adult: ⚠️ field missing/empty
#   • tomb: ⚠️ field missing/empty
#   ▶︎ SUMMARY: ❌ URL missed (no usable URLs under any image fields)
#
# [27] Mina Izadyar
#   • young: ⚠️ field missing/empty
#   • adult: ⚠️ field missing/empty
#   • tomb: ⚠️ field missing/empty
#   ▶︎ SUMMARY: ❌ URL missed (no usable URLs under any image fields)
#
# [28] Mohammad Jorjandi
#   • young: ⚠️ field missing/empty
#   • adult: ⚠️ field missing/empty
#   • tomb: ⚠️ field missing/empty
#   ▶︎ SUMMARY: ❌ URL missed (no usable URLs under any image fields)
#
# [29] Mohammad Taqi Danesh Pajouh
#   • young: ⚠️ field missing/empty
#   • adult: ⚠️ field missing/empty
#   • tomb: ⚠️ field missing/empty
#   ▶︎ SUMMARY: ❌ URL missed (no usable URLs under any image fields)
#
# [30] Mohammed Ghanbari
#   • young: ⚠️ field missing/empty
#   • adult: ⚠️ field missing/empty
#   • tomb: ⚠️ field missing/empty
#   ▶︎ SUMMARY: ❌ URL missed (no usable URLs under any image fields)
#
# [31] Morvarid Karimi
#   • young: ⚠️ field missing/empty
#   • adult: ⚠️ field missing/empty
#   • tomb: ⚠️ field missing/empty
#   ▶︎ SUMMARY: ❌ URL missed (no usable URLs under any image fields)
#
# [32] Mostafa Azkia
#   • young: ⚠️ field missing/empty
#   • adult: ⚠️ field missing/empty
#   • tomb: ⚠️ field missing/empty
#   ▶︎ SUMMARY: ❌ URL missed (no usable URLs under any image fields)
#
# [33] Najm al-Din Kubra
#   • young: ⚠️ field missing/empty
#   • adult: ⚠️ field missing/empty
#   • tomb: ⚠️ no URL found under this field
#   ▶︎ SUMMARY: ❌ URL missed (no usable URLs under any image fields)
#
# [34] Nasrin Rahimieh
#   • young: ⚠️ field missing/empty
#   • adult: ⚠️ field missing/empty
#   • tomb: ⚠️ field missing/empty
#   ▶︎ SUMMARY: ❌ URL missed (no usable URLs under any image fields)
#
# [35] Nasser Behnegar
#   • young: ⚠️ field missing/empty
#   • adult: ⚠️ field missing/empty
#   • tomb: ⚠️ field missing/empty
#   ▶︎ SUMMARY: ❌ URL missed (no usable URLs under any image fields)
#
# [36] Sayyed Bozorg Mahmoody
#   • adult: ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/b/b2/Gholam_Peyman.jpg → ℹ️ resolved 1 candidate(s)
#          ✅ download OK → 36_Sayyed_Bozorg_Mahmoody_adult.jpg
#   ▶︎ SUMMARY: ✅ Download COMPLETE for this record
#
# [37] Sayyid Zayn al-Din Isma'il al-Husayni al-Jurjani
#   • young: ⚠️ field missing/empty
#   • adult: ⚠️ field missing/empty
#   • tomb: ⚠️ field missing/empty
#   ▶︎ SUMMARY: ❌ URL missed (no usable URLs under any image fields)
#
# [38] Shahrokh Razmjou
#   • young: ⚠️ field missing/empty
#   • adult: ⚠️ field missing/empty
#   • tomb: ⚠️ field missing/empty
#   ▶︎ SUMMARY: ❌ URL missed (no usable URLs under any image fields)
#
# [39] Shams al-Din al-Kirmani
#   • young: ⚠️ field missing/empty
#   • adult: ⚠️ field missing/empty
#   • tomb: ⚠️ field missing/empty
#   ▶︎ SUMMARY: ❌ URL missed (no usable URLs under any image fields)
#
# [40] Sultan Walad
#   • young: ⚠️ field missing/empty
#   • adult: ⚠️ field missing/empty
#   • tomb: ⚠️ field missing/empty
#   ▶︎ SUMMARY: ❌ URL missed (no usable URLs under any image fields)
#
# [41] Sultanu al-Wa'izin Shirazi
#   • young: ⚠️ field missing/empty
#   • adult: ⚠️ field missing/empty
#   • tomb: ⚠️ field missing/empty
#   ▶︎ SUMMARY: ❌ URL missed (no usable URLs under any image fields)
#
# [42] آرامش دوستدار
#   • young: ⚠️ field missing/empty
#   • adult: ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/fa/thumb/1/16/Aramesh-doustdar.jpg/220px-Aramesh-doustdar.jpg → ℹ️ resolved 1 candidate(s)
#          ✅ download OK → 42_آرامش_دوستدار_adult.jpg
#   • tomb: ⚠️ field missing/empty
#   ▶︎ SUMMARY: ✅ Download COMPLETE for this record
#
# [43] أبو الحسن محمد ابن یوسف العامري
#   • young: ⚠️ field missing/empty
#   • adult: ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/fa/thumb/7/7d/Al_Ameri.png/250px-Al_Ameri.png → ℹ️ resolved 1 candidate(s)
#          ✅ download OK → 43_أبو_الحسن_محمد_ابن_یوسف_العامري_adult.jpg
#   • tomb: ⚠️ field missing/empty
#   ▶︎ SUMMARY: ✅ Download COMPLETE for this record
#
# [44] ابن خصیب
#   • young: ⚠️ field missing/empty
#   • adult: ⚠️ field missing/empty
#   • tomb: ⚠️ field missing/empty
#   •   : ℹ️ found 1 URL(s) → resolving…
#       - https://fa.wikipedia.org/wiki/%D9%BE%D8%B1%D9%88%D9%86%D8%AF%D9%87:Abu_Bakr_ibn_al-Khasil,_al-Kharashi_%E2%80%93_De_nativitatibus,_1501_%E2%80%93_BEIC_11389369.jpg → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   •   : ❌ URL extracted but download missed for all candidates
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [45] ابن ربن الطبری
#   • young: ⚠️ field missing/empty
#   • adult: ⚠️ field missing/empty
#   • tomb: ⚠️ field missing/empty
#   • رنگ  قرمز  نشاندهندهٔ طبرستان است؛ نقطهٔ  سفید  در طبرستان، شهریارکوه است که ساری اندکی از آن فاصله دارد.
# نقطهٔ  مشکی  در سمت راست نقشه، طوس است که مرو کمی از آن فاصله دارد.
# نقطهٔ  مشکی  سمت چپ نقشه، بغداد است که سامرا اندکی از آن فاصله دارد.: ℹ️ found 1 URL(s) → resolving…
#       - https://fa.wikipedia.org/wiki/%D9%BE%D8%B1%D9%88%D9%86%D8%AF%D9%87:Mazyar_and_Babak_map.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   • رنگ  قرمز  نشاندهندهٔ طبرستان است؛ نقطهٔ  سفید  در طبرستان، شهریارکوه است که ساری اندکی از آن فاصله دارد.
# نقطهٔ  مشکی  در سمت راست نقشه، طوس است که مرو کمی از آن فاصله دارد.
# نقطهٔ  مشکی  سمت چپ نقشه، بغداد است که سامرا اندکی از آن فاصله دارد.: ❌ URL extracted but download missed for all candidates
#   • تندیس خیالی از علی بن رَبَّن الطبری: ℹ️ found 1 URL(s) → resolving…
#       - https://fa.wikipedia.org/wiki/%D9%BE%D8%B1%D9%88%D9%86%D8%AF%D9%87:Rabban-tabari-s.jpg → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   • تندیس خیالی از علی بن رَبَّن الطبری: ❌ URL extracted but download missed for all candidates
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [46] ابن سینا
#   • young: ⚠️ field missing/empty
#   • adult: ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/f/fe/Pursina.jpg → ℹ️ resolved 1 candidate(s)
#          ✅ download OK → 46_ابن_سینا_adult.jpg
#   • tomb: ℹ️ found 1 URL(s) → resolving…
#       - https://fa.wikipedia.org/wiki/%D9%BE%D8%B1%D9%88%D9%86%D8%AF%D9%87:
#   ▶︎ SUMMARY: ✅ Download COMPLETE for this record
#
# [286] یغما جندقی
#   • young: ⚠️ field missing/empty
#   • adult: ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/d/de/Portrait_of_the_poet_Yaghma_Jandaqi_-_Iran%2C_Tehran_-_c.1850-1860_-_Aqa_Buzurg_Shirazi_%28%3F%29_-_Louvre_museum_-_MAO_779_%28cropped%29.jpg/250px-Portrait_of_the_poet_Yaghma_Jandaqi_-_Iran%2C_Tehran_-_c.1850-1860_-_Aqa_Buzurg_Shirazi_%28%3F%29_-_Louvre_museum_-_MAO_779_%28cropped%29.jpg → ℹ️ resolved 1 candidate(s)
#          ✅ download OK → 286_یغما_جندقی_adult.jpg
#   • tomb: ⚠️ field missing/empty
#   ▶︎ SUMMARY: ✅ Download COMPLETE for this record
#
# [287] یغما گلرویی
#   • young: ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/0/02/%DB%8C%D8%BA%D9%85%D8%A7_%DA%AF%D9%84%D8%B1%D9%88%DB%8C%DB%8C.jpg/250px-%DB%8C%D8%BA%D9%85%D8%A7_%DA%AF%D9%84%D8%B1%D9%88%DB%8C%DB%8C.jpg → ℹ️ resolved 1 candidate(s)
#          ✅ download OK → 287_یغما_گلرویی_young.jpg
#   • adult: ⚠️ field missing/empty
#   • tomb: ⚠️ field missing/empty
#   ▶︎ SUMMARY: ✅ Download COMPLETE for this record
#
# [288] یغمای جندقی
#   • young: ⚠️ field missing/empty
#   • adult: ℹ️ found 1 URL(s) → resolving…
#       - https://api.ganjoor.net/api/ganjoor/poet/image/yaghma.gif → ℹ️ resolved 1 candidate(s)
#          ✅ download OK → 288_یغمای_جندقی_adult.jpg
#   • tomb: ⚠️ field missing/empty
#   ▶︎ SUMMARY: ✅ Download COMPLETE for this record
#
# ----------------------------------------------------------------------------------------------------
# FILE DONE: poets_merged_with_bios.json
# Images dir: poets_images
# Output JSON: poets_merged_with_bios_imaged.json
# Total records:              289
# is_image_downloaded = True: 268
# is_image_downloaded = False:21
# ----------------------------------------------------------------------------------------------------

# %%
ART_IN   = Path("art_music_with_bios.json")
NOURL_IN = Path("no_url_records_art_and_music.json")
ART_OUT  = Path("art_music_with_bios_imaged.json")

def normalize_name(s: str) -> str:
    return (s or "").strip().casefold()

# %%
with ART_IN.open("r", encoding="utf-8") as f:
    art_records = json.load(f)

with NOURL_IN.open("r", encoding="utf-8") as f:
    # expected like: [{"10": "name1"}, {"15": "name2"}, ...]
    no_url_rows = json.load(f)

# %%
no_url_names = []
no_url_idx_by_name = defaultdict(list)

for row in no_url_rows:
    if isinstance(row, dict):
        for k, v in row.items():
            if isinstance(v, str) and v.strip():
                nm = v.strip()
                key = normalize_name(nm)
                no_url_names.append(key)
                no_url_idx_by_name[key].append(k)
    elif isinstance(row, str) and row.strip():  # just in case any row is directly a name
        key = normalize_name(row)
        no_url_names.append(key)
        no_url_idx_by_name[key].append(None)

no_url_set = set(no_url_names)
no_url_dups = {n for n in no_url_names if no_url_names.count(n) > 1}

# %%
index_by_name = {}
for rec in art_records:
    nm = rec.get("name")
    if isinstance(nm, str) and nm.strip():
        index_by_name[normalize_name(nm)] = rec

# %%
matched_false = 0
set_true = 0
unfound_in_art = []

for key in no_url_set:
    rec = index_by_name.get(key)
    if rec is None:
        unfound_in_art.append(key)
    else:
        rec["is_image_downloaded"] = False
        matched_false += 1

# All others -> True
for key, rec in index_by_name.items():
    if key not in no_url_set:
        rec["is_image_downloaded"] = True
        set_true += 1

# Note: if any record lacks a usable name (cannot be normalized), set True by instruction “all other records”
missing_name_true = 0
for rec in art_records:
    nm = rec.get("name")
    if not (isinstance(nm, str) and nm.strip()):
        rec["is_image_downloaded"] = True
        missing_name_true += 1

# ---- write output ----
with ART_OUT.open("w", encoding="utf-8") as f:
    json.dump(art_records, f, ensure_ascii=False, indent=2)

# ---- report ----
total = len(art_records)
print("\n" + "="*90)
print("ART & MUSIC — is_image_downloaded assignment report")
print("="*90)
print(f"Input JSON:             {ART_IN.name}")
print(f"No-URL JSON:            {NOURL_IN.name}")
print("-"*90)
print(f"Total art/music records:        {total}")
print(f"Names in no-URL list:           {len(no_url_set)} (raw rows: {len(no_url_rows)})")
print(f"Duplicate names in no-URL list: {len(no_url_dups)}")
print("-"*90)
print(f"Set is_image_downloaded = False (matched): {matched_false}")
print(f"Set is_image_downloaded = True  (others):  {set_true}")
print(f"Records with missing/blank name set to True: {missing_name_true}")
print(f"Unfound names from no-URL list: {len(unfound_in_art)}")
if unfound_in_art:
    sample = unfound_in_art[:20]
    print(f"  e.g. (normalized): {sample}")
print("-"*90)
print(f"Output written to: {ART_OUT.name}")
print("="*90)
# Out:
# ==========================================================================================
# ART & MUSIC — is_image_downloaded assignment report
# ==========================================================================================
# Input JSON:             art_music_with_bios.json
# No-URL JSON:            no_url_records_art_and_music.json
# ------------------------------------------------------------------------------------------
# Total art/music records:        1338
# Names in no-URL list:           54 (raw rows: 56)
# Duplicate names in no-URL list: 2
# ------------------------------------------------------------------------------------------
# Set is_image_downloaded = False (matched): 54
# Set is_image_downloaded = True  (others):  1214
# Records with missing/blank name set to True: 0
# Unfound names from no-URL list: 0
# ------------------------------------------------------------------------------------------
# Output written to: art_music_with_bios_imaged.json
# ==========================================================================================

# %% [markdown]
# # Crawling for False "is_image_downloaded" records' images

# %%
import os
import re
import json
import time
import random
import urllib.request
import urllib.parse
from io import BytesIO
from pathlib import Path
from PIL import Image

# %%
INPUTS = [
    {
        "json_in":  "scientists_merged_with_bios_imaged.json",
        "json_out": "scientists_merged_with_bios_imaged_crawled.json",
        "img_dir":  "scientists_images",
    },
    {
        "json_in":  "poets_merged_with_bios_imaged.json",
        "json_out": "poets_merged_with_bios_imaged_crawled.json",
        "img_dir":  "poets_images",
    },
    {
        "json_in":  "art_music_with_bios_imaged.json",
        "json_out": "art_music_with_bios_imaged_crawled.json",
        "img_dir":  "art_music_images",
    },
]

# %%
MAX_IMAGE_CANDIDATES = 10

HEADERS = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/115.0.0.0 Safari/537.36"
    )
}

# %%
def sanitize_filename(s: str) -> str:
    s = (str(s) or "").strip()
    s = re.sub(r"\s+", "_", s)
    s = re.sub(r"[^\w\-.]+", "", s)
    return s or "image"

def http_open(url, timeout=35):
    req = urllib.request.Request(url, headers=HEADERS)
    return urllib.request.urlopen(req, timeout=timeout)

def download_image_to_jpeg(url, image_path) -> bool:
    try:
        with http_open(url, timeout=35) as resp:
            final_url = resp.geturl()
            ctype = (resp.headers.get("Content-Type") or "").lower()
            if not ctype.startswith("image/"):
                with http_open(final_url, timeout=35) as resp2:
                    ctype2 = (resp2.headers.get("Content-Type") or "").lower()
                    if not ctype2.startswith("image/"):
                        return False
                    data = resp2.read()
            else:
                data = resp.read()

        img = Image.open(BytesIO(data))
        if img.mode not in ("RGB", "L"):
            img = img.convert("RGB")
        elif img.mode == "L":
            img = img.convert("RGB")
        img.save(image_path, format="JPEG", quality=92)
        return True
    except Exception:
        return False

# ---------- Google providers (optional; use if keys set) ----------

def google_images_serpapi(query: str, num: int) -> list:
    api_key = os.getenv("SERPAPI_API_KEY")
    if not api_key:
        return []
    params = {"engine": "google_images", "q": query, "api_key": api_key, "ijn": "0", "safe": "active"}
    url = "https://serpapi.com/search.json?" + urllib.parse.urlencode(params)
    try:
        with http_open(url, timeout=35) as resp:
            data = json.loads(resp.read().decode("utf-8", errors="ignore"))
        results = data.get("images_results") or []
        out, seen = [], set()
        for r in results:
            u = r.get("original") or r.get("thumbnail")
            if u and u.startswith("http") and u not in seen:
                seen.add(u)
                out.append(u)
            if len(out) >= num:
                break
        return out
    except Exception:
        return []

def google_images_cse(query: str, num: int) -> list:
    api_key = os.getenv("GOOGLE_API_KEY")
    cse_id  = os.getenv("GOOGLE_CSE_ID")
    if not api_key or not cse_id:
        return []
    params = {"q": query, "key": api_key, "cx": cse_id, "searchType": "image", "num": min(num, 10), "safe": "active"}
    url = "https://www.googleapis.com/customsearch/v1?" + urllib.parse.urlencode(params)
    try:
        with http_open(url, timeout=35) as resp:
            data = json.loads(resp.read().decode("utf-8", errors="ignore"))
        items = data.get("items") or []
        out, seen = [], set()
        for it in items:
            link = it.get("link")
            if link and link.startswith("http") and link not in seen:
                seen.add(link)
                out.append(link)
        return out[:num]
    except Exception:
        return []

# ---------- Wikimedia fallback (no keys needed) ----------

IMG_EXTS = {".jpg", ".jpeg", ".png", ".webp", ".gif", ".tif", ".tiff", ".bmp", ".svg"}

def read_json_url(url, timeout=35):
    with http_open(url, timeout=timeout) as resp:
        return json.loads(resp.read().decode("utf-8", errors="ignore"))

def basename_from_url(url: str) -> str:
    p = urllib.parse.urlparse(url)
    return os.path.basename(p.path)

def svg_to_png_thumbnail(file_name: str, prefer_host: str = "commons.wikimedia.org", width: int = 1200) -> str:
    quoted = urllib.parse.quote(file_name)
    return f"https://{prefer_host}/wiki/Special:FilePath/{quoted}?width={width}"

def wikipedia_search_first_title(host: str, name: str) -> str | None:
    # try exact title first
    exact = f"https://{host}/w/api.php?action=query&titles={urllib.parse.quote(name)}&format=json"
    try:
        data = read_json_url(exact)
        pages = (data.get("query") or {}).get("pages") or {}
        if pages and list(pages.keys())[0] != "-1":
            # found exact
            return list(pages.values())[0].get("title")
    except Exception:
        pass
    # fallback: search
    url = f"https://{host}/w/api.php?action=query&list=search&srsearch={urllib.parse.quote(name)}&srlimit=1&format=json"
    try:
        data = read_json_url(url)
        hits = (data.get("query") or {}).get("search") or []
        if hits:
            return hits[0].get("title")
    except Exception:
        pass
    return None

def wikipedia_lead_image(host: str, title: str) -> str | None:
    url = f"https://{host}/w/api.php?action=query&titles={urllib.parse.quote(title)}&prop=pageimages&piprop=original&format=json"
    try:
        data = read_json_url(url)
        pages = (data.get("query") or {}).get("pages") or {}
        for _, pg in pages.items():
            orig = pg.get("original")
            if orig and orig.get("source"):
                return orig["source"]
    except Exception:
        pass
    return None

def commons_file_urls_from_search(name: str, limit: int = 5) -> list:
    # namespace 6 = File:
    url = f"https://commons.wikimedia.org/w/api.php?action=query&list=search&srnamespace=6&srsearch={urllib.parse.quote(name)}&srlimit={limit}&format=json"
    out = []
    try:
        data = read_json_url(url)
        hits = (data.get("query") or {}).get("search") or []
        titles = [h.get("title") for h in hits if h.get("title")]
        if not titles:
            return []
        # get imageinfo for titles
        titles_q = "|".join(titles)
        info = f"https://commons.wikimedia.org/w/api.php?action=query&titles={urllib.parse.quote(titles_q)}&prop=imageinfo&iiprop=url&format=json"
        data2 = read_json_url(info)
        pages = (data2.get("query") or {}).get("pages") or {}
        for _, pg in pages.items():
            ii = pg.get("imageinfo") or []
            if ii and ii[0].get("url"):
                out.append(ii[0]["url"])
    except Exception:
        return []
    return out

def wikimedia_image_candidates(name: str, num: int) -> list:
    """
    Try fa.wikipedia → en.wikipedia lead image → Commons file search.
    Convert SVGs to PNG thumbnails.
    """
    urls = []

    for host in ("fa.wikipedia.org", "en.wikipedia.org"):
        title = wikipedia_search_first_title(host, name)
        if title:
            img = wikipedia_lead_image(host, title)
            if img:
                if img.lower().endswith(".svg"):
                    urls.append(svg_to_png_thumbnail(basename_from_url(img)))
                else:
                    urls.append(img)
                if len(urls) >= num:
                    break

    if len(urls) < num:
        commons = commons_file_urls_from_search(name, limit=max(3, num))
        for u in commons:
            if u.lower().endswith(".svg"):
                urls.append(svg_to_png_thumbnail(basename_from_url(u)))
            else:
                urls.append(u)
            if len(urls) >= num:
                break

    # unique in order
    seen, uniq = set(), []
    for u in urls:
        if u not in seen:
            seen.add(u)
            uniq.append(u)
    return uniq[:num]

# Unified selector
def image_candidates_by_provider(query: str, num: int, provider: str) -> list:
    if provider == "SerpAPI":
        c = google_images_serpapi(query, num)
        if c: return c
        # fall through to CSE then Wikimedia
        provider = "CSE"
    if provider == "CSE":
        c = google_images_cse(query, num)
        if c: return c
        provider = "Wikimedia"
    # Wikimedia works with no keys
    return wikimedia_image_candidates(query, num)

# %%
for pack in INPUTS:
    json_in  = Path(pack["json_in"])
    json_out = Path(pack["json_out"])
    img_dir  = Path(pack["img_dir"])

    if not json_in.exists():
        print(f"⚠️  Skipping (missing): {json_in}")
        continue

    img_dir.mkdir(parents=True, exist_ok=True)

    with json_in.open("r", encoding="utf-8") as f:
        records = json.load(f)

    total = len(records)
    need_crawl = [i for i, r in enumerate(records) if not r.get("is_image_downloaded", False)]

    # Decide starting provider label for logs
    start_provider = "SerpAPI" if os.getenv("SERPAPI_API_KEY") else ("CSE" if os.getenv("GOOGLE_API_KEY") and os.getenv("GOOGLE_CSE_ID") else "Wikimedia")

    print("\n" + "="*110)
    print(f"CRAWLING FILE: {json_in.name}  |  Provider: {start_provider} (fallbacks enabled)")
    print("="*110)
    print(f"Total records: {total} | Need crawl: {len(need_crawl)}")

    success = 0
    failed  = 0

    for idx in need_crawl:
        rec  = records[idx]
        name = rec.get("name") or f"record_{idx}"
        name_safe = sanitize_filename(name)
        print(f"\n[{idx}] {name}  → searching images…")

        candidates = image_candidates_by_provider(name, MAX_IMAGE_CANDIDATES, start_provider)
        if not candidates:
            print("  ⚠️ No candidates found by any provider.")
            rec["is_image_downloaded"] = False
            failed += 1
            time.sleep(random.uniform(0.2, 0.5))
            continue

        print(f"  ℹ️ {len(candidates)} candidate(s) found")
        saved = False
        out_path = img_dir / f"{idx}_{name_safe}_crawled.jpg"

        for ci, url in enumerate(candidates, start=1):
            ok = download_image_to_jpeg(url, str(out_path))
            if ok:
                if not isinstance(rec.get("image"), dict):
                    rec["image"] = {}
                rec["image"]["crawled"] = url
                rec["is_image_downloaded"] = True
                print(f"  ✅ Candidate {ci}/{len(candidates)} OK → {out_path.name}")
                saved = True
                success += 1
                break
            else:
                print(f"  ❌ Candidate {ci}/{len(candidates)} FAILED")

            time.sleep(random.uniform(0.15, 0.35))

        if not saved:
            rec["is_image_downloaded"] = False
            print("  ▶︎ RESULT: ❌ All candidates failed")
            failed += 1

        time.sleep(random.uniform(0.25, 0.6))

    # Write output JSON
    with json_out.open("w", encoding="utf-8") as f:
        json.dump(records, f, ensure_ascii=False, indent=2)

    # Final per-file report
    print("\n" + "-"*110)
    print(f"FILE DONE: {json_in.name}")
    print(f"Output JSON: {json_out.name}")
    print(f"Images dir:  {img_dir}")
    print("-"*110)
    print(f"Needed crawl: {len(need_crawl)}")
    print(f"Succeeded:    {success}")
    print(f"Failed:       {failed}")
    print("-"*110)

print("\nAll files processed.")
# Out:
# ==============================================================================================================
# CRAWLING FILE: scientists_merged_with_bios_imaged.json  |  Provider: Wikimedia (fallbacks enabled)
# ==============================================================================================================
# Total records: 241 | Need crawl: 105
#
# [0] Abbas Shafiee  → searching images…
#   ℹ️ 2 candidate(s) found
#   ✅ Candidate 1/2 OK → 0_Abbas_Shafiee_crawled.jpg
#
# [1] Abdullah Ibn al-Muqaffa'  → searching images…
#   ℹ️ 4 candidate(s) found
#   ✅ Candidate 1/4 OK → 1_Abdullah_Ibn_al-Muqaffa_crawled.jpg
#
# [2] Abu Mansur al-Maturidi  → searching images…
#   ℹ️ 8 candidate(s) found
#   ✅ Candidate 1/8 OK → 2_Abu_Mansur_al-Maturidi_crawled.jpg
#
# [3] Abu Sa'id 'Ubayd Allah ibn Bakhtishu  → searching images…
#   ℹ️ 6 candidate(s) found
#   ✅ Candidate 1/6 OK → 3_Abu_Said_Ubayd_Allah_ibn_Bakhtishu_crawled.jpg
#
# [4] Abu Zayd Ahmed ibn Sahl Balkhi  → searching images…
#   ℹ️ 2 candidate(s) found
#   ✅ Candidate 1/2 OK → 4_Abu_Zayd_Ahmed_ibn_Sahl_Balkhi_crawled.jpg
#
# [5] Abū Sulaimān al-Maqdisī  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 5_Abū_Sulaimān_al-Maqdisī_crawled.jpg
#
# [6] Ahmad Parsa  → searching images…
#   ℹ️ 10 candidate(s) found
#   ✅ Candidate 1/10 OK → 6_Ahmad_Parsa_crawled.jpg
#
# [7] Al-Farghani  → searching images…
#   ℹ️ 8 candidate(s) found
#   ✅ Candidate 1/8 OK → 7_Al-Farghani_crawled.jpg
#
# [8] Al-Ramhormuzi  → searching images…
#   ℹ️ 5 candidate(s) found
#   ❌ Candidate 1/5 FAILED
#   ❌ Candidate 2/5 FAILED
#   ✅ Candidate 3/5 OK → 8_Al-Ramhormuzi_crawled.jpg
#
# [9] Ali Asghar Mosleh Fasaei  → searching images…
#   ℹ️ 6 candidate(s) found
#   ✅ Candidate 1/6 OK → 9_Ali_Asghar_Mosleh_Fasaei_crawled.jpg
#
# [11] Ali R. Rabi  → searching images…
#   ℹ️ 10 candidate(s) found
#   ✅ Candidate 1/10 OK → 11_Ali_R._Rabi_crawled.jpg
#
# [12] Ali-Akbar Saboury  → searching images…
#   ℹ️ 2 candidate(s) found
#   ✅ Candidate 1/2 OK → 12_Ali-Akbar_Saboury_crawled.jpg
#
# [13] Alireza Yalda  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [14] Dariush Safvat  → searching images…
#   ℹ️ 2 candidate(s) found
#   ✅ Candidate 1/2 OK → 14_Dariush_Safvat_crawled.jpg
#
# [15] Emad Afroogh  → searching images…
#   ℹ️ 3 candidate(s) found
#   ✅ Candidate 1/3 OK → 15_Emad_Afroogh_crawled.jpg
#
# [16] Ezzatollah Negahban  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 16_Ezzatollah_Negahban_crawled.jpg
#
# [17] Fazlallah Khunji Isfahani  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [18] Haleh Afshar  → searching images…
#   ℹ️ 8 candidate(s) found
#   ✅ Candidate 1/8 OK → 18_Haleh_Afshar_crawled.jpg
#
# [19] Hamdallah Mustawfi  → searching images…
#   ℹ️ 9 candidate(s) found
#   ✅ Candidate 1/9 OK → 19_Hamdallah_Mustawfi_crawled.jpg
#
# [20] Hamidreza Pouretemad  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [21] Husayn ibn Muhammad ibn Ali al-Astarabadi  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 21_Husayn_ibn_Muhammad_ibn_Ali_al-Astarabadi_crawled.jpg
#
# [22] Jalal ad-Din Muḥammad Rūmī  → searching images…
#   ℹ️ 9 candidate(s) found
#   ✅ Candidate 1/9 OK → 22_Jalal_ad-Din_Muḥammad_Rūmī_crawled.jpg
#
# [23] Jamileh Alamolhoda  → searching images…
#   ℹ️ 10 candidate(s) found
#   ✅ Candidate 1/10 OK → 23_Jamileh_Alamolhoda_crawled.jpg
#
# [24] Kaave Lajevardi  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [25] Mahmud ibn Ilyas Shirazi  → searching images…
#   ℹ️ 1 candidate(s) found
#   ❌ Candidate 1/1 FAILED
#   ▶︎ RESULT: ❌ All candidates failed
#
# [26] Masoud Ahmadzadeh  → searching images…
#   ℹ️ 5 candidate(s) found
#   ✅ Candidate 1/5 OK → 26_Masoud_Ahmadzadeh_crawled.jpg
#
# [27] Mina Izadyar  → searching images…
#   ℹ️ 2 candidate(s) found
#   ✅ Candidate 1/2 OK → 27_Mina_Izadyar_crawled.jpg
#
# [28] Mohammad Jorjandi  → searching images…
#   ℹ️ 3 candidate(s) found
#   ✅ Candidate 1/3 OK → 28_Mohammad_Jorjandi_crawled.jpg
#
# [29] Mohammad Taqi Danesh Pajouh  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 29_Mohammad_Taqi_Danesh_Pajouh_crawled.jpg
#
# [30] Mohammed Ghanbari  → searching images…
#   ℹ️ 10 candidate(s) found
#   ✅ Candidate 1/10 OK → 30_Mohammed_Ghanbari_crawled.jpg
#
# [31] Morvarid Karimi  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [32] Mostafa Azkia  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 32_Mostafa_Azkia_crawled.jpg
#
# [33] Najm al-Din Kubra  → searching images…
#   ℹ️ 9 candidate(s) found
#   ✅ Candidate 1/9 OK → 33_Najm_al-Din_Kubra_crawled.jpg
#
# [34] Nasrin Rahimieh  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [35] Nasser Behnegar  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [37] Sayyid Zayn al-Din Isma'il al-Husayni al-Jurjani  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 37_Sayyid_Zayn_al-Din_Ismail_al-Husayni_al-Jurjani_crawled.jpg
#
# [38] Shahrokh Razmjou  → searching images…
#   ℹ️ 8 candidate(s) found
#   ✅ Candidate 1/8 OK → 38_Shahrokh_Razmjou_crawled.jpg
#
# [39] Shams al-Din al-Kirmani  → searching images…
#   ℹ️ 10 candidate(s) found
#   ✅ Candidate 1/10 OK → 39_Shams_al-Din_al-Kirmani_crawled.jpg
#
# [40] Sultan Walad  → searching images…
#   ℹ️ 10 candidate(s) found
#   ✅ Candidate 1/10 OK → 40_Sultan_Walad_crawled.jpg
#
# [41] Sultanu al-Wa'izin Shirazi  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 41_Sultanu_al-Waizin_Shirazi_crawled.jpg
#
# [44] ابن خصیب  → searching images…
#   ℹ️ 9 candidate(s) found
#   ✅ Candidate 1/9 OK → 44_ابن_خصیب_crawled.jpg
#
# [45] ابن ربن الطبری  → searching images…
#   ℹ️ 5 candidate(s) found
#   ❌ Candidate 1/5 FAILED
#   ❌ Candidate 2/5 FAILED
#   ❌ Candidate 3/5 FAILED
#   ❌ Candidate 4/5 FAILED
#   ❌ Candidate 5/5 FAILED
#   ▶︎ RESULT: ❌ All candidates failed
#
# [51] ابو علی بلعمی  → searching images…
#   ℹ️ 10 candidate(s) found
#   ✅ Candidate 1/10 OK → 51_ابو_علی_بلعمی_crawled.jpg
#
# [52] ابواسحاق ابراهیم بن محمد بن حبیب بن سمرة بن جندب بغدادی فزاری  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [53] ابواسحاق ابراهیم بن محمد فارسی اصطخری  → searching images…
#   ℹ️ 3 candidate(s) found
#   ✅ Candidate 1/3 OK → 53_ابواسحاق_ابراهیم_بن_محمد_فارسی_اصطخری_crawled.jpg
#
# [54] ابوالحسن بهمنیار بن مرزبان سالاری  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 54_ابوالحسن_بهمنیار_بن_مرزبان_سالاری_crawled.jpg
#
# [56] ابوالعباس احمد ابن محمد ابن کثیر فَرغانی  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 56_ابوالعباس_احمد_ابن_محمد_ابن_کثیر_فرغانی_crawled.jpg
#
# [57] ابوالقاسم عبدالکریم بن هَوازِن قشیری  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 57_ابوالقاسم_عبدالکریم_بن_هوازن_قشیری_crawled.jpg
#
# [63] ابوزکریا یوحنا یحیی بن ماسویهٔ خوزی  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 63_ابوزکریا_یوحنا_یحیی_بن_ماسویه_خوزی_crawled.jpg
#
# [65] ابومنصور حسن بن نوح کمرهای بخاری  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 65_ابومنصور_حسن_بن_نوح_کمرهای_بخاری_crawled.jpg
#
# [69] احسانالله یارشاطر  → searching images…
#   ℹ️ 10 candidate(s) found
#   ✅ Candidate 1/10 OK → 69_احسانالله_یارشاطر_crawled.jpg
#
# [70] احمد بن شعیب نسائی  → searching images…
#   ℹ️ 9 candidate(s) found
#   ✅ Candidate 1/9 OK → 70_احمد_بن_شعیب_نسائی_crawled.jpg
#
# [72] احمدرضا دهپور  → searching images…
#   ℹ️ 2 candidate(s) found
#   ✅ Candidate 1/2 OK → 72_احمدرضا_دهپور_crawled.jpg
#
# [73] احمدرضا دِهپور  → searching images…
#   ℹ️ 2 candidate(s) found
#   ✅ Candidate 1/2 OK → 73_احمدرضا_دهپور_crawled.jpg
#
# [75] اردشیر قوام زاده  → searching images…
#   ℹ️ 2 candidate(s) found
#   ✅ Candidate 1/2 OK → 75_اردشیر_قوام_زاده_crawled.jpg
#
# [76] اردشیر قوام‌زاده  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 76_اردشیر_قوامزاده_crawled.jpg
#
# [83] براند تروآز  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [84] برانوش  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [88] بهادر اعلمی هرندی  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [90] بیتا دریاباری  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 90_بیتا_دریاباری_crawled.jpg
#
# [92] بیژن پاکزاد  → searching images…
#   ℹ️ 10 candidate(s) found
#   ✅ Candidate 1/10 OK → 92_بیژن_پاکزاد_crawled.jpg
#
# [97] جمشید کاشانی  → searching images…
#   ℹ️ 8 candidate(s) found
#   ✅ Candidate 1/8 OK → 97_جمشید_کاشانی_crawled.jpg
#
# [98] جمیله کدیور  → searching images…
#   ℹ️ 2 candidate(s) found
#   ✅ Candidate 1/2 OK → 98_جمیله_کدیور_crawled.jpg
#
# [101] حسین راغفر  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [102] حسین ملک‌افضلی  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [104] خواجه عبدالله انصاری  → searching images…
#   ℹ️ 9 candidate(s) found
#   ✅ Candidate 1/9 OK → 104_خواجه_عبدالله_انصاری_crawled.jpg
#
# [115] سید حسن امین  → searching images…
#   ℹ️ 9 candidate(s) found
#   ✅ Candidate 1/9 OK → 115_سید_حسن_امین_crawled.jpg
#
# [116] سید حسین سیفزاده  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 116_سید_حسین_سیفزاده_crawled.jpg
#
# [120] سید محمد عزالدین حسینی الموسوی زنجانی  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [123] سید کریم قنبری  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [124] سید یعقوب موسوی  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [135] عباس مصلی‌نژاد  → searching images…
#   ℹ️ 3 candidate(s) found
#   ✅ Candidate 1/3 OK → 135_عباس_مصلینژاد_crawled.jpg
#
# [145] علی رحمانی  → searching images…
#   ℹ️ 10 candidate(s) found
#   ✅ Candidate 1/10 OK → 145_علی_رحمانی_crawled.jpg
#
# [150] علیرضا ربیع  → searching images…
#   ℹ️ 10 candidate(s) found
#   ✅ Candidate 1/10 OK → 150_علیرضا_ربیع_crawled.jpg
#
# [153] علیرضا یلدا  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [160] فاطمه راکعی  → searching images…
#   ℹ️ 9 candidate(s) found
#   ✅ Candidate 1/9 OK → 160_فاطمه_راکعی_crawled.jpg
#
# [163] فرناز ناظرزاده کرمانی  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [164] فریار شیرزاد  → searching images…
#   ℹ️ 4 candidate(s) found
#   ✅ Candidate 1/4 OK → 164_فریار_شیرزاد_crawled.jpg
#
# [165] فریدون  → searching images…
#   ℹ️ 9 candidate(s) found
#   ✅ Candidate 1/9 OK → 165_فریدون_crawled.jpg
#
# [167] فِرِیدون  → searching images…
#   ℹ️ 9 candidate(s) found
#   ✅ Candidate 1/9 OK → 167_فریدون_crawled.jpg
#
# [172] مجتبی شمسی‌پور  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [174] محبوبه مباشری  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [175] محرم حبیب‌نژاد  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [182] محمدباقر اصفهانی  → searching images…
#   ℹ️ 3 candidate(s) found
#   ✅ Candidate 1/3 OK → 182_محمدباقر_اصفهانی_crawled.jpg
#
# [183] محمدجعفر یاحقی  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 183_محمدجعفر_یاحقی_crawled.jpg
#
# [184] محمدحسن شجاعی‌فرد  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [187] محمدرضا مخبر  → searching images…
#   ℹ️ 2 candidate(s) found
#   ✅ Candidate 1/2 OK → 187_محمدرضا_مخبر_crawled.jpg
#
# [189] محمود ابن محمد ابن عمر جغمینی  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 189_محمود_ابن_محمد_ابن_عمر_جغمینی_crawled.jpg
#
# [190] محمود حسابی  → searching images…
#   ℹ️ 9 candidate(s) found
#   ✅ Candidate 1/9 OK → 190_محمود_حسابی_crawled.jpg
#
# [192] محمود مهرداد شکریه  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [193] محمود کمره‌ای  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [199] مراد فرهادپور  → searching images…
#   ℹ️ 10 candidate(s) found
#   ✅ Candidate 1/10 OK → 199_مراد_فرهادپور_crawled.jpg
#
# [200] مرتضی مطهری فریمانی  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 200_مرتضی_مطهری_فریمانی_crawled.jpg
#
# [201] مریم میرزاخانی  → searching images…
#   ℹ️ 10 candidate(s) found
#   ✅ Candidate 1/10 OK → 201_مریم_میرزاخانی_crawled.jpg
#
# [202] مزدک بامدادان  → searching images…
#   ℹ️ 1 candidate(s) found
#   ❌ Candidate 1/1 FAILED
#   ▶︎ RESULT: ❌ All candidates failed
#
# [206] ملا عبدالله بهابادی  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 206_ملا_عبدالله_بهابادی_crawled.jpg
#
# [208] ملا محسن فیض کاشانی  → searching images…
#   ℹ️ 6 candidate(s) found
#   ✅ Candidate 1/6 OK → 208_ملا_محسن_فیض_کاشانی_crawled.jpg
#
# [210] مهتاب مستعان  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [216] میرعبدالحسین نقیب زاده جلالی  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [220] نرسه  → searching images…
#   ℹ️ 9 candidate(s) found
#   ✅ Candidate 1/9 OK → 220_نرسه_crawled.jpg
#
# [225] نظام‌الدین مهدوی امیری  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [227] نَرْسه  → searching images…
#   ℹ️ 9 candidate(s) found
#   ✅ Candidate 1/9 OK → 227_نرسه_crawled.jpg
#
# [237] کاوه پهلوان  → searching images…
#   ℹ️ 3 candidate(s) found
#   ✅ Candidate 1/3 OK → 237_کاوه_پهلوان_crawled.jpg
#
# [238] کرامت‌الله ایزدپناه  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [240] کمالالدین فارسی  → searching images…
#   ℹ️ 9 candidate(s) found
#   ✅ Candidate 1/9 OK → 240_کمالالدین_فارسی_crawled.jpg
#
# --------------------------------------------------------------------------------------------------------------
# FILE DONE: scientists_merged_with_bios_imaged.json
# Output JSON: scientists_merged_with_bios_imaged_crawled.json
# Images dir:  scientists_images
# --------------------------------------------------------------------------------------------------------------
# Needed crawl: 105
# Succeeded:    74
# Failed:       31
# --------------------------------------------------------------------------------------------------------------
#
# ==============================================================================================================
# CRAWLING FILE: poets_merged_with_bios_imaged.json  |  Provider: Wikimedia (fallbacks enabled)
# ==============================================================================================================
# Total records: 289 | Need crawl: 21
#
# [0] آصفی هروی  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 0_آصفی_هروی_crawled.jpg
#
# [3] ابن یمین فریومدی  → searching images…
#   ℹ️ 3 candidate(s) found
#   ❌ Candidate 1/3 FAILED
#   ❌ Candidate 2/3 FAILED
#   ✅ Candidate 3/3 OK → 3_ابن_یمین_فریومدی_crawled.jpg
#
# [8] ابوالعباس ربنجنی  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [17] ابوسلیک گرگانی  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [18] ابوشعیب هروی  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [19] ابوشکور بلخی  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [20] ابوطاهر خسروانی  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [46] اهلی شیرازی  → searching images…
#   ℹ️ 6 candidate(s) found
#   ✅ Candidate 1/6 OK → 46_اهلی_شیرازی_crawled.jpg
#
# [90] رضا براهنی  → searching images…
#   ℹ️ 9 candidate(s) found
#   ✅ Candidate 1/9 OK → 90_رضا_براهنی_crawled.jpg
#
# [98] زویا زاکاریان  → searching images…
#   ℹ️ 2 candidate(s) found
#   ✅ Candidate 1/2 OK → 98_زویا_زاکاریان_crawled.jpg
#
# [113] سنایی  → searching images…
#   ℹ️ 8 candidate(s) found
#   ✅ Candidate 1/8 OK → 113_سنایی_crawled.jpg
#
# [123] سیدای نسفی  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 123_سیدای_نسفی_crawled.jpg
#
# [138] طالب آملی  → searching images…
#   ℹ️ 6 candidate(s) found
#   ❌ Candidate 1/6 FAILED
#   ✅ Candidate 2/6 OK → 138_طالب_آملی_crawled.jpg
#
# [168] فروغی بسطامی  → searching images…
#   ℹ️ 9 candidate(s) found
#   ✅ Candidate 1/9 OK → 168_فروغی_بسطامی_crawled.jpg
#
# [192] محمد بن وصیف سجزی  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [197] محمد فرخی یزدی  → searching images…
#   ℹ️ 9 candidate(s) found
#   ✅ Candidate 1/9 OK → 197_محمد_فرخی_یزدی_crawled.jpg
#
# [235] مونا برزویی  → searching images…
#   ℹ️ 2 candidate(s) found
#   ✅ Candidate 1/2 OK → 235_مونا_برزویی_crawled.jpg
#
# [250] نشاط اصفهانی  → searching images…
#   ℹ️ 7 candidate(s) found
#   ✅ Candidate 1/7 OK → 250_نشاط_اصفهانی_crawled.jpg
#
# [265] وحشی بافقی  → searching images…
#   ℹ️ 9 candidate(s) found
#   ✅ Candidate 1/9 OK → 265_وحشی_بافقی_crawled.jpg
#
# [267] وحید قزوینی  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 267_وحید_قزوینی_crawled.jpg
#
# [279] کمال الدین علی محتشم کاشانی  → searching images…
#   ⚠️ No candidates found by any provider.
#
# --------------------------------------------------------------------------------------------------------------
# FILE DONE: poets_merged_with_bios_imaged.json
# Output JSON: poets_merged_with_bios_imaged_crawled.json
# Images dir:  poets_images
# --------------------------------------------------------------------------------------------------------------
# Needed crawl: 21
# Succeeded:    14
# Failed:       7
# --------------------------------------------------------------------------------------------------------------
#
# ==============================================================================================================
# CRAWLING FILE: art_music_with_bios_imaged.json  |  Provider: Wikimedia (fallbacks enabled)
# ==============================================================================================================
# Total records: 1338 | Need crawl: 124
#
# [2] فتح‌الله منوچهری  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 2_فتحالله_منوچهری_crawled.jpg
#
# [10] نورمحمد ذوالفقاری  → searching images…
#   ℹ️ 7 candidate(s) found
#   ✅ Candidate 1/7 OK → 10_نورمحمد_ذوالفقاری_crawled.jpg
#
# [15] جمشید اسماعیل‌خانی  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 15_جمشید_اسماعیلخانی_crawled.jpg
#
# [16] منوچهر افسری  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [39] رضا فاضلی  → searching images…
#   ℹ️ 8 candidate(s) found
#   ✅ Candidate 1/8 OK → 39_رضا_فاضلی_crawled.jpg
#
# [44] مازیار جبرانی  → searching images…
#   ℹ️ 10 candidate(s) found
#   ✅ Candidate 1/10 OK → 44_مازیار_جبرانی_crawled.jpg
#
# [46] پروین غفاری  → searching images…
#   ℹ️ 2 candidate(s) found
#   ✅ Candidate 1/2 OK → 46_پروین_غفاری_crawled.jpg
#
# [74] محمدعلی ورشوچی  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 74_محمدعلی_ورشوچی_crawled.jpg
#
# [77] احمدرضا شفیعی‌جم  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 77_احمدرضا_شفیعیجم_crawled.jpg
#
# [92] پروین‌دخت یزدانیان  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 92_پرویندخت_یزدانیان_crawled.jpg
#
# [97] فرامرز قریبیان  → searching images…
#   ℹ️ 8 candidate(s) found
#   ✅ Candidate 1/8 OK → 97_فرامرز_قریبیان_crawled.jpg
#
# [114] هادی حجازی‌فر  → searching images…
#   ℹ️ 8 candidate(s) found
#   ✅ Candidate 1/8 OK → 114_هادی_حجازیفر_crawled.jpg
#
# [130] سیاوش مفیدی  → searching images…
#   ℹ️ 2 candidate(s) found
#   ✅ Candidate 1/2 OK → 130_سیاوش_مفیدی_crawled.jpg
#
# [145] لاله پورکریم  → searching images…
#   ℹ️ 9 candidate(s) found
#   ✅ Candidate 1/9 OK → 145_لاله_پورکریم_crawled.jpg
#
# [172] احمد سعید حق‌پرست راد  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 172_احمد_سعید_حقپرست_راد_crawled.jpg
#
# [176] محمد برسوزیان  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 176_محمد_برسوزیان_crawled.jpg
#
# [183] بهرام رادان  → searching images…
#   ℹ️ 8 candidate(s) found
#   ✅ Candidate 1/8 OK → 183_بهرام_رادان_crawled.jpg
#
# [189] داریوش فرهنگ درخشانی  → searching images…
#   ℹ️ 3 candidate(s) found
#   ✅ Candidate 1/3 OK → 189_داریوش_فرهنگ_درخشانی_crawled.jpg
#
# [199] داوود رشیدی ده رشیدی  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 199_داوود_رشیدی_ده_رشیدی_crawled.jpg
#
# [202] عزت‌الله انتظامی  → searching images…
#   ℹ️ 9 candidate(s) found
#   ✅ Candidate 1/9 OK → 202_عزتالله_انتظامی_crawled.jpg
#
# [210] عسل بدیعی  → searching images…
#   ℹ️ 10 candidate(s) found
#   ✅ Candidate 1/10 OK → 210_عسل_بدیعی_crawled.jpg
#
# [217] مختار سائقی  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [246] یاسمین طباطبایی  → searching images…
#   ℹ️ 8 candidate(s) found
#   ✅ Candidate 1/8 OK → 246_یاسمین_طباطبایی_crawled.jpg
#
# [273] نیما فلاح  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [276] شهناز تهرانی  → searching images…
#   ℹ️ 5 candidate(s) found
#   ✅ Candidate 1/5 OK → 276_شهناز_تهرانی_crawled.jpg
#
# [282] محمّدعلی کشاورز  → searching images…
#   ℹ️ 9 candidate(s) found
#   ✅ Candidate 1/9 OK → 282_محمدعلی_کشاورز_crawled.jpg
#
# [333] فائقه آتشین  → searching images…
#   ℹ️ 9 candidate(s) found
#   ✅ Candidate 1/9 OK → 333_فائقه_آتشین_crawled.jpg
#
# [343] احمد ساعتچیان ابدالی  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 343_احمد_ساعتچیان_ابدالی_crawled.jpg
#
# [350] شادمهر عقیلی  → searching images…
#   ℹ️ 4 candidate(s) found
#   ✅ Candidate 1/4 OK → 350_شادمهر_عقیلی_crawled.jpg
#
# [360] آشا محرابی  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 360_آشا_محرابی_crawled.jpg
#
# [361] رفیع حالتی  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [373] بیژن بنفشه‌خواه  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 373_بیژن_بنفشهخواه_crawled.jpg
#
# [380] محسن یوسف‌بیک  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [385] گیتی فروهر  → searching images…
#   ℹ️ 9 candidate(s) found
#   ✅ Candidate 1/9 OK → 385_گیتی_فروهر_crawled.jpg
#
# [430] اکبر عبدی آقاباقر  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 430_اکبر_عبدی_آقاباقر_crawled.jpg
#
# [435] لیلا فروهر  → searching images…
#   ℹ️ 7 candidate(s) found
#   ✅ Candidate 1/7 OK → 435_لیلا_فروهر_crawled.jpg
#
# [438] رهاورد فراهانی  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 438_رهاورد_فراهانی_crawled.jpg
#
# [450] سید شهاب‌الدین حسینی تنکابنی  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 450_سید_شهابالدین_حسینی_تنکابنی_crawled.jpg
#
# [460] شاهین جعفرقلی  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 460_شاهین_جعفرقلی_crawled.jpg
#
# [462] سید جواد رضویان  → searching images…
#   ℹ️ 3 candidate(s) found
#   ✅ Candidate 1/3 OK → 462_سید_جواد_رضویان_crawled.jpg
#
# [470] رضا رویگری  → searching images…
#   ℹ️ 8 candidate(s) found
#   ✅ Candidate 1/8 OK → 470_رضا_رویگری_crawled.jpg
#
# [488] حبیب‌الله بلور  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 488_حبیبالله_بلور_crawled.jpg
#
# [494] فرزاد فرزین  → searching images…
#   ℹ️ 10 candidate(s) found
#   ✅ Candidate 1/10 OK → 494_فرزاد_فرزین_crawled.jpg
#
# [508] فاطمه صادقی  → searching images…
#   ℹ️ 10 candidate(s) found
#   ✅ Candidate 1/10 OK → 508_فاطمه_صادقی_crawled.jpg
#
# [510] زانیار خسروی  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 510_زانیار_خسروی_crawled.jpg
#
# [511] مازیار فلاحی  → searching images…
#   ℹ️ 9 candidate(s) found
#   ✅ Candidate 1/9 OK → 511_مازیار_فلاحی_crawled.jpg
#
# [526] شهیار قنبری  → searching images…
#   ℹ️ 8 candidate(s) found
#   ✅ Candidate 1/8 OK → 526_شهیار_قنبری_crawled.jpg
#
# [530] مهدی فخیم‌زاده  → searching images…
#   ℹ️ 5 candidate(s) found
#   ✅ Candidate 1/5 OK → 530_مهدی_فخیمزاده_crawled.jpg
#
# [543] هوتن شکیبا  → searching images…
#   ℹ️ 8 candidate(s) found
#   ✅ Candidate 1/8 OK → 543_هوتن_شکیبا_crawled.jpg
#
# [545] اردشیر کاظمی  → searching images…
#   ℹ️ 5 candidate(s) found
#   ✅ Candidate 1/5 OK → 545_اردشیر_کاظمی_crawled.jpg
#
# [560] دلیله نمازی  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [581] شهرام عبدلی  → searching images…
#   ℹ️ 9 candidate(s) found
#   ✅ Candidate 1/9 OK → 581_شهرام_عبدلی_crawled.jpg
#
# [589] فرح‌دخت عباس خاقانی  → searching images…
#   ℹ️ 2 candidate(s) found
#   ✅ Candidate 1/2 OK → 589_فرحدخت_عباس_خاقانی_crawled.jpg
#
# [590] حمید فرّخ‌نژاد  → searching images…
#   ℹ️ 4 candidate(s) found
#   ✅ Candidate 1/4 OK → 590_حمید_فرخنژاد_crawled.jpg
#
# [596] نیکو خردمند  → searching images…
#   ℹ️ 2 candidate(s) found
#   ✅ Candidate 1/2 OK → 596_نیکو_خردمند_crawled.jpg
#
# [624] رقیه چهره‌آزاد  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 624_رقیه_چهرهآزاد_crawled.jpg
#
# [639] شهلا صافی‌ضمیر  → searching images…
#   ℹ️ 2 candidate(s) found
#   ✅ Candidate 1/2 OK → 639_شهلا_صافیضمیر_crawled.jpg
#
# [646] حامد تفنگساز صابری بهداد  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [647] علی نصیریان  → searching images…
#   ℹ️ 9 candidate(s) found
#   ✅ Candidate 1/9 OK → 647_علی_نصیریان_crawled.jpg
#
# [661] زهرا سعیدی  → searching images…
#   ℹ️ 8 candidate(s) found
#   ✅ Candidate 1/8 OK → 661_زهرا_سعیدی_crawled.jpg
#
# [686] عارف عارف‌کیا  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 686_عارف_عارفکیا_crawled.jpg
#
# [687] سید منوچهر سخایی کاشانی  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 687_سید_منوچهر_سخایی_کاشانی_crawled.jpg
#
# [691] داریوش اقبالی  → searching images…
#   ℹ️ 9 candidate(s) found
#   ✅ Candidate 1/9 OK → 691_داریوش_اقبالی_crawled.jpg
#
# [706] پوپک گلدره  → searching images…
#   ℹ️ 4 candidate(s) found
#   ✅ Candidate 1/4 OK → 706_پوپک_گلدره_crawled.jpg
#
# [708] صدف طاهریان  → searching images…
#   ℹ️ 9 candidate(s) found
#   ✅ Candidate 1/9 OK → 708_صدف_طاهریان_crawled.jpg
#
# [709] ابراهیم حامدی  → searching images…
#   ℹ️ 9 candidate(s) found
#   ✅ Candidate 1/9 OK → 709_ابراهیم_حامدی_crawled.jpg
#
# [714] رضا بنفشه‌خواه  → searching images…
#   ℹ️ 3 candidate(s) found
#   ✅ Candidate 1/3 OK → 714_رضا_بنفشهخواه_crawled.jpg
#
# [722] علی عباس صادقی  → searching images…
#   ℹ️ 6 candidate(s) found
#   ✅ Candidate 1/6 OK → 722_علی_عباس_صادقی_crawled.jpg
#
# [742] آرش لباف  → searching images…
#   ℹ️ 9 candidate(s) found
#   ✅ Candidate 1/9 OK → 742_آرش_لباف_crawled.jpg
#
# [743] حبیب محبیان  → searching images…
#   ℹ️ 9 candidate(s) found
#   ✅ Candidate 1/9 OK → 743_حبیب_محبیان_crawled.jpg
#
# [750] طوفان هل‌عطایی  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [757] محسن چاوشی حسینی  → searching images…
#   ℹ️ 2 candidate(s) found
#   ✅ Candidate 1/2 OK → 757_محسن_چاوشی_حسینی_crawled.jpg
#
# [762] رهاورد فراهانی  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 762_رهاورد_فراهانی_crawled.jpg
#
# [770] بهرام سیر  → searching images…
#   ℹ️ 9 candidate(s) found
#   ❌ Candidate 1/9 FAILED
#   ❌ Candidate 2/9 FAILED
#   ❌ Candidate 3/9 FAILED
#   ❌ Candidate 4/9 FAILED
#   ❌ Candidate 5/9 FAILED
#   ❌ Candidate 6/9 FAILED
#   ❌ Candidate 7/9 FAILED
#   ❌ Candidate 8/9 FAILED
#   ❌ Candidate 9/9 FAILED
#   ▶︎ RESULT: ❌ All candidates failed
#
# [791] گروه پالت  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 791_گروه_پالت_crawled.jpg
#
# [796] ویگن دردریان  → searching images…
#   ℹ️ 5 candidate(s) found
#   ✅ Candidate 1/5 OK → 796_ویگن_دردریان_crawled.jpg
#
# [797] فاطمه واعظی  → searching images…
#   ℹ️ 10 candidate(s) found
#   ✅ Candidate 1/10 OK → 797_فاطمه_واعظی_crawled.jpg
#
# [798] سید محمد معتمدی  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [802] فائقه آتشین  → searching images…
#   ℹ️ 9 candidate(s) found
#   ✅ Candidate 1/9 OK → 802_فائقه_آتشین_crawled.jpg
#
# [803] حامد تفنگساز صابری بهداد  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [812] شهرام شب‌پره  → searching images…
#   ℹ️ 8 candidate(s) found
#   ✅ Candidate 1/8 OK → 812_شهرام_شبپره_crawled.jpg
#
# [834] ابراهیم حامدی  → searching images…
#   ℹ️ 9 candidate(s) found
#   ✅ Candidate 1/9 OK → 834_ابراهیم_حامدی_crawled.jpg
#
# [836] خدیجه اشرف‌السادات مرتضایی  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 836_خدیجه_اشرفالسادات_مرتضایی_crawled.jpg
#
# [844] احسان خواجه‌امیری  → searching images…
#   ℹ️ 8 candidate(s) found
#   ✅ Candidate 1/8 OK → 844_احسان_خواجهامیری_crawled.jpg
#
# [845] علیرضا افتخاری مهیاری  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 845_علیرضا_افتخاری_مهیاری_crawled.jpg
#
# [865] عبدالحسن ستارپور  → searching images…
#   ℹ️ 9 candidate(s) found
#   ✅ Candidate 1/9 OK → 865_عبدالحسن_ستارپور_crawled.jpg
#
# [880] عصمت باقرپور بابلی  → searching images…
#   ℹ️ 9 candidate(s) found
#   ✅ Candidate 1/9 OK → 880_عصمت_باقرپور_بابلی_crawled.jpg
#
# [893] جواد یساری  → searching images…
#   ℹ️ 4 candidate(s) found
#   ✅ Candidate 1/4 OK → 893_جواد_یساری_crawled.jpg
#
# [896] پویا پورجلیل  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 896_پویا_پورجلیل_crawled.jpg
#
# [902] عبدالعلی وزیری  → searching images…
#   ℹ️ 3 candidate(s) found
#   ✅ Candidate 1/3 OK → 902_عبدالعلی_وزیری_crawled.jpg
#
# [903] لیلا فروهر  → searching images…
#   ℹ️ 7 candidate(s) found
#   ✅ Candidate 1/7 OK → 903_لیلا_فروهر_crawled.jpg
#
# [907] آندرانیک مددیان  → searching images…
#   ℹ️ 9 candidate(s) found
#   ✅ Candidate 1/9 OK → 907_آندرانیک_مددیان_crawled.jpg
#
# [914] حسن گل‌نراقی  → searching images…
#   ℹ️ 7 candidate(s) found
#   ✅ Candidate 1/7 OK → 914_حسن_گلنراقی_crawled.jpg
#
# [925] علی جهانبخش  → searching images…
#   ℹ️ 9 candidate(s) found
#   ✅ Candidate 1/9 OK → 925_علی_جهانبخش_crawled.jpg
#
# [928] داوود مقامی  → searching images…
#   ℹ️ 2 candidate(s) found
#   ✅ Candidate 1/2 OK → 928_داوود_مقامی_crawled.jpg
#
# [929] امجدالملوک جاهدیان  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 929_امجدالملوک_جاهدیان_crawled.jpg
#
# [930] حسن شماعی‌زاده  → searching images…
#   ℹ️ 8 candidate(s) found
#   ✅ Candidate 1/8 OK → 930_حسن_شماعیزاده_crawled.jpg
#
# [940] شادمهر عقیلی  → searching images…
#   ℹ️ 4 candidate(s) found
#   ✅ Candidate 1/4 OK → 940_شادمهر_عقیلی_crawled.jpg
#
# [942] نصرالله معین نجف‌آبادی  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 942_نصرالله_معین_نجفآبادی_crawled.jpg
#
# [955] منوچهر همایون‌پور  → searching images…
#   ℹ️ 2 candidate(s) found
#   ✅ Candidate 1/2 OK → 955_منوچهر_همایونپور_crawled.jpg
#
# [960] معصومه عزیزی بروجردی  → searching images…
#   ℹ️ 2 candidate(s) found
#   ✅ Candidate 1/2 OK → 960_معصومه_عزیزی_بروجردی_crawled.jpg
#
# [974] عارف عارف‌کیا  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 974_عارف_عارفکیا_crawled.jpg
#
# [975] سید علیرضا عصار  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 975_سید_علیرضا_عصار_crawled.jpg
#
# [981] منصور جعفری ممقانی  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 981_منصور_جعفری_ممقانی_crawled.jpg
#
# [984] وحید بهادری  → searching images…
#   ℹ️ 9 candidate(s) found
#   ✅ Candidate 1/9 OK → 984_وحید_بهادری_crawled.jpg
#
# [1006] معصومه دده‌بالا  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 1006_معصومه_ددهبالا_crawled.jpg
#
# [1008] مرتضی پاشایی  → searching images…
#   ℹ️ 8 candidate(s) found
#   ✅ Candidate 1/8 OK → 1008_مرتضی_پاشایی_crawled.jpg
#
# [1018] امید سلطانی  → searching images…
#   ℹ️ 10 candidate(s) found
#   ✅ Candidate 1/10 OK → 1018_امید_سلطانی_crawled.jpg
#
# [1020] شهپر امیرابراهیمی  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [1038] نعمت‌الله آزموده  → searching images…
#   ℹ️ 10 candidate(s) found
#   ✅ Candidate 1/10 OK → 1038_نعمتالله_آزموده_crawled.jpg
#
# [1040] سید بهنام صفوی  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 1040_سید_بهنام_صفوی_crawled.jpg
#
# [1074] داوود شعبانی نصر  → searching images…
#   ℹ️ 10 candidate(s) found
#   ✅ Candidate 1/10 OK → 1074_داوود_شعبانی_نصر_crawled.jpg
#
# [1118] گوهر خیراندیش  → searching images…
#   ℹ️ 6 candidate(s) found
#   ✅ Candidate 1/6 OK → 1118_گوهر_خیراندیش_crawled.jpg
#
# [1163] مریم شیرزاد  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [1174] یدالله کابلی خوانساری  → searching images…
#   ℹ️ 4 candidate(s) found
#   ✅ Candidate 1/4 OK → 1174_یدالله_کابلی_خوانساری_crawled.jpg
#
# [1217] روح‌الله خالقی  → searching images…
#   ℹ️ 9 candidate(s) found
#   ✅ Candidate 1/9 OK → 1217_روحالله_خالقی_crawled.jpg
#
# [1219] محمود ذوالفنون  → searching images…
#   ℹ️ 3 candidate(s) found
#   ✅ Candidate 1/3 OK → 1219_محمود_ذوالفنون_crawled.jpg
#
# [1240] محمدعلی زرندی  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 1240_محمدعلی_زرندی_crawled.jpg
#
# [1250] کتایون اعظمی  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [1252] مهین نویدی  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 1252_مهین_نویدی_crawled.jpg
#
# [1276] ایرج ناظریان  → searching images…
#   ℹ️ 2 candidate(s) found
#   ✅ Candidate 1/2 OK → 1276_ایرج_ناظریان_crawled.jpg
#
# [1279] پوران جین چی  → searching images…
#   ⚠️ No candidates found by any provider.
#
# [1325] مهین بزرگی  → searching images…
#   ℹ️ 3 candidate(s) found
#   ❌ Candidate 1/3 FAILED
#   ✅ Candidate 2/3 OK → 1325_مهین_بزرگی_crawled.jpg
#
# [1327] احمدرضا شفیعی‌جم  → searching images…
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 1327_احمدرضا_شفیعیجم_crawled.jpg
#
# --------------------------------------------------------------------------------------------------------------
# FILE DONE: art_music_with_bios_imaged.json
# Output JSON: art_music_with_bios_imaged_crawled.json
# Images dir:  art_music_images
# --------------------------------------------------------------------------------------------------------------
# Needed crawl: 124
# Succeeded:    109
# Failed:       15
# --------------------------------------------------------------------------------------------------------------
#
# All files processed.

# %% [markdown]
# # Athlete 2 files

# %%
Athlete_report = merge_pair("athlete17.json", "athlete19.json", "Athlete_merged.json")
# Out:
# ================================================================================
# Merged: athlete17.json  +  athlete19.json  →  Athlete_merged.json
# --------------------------------------------------------------------------------
# Inputs:
#   athlete17.json: 272
#   athlete19.json: 3068
# Name-key stats:
#   duplicates: 239
#   only_in_athlete17.json: 33
#   only_in_athlete19.json: 2810
# Duplicate image breakdown:
#   both_have_image: 239
#   only_first_has_image: 0
#   only_second_has_image: 0
#   neither_has_image: 0
# Output records: 3082
# --------------------------------------------------------------------------------
# Duplicates detail (name | added_keys_from_second | merged_keys):
#   - آرشام یسایی | +[] | merged=['_value']
#   - آرمین تشکری | +[] | merged=['_value']
#   - آرن داوودی | +[] | merged=['_value']
#   - آلمدین زیلیکیچ | +[] | merged=['_value']
#   - آلکس آغاسی | +[] | merged=['_value']
#   - ابوالفضل انوری | +[] | merged=['_value']
#   - ابوالفضل شهرجردی | +[] | merged=['_value']
#   - احسان حدادی | +[] | merged=['_value']
#   - احسان حسینی | +[] | merged=['_value']
#   - احسان روزبهانی | +[] | merged=['_value']
#   - احسان مرادیان | +[] | merged=['_value']
#   - احسان پیرهادی | +[] | merged=['_value']
#   - احمد عبدالله‌زاده | +[] | merged=['_value']
#   - احمد نوراللهی | +[] | merged=['_value']
#   - ادمیر آدرویچ | +[] | merged=['_value']
#   - ارشیا ارباب بهرامی | +[] | merged=['_value']
#   - ارغوان رضایی | +[] | merged=['_value']
#   - اسماعیل عبدی | +[] | merged=['_value']
#   - اشکان خورشیدی | +[] | merged=['_value']
#   - افسانه چترنور | +[] | merged=['_value']
#   - افشین ناظمی | +[] | merged=['_value']
#   - الشن مرادی | +[] | merged=['_value']
#   - الکساندر مرکل | +[] | merged=['_value']
#   - امامعلی حبیبی | +[] | merged=['_value']
#   - امید ابراهیمی | +[] | merged=['_value']
#   - امید نظامی‌پور | +[] | merged=['_value']
#   - امید نمازی | +[] | merged=['_value']
#   - امیر توکلیان | +[] | merged=['_value']
#   - امیر مهدی‌زاده | +[] | merged=['_value']
#   - امیرحسین اسفندیار | +[] | merged=['_value']
#   - امیرعلی صادقی | +[] | merged=['_value']
#   - امیرمحمد نکونام | +[] | merged=['_value']
#   - امین منوچهری | +[] | merged=['_value']
#   - اکبر افتخاری | +[] | merged=['_value']
#   - اکبر میثاقیان | +[] | merged=['_value']
#   - اکرم خدابنده | +[] | merged=['_value']
#   - ایمن زاید | +[] | merged=['_value']
#   - ایوان مارکوویچ | +[] | merged=['_value']
#   - ایوب بنی‌نصرت | +[] | merged=['_value']
#   - بهادر نسیم‌اف | +[] | merged=['_value']
#   - بهرام مشتاقی | +[] | merged=['_value']
#   - بهروز نعمتی | +[] | merged=['_value']
#   - بولی سامبو | +[] | merged=['_value']
#   - بوژیدار رادوشویچ | +[] | merged=['_value']
#   - تومیسلاو ایویچ | +[] | merged=['_value']
#   - جواد یساری | +[] | merged=['_value']
#   - جورج توپالوویچ | +[] | merged=['_value']
#   - جی‌لوید ساموئل | +[] | merged=['_value']
#   - حامد میرزاپور | +[] | merged=['_value']
#   - حجت صدقی | +[] | merged=['_value']
#   - حسن اکرمی | +[] | merged=['_value']
#   - حسین باقری | +[] | merged=['_value']
#   - حسین بغلانی | +[] | merged=['_value']
#   - حسین تهامی | +[] | merged=['_value']
#   - حسین رضازاده | +[] | merged=['_value']
#   - حسین زامهران | +[] | merged=['_value']
#   - حسین ساکی | +[] | merged=['_value']
#   - حسین کریمی | +[] | merged=['_value']
#   - حسین کعبی | +[] | merged=['_value']
#   - حسین کیهانی | +[] | merged=['_value']
#   - حمید استیلی | +[] | merged=['_value']
#   - حمیدرضا گرشاسبی | +[] | merged=['_value']
#   - حنیف عمران‌زاده | +[] | merged=['_value']
#   - حیدر بهاروند | +[] | merged=['_value']
#   - خوان ایگناسیو مارتینز | +[] | merged=['_value']
#   - دلیمیر باجیچ | +[] | merged=['_value']
#   - دیوید ویکروم | +[] | merged=['_value']
#   - رابسون جانواریو | +[] | merged=['_value']
#   - رامین طاهری | +[] | merged=['_value']
#   - رحمان جعفری | +[] | merged=['_value']
#   - رحیم دست‌نشان | +[] | merged=['_value']
#   - رشاد صادقوف | +[] | merged=['_value']
#   - رضا صفایی | +[] | merged=['_value']
#   - رضا قوچان‌نژاد | +[] | merged=['_value']
#   - رناتو سیلویرا | +[] | merged=['_value']
#   - رودی گوتندورف | +[] | merged=['_value']
#   - زلاتکو کرانچار | +[] | merged=['_value']
#   - زهرا کریمی | +[] | merged=['_value']
#   - زوران کوکوت | +[] | merged=['_value']
#   - زینب گیوه | +[] | merged=['_value']
#   - سارا سادات خادم‌الشریعه | +[] | merged=['_value']
#   - سارا قمی | +[] | merged=['_value']
#   - سامان طهماسبی | +[] | merged=['_value']
#   - سامان قدوس | +[] | merged=['_value']
#   - سجاد مشایخی | +[] | merged=['_value']
#   - سجاد گنج‌زاده | +[] | merged=['_value']
#   - سرور جباروف | +[] | merged=['_value']
#   - سعید سحرخیزان | +[] | merged=['_value']
#   - سعید صادقی | +[] | merged=['_value']
#   - سعید عبدولی | +[] | merged=['_value']
#   - سعید علی‌نژادیان | +[] | merged=['_value']
#   - سعید محمدپور | +[] | merged=['_value']
#   - سعید ملایی | +[] | merged=['_value']
#   - سعید واسعی | +[] | merged=['_value']
#   - سعید چاه‌جویی | +[] | merged=['_value']
#   - سلیمان مهدیزاده | +[] | merged=['_value']
#   - سوشا مکانی | +[] | merged=['_value']
#   - سپهر ساعتچی | +[] | merged=['_value']
#   - سیامند رحمان | +[] | merged=['_value']
#   - سیاوش بختیاری‌زاده | +[] | merged=['_value']
#   - سید حمید سجادی | +[] | merged=['_value']
#   - سید مصطفی هاشمی‌طبا | +[] | merged=['_value']
#   - سیروس دین‌محمدی | +[] | merged=['_value']
#   - شاهین حاجی‌بابایی | +[] | merged=['_value']
#   - شبنم علیخانی | +[] | merged=['_value']
#   - شجاعت قانع | +[] | merged=['_value']
#   - شیخ آهنین | +[] | merged=['_value']
#   - شیرکوه حاجی رسولی | +[] | merged=['_value']
#   - طاها زارعی | +[] | merged=['_value']
#   - عباس رضوی | +[] | merged=['_value']
#   - عباس زندی | +[] | merged=['_value']
#   - عبدالصادق گرگانی | +[] | merged=['_value']
#   - عبدالله موحد | +[] | merged=['_value']
#   - عرفان آهنگریان | +[] | merged=['_value']
#   - عزت‌الله اکبری | +[] | merged=['_value']
#   - عظیم گوک | +[] | merged=['_value']
#   - علی تاجرنیا | +[] | merged=['_value']
#   - علی ثمری | +[] | merged=['_value']
#   - علی سامره | +[] | merged=['_value']
#   - علی شفیعی | +[] | merged=['_value']
#   - علی فتح‌الله‌زاده | +[] | merged=['_value']
#   - علی فداکار | +[] | merged=['_value']
#   - علی قربانی | +[] | merged=['_value']
#   - علی نجفی | +[] | merged=['_value']
#   - علی کفاشیان | +[] | merged=['_value']
#   - علیرضا اسدی | +[] | merged=['_value']
#   - علیرضا حقیقی | +[] | merged=['_value']
#   - علیرضا حیدری | +[] | merged=['_value']
#   - علیرضا فیروزجا | +[] | merged=['_value']
#   - عیسی مرادی | +[] | merged=['_value']
#   - غلام وفاخواه | +[] | merged=['_value']
#   - غلام‌رضا قصاب | +[] | merged=['_value']
#   - فاطمه ارژنگی | +[] | merged=['_value']
#   - فاطمه خلیلی | +[] | merged=['_value']
#   - فردین رابط | +[] | merged=['_value']
#   - فرزان عاشورزاده | +[] | merged=['_value']
#   - فرزین گروسیان | +[] | merged=['_value']
#   - فرشاد فرجی | +[] | merged=['_value']
#   - فرشاد محمدی‌مهر | +[] | merged=['_value']
#   - فرشید باقری | +[] | merged=['_value']
#   - فضل‌الله دهخدا | +[] | merged=['_value']
#   - لیتا سهیلا سهی | +[] | merged=['_value']
#   - لیلا وزیری | +[] | merged=['_value']
#   - ماریو بودیمیر | +[] | merged=['_value']
#   - مازیار زارع | +[] | merged=['_value']
#   - مامه بابا تیام | +[] | merged=['_value']
#   - مانوئل ژوزه | +[] | merged=['_value']
#   - مایک رستم‌پور | +[] | merged=['_value']
#   - مجتبی جباری | +[] | merged=['_value']
#   - مجیدرضا رهنورد | +[] | merged=['_value']
#   - محدثه گوداسیایی | +[] | merged=['_value']
#   - محرم علی خدایی | +[] | merged=['_value']
#   - محسن بیاتی‌نیا | +[] | merged=['_value']
#   - محسن قهرمانی | +[] | merged=['_value']
#   - محسن محمدسیفی | +[] | merged=['_value']
#   - محسن یزدانی | +[] | merged=['_value']
#   - محمد رضی‌پور | +[] | merged=['_value']
#   - محمد رهبری | +[] | merged=['_value']
#   - محمد رکنی‌پور | +[] | merged=['_value']
#   - محمد عسکری | +[] | merged=['_value']
#   - محمد عمری | +[] | merged=['_value']
#   - محمد عیسی | +[] | merged=['_value']
#   - محمد فرهنگ‌دوست | +[] | merged=['_value']
#   - محمد قاسمی | +[] | merged=['_value']
#   - محمد نژادمهدی | +[] | merged=['_value']
#   - محمد کشاورز | +[] | merged=['_value']
#   - محمدامین حاج‌محمدی | +[] | merged=['_value']
#   - محمدجعفر مرادی | +[] | merged=['_value']
#   - محمدجواد فالیزوانیان | +[] | merged=['_value']
#   - محمدحسین زاهدی‌فرد | +[] | merged=['_value']
#   - محمدرضا بردبار | +[] | merged=['_value']
#   - محمدرضا خالدآبادی | +[] | merged=['_value']
#   - محمدرضا خلعتبری | +[] | merged=['_value']
#   - محمدطاهر وادی | +[] | merged=['_value']
#   - محمدمبین عظیمی | +[] | merged=['_value']
#   - محمدمهدی یعقوبی | +[] | merged=['_value']
#   - محمود نامجوی | +[] | merged=['_value']
#   - مریم شیخعلی‌زاده | +[] | merged=['_value']
#   - مریم طوسی | +[] | merged=['_value']
#   - مریم هاشمی | +[] | merged=['_value']
#   - مسعود ریگی | +[] | merged=['_value']
#   - مسلم اسکندر فیلابی | +[] | merged=['_value']
#   - معراج اسماعیلی | +[] | merged=['_value']
#   - ملینا اسماعیلی | +[] | merged=['_value']
#   - منوچهر شفایی | +[] | merged=['_value']
#   - مهدی تاج | +[] | merged=['_value']
#   - مهدی جعفرپور | +[] | merged=['_value']
#   - مهدی زیدوند | +[] | merged=['_value']
#   - مهدی عبدی | +[] | merged=['_value']
#   - مهدی مرندی | +[] | merged=['_value']
#   - مهدی هاشمی‌نسب | +[] | merged=['_value']
#   - مهران امیری | +[] | merged=['_value']
#   - مهران برخورداری | +[] | merged=['_value']
#   - مهسا کدخدا | +[] | merged=['_value']
#   - موسی کولیبالی | +[] | merged=['_value']
#   - مونا دریس محمودی | +[] | merged=['_value']
#   - میثم مجیدی | +[] | merged=['_value']
#   - میشل ته ورده | +[] | merged=['_value']
#   - میلاد سرلک | +[] | merged=['_value']
#   - میلاد میداوودی | +[] | merged=['_value']
#   - ناصر حمصی | +[] | merged=['_value']
#   - ناهید کیانی | +[] | merged=['_value']
#   - نگار کیانی | +[] | merged=['_value']
#   - نیما انتظاری | +[] | merged=['_value']
#   - هادی ساعی | +[] | merged=['_value']
#   - هادی محمدی | +[] | merged=['_value']
#   - هادی نوری | +[] | merged=['_value']
#   - هوشنگ نصیرزاده | +[] | merged=['_value']
#   - وارتکس پارسانیان | +[] | merged=['_value']
#   - وازیک قازاریان | +[] | merged=['_value']
#   - پاکو خمز | +[] | merged=['_value']
#   - پدرام قاضی‌پور | +[] | merged=['_value']
#   - پری فردی | +[] | merged=['_value']
#   - پریسا جهانفکریان | +[] | merged=['_value']
#   - پوران زارع | +[] | merged=['_value']
#   - پوریای ولی | +[] | merged=['_value']
#   - پویا نزهتی | +[] | merged=['_value']
#   - پژمان جمشیدی | +[] | merged=['_value']
#   - پیام حیدری | +[] | merged=['_value']
#   - پیمان اکبری | +[] | merged=['_value']
#   - ژاله سید هادی‌زاده | +[] | merged=['_value']
#   - ژرژ لیکنز | +[] | merged=['_value']
#   - ژلیکو میاچ | +[] | merged=['_value']
#   - کرار جاسم | +[] | merged=['_value']
#   - کریستین اوساگونا | +[] | merged=['_value']
#   - کریم احمدی | +[] | merged=['_value']
#   - کوروش قربانی | +[] | merged=['_value']
#   - کوروش محمدخانی | +[] | merged=['_value']
#   - کوین یانسن | +[] | merged=['_value']
#   - کیا اسکندانی | +[] | merged=['_value']
#   - کیا جورابچیان | +[] | merged=['_value']
#   - کیانوش رحمتی | +[] | merged=['_value']
#   - کیانوش رستمی | +[] | merged=['_value']
#   - کیمیا علیزاده | +[] | merged=['_value']
#   - گئورگی گئورگیف | +[] | merged=['_value']
#   - گئورگی گولسیانی | +[] | merged=['_value']
#   - گیتی محبان | +[] | merged=['_value']
#   - یاسین سلمانی | +[] | merged=['_value']
#   - یونس دلفی | +[] | merged=['_value']
# ================================================================================

# %%
ATHLETE_JSON_IN = "Athlete_merged.json"
ATHLETE_JSON_OUT = "athlete_merged_with_bios.json"

ATHLETE_CSVS = ["athlete_biography_1.csv", "athlete_biography_2.csv"]

# %%
run_pipeline("athlete", ATHLETE_JSON_IN, ATHLETE_JSON_OUT, ATHLETE_CSVS)
# Out:
# ========================================================================================
# ATHLETE — Merging narratives into JSON
# ========================================================================================
# CSV inputs: athlete_biography_1.csv, athlete_biography_2.csv
# Biographies parsed (rows with '،'): 5881
# Unique names in CSVs: 5293
# Names with multiple bios: 569 (first few: کوین بولی, بهرام مشتاقی, محمد چهارمحالی, فرهاد پیروت‌پور, رشاد صادقوف, کیانوش رحمتی, علی تاجرنیا, اکبر میثاقیان, حمیدرضا زوهانی, ادمیر آدرویچ)
# JSON input: Athlete_merged.json | records: 3082 | indexable by name: 3081
# ----------------------------------------------------------------------------------------
# Added summary fields:
#   summary : 3064
#   summary2: 376
#   summary3: 12
# Skipped extra bios (already had summary3): 3
# Unfound narrative records: 2229
# Examples (normalized): ['کوین بولی', 'محمد چهارمحالی', 'علا عبدالزَهره', 'مهران عالیقدر', 'احسان جودکی', 'مهرشاد مؤمنی', 'بهروز رهبر', 'محمدرضا تندروان', 'سعید بهاءلو هوره', 'اسحاق سبحانی', 'سعید امرایی', 'fábio carvalho', 'آرش شرقی', 'حمید سلطانی', 'هوشنگ ملک\u200cلو', 'آدمار براگا', 'علیرضا قدیری', 'هاشم صیامی', 'پوریا کیاشمشکی', 'امین تقی\u200cزاده']
# Output written to: athlete_merged_with_bios.json
# ========================================================================================

# %%
FILES = ["athlete_merged_with_bios.json"]

reports = []
for fname in FILES:
    p = Path(fname)
    if p.exists():
        rep = summarize_file(p)
        reports.append(rep)
    else:
        print(f"⚠️  Skipping (not found): {fname}")

# Print per-file and totals
totals = {"total": 0, "summary": 0, "summary2": 0, "summary3": 0, "without_any_summary": 0}

for r in reports:
    print("\n" + "="*70)
    print(f"File: {r['file']}")
    print("-"*70)
    print(f"Total records:           {r['total']}")
    print(f"With summary:            {r['summary']}")
    print(f"With summary2:           {r['summary2']}")
    print(f"With summary3:           {r['summary3']}")
    print(f"Without any summary*:    {r['without_any_summary']}")
    print("="*70)

    for k in totals:
        totals[k] += r[k] if k in r else 0

if reports:
    print("\n" + "#"*70)
    print("AGGREGATE TOTALS (all processed files)")
    print("#"*70)
    print(f"Total records:           {totals['total']}")
    print(f"With summary:            {totals['summary']}")
    print(f"With summary2:           {totals['summary2']}")
    print(f"With summary3:           {totals['summary3']}")
    print(f"Without any summary*:    {totals['without_any_summary']}")
    print("#"*70)
else:
    print("No files processed.")
# Out:
# ======================================================================
# File: athlete_merged_with_bios.json
# ----------------------------------------------------------------------
# Total records:           3082
# With summary:            3064
# With summary2:           376
# With summary3:           12
# Without any summary*:    18
# ======================================================================
#
# ######################################################################
# AGGREGATE TOTALS (all processed files)
# ######################################################################
# Total records:           3082
# With summary:            3064
# With summary2:           376
# With summary3:           12
# Without any summary*:    18
# ######################################################################

# %%
INPUTS = [
    {
        "json_in":  "athlete_merged_with_bios.json",
        "json_out": "athlete_merged_with_bios_imaged.json",
        "img_dir":  "athlete_images",
    }
]

# %%
for idx, rec in enumerate(records):
    name = rec.get("name") or f"record_{idx}"
    name_safe = sanitize_filename(name)
    image_obj = rec.get("image")

    print(f"\n[{idx}] {name}")
    record_ok = False
    any_urls_found = False

    if isinstance(image_obj, dict) and image_obj:
        # (UNCHANGED) original dict-style handling (young/adult/tomb, etc.)
        image_fields = list(image_obj.keys())
        if FIELDS_WHITELIST:
            image_fields = [k for k in image_fields if k in FIELDS_WHITELIST]

        if not image_fields:
            print("  ⚠️ image object present but no fields to check (whitelist filtered all).")

        for field in image_fields:
            field_val = image_obj.get(field)
            if field_val is None or (isinstance(field_val, (str, list, dict)) and not field_val):
                print(f"  • {field}: ⚠️ field missing/empty")
                continue

            urls = list(dict.fromkeys(iter_urls(field_val)))  # dedup in-order
            if not urls:
                print(f"  • {field}: ⚠️ no URL found under this field")
                continue

            any_urls_found = True
            print(f"  • {field}: ℹ️ found {len(urls)} URL(s) → resolving…")

            saved_this_field = False
            for url in urls:
                candidates = resolve_to_direct_images(url)
                if not candidates:
                    print(f"      - {url} → ℹ️ no direct image resolvable")
                    continue

                print(f"      - {url} → ℹ️ resolved {len(candidates)} candidate(s)")
                for cand in candidates:
                    filename = f"{idx}_{name_safe}_{sanitize_filename(field)}.jpg"
                    out_path = img_dir / filename
                    ok = download_image(cand, str(out_path))
                    if ok:
                        print(f"         ✅ download OK → {out_path.name}")
                        saved_this_field = True
                        record_ok = True
                        break
                    else:
                        print(f"         ❌ download FAILED for candidate")

                if saved_this_field:
                    break

            if not saved_this_field:
                print(f"  • {field}: ❌ URL extracted but download missed for all candidates")

            time.sleep(random.uniform(0.05, 0.2))

    # ===== ADDED: handle a single URL string in image =====
    elif isinstance(image_obj, str):
        urls = list(dict.fromkeys(iter_urls(image_obj)))  # will yield the string if it looks like a URL
        if not urls:
            print("  • image(str): ⚠️ no URL found in string value")
        else:
            any_urls_found = True
            print(f"  • image(str): ℹ️ found {len(urls)} URL(s) → resolving…")
            for url in urls:
                candidates = resolve_to_direct_images(url)
                if not candidates:
                    print(f"      - {url} → ℹ️ no direct image resolvable")
                    continue
                print(f"      - {url} → ℹ️ resolved {len(candidates)} candidate(s)")
                for cand in candidates:
                    filename = f"{idx}_{name_safe}_image.jpg"
                    out_path = img_dir / filename
                    ok = download_image(cand, str(out_path))
                    if ok:
                        print(f"         ✅ download OK → {out_path.name}")
                        record_ok = True
                        break
                    else:
                        print("         ❌ download FAILED for candidate")
                if record_ok:
                    break
            time.sleep(random.uniform(0.05, 0.2))

    # ===== ADDED: handle a list/tuple/set of URL strings =====
    elif isinstance(image_obj, (list, tuple, set)):
        list_urls = list(dict.fromkeys(iter_urls(list(image_obj))))  # de-dup in order
        if not list_urls:
            print("  • image(list): ⚠️ no URL(s) found in list")
        else:
            any_urls_found = True
            print(f"  • image(list): ℹ️ found {len(list_urls)} URL(s) → resolving…")
            for i, url in enumerate(list_urls, start=1):
                candidates = resolve_to_direct_images(url)
                if not candidates:
                    print(f"      - {url} → ℹ️ no direct image resolvable")
                    continue
                print(f"      - {url} → ℹ️ resolved {len(candidates)} candidate(s)")
                for cand in candidates:
                    filename = f"{idx}_{name_safe}_image{i}.jpg"
                    out_path = img_dir / filename
                    ok = download_image(cand, str(out_path))
                    if ok:
                        print(f"         ✅ download OK → {out_path.name}")
                        record_ok = True
                        break
                    else:
                        print("         ❌ download FAILED for candidate")
                if record_ok:
                    break
            time.sleep(random.uniform(0.05, 0.2))

    else:
        print("  ⚠️ image field missing/empty or unsupported type")

    # per-record summary + flag (UNCHANGED)
    rec["is_image_downloaded"] = bool(record_ok)
    if record_ok:
        print("  ▶︎ SUMMARY: ✅ Download COMPLETE for this record")
        downloaded_true += 1
    else:
        if any_urls_found:
            print("  ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed")
        else:
            print("  ▶︎ SUMMARY: ❌ URL missed (no usable URLs)")
        downloaded_false += 1

    time.sleep(random.uniform(0.05, 0.25))
# Out:
# [0] Hellper/صفحه تمرین
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [1] Jorvan Vieira
#   • image(list): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/3/34/Jorvan_Vieira.jpg/250px-Jorvan_Vieira.jpg → ℹ️ resolved 1 candidate(s)
#          ✅ download OK → 1_Jorvan_Vieira_image1.jpg
#   ▶︎ SUMMARY: ✅ Download COMPLETE for this record
#
# [2] آتسو استویکوف
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/d/dd/20170621_Admira_Wacker_vs_Vardar_Skopje_Aco_Stojkov_DSC_6107.jpg/250px-20170621_Admira_Wacker_vs_Vardar_Skopje_Aco_Stojkov_DSC_6107.jpg → ℹ️ resolved 1 candidate(s)
#          ✅ download OK → 2_آتسو_استویکوف_image.jpg
#   ▶︎ SUMMARY: ✅ Download COMPLETE for this record
#
# [3] آتنا محمدی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/fa/thumb/9/9e/Atena_Mohammadi.jpg/250px-Atena_Mohammadi.jpg → ℹ️ resolved 1 candidate(s)
#          ✅ download OK → 3_آتنا_محمدی_image.jpg
#   ▶︎ SUMMARY: ✅ Download COMPLETE for this record
#
# [4] آتوسا پورکاشیان
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/AtousaPourkashiyan.jpg/250px-AtousaPourkashiyan.jpg → ℹ️ resolved 1 candidate(s)
#          ✅ download OK → 4_آتوسا_پورکاشیان_image.jpg
#   ▶︎ SUMMARY: ✅ Download COMPLETE for this record
#
# [5] آتوسا گلشادنژاد
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [6] آتیلا حجازی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/5/56/Atila_Hejazi.jpg/250px-Atila_Hejazi.jpg → ℹ️ resolved 1 candidate(s)
#          ✅ download OK → 6_آتیلا_حجازی_image.jpg
#   ▶︎ SUMMARY: ✅ Download COMPLETE for this record
#
# [7] آدام جمیلی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/cb/Adam_Gemili_Rio_2016.jpg/250px-Adam_Gemili_Rio_2016.jpg → ℹ️ resolved 1 candidate(s)
#          ✅ download OK → 7_آدام_جمیلی_image.jpg
#   ▶︎ SUMMARY: ✅ Download COMPLETE for this record
#
# [8] آدام همتی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/b/b2/Adam_Hemati.jpg/250px-Adam_Hemati.jpg → ℹ️ resolved 1 candidate(s)
#          ✅ download OK → 8_آدام_همتی_image.jpg
#   ▶︎ SUMMARY: ✅ Download COMPLETE for this record
#
# [9] آدریانو آلوز
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/4/41/Adriano_Alves%2C_Esteghlal_Ahvaz_FC_vs_Esteghlal_FC%2C_29_September_2005.jpg → ℹ️ resolved 1 candidate(s)
#          ✅ download OK → 9_آدریانو_آلوز_image.jpg
#   ▶︎ SUMMARY: ✅ Download COMPLETE for this record
#
# [10] آرا هاکوبیان
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/2/22/Bayat_Shohreh_%2829398726383%29_%28cropped%29.jpg/250px-Bayat_Shohreh_%2829398726383%29_%28cropped%29.jpg → ℹ️ resolved 1 candidate(s)
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\socket.py:837, in create_connection(address, timeout, source_address, all_errors)
#     836     sock.bind(source_address)
# --> 837 sock.connect(sa)
#     838 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[69], line 78
#      76 filename = f"{idx}_{name_safe}_image.jpg"
#      77 out_path = img_dir / filename
# ---> 78 ok = download_image(cand, str(out_path))
#      79 if ok:
#      80     print(f"         ✅ download OK → {out_path.name}")
#
# Cell In[34], line 187, in download_image(url, image_path)
#     185 def download_image(url, image_path):
#     186     try:
# --> 187         with http_open(url, timeout=35) as resp:
#     188             final_url = resp.geturl()
#     189             ctype = (resp.headers.get("Content-Type") or "").lower()
#
# Cell In[59], line 9, in http_open(url, timeout)
#       7 def http_open(url, timeout=35):
#       8     req = urllib.request.Request(url, headers=HEADERS)
# ----> 9     return urllib.request.urlopen(req, timeout=timeout)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:215, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213 else:
#     214     opener = _opener
# --> 215 return opener.open(url, data, timeout)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:515, in OpenerDirector.open(self, fullurl, data, timeout)
#     512     req = meth(req)
#     514 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 515 response = self._open(req, data)
#     517 # post-process response
#     518 meth_name = protocol+"_response"
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:532, in OpenerDirector._open(self, req, data)
#     529     return result
#     531 protocol = req.type
# --> 532 result = self._call_chain(self.handle_open, protocol, protocol +
#     533                           '_open', req)
#     534 if result:
#     535     return result
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:492, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     490 for handler in handlers:
#     491     func = getattr(handler, meth_name)
# --> 492     result = func(*args)
#     493     if result is not None:
#     494         return result
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:1392, in HTTPSHandler.https_open(self, req)
#    1391 def https_open(self, req):
# -> 1392     return self.do_open(http.client.HTTPSConnection, req,
#    1393                         context=self._context)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:1344, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1342 try:
#    1343     try:
# -> 1344         h.request(req.get_method(), req.selector, req.data, headers,
#    1345                   encode_chunked=req.has_header('Transfer-encoding'))
#    1346     except OSError as err: # timeout error
#    1347         raise URLError(err)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\http\client.py:1327, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1324 def request(self, method, url, body=None, headers={}, *,
#    1325             encode_chunked=False):
#    1326     """Send a complete request to the server."""
# -> 1327     self._send_request(method, url, body, headers, encode_chunked)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\http\client.py:1373, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1369 if isinstance(body, str):
#    1370     # RFC 2616 Section 3.7.1 says that text default has a
#    1371     # default charset of iso-8859-1.
#    1372     body = _encode(body, 'body')
# -> 1373 self.endheaders(body, encode_chunked=encode_chunked)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\http\client.py:1322, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1320 else:
#    1321     raise CannotSendHeader()
# -> 1322 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\http\client.py:1081, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1079 msg = b"\r\n".join(self._buffer)
#    1080 del self._buffer[:]
# -> 1081 self.send(msg)
#    1083 if message_body is not None:
#    1084
#    1085     # create a consistent interface to message_body
#    1086     if hasattr(message_body, 'read'):
#    1087         # Let file-like take precedence over byte-like.  This
#    1088         # is needed to allow the current position of mmap'ed
#    1089         # files to be taken into account.
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\http\client.py:1025, in HTTPConnection.send(self, data)
#    1023 if self.sock is None:
#    1024     if self.auto_open:
# -> 1025         self.connect()
#    1026     else:
#    1027         raise NotConnected()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\http\client.py:1461, in HTTPSConnection.connect(self)
#    1458 def connect(self):
#    1459     "Connect to a host on a given (SSL) port."
# -> 1461     super().connect()
#    1463     if self._tunnel_host:
#    1464         server_hostname = self._tunnel_host
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\http\client.py:991, in HTTPConnection.connect(self)
#     989 """Connect to the host and port specified in __init__."""
#     990 sys.audit("http.client.connect", self, self.host, self.port)
# --> 991 self.sock = self._create_connection(
#     992     (self.host,self.port), self.timeout, self.source_address)
#     993 # Might fail in OSs that don't implement TCP_NODELAY
#     994 try:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\socket.py:844, in create_connection(address, timeout, source_address, all_errors)
#     842 except error as exc:
#     843     if not all_errors:
# --> 844         exceptions.clear()  # raise only the last error
#     845     exceptions.append(exc)
#     846     if sock is not None:
#
# KeyboardInterrupt:

# %%
for idx, rec in enumerate(records):
    name = rec.get("name") or f"record_{idx}"
    name_safe = sanitize_filename(name)
    image_obj = rec.get("image")

    # NEW: skip records already downloaded in a previous run
    if rec.get("is_image_downloaded", False) is True:
        print(f"\n[{idx}] {name}  ▶︎ already downloaded — skipping")
        downloaded_true += 1   # (or use a separate 'skipped' counter if you prefer)
        continue

    print(f"\n[{idx}] {name}")
    record_ok = False
    any_urls_found = False

    if isinstance(image_obj, dict) and image_obj:
        # (UNCHANGED) original dict-style handling (young/adult/tomb, etc.)
        image_fields = list(image_obj.keys())
        if FIELDS_WHITELIST:
            image_fields = [k for k in image_fields if k in FIELDS_WHITELIST]

        if not image_fields:
            print("  ⚠️ image object present but no fields to check (whitelist filtered all).")

        for field in image_fields:
            field_val = image_obj.get(field)
            if field_val is None or (isinstance(field_val, (str, list, dict)) and not field_val):
                print(f"  • {field}: ⚠️ field missing/empty")
                continue

            urls = list(dict.fromkeys(iter_urls(field_val)))  # dedup in-order
            if not urls:
                print(f"  • {field}: ⚠️ no URL found under this field")
                continue

            any_urls_found = True
            print(f"  • {field}: ℹ️ found {len(urls)} URL(s) → resolving…")

            saved_this_field = False
            for url in urls:
                candidates = resolve_to_direct_images(url)
                if not candidates:
                    print(f"      - {url} → ℹ️ no direct image resolvable")
                    continue

                print(f"      - {url} → ℹ️ resolved {len(candidates)} candidate(s)")
                for cand in candidates:
                    filename = f"{idx}_{name_safe}_{sanitize_filename(field)}.jpg"
                    out_path = img_dir / filename
                    ok = download_image(cand, str(out_path))
                    if ok:
                        print(f"         ✅ download OK → {out_path.name}")
                        saved_this_field = True
                        record_ok = True
                        break
                    else:
                        print(f"         ❌ download FAILED for candidate")

                if saved_this_field:
                    break

            if not saved_this_field:
                print(f"  • {field}: ❌ URL extracted but download missed for all candidates")

            time.sleep(random.uniform(0.05, 0.2))

    # ===== handle a single URL string in image =====
    elif isinstance(image_obj, str):
        urls = list(dict.fromkeys(iter_urls(image_obj)))  # will yield the string if it looks like a URL
        if not urls:
            print("  • image(str): ⚠️ no URL found in string value")
        else:
            any_urls_found = True
            print(f"  • image(str): ℹ️ found {len(urls)} URL(s) → resolving…")
            for url in urls:
                candidates = resolve_to_direct_images(url)
                if not candidates:
                    print(f"      - {url} → ℹ️ no direct image resolvable")
                    continue
                print(f"      - {url} → ℹ️ resolved {len(candidates)} candidate(s)")
                for cand in candidates:
                    filename = f"{idx}_{name_safe}_image.jpg"
                    out_path = img_dir / filename
                    ok = download_image(cand, str(out_path))
                    if ok:
                        print(f"         ✅ download OK → {out_path.name}")
                        record_ok = True
                        break
                    else:
                        print("         ❌ download FAILED for candidate")
                if record_ok:
                    break
            time.sleep(random.uniform(0.05, 0.2))

    # ===== handle a list/tuple/set of URL strings =====
    elif isinstance(image_obj, (list, tuple, set)):
        list_urls = list(dict.fromkeys(iter_urls(list(image_obj))))  # de-dup in order
        if not list_urls:
            print("  • image(list): ⚠️ no URL(s) found in list")
        else:
            any_urls_found = True
            print(f"  • image(list): ℹ️ found {len(list_urls)} URL(s) → resolving…")
            for i, url in enumerate(list_urls, start=1):
                candidates = resolve_to_direct_images(url)
                if not candidates:
                    print(f"      - {url} → ℹ️ no direct image resolvable")
                    continue
                print(f"      - {url} → ℹ️ resolved {len(candidates)} candidate(s)")
                for cand in candidates:
                    filename = f"{idx}_{name_safe}_image{i}.jpg"
                    out_path = img_dir / filename
                    ok = download_image(cand, str(out_path))
                    if ok:
                        print(f"         ✅ download OK → {out_path.name}")
                        record_ok = True
                        break
                    else:
                        print("         ❌ download FAILED for candidate")
                if record_ok:
                    break
            time.sleep(random.uniform(0.05, 0.2))

    else:
        print("  ⚠️ image field missing/empty or unsupported type")

    # per-record summary + flag (UNCHANGED)
    rec["is_image_downloaded"] = bool(record_ok)
    if record_ok:
        print("  ▶︎ SUMMARY: ✅ Download COMPLETE for this record")
        downloaded_true += 1
    else:
        if any_urls_found:
            print("  ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed")
        else:
            print("  ▶︎ SUMMARY: ❌ URL missed (no usable URLs)")
        downloaded_false += 1

    time.sleep(random.uniform(0.05, 0.25))
# Out:
# [0] Hellper/صفحه تمرین
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [1] Jorvan Vieira  ▶︎ already downloaded — skipping
#
# [2] آتسو استویکوف  ▶︎ already downloaded — skipping
#
# [3] آتنا محمدی  ▶︎ already downloaded — skipping
#
# [4] آتوسا پورکاشیان  ▶︎ already downloaded — skipping
#
# [5] آتوسا گلشادنژاد
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [6] آتیلا حجازی  ▶︎ already downloaded — skipping
#
# [7] آدام جمیلی  ▶︎ already downloaded — skipping
#
# [8] آدام همتی  ▶︎ already downloaded — skipping
#
# [9] آدریانو آلوز  ▶︎ already downloaded — skipping
#
# [10] آرا هاکوبیان
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/2/2f/Flag_of_Armenia.svg/40px-Flag_of_Armenia.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [11] آرارات آراکلیان
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/2/2f/Flag_of_Armenia.svg/40px-Flag_of_Armenia.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [12] آرامائیس تونویان
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/2/2f/Flag_of_Armenia.svg/40px-Flag_of_Armenia.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [13] آرتور میناسیان
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/2/2f/Flag_of_Armenia.svg/40px-Flag_of_Armenia.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [14] آرتور یدیگاریان  ▶︎ already downloaded — skipping
#
# [15] آرتوش آساطوریان
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/f/fd/State_flag_of_Iran_%281964%E2%80%931980%29.svg/40px-State_flag_of_Iran_%281964%E2%80%931980%29.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [16] آرداشس ساگینیان
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/f/fd/State_flag_of_Iran_%281964%E2%80%931980%29.svg/40px-State_flag_of_Iran_%281964%E2%80%931980%29.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [17] آرزو حکیمی مقدم
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [18] آرش استواری  ▶︎ already downloaded — skipping
#
# [19] آرش افشین  ▶︎ already downloaded — skipping
#
# [20] آرش برهانی  ▶︎ already downloaded — skipping
#
# [21] آرش خرم‌علی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [22] آرش داجلیری  ▶︎ already downloaded — skipping
#
# [23] آرش رضاوند  ▶︎ already downloaded — skipping
#
# [24] آرش طاهباز
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [25] آرش کمانگیر  ▶︎ already downloaded — skipping
#
# [26] آرشام یسایی  ▶︎ already downloaded — skipping
#
# [27] آرشاک آمیریان
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/2/2f/Flag_of_Armenia.svg/40px-Flag_of_Armenia.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [28] آرمان اکوان  ▶︎ already downloaded — skipping
#
# [29] آرمان رمضانی  ▶︎ already downloaded — skipping
#
# [30] آرمان زنگنه
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Silver_medal_icon_%28Nun_initial%29_fa.svg/16px-Silver_medal_icon_%28Nun_initial%29_fa.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [31] آرمان علیزاده عبدولی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [32] آرمان غفاری  ▶︎ already downloaded — skipping
#
# [33] آرمان قاسمی  ▶︎ already downloaded — skipping
#
# [34] آرماندو سا  ▶︎ already downloaded — skipping
#
# [35] آرمن تیگرانیان
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/2/2f/Flag_of_Armenia.svg/40px-Flag_of_Armenia.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [36] آرمناک پطروسیان  ▶︎ already downloaded — skipping
#
# [37] آرمین افشین فر  ▶︎ already downloaded — skipping
#
# [38] آرمین تشکری  ▶︎ already downloaded — skipping
#
# [39] آرمین سهرابیان  ▶︎ already downloaded — skipping
#
# [40] آرمین هادی‌پور  ▶︎ already downloaded — skipping
#
# [41] آرمینا صادقیان  ▶︎ already downloaded — skipping
#
# [42] آرن داوودی  ▶︎ already downloaded — skipping
#
# [43] آروین معظمی گودرزی  ▶︎ already downloaded — skipping
#
# [44] آری هان  ▶︎ already downloaded — skipping
#
# [45] آریا برزگر  ▶︎ already downloaded — skipping
#
# [46] آریا جسورو هاسگاوا  ▶︎ already downloaded — skipping
#
# [47] آریا داوری  ▶︎ already downloaded — skipping
#
# [48] آریا نسیمی‌شاد  ▶︎ already downloaded — skipping
#
# [49] آرین سلیمی  ▶︎ already downloaded — skipping
#
# [50] آرین طاری  ▶︎ already downloaded — skipping
#
# [51] آرین غلامی  ▶︎ already downloaded — skipping
#
# [52] آستان ارونوف  ▶︎ already downloaded — skipping
#
# [53] آقاخان چهارم  ▶︎ already downloaded — skipping
#
# [54] آقوان مکرتچیان
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/2/2f/Flag_of_Armenia.svg/40px-Flag_of_Armenia.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [55] آلساندرو   ▶︎ already downloaded — skipping
#
# [56] آلمدین زیلیکیچ  ▶︎ already downloaded — skipping
#
# [57] آلن راجرز  ▶︎ already downloaded — skipping
#
# [58] آلوارو خوزه خیمنز گررو  ▶︎ already downloaded — skipping
#
# [59] آلویس نانگ  ▶︎ already downloaded — skipping
#
# [60] آلکس آغاسی  ▶︎ already downloaded — skipping
#
# [61] آلکو اسکندریان  ▶︎ already downloaded — skipping
#
# [62] آنا براتی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [63] آناهیتا زاهدی‌فر  ▶︎ already downloaded — skipping
#
# [64] آناهیتا زمانیان  ▶︎ already downloaded — skipping
#
# [65] آنتونی استوکس  ▶︎ already downloaded — skipping
#
# [66] آنتونیو سیموئز  ▶︎ already downloaded — skipping
#
# [67] آنتونیو مانیکونه
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/0/03/Flag_of_Italy.svg/40px-Flag_of_Italy.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [68] آنتونیو ژوزه کونسیسائو اولیویرا  ▶︎ already downloaded — skipping
#
# [69] آندرانیک اسکندریان  ▶︎ already downloaded — skipping
#
# [70] آندرانیک تیموریان  ▶︎ already downloaded — skipping
#
# [71] آندره آغاسی  ▶︎ already downloaded — skipping
#
# [72] آندره رینالدو
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/0/05/Flag_of_Brazil.svg/40px-Flag_of_Brazil.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [73] آندره‌آ استراماچونی  ▶︎ already downloaded — skipping
#
# [74] آندری پانادیچ  ▶︎ already downloaded — skipping
#
# [75] آنوشا مهدیان
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [76] آوانس مگردومیان
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/f/fd/State_flag_of_Iran_%281964%E2%80%931980%29.svg/40px-State_flag_of_Iran_%281964%E2%80%931980%29.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [77] آوسنتی گیلائوری  ▶︎ already downloaded — skipping
#
# [78] آگوستو سزار موریرا  ▶︎ already downloaded — skipping
#
# [79] آیاندا پاتوسی  ▶︎ already downloaded — skipping
#
# [80] آیت واگذاری
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [81] آیتک سلامت  ▶︎ already downloaded — skipping
#
# [82] آیدا گل‌محمدی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [83] آیدین ختائی  ▶︎ already downloaded — skipping
#
# [84] آیدین نیکخواه بهرامی  ▶︎ already downloaded — skipping
#
# [85] ابراهیم آشتیانی  ▶︎ already downloaded — skipping
#
# [86] ابراهیم افشارپور
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/f/fd/State_flag_of_Iran_%281964%E2%80%931980%29.svg/40px-State_flag_of_Iran_%281964%E2%80%931980%29.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [87] ابراهیم الهی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [88] ابراهیم برخورداری
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [89] ابراهیم بیوگرادلیچ  ▶︎ already downloaded — skipping
#
# [90] ابراهیم تقی‌پور  ▶︎ already downloaded — skipping
#
# [91] ابراهیم تهامی  ▶︎ already downloaded — skipping
#
# [92] ابراهیم جوادی  ▶︎ already downloaded — skipping
#
# [93] ابراهیم حلاج یزدی  ▶︎ already downloaded — skipping
#
# [94] ابراهیم خواری
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [95] ابراهیم رحیمیان
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [96] ابراهیم شکوری  ▶︎ already downloaded — skipping
#
# [97] ابراهیم صادقی  ▶︎ already downloaded — skipping
#
# [98] ابراهیم فتحی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [99] ابراهیم قادری
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [100] ابراهیم قاسم‌پور  ▶︎ already downloaded — skipping
#
# [101] ابراهیم مهربان
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/8/8d/Gold_medal_icon_%28Ta_initial%29_fa.svg/16px-Gold_medal_icon_%28Ta_initial%29_fa.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [102] ابراهیم میرزاپور  ▶︎ already downloaded — skipping
#
# [103] ابراهیم نصیری
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [104] ابراهیم پیروی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/f/fd/State_flag_of_Iran_%281964%E2%80%931980%29.svg/40px-State_flag_of_Iran_%281964%E2%80%931980%29.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [105] ابراهیم کریمی  ▶︎ already downloaded — skipping
#
# [106] ابوالحسن ابتهاج  ▶︎ already downloaded — skipping
#
# [107] ابوالحسن ایلچی کبیر
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [108] ابوالفتح یافت‌آبادی  ▶︎ already downloaded — skipping
#
# [109] ابوالفضل انوری  ▶︎ already downloaded — skipping
#
# [110] ابوالفضل اولیایی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [111] ابوالفضل بهادرانی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [112] ابوالفضل جلالی  ▶︎ already downloaded — skipping
#
# [113] ابوالفضل حاجی‌زاده  ▶︎ already downloaded — skipping
#
# [114] ابوالفضل حسین‌پور
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/8/8d/Gold_medal_icon_%28Ta_initial%29_fa.svg/16px-Gold_medal_icon_%28Ta_initial%29_fa.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [115] ابوالفضل درویش‌وند  ▶︎ already downloaded — skipping
#
# [116] ابوالفضل رحمانی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [117] ابوالفضل رزاق‌پور  ▶︎ already downloaded — skipping
#
# [118] ابوالفضل شهرجردی  ▶︎ already downloaded — skipping
#
# [119] ابوالفضل صلبی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/f/fd/State_flag_of_Iran_%281964%E2%80%931980%29.svg/40px-State_flag_of_Iran_%281964%E2%80%931980%29.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [120] ابوالفضل عکاشه  ▶︎ already downloaded — skipping
#
# [121] ابوالفضل یعقوبی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [122] ابوالقاسم عروجی  ▶︎ already downloaded — skipping
#
# [123] ابوبکر کامارا  ▶︎ already downloaded — skipping
#
# [124] ابوذر ربیع‌زاده هفشجانی  ▶︎ already downloaded — skipping
#
# [125] ابوذر رحیمی  ▶︎ already downloaded — skipping
#
# [126] ابوطالب طالبی  ▶︎ already downloaded — skipping
#
# [127] احد جوان‌صالحی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [128] احد شیخ‌لاری  ▶︎ already downloaded — skipping
#
# [129] احد پازاج
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [130] احسان امینی  ▶︎ already downloaded — skipping
#
# [131] احسان حاج‌صفی  ▶︎ already downloaded — skipping
#
# [132] احسان حدادی  ▶︎ already downloaded — skipping
#
# [133] احسان حسینی  ▶︎ already downloaded — skipping
#
# [134] احسان دانش دوست
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [135] احسان دلیرزهان
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/a/a4/Bronze_medal_icon_%28Ba_initial%29_fa.svg/16px-Bronze_medal_icon_%28Ba_initial%29_fa.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [136] احسان روزبهانی  ▶︎ already downloaded — skipping
#
# [137] احسان علوان‌زاده  ▶︎ already downloaded — skipping
#
# [138] احسان قائم‌مقامی  ▶︎ already downloaded — skipping
#
# [139] احسان لشگری  ▶︎ already downloaded — skipping
#
# [140] احسان مرادیان  ▶︎ already downloaded — skipping
#
# [141] احسان مهاجرشجاعی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [142] احسان پنشنبه  ▶︎ already downloaded — skipping
#
# [143] احسان پهلوان  ▶︎ already downloaded — skipping
#
# [144] احسان پیرهادی  ▶︎ already downloaded — skipping
#
# [145] احسان پیغمبری
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [146] احسن‌الله شیرکوند  ▶︎ already downloaded — skipping
#
# [147] احلام   ▶︎ already downloaded — skipping
#
# [148] احمد آل نعمه  ▶︎ already downloaded — skipping
#
# [149] احمد آهی  ▶︎ already downloaded — skipping
#
# [150] احمد اسکندرپور
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [151] احمد افغان
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [152] احمد الجبوری  ▶︎ already downloaded — skipping
#
# [153] احمد امین‌زاده
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [154] احمد اکبری
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [155] احمد ایری
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [156] احمد ایزدپناه
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/f/fd/State_flag_of_Iran_%281964%E2%80%931980%29.svg/40px-State_flag_of_Iran_%281964%E2%80%931980%29.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [157] احمد بذری
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [158] احمد جمشیدیان  ▶︎ already downloaded — skipping
#
# [159] احمد خطیبی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [160] احمد درگاهی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/f/fd/State_flag_of_Iran_%281964%E2%80%931980%29.svg/40px-State_flag_of_Iran_%281964%E2%80%931980%29.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [161] احمد دنیامالی  ▶︎ already downloaded — skipping
#
# [162] احمد زنده‌روح
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [163] احمد سنجری
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [164] احمد صالحی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [165] احمد صمدیان  ▶︎ already downloaded — skipping
#
# [166] احمد عبدالله‌زاده  ▶︎ already downloaded — skipping
#
# [167] احمد قاسمی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [168] احمد مؤمن‌زاده  ▶︎ already downloaded — skipping
#
# [169] احمد محمدنژاد جوان
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [170] احمد محمدی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [171] احمد معین
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/6/65/Flag_of_Qatar.svg/40px-Flag_of_Qatar.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [172] احمد موسوی  ▶︎ already downloaded — skipping
#
# [173] احمد میرزاپور
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [174] احمد نوراللهی  ▶︎ already downloaded — skipping
#
# [175] احمد وفادار  ▶︎ already downloaded — skipping
#
# [176] احمد پیدایش
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [177] احمد گلبو
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [178] احمد گوهری  ▶︎ already downloaded — skipping
#
# [179] احمد یاقوتی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [180] احمدرضا جلالی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [181] احمدرضا زنده‌روح
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [182] احمدرضا طالبیان
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [183] احمدرضا عابدزاده  ▶︎ already downloaded — skipping
#
# [184] احمدعلی ابتهاج
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/f/fd/State_flag_of_Iran_%281964%E2%80%931980%29.svg/40px-State_flag_of_Iran_%281964%E2%80%931980%29.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [185] ادسون   ▶︎ already downloaded — skipping
#
# [186] ادموند اختر  ▶︎ already downloaded — skipping
#
# [187] ادموند بزیک  ▶︎ already downloaded — skipping
#
# [188] ادموند مایوفسکی  ▶︎ already downloaded — skipping
#
# [189] ادمیر آدرویچ  ▶︎ already downloaded — skipping
#
# [190] ادوارد مانگاسار
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [191] ادواردو فریرا  ▶︎ already downloaded — skipping
#
# [192] ادون حسنی  ▶︎ already downloaded — skipping
#
# [193] ادینیو  ▶︎ already downloaded — skipping
#
# [194] اردشیر قوانلوپور
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [195] اردلان آشتیانی  ▶︎ already downloaded — skipping
#
# [196] ارسلان امینی  ▶︎ already downloaded — skipping
#
# [197] ارسلان علیجانی منفرد
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [198] ارسلان مطهری  ▶︎ already downloaded — skipping
#
# [199] ارسلان کاظمی  ▶︎ already downloaded — skipping
#
# [200] ارشاد یوسفی  ▶︎ already downloaded — skipping
#
# [201] ارشک محبی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [202] ارشیا ارباب بهرامی  ▶︎ already downloaded — skipping
#
# [203] ارشیا الماسی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [204] ارطغرل ساغلام  ▶︎ already downloaded — skipping
#
# [205] ارغوان رضایی  ▶︎ already downloaded — skipping
#
# [206] ارنست میدندروپ  ▶︎ already downloaded — skipping
#
# [207] ارنی برندتس  ▶︎ already downloaded — skipping
#
# [208] اروین بولکو  ▶︎ already downloaded — skipping
#
# [209] استانکو پوکله‌پوویچ  ▶︎ already downloaded — skipping
#
# [210] استوان مویسیلوویچ  ▶︎ already downloaded — skipping
#
# [211] استیون ان‌زونزی  ▶︎ already downloaded — skipping
#
# [212] استیون بیت‌آشور  ▶︎ already downloaded — skipping
#
# [213] اسحاق حاتمی‌فر
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [214] اسحاق قویدل  ▶︎ already downloaded — skipping
#
# [215] اسدالله عظیمی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [216] اسدالله میهنی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/f/fd/State_flag_of_Iran_%281964%E2%80%931980%29.svg/40px-State_flag_of_Iran_%281964%E2%80%931980%29.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [217] اسفندیار زرنگار
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [218] اسلام جاهدی  ▶︎ already downloaded — skipping
#
# [219] اسما سعیدی  ▶︎ already downloaded — skipping
#
# [220] اسماعیل اسماعیلی  ▶︎ already downloaded — skipping
#
# [221] اسماعیل حلالی  ▶︎ already downloaded — skipping
#
# [222] اسماعیل شریفات  ▶︎ already downloaded — skipping
#
# [223] اسماعیل صفرزاده
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [224] اسماعیل عبادی  ▶︎ already downloaded — skipping
#
# [225] اسماعیل عبدی  ▶︎ already downloaded — skipping
#
# [226] اسماعیل علم‌خواه  ▶︎ already downloaded — skipping
#
# [227] اسماعیل مسافر  ▶︎ already downloaded — skipping
#
# [228] اسماعیل پاشاپور
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [229] اسماعیل کارتال  ▶︎ already downloaded — skipping
#
# [230] اسکندر شورا
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/f/fd/State_flag_of_Iran_%281964%E2%80%931980%29.svg/40px-State_flag_of_Iran_%281964%E2%80%931980%29.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [231] اشراق نجف‌آبادی  ▶︎ already downloaded — skipping
#
# [232] اشرف وحیدیان  ▶︎ already downloaded — skipping
#
# [233] اشپیتیم آرفی  ▶︎ already downloaded — skipping
#
# [234] اشکان خورشیدی  ▶︎ already downloaded — skipping
#
# [235] اشکان دژآگه  ▶︎ already downloaded — skipping
#
# [236] اشکان سعادتی فرد
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [237] اشکان شکوفی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [238] اشکان نامداری  ▶︎ already downloaded — skipping
#
# [239] اصغر ابراهیمی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [240] اصغر احساسی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/f/fd/State_flag_of_Iran_%281964%E2%80%931980%29.svg/40px-State_flag_of_Iran_%281964%E2%80%931980%29.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [241] اصغر حاجیلو  ▶︎ already downloaded — skipping
#
# [242] اصغر شرفی  ▶︎ already downloaded — skipping
#
# [243] اصغر کاردوست
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [244] اصغر گلی‌زاده  ▶︎ already downloaded — skipping
#
# [245] اعظم آخوندی  ▶︎ already downloaded — skipping
#
# [246] افسانه شیخی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [247] افسانه چترنور  ▶︎ already downloaded — skipping
#
# [248] افشین اسماعیل‌زاده
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [249] افشین بیابانگرد
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [250] افشین سلیمی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [251] افشین قطبی  ▶︎ already downloaded — skipping
#
# [252] افشین ناظمی  ▶︎ already downloaded — skipping
#
# [253] افشین نوروزی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [254] افشین پیروانی  ▶︎ already downloaded — skipping
#
# [255] افشین چاووشی  ▶︎ already downloaded — skipping
#
# [256] اف‌ام-۲۰۳۰  ▶︎ already downloaded — skipping
#
# [257] البرز حاجی‌پور  ▶︎ already downloaded — skipping
#
# [258] البرز زارعی  ▶︎ already downloaded — skipping
#
# [259] البرز زارعی کوهسرک  ▶︎ already downloaded — skipping
#
# [260] الشن مرادی  ▶︎ already downloaded — skipping
#
# [261] اللهیار صیادمنش  ▶︎ already downloaded — skipping
#
# [262] الله‌کرم استکی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Silver_medal_icon_%28Nun_initial%29_fa.svg/16px-Silver_medal_icon_%28Nun_initial%29_fa.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [263] الله‌یار صالح  ▶︎ already downloaded — skipping
#
# [264] الناز رکابی  ▶︎ already downloaded — skipping
#
# [265] الناز شفیعیان
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [266] الناز قاسمی  ▶︎ already downloaded — skipping
#
# [267] الناز کمپانی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [268] الهام حسینی  ▶︎ already downloaded — skipping
#
# [269] الهام رمضانی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [270] الهام شیخی   ▶︎ already downloaded — skipping
#
# [271] الهام فلاح  ▶︎ already downloaded — skipping
#
# [272] الهام قنبروف
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/d/dd/Flag_of_Azerbaijan.svg/40px-Flag_of_Azerbaijan.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [273] الهام هاشمی  ▶︎ already downloaded — skipping
#
# [274] الهام هریجانی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [275] الهام‌السادات اصغری
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [276] الهه احمدی  ▶︎ already downloaded — skipping
#
# [277] الهه منصوریان  ▶︎ already downloaded — skipping
#
# [278] الهه پورصالح  ▶︎ already downloaded — skipping
#
# [279] الویس کامسوبا  ▶︎ already downloaded — skipping
#
# [280] الکس سمیع‌زاده
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [281] الکساندر تادووسیان
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/2/2f/Flag_of_Armenia.svg/40px-Flag_of_Armenia.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [282] الکساندر مرکل  ▶︎ already downloaded — skipping
#
# [283] الیاس حضرتی  ▶︎ already downloaded — skipping
#
# [284] الیاس علی‌اکبری  ▶︎ already downloaded — skipping
#
# [285] الیاس هوریابند  ▶︎ already downloaded — skipping
#
# [286] الیاس پاکدل
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [287] امامعلی حبیبی  ▶︎ already downloaded — skipping
#
# [288] امانوئل آغاسی  ▶︎ already downloaded — skipping
#
# [289] امانوئل آغاسیEmmanuel B. Aghassi  ▶︎ already downloaded — skipping
#
# [290] امان‌الله جهانبانی  ▶︎ already downloaded — skipping
#
# [291] امان‌الله پاپی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [292] امید ابراهیمی  ▶︎ already downloaded — skipping
#
# [293] امید احمدی   ▶︎ already downloaded — skipping
#
# [294] امید احمدی‌صفا
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [295] امید تیزتک  ▶︎ already downloaded — skipping
#
# [296] امید حامدی‌فر  ▶︎ already downloaded — skipping
#
# [297] امید خالدی  ▶︎ already downloaded — skipping
#
# [298] امید سه‌کناری
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [299] امید سینگ  ▶︎ already downloaded — skipping
#
# [300] امید عالیشاه  ▶︎ already downloaded — skipping
#
# [301] امید لطف‌پور
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [302] امید منصوری  ▶︎ already downloaded — skipping
#
# [303] امید نظامی‌پور  ▶︎ already downloaded — skipping
#
# [304] امید نظری  ▶︎ already downloaded — skipping
#
# [305] امید نمازی  ▶︎ already downloaded — skipping
#
# [306] امید نورافکن  ▶︎ already downloaded — skipping
#
# [307] امید نوروزی  ▶︎ already downloaded — skipping
#
# [308] امیدرضا روانخواه  ▶︎ already downloaded — skipping
#
# [309] امیر امینی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [310] امیر باقری  ▶︎ already downloaded — skipping
#
# [311] امیر توکلیان  ▶︎ already downloaded — skipping
#
# [312] امیر جعفری ارنگه
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [313] امیر جوهری‌خو
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [314] امیر حاج رضایی  ▶︎ already downloaded — skipping
#
# [315] امیر حقوقی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [316] امیر دهداری
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [317] امیر راهنمای رونقی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [318] امیر روستایی  ▶︎ already downloaded — skipping
#
# [319] امیر زرگری
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [320] امیر شاپورزاده  ▶︎ already downloaded — skipping
#
# [321] امیر شرفی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [322] امیر شمسایی  ▶︎ already downloaded — skipping
#
# [323] امیر صدیقی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [324] امیر عابدزاده  ▶︎ already downloaded — skipping
#
# [325] امیر عابدینی  ▶︎ already downloaded — skipping
#
# [326] امیر عراقی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [327] امیر عرب‌براقی  ▶︎ already downloaded — skipping
#
# [328] امیر علی سعدالله  ▶︎ already downloaded — skipping
#
# [329] امیر علی‌اکبری  ▶︎ already downloaded — skipping
#
# [330] امیر غفور  ▶︎ already downloaded — skipping
#
# [331] امیر قاسمی‌منجزی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
# ...
#   ▶︎ SUMMARY: ✅ Download COMPLETE for this record
#
# [3033] گابریل کالدرون
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/1/1c/Persepolis_V_Pars_Jam_FC%2C_22_August_2019_1112.jpg/250px-Persepolis_V_Pars_Jam_FC%2C_22_August_2019_1112.jpg → ℹ️ resolved 1 candidate(s)
#          ✅ download OK → 3033_گابریل_کالدرون_image.jpg
#   ▶︎ SUMMARY: ✅ Download COMPLETE for this record
#
# [3034] گابریله پین
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/b/b4/Gabriele_Pin.JPG/250px-Gabriele_Pin.JPG → ℹ️ resolved 1 candidate(s)
#          ✅ download OK → 3034_گابریله_پین_image.jpg
#   ▶︎ SUMMARY: ✅ Download COMPLETE for this record
#
# [3035] گادوین منشا
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/b/bd/Godwin_Mensha_in_Fars_News_Agency.jpg/250px-Godwin_Mensha_in_Fars_News_Agency.jpg → ℹ️ resolved 1 candidate(s)
#          ✅ download OK → 3035_گادوین_منشا_image.jpg
#   ▶︎ SUMMARY: ✅ Download COMPLETE for this record
#
# [3036] گارنیک شه‌بندری
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/fa/thumb/e/e2/Garnik_Shahbandari.jpg/250px-Garnik_Shahbandari.jpg → ℹ️ resolved 1 candidate(s)
#          ✅ download OK → 3036_گارنیک_شهبندری_image.jpg
#   ▶︎ SUMMARY: ✅ Download COMPLETE for this record
#
# [3037] گارنیک مهرابیان
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/fa/thumb/c/c4/Garnik_Mehrabian.jpg/250px-Garnik_Mehrabian.jpg → ℹ️ resolved 1 candidate(s)
#          ✅ download OK → 3037_گارنیک_مهرابیان_image.jpg
#   ▶︎ SUMMARY: ✅ Download COMPLETE for this record
#
# [3038] گالوست پطروسیان
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/2/2f/Flag_of_Armenia.svg/40px-Flag_of_Armenia.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [3039] گریگور ملیکستیان
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/2/2f/Flag_of_Armenia.svg/40px-Flag_of_Armenia.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [3040] گریگول چابرادزه
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/8/85/Grigol_Chabradze_1.jpg → ℹ️ resolved 1 candidate(s)
#          ✅ download OK → 3040_گریگول_چابرادزه_image.jpg
#   ▶︎ SUMMARY: ✅ Download COMPLETE for this record
#
# [3041] گغارد موساسی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/0/09/Gegard_Mousasi.jpg/250px-Gegard_Mousasi.jpg → ℹ️ resolved 1 candidate(s)
#          ✅ download OK → 3041_گغارد_موساسی_image.jpg
#   ▶︎ SUMMARY: ✅ Download COMPLETE for this record
#
# [3042] گلاره ناظمی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/e/e1/Gelareh_Nazemi_2018-10-23_06.jpg/250px-Gelareh_Nazemi_2018-10-23_06.jpg → ℹ️ resolved 1 candidate(s)
#          ✅ download OK →
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/d/da/Yu_Darvish_on_August_5%2C_2017.jpg/250px-Yu_Darvish_on_August_5%2C_2017.jpg → ℹ️ resolved 1 candidate(s)
#          ✅ download OK → 3063_یو_درویش_image.jpg
#   ▶︎ SUMMARY: ✅ Download COMPLETE for this record
#
# [3064] یوانیس توپالیدیس
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/e/e5/Ioannis_Topalidis.jpg/250px-Ioannis_Topalidis.jpg → ℹ️ resolved 1 candidate(s)
#          ✅ download OK → 3064_یوانیس_توپالیدیس_image.jpg
#   ▶︎ SUMMARY: ✅ Download COMPLETE for this record
#
# [3065] یوسف سیدی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/5/54/Yousef_seyedi.jpg/250px-Yousef_seyedi.jpg → ℹ️ resolved 1 candidate(s)
#          ✅ download OK → 3065_یوسف_سیدی_image.jpg
#   ▶︎ SUMMARY: ✅ Download COMPLETE for this record
#
# [3066] یوسف سیدی گلی بلاغ
#   • image(list): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/5/54/Yousef_seyedi.jpg/250px-Yousef_seyedi.jpg → ℹ️ resolved 1 candidate(s)
#          ✅ download OK → 3066_یوسف_سیدی_گلی_بلاغ_image1.jpg
#   ▶︎ SUMMARY: ✅ Download COMPLETE for this record
#
# [3067] یوسف صبری
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [3068] یوسف صفوت
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/fa/thumb/a/a4/Yousof_Safvat_1960s.jpg/250px-Yousof_Safvat_1960s.jpg → ℹ️ resolved 1 candidate(s)
#          ✅ download OK → 3068_یوسف_صفوت_image.jpg
#   ▶︎ SUMMARY: ✅ Download COMPLETE for this record
#
# [3069] یوسف قادریان
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/7/70/Yousef_Ghaderian_2017.jpg → ℹ️ resolved 1 candidate(s)
#          ✅ download OK → 3069_یوسف_قادریان_image.jpg
#   ▶︎ SUMMARY: ✅ Download COMPLETE for this record
#
# [3070] یوسف وکیا
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/2/27/Yousef_Vakia.jpg → ℹ️ resolved 1 candidate(s)
#          ✅ download OK → 3070_یوسف_وکیا_image.jpg
#   ▶︎ SUMMARY: ✅ Download COMPLETE for this record
#
# [3071] یوسف کرمی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [3072] یونس امامی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [3073] یونس اکبرپور
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [3074] یونس باهنر
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/7/73/Younes_Bahonar.jpg/250px-Younes_Bahonar.jpg → ℹ️ resolved 1 candidate(s)
#          ✅ download OK → 3074_یونس_باهنر_image.jpg
#   ▶︎ SUMMARY: ✅ Download COMPLETE for this record
#
# [3075] یونس دلفی
#   • _value: ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/c8/Younes_Delfi_playing_for_Iran_U23_at_Asian_Games.jpg/250px-Younes_Delfi_playing_for_Iran_U23_at_Asian_Games.jpg → ℹ️ resolved 1 candidate(s)
#          ✅ download OK → 3075_یونس_دلفی__value.jpg
#   ▶︎ SUMMARY: ✅ Download COMPLETE for this record
#
# [3076] یونس سرمستی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed
#
# [3077] یونس شاکری
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/6/6d/Younes_Shakeri_2018.jpg/220px-Younes_Shakeri_2018.jpg → ℹ️ resolved 1 candidate(s)
#          ✅ download OK → 3077_یونس_شاکری_image.jpg
#   ▶︎ SUMMARY: ✅ Download COMPLETE for this record
#
# [3078] یونس فضلی جمور
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/8/82/%DB%8C%D9%88%D9%86%D8%B3_%D9%81%D8%B6%D9%84%DB%8C_%D8%AC%D9%85%D9%88%D8%B1.jpg/330px-%DB%8C%D9%88%D9%86%D8%B3_%D9%81%D8%B6%D9%84%DB%8C_%D8%AC%D9%85%D9%88%D8%B1.jpg → ℹ️ resolved 1 candidate(s)
#          ✅ download OK → 3078_یونس_فضلی_جمور_image.jpg
#   ▶︎ SUMMARY: ✅ Download COMPLETE for this record
#
# [3079] یونس مسعودی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/b/b8/Younes_masoudi_2019.jpg/250px-Younes_masoudi_2019.jpg → ℹ️ resolved 1 candidate(s)
#          ✅ download OK → 3079_یونس_مسعودی_image.jpg
#   ▶︎ SUMMARY: ✅ Download COMPLETE for this record
#
# [3080] یوکیا سوگیتا
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/5/58/Yukiya_Sugita_%28Sirius%2C_2020%2C_cropped%29.jpg/250px-Yukiya_Sugita_%28Sirius%2C_2020%2C_cropped%29.jpg → ℹ️ resolved 1 candidate(s)
#          ✅ download OK → 3080_یوکیا_سوگیتا_image.jpg
#   ▶︎ SUMMARY: ✅ Download COMPLETE for this record
#
# [3081] یکتا جمالی
#   • image(str): ℹ️ found 1 URL(s) → resolving…
#       - https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_Iran.svg/40px-Flag_of_Iran.svg.png → ℹ️ resolved 1 candidate(s)
#          ❌ download FAILED for candidate
#   ▶︎ SUMMARY: ❌ URL extracted but ALL downloads failed

# %%
need_crawl_count = sum(1 for r in records if not r.get("is_image_downloaded", False))
skipped_already_true = 0

for idx, rec in enumerate(records):
    name = rec.get("name") or f"record_{idx}"
    name_safe = sanitize_filename(name)

    # NEW: skip already-downloaded records (no re-download on reruns)
    if rec.get("is_image_downloaded", False) is True:
        print(f"\n[{idx}] {name}  ▶︎ already downloaded — skipping")
        skipped_already_true += 1
        continue

    query = name
    print(f"\n[{idx}] {name}  → searching images with query: {query} …")

    candidates = image_candidates_by_provider(query, MAX_IMAGE_CANDIDATES, start_provider)
    if not candidates:
        print("  ⚠️ No candidates found by any provider.")
        rec["is_image_downloaded"] = False
        failed += 1
        time.sleep(random.uniform(0.2, 0.5))
        continue

    print(f"  ℹ️ {len(candidates)} candidate(s) found")
    saved = False
    out_path = img_dir / f"{idx}_{name_safe}_crawled.jpg"

    for ci, url in enumerate(candidates, start=1):
        ok = download_image_to_jpeg(url, str(out_path))
        if ok:
            # --- CHANGED (preserve image value) ---
            img = rec.get("image")
            if isinstance(img, dict):
                img["crawled"] = url
            elif isinstance(img, (str, list)):
                rec["image"] = {"_value": img, "crawled": url}
            else:
                rec["image"] = {"crawled": url}

            rec["is_image_downloaded"] = True
            print(f"  ✅ Candidate {ci}/{len(candidates)} OK → {out_path.name}")
            saved = True
            success += 1
            break
        else:
            print(f"  ❌ Candidate {ci}/{len(candidates)} FAILED")
        time.sleep(random.uniform(0.15, 0.35))

    if not saved:
        rec["is_image_downloaded"] = False
        print("  ▶︎ RESULT: ❌ All candidates failed")
        failed += 1

    time.sleep(random.uniform(0.25, 0.6))

print(f"Needed crawl: {need_crawl_count}")
print(f"Skipped (already True): {skipped_already_true}")
print(f"Succeeded:    {success}")
print(f"Failed:       {failed}")
# Out:
# [0] Hellper/صفحه تمرین  → searching images with query: Hellper/صفحه تمرین …
#   ⚠️ No candidates found by any provider.
#
# [1] Jorvan Vieira  ▶︎ already downloaded — skipping
#
# [2] آتسو استویکوف  ▶︎ already downloaded — skipping
#
# [3] آتنا محمدی  ▶︎ already downloaded — skipping
#
# [4] آتوسا پورکاشیان  ▶︎ already downloaded — skipping
#
# [5] آتوسا گلشادنژاد  → searching images with query: آتوسا گلشادنژاد …
#   ⚠️ No candidates found by any provider.
#
# [6] آتیلا حجازی  ▶︎ already downloaded — skipping
#
# [7] آدام جمیلی  ▶︎ already downloaded — skipping
#
# [8] آدام همتی  ▶︎ already downloaded — skipping
#
# [9] آدریانو آلوز  ▶︎ already downloaded — skipping
#
# [10] آرا هاکوبیان   ▶︎ already downloaded — skipping
#
# [11] آرارات آراکلیان  → searching images with query: آرارات آراکلیان …
#   ⚠️ No candidates found by any provider.
#
# [12] آرامائیس تونویان  → searching images with query: آرامائیس تونویان …
#   ⚠️ No candidates found by any provider.
#
# [13] آرتور میناسیان  → searching images with query: آرتور میناسیان …
#   ⚠️ No candidates found by any provider.
#
# [14] آرتور یدیگاریان  ▶︎ already downloaded — skipping
#
# [15] آرتوش آساطوریان  → searching images with query: آرتوش آساطوریان …
#   ⚠️ No candidates found by any provider.
#
# [16] آرداشس ساگینیان  → searching images with query: آرداشس ساگینیان …
#   ⚠️ No candidates found by any provider.
#
# [17] آرزو حکیمی مقدم  → searching images with query: آرزو حکیمی مقدم …
#   ⚠️ No candidates found by any provider.
#
# [18] آرش استواری  ▶︎ already downloaded — skipping
#
# [19] آرش افشین  ▶︎ already downloaded — skipping
#
# [20] آرش برهانی  ▶︎ already downloaded — skipping
#
# [21] آرش خرم‌علی  → searching images with query: آرش خرم‌علی …
#   ⚠️ No candidates found by any provider.
#
# [22] آرش داجلیری  ▶︎ already downloaded — skipping
#
# [23] آرش رضاوند  ▶︎ already downloaded — skipping
#
# [24] آرش طاهباز  → searching images with query: آرش طاهباز …
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 24_آرش_طاهباز_crawled.jpg
#
# [25] آرش کمانگیر  ▶︎ already downloaded — skipping
#
# [26] آرشام یسایی  ▶︎ already downloaded — skipping
#
# [27] آرشاک آمیریان  → searching images with query: آرشاک آمیریان …
#   ⚠️ No candidates found by any provider.
#
# [28] آرمان اکوان  ▶︎ already downloaded — skipping
#
# [29] آرمان رمضانی  ▶︎ already downloaded — skipping
#
# [30] آرمان زنگنه  → searching images with query: آرمان زنگنه …
#   ⚠️ No candidates found by any provider.
#
# [31] آرمان علیزاده عبدولی  → searching images with query: آرمان علیزاده عبدولی …
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 31_آرمان_علیزاده_عبدولی_crawled.jpg
#
# [32] آرمان غفاری  ▶︎ already downloaded — skipping
#
# [33] آرمان قاسمی  ▶︎ already downloaded — skipping
#
# [34] آرماندو سا  ▶︎ already downloaded — skipping
#
# [35] آرمن تیگرانیان   → searching images with query: آرمن تیگرانیان  …
#   ℹ️ 10 candidate(s) found
#   ✅ Candidate 1/10 OK → 35_آرمن_تیگرانیان_crawled.jpg
#
# [36] آرمناک پطروسیان  ▶︎ already downloaded — skipping
#
# [37] آرمین افشین فر  ▶︎ already downloaded — skipping
#
# [38] آرمین تشکری  ▶︎ already downloaded — skipping
#
# [39] آرمین سهرابیان  ▶︎ already downloaded — skipping
#
# [40] آرمین هادی‌پور  ▶︎ already downloaded — skipping
#
# [41] آرمینا صادقیان  ▶︎ already downloaded — skipping
#
# [42] آرن داوودی  ▶︎ already downloaded — skipping
#
# [43] آروین معظمی گودرزی  ▶︎ already downloaded — skipping
#
# [44] آری هان  ▶︎ already downloaded — skipping
#
# [45] آریا برزگر  ▶︎ already downloaded — skipping
#
# [46] آریا جسورو هاسگاوا  ▶︎ already downloaded — skipping
#
# [47] آریا داوری  ▶︎ already downloaded — skipping
#
# [48] آریا نسیمی‌شاد  ▶︎ already downloaded — skipping
#
# [49] آرین سلیمی  ▶︎ already downloaded — skipping
#
# [50] آرین طاری  ▶︎ already downloaded — skipping
#
# [51] آرین غلامی  ▶︎ already downloaded — skipping
#
# [52] آستان ارونوف  ▶︎ already downloaded — skipping
#
# [53] آقاخان چهارم  ▶︎ already downloaded — skipping
#
# [54] آقوان مکرتچیان  → searching images with query: آقوان مکرتچیان …
#   ⚠️ No candidates found by any provider.
#
# [55] آلساندرو   ▶︎ already downloaded — skipping
#
# [56] آلمدین زیلیکیچ  ▶︎ already downloaded — skipping
#
# [57] آلن راجرز  ▶︎ already downloaded — skipping
#
# [58] آلوارو خوزه خیمنز گررو  ▶︎ already downloaded — skipping
#
# [59] آلویس نانگ  ▶︎ already downloaded — skipping
#
# [60] آلکس آغاسی  ▶︎ already downloaded — skipping
#
# [61] آلکو اسکندریان  ▶︎ already downloaded — skipping
#
# [62] آنا براتی  → searching images with query: آنا براتی …
#   ℹ️ 1 candidate(s) found
#   ❌ Candidate 1/1 FAILED
#   ▶︎ RESULT: ❌ All candidates failed
#
# [63] آناهیتا زاهدی‌فر  ▶︎ already downloaded — skipping
#
# [64] آناهیتا زمانیان  ▶︎ already downloaded — skipping
#
# [65] آنتونی استوکس  ▶︎ already downloaded — skipping
#
# [66] آنتونیو سیموئز  ▶︎ already downloaded — skipping
#
# [67] آنتونیو مانیکونه  → searching images with query: آنتونیو مانیکونه …
#   ⚠️ No candidates found by any provider.
#
# [68] آنتونیو ژوزه کونسیسائو اولیویرا  ▶︎ already downloaded — skipping
#
# [69] آندرانیک اسکندریان  ▶︎ already downloaded — skipping
#
# [70] آندرانیک تیموریان  ▶︎ already downloaded — skipping
#
# [71] آندره آغاسی  ▶︎ already downloaded — skipping
#
# [72] آندره رینالدو  → searching images with query: آندره رینالدو …
#   ℹ️ 10 candidate(s) found
#   ✅ Candidate 1/10 OK → 72_آندره_رینالدو_crawled.jpg
#
# [73] آندره‌آ استراماچونی  ▶︎ already downloaded — skipping
#
# [74] آندری پانادیچ  ▶︎ already downloaded — skipping
#
# [75] آنوشا مهدیان  → searching images with query: آنوشا مهدیان …
#   ⚠️ No candidates found by any provider.
#
# [76] آوانس مگردومیان  → searching images with query: آوانس مگردومیان …
#   ⚠️ No candidates found by any provider.
#
# [77] آوسنتی گیلائوری  ▶︎ already downloaded — skipping
#
# [78] آگوستو سزار موریرا  ▶︎ already downloaded — skipping
#
# [79] آیاندا پاتوسی  ▶︎ already downloaded — skipping
#
# [80] آیت واگذاری  → searching images with query: آیت واگذاری …
#   ℹ️ 3 candidate(s) found
#   ❌ Candidate 1/3 FAILED
#   ✅ Candidate 2/3 OK → 80_آیت_واگذاری_crawled.jpg
#
# [81] آیتک سلامت  ▶︎ already downloaded — skipping
#
# [82] آیدا گل‌محمدی  → searching images with query: آیدا گل‌محمدی …
#   ⚠️ No candidates found by any provider.
#
# [83] آیدین ختائی  ▶︎ already downloaded — skipping
#
# [84] آیدین نیکخواه بهرامی  ▶︎ already downloaded — skipping
#
# [85] ابراهیم آشتیانی  ▶︎ already downloaded — skipping
#
# [86] ابراهیم افشارپور  → searching images with query: ابراهیم افشارپور …
#   ⚠️ No candidates found by any provider.
#
# [87] ابراهیم الهی  → searching images with query: ابراهیم الهی …
#   ℹ️ 10 candidate(s) found
#   ✅ Candidate 1/10 OK → 87_ابراهیم_الهی_crawled.jpg
#
# [88] ابراهیم برخورداری  → searching images with query: ابراهیم برخورداری …
#   ℹ️ 1 candidate(s) found
#   ❌ Candidate 1/1 FAILED
#   ▶︎ RESULT: ❌ All candidates failed
#
# [89] ابراهیم بیوگرادلیچ  ▶︎ already downloaded — skipping
#
# [90] ابراهیم تقی‌پور  ▶︎ already downloaded — skipping
#
# [91] ابراهیم تهامی  ▶︎ already downloaded — skipping
#
# [92] ابراهیم جوادی  ▶︎ already downloaded — skipping
#
# [93] ابراهیم حلاج یزدی  ▶︎ already downloaded — skipping
#
# [94] ابراهیم خواری  → searching images with query: ابراهیم خواری …
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 94_ابراهیم_خواری_crawled.jpg
#
# [95] ابراهیم رحیمیان   → searching images with query: ابراهیم رحیمیان  …
#   ⚠️ No candidates found by any provider.
#
# [96] ابراهیم شکوری  ▶︎ already downloaded — skipping
#
# [97] ابراهیم صادقی  ▶︎ already downloaded — skipping
#
# [98] ابراهیم فتحی  → searching images with query: ابراهیم فتحی …
#   ℹ️ 9 candidate(s) found
#   ✅ Candidate 1/9 OK → 98_ابراهیم_فتحی_crawled.jpg
#
# [99] ابراهیم قادری  → searching images with query: ابراهیم قادری …
#   ℹ️ 3 candidate(s) found
#   ❌ Candidate 1/3 FAILED
#   ✅ Candidate 2/3 OK → 99_ابراهیم_قادری_crawled.jpg
#
# [100] ابراهیم قاسم‌پور  ▶︎ already downloaded — skipping
#
# [101] ابراهیم مهربان  → searching images with query: ابراهیم مهربان …
#   ℹ️ 1 candidate(s) found
#   ❌ Candidate 1/1 FAILED
#   ▶︎ RESULT: ❌ All candidates failed
#
# [102] ابراهیم میرزاپور  ▶︎ already downloaded — skipping
#
# [103] ابراهیم نصیری  → searching images with query: ابراهیم نصیری …
#   ℹ️ 4 candidate(s) found
#   ✅ Candidate 1/4 OK → 103_ابراهیم_نصیری_crawled.jpg
#
# [104] ابراهیم پیروی  → searching images with query: ابراهیم پیروی …
#   ℹ️ 5 candidate(s) found
#   ❌ Candidate 1/5 FAILED
#   ❌ Candidate 2/5 FAILED
#   ✅ Candidate 3/5 OK → 104_ابراهیم_پیروی_crawled.jpg
#
# [105] ابراهیم کریمی  ▶︎ already downloaded — skipping
#
# [106] ابوالحسن ابتهاج  ▶︎ already downloaded — skipping
#
# [107] ابوالحسن ایلچی کبیر  → searching images with query: ابوالحسن ایلچی کبیر …
#   ⚠️ No candidates found by any provider.
#
# [108] ابوالفتح یافت‌آبادی  ▶︎ already downloaded — skipping
#
# [109] ابوالفضل انوری  ▶︎ already downloaded — skipping
#
# [110] ابوالفضل اولیایی  → searching images with query: ابوالفضل اولیایی …
#   ⚠️ No candidates found by any provider.
#
# [111] ابوالفضل بهادرانی  → searching images with query: ابوالفضل بهادرانی …
#   ⚠️ No candidates found by any provider.
#
# [112] ابوالفضل جلالی  ▶︎ already downloaded — skipping
#
# [113] ابوالفضل حاجی‌زاده  ▶︎ already downloaded — skipping
#
# [114] ابوالفضل حسین‌پور  → searching images with query: ابوالفضل حسین‌پور …
#   ⚠️ No candidates found by any provider.
#
# [115] ابوالفضل درویش‌وند  ▶︎ already downloaded — skipping
#
# [116] ابوالفضل رحمانی  → searching images with query: ابوالفضل رحمانی …
#   ℹ️ 1 candidate(s) found
#   ❌ Candidate 1/1 FAILED
#   ▶︎ RESULT: ❌ All candidates failed
#
# [117] ابوالفضل رزاق‌پور  ▶︎ already downloaded — skipping
#
# [118] ابوالفضل شهرجردی  ▶︎ already downloaded — skipping
#
# [119] ابوالفضل صلبی  → searching images with query: ابوالفضل صلبی …
#   ⚠️ No candidates found by any provider.
#
# [120] ابوالفضل عکاشه  ▶︎ already downloaded — skipping
#
# [121] ابوالفضل یعقوبی  → searching images with query: ابوالفضل یعقوبی …
#   ⚠️ No candidates found by any provider.
#
# [122] ابوالقاسم عروجی  ▶︎ already downloaded — skipping
#
# [123] ابوبکر کامارا  ▶︎ already downloaded — skipping
#
# [124] ابوذر ربیع‌زاده هفشجانی  ▶︎ already downloaded — skipping
#
# [125] ابوذر رحیمی  ▶︎ already downloaded — skipping
#
# [126] ابوطالب طالبی  ▶︎ already downloaded — skipping
#
# [127] احد جوان‌صالحی  → searching images with query: احد جوان‌صالحی …
#   ⚠️ No candidates found by any provider.
#
# [128] احد شیخ‌لاری  ▶︎ already downloaded — skipping
#
# [129] احد پازاج  → searching images with query: احد پازاج …
#   ⚠️ No candidates found by any provider.
#
# [130] احسان امینی  ▶︎ already downloaded — skipping
#
# [131] احسان حاج‌صفی  ▶︎ already downloaded — skipping
#
# [132] احسان حدادی  ▶︎ already downloaded — skipping
#
# [133] احسان حسینی  ▶︎ already downloaded — skipping
#
# [134] احسان دانش دوست  → searching images with query: احسان دانش دوست …
#   ⚠️ No candidates found by any provider.
#
# [135] احسان دلیرزهان  → searching images with query: احسان دلیرزهان …
#   ⚠️ No candidates found by any provider.
#
# [136] احسان روزبهانی  ▶︎ already downloaded — skipping
#
# [137] احسان علوان‌زاده  ▶︎ already downloaded — skipping
#
# [138] احسان قائم‌مقامی  ▶︎ already downloaded — skipping
#
# [139] احسان لشگری  ▶︎ already downloaded — skipping
#
# [140] احسان مرادیان  ▶︎ already downloaded — skipping
#
# [141] احسان مهاجرشجاعی  → searching images with query: احسان مهاجرشجاعی …
#   ⚠️ No candidates found by any provider.
#
# [142] احسان پنشنبه  ▶︎ already downloaded — skipping
#
# [143] احسان پهلوان  ▶︎ already downloaded — skipping
#
# [144] احسان پیرهادی  ▶︎ already downloaded — skipping
#
# [145] احسان پیغمبری  → searching images with query: احسان پیغمبری …
#   ⚠️ No candidates found by any provider.
#
# [146] احسن‌الله شیرکوند  ▶︎ already downloaded — skipping
#
# [147] احلام   ▶︎ already downloaded — skipping
#
# [148] احمد آل نعمه  ▶︎ already downloaded — skipping
#
# [149] احمد آهی  ▶︎ already downloaded — skipping
#
# [150] احمد اسکندرپور  → searching images with query: احمد اسکندرپور …
#   ⚠️ No candidates found by any provider.
#
# [151] احمد افغان  → searching images with query: احمد افغان …
#   ℹ️ 10 candidate(s) found
#   ✅ Candidate 1/10 OK → 151_احمد_افغان_crawled.jpg
#
# [152] احمد الجبوری  ▶︎ already downloaded — skipping
#
# [153] احمد امین‌زاده  → searching images with query: احمد امین‌زاده …
#   ⚠️ No candidates found by any provider.
#
# [154] احمد اکبری  → searching images with query: احمد اکبری …
#   ℹ️ 10 candidate(s) found
#   ❌ Candidate 1/10 FAILED
#   ❌ Candidate 2/10 FAILED
#   ❌ Candidate 3/10 FAILED
#   ✅ Candidate 4/10 OK → 154_احمد_اکبری_crawled.jpg
#
# [155] احمد ایری  → searching images with query: احمد ایری …
#   ℹ️ 4 candidate(s) found
#   ✅ Candidate 1/4 OK → 155_احمد_ایری_crawled.jpg
#
# [156] احمد ایزدپناه  → searching images with query: احمد ایزدپناه …
#   ⚠️ No candidates found by any provider.
#
# [157] احمد بذری  → searching images with query: احمد بذری …
#   ⚠️ No candidates found by any provider.
#
# [158] احمد جمشیدیان  ▶︎ already downloaded — skipping
#
# [159] احمد خطیبی  → searching images with query: احمد خطیبی …
#   ℹ️ 2 candidate(s) found
#   ❌ Candidate 1/2 FAILED
#   ❌ Candidate 2/2 FAILED
#   ▶︎ RESULT: ❌ All candidates failed
#
# [160] احمد درگاهی  → searching images with query: احمد درگاهی …
#   ⚠️ No candidates found by any provider.
#
# [161] احمد دنیامالی  ▶︎ already downloaded — skipping
#
# [162] احمد زنده‌روح  → searching images with query: احمد زنده‌روح …
#   ⚠️ No candidates found by any provider.
#
# [163] احمد سنجری  → searching images with query: احمد سنجری …
#   ℹ️ 1 candidate(s) found
#   ❌ Candidate 1/1 FAILED
#   ▶︎ RESULT: ❌ All candidates failed
#
# [164] احمد صالحی  → searching images with query: احمد صالحی …
#   ℹ️ 3 candidate(s) found
#   ✅ Candidate 1/3 OK → 164_احمد_صالحی_crawled.jpg
#
# [165] احمد صمدیان  ▶︎ already downloaded — skipping
#
# [166] احمد عبدالله‌زاده  ▶︎ already downloaded — skipping
#
# [167] احمد قاسمی   → searching images with query: احمد قاسمی  …
#   ℹ️ 9 candidate(s) found
#   ✅ Candidate 1/9 OK → 167_احمد_قاسمی_crawled.jpg
#
# [168] احمد مؤمن‌زاده  ▶︎ already downloaded — skipping
#
# [169] احمد محمدنژاد جوان  → searching images with query: احمد محمدنژاد جوان …
#   ⚠️ No candidates found by any provider.
#
# [170] احمد محمدی   → searching images with query: احمد محمدی  …
#   ℹ️ 10 candidate(s) found
#   ✅ Candidate 1/10 OK → 170_احمد_محمدی_crawled.jpg
#
# [171] احمد معین  → searching images with query: احمد معین …
#   ℹ️ 10 candidate(s) found
#   ✅ Candidate 1/10 OK → 171_احمد_معین_crawled.jpg
#
# [172] احمد موسوی  ▶︎ already downloaded — skipping
#
# [173] احمد میرزاپور  → searching images with query: احمد میرزاپور …
#   ⚠️ No candidates found by any provider.
#
# [174] احمد نوراللهی  ▶︎ already downloaded — skipping
#
# [175] احمد وفادار  ▶︎ already downloaded — skipping
#
# [176] احمد پیدایش  → searching images with query: احمد پیدایش …
#   ℹ️ 9 candidate(s) found
#   ❌ Candidate 1/9 FAILED
#   ❌ Candidate 2/9 FAILED
#   ❌ Candidate 3/9 FAILED
#   ❌ Candidate 4/9 FAILED
#   ❌ Candidate 5/9 FAILED
#   ❌ Candidate 6/9 FAILED
#   ❌ Candidate 7/9 FAILED
#   ❌ Candidate 8/9 FAILED
#   ❌ Candidate 9/9 FAILED
#   ▶︎ RESULT: ❌ All candidates failed
#
# [177] احمد گلبو  → searching images with query: احمد گلبو …
#   ⚠️ No candidates found by any provider.
#
# [178] احمد گوهری  ▶︎ already downloaded — skipping
#
# [179] احمد یاقوتی  → searching images with query: احمد یاقوتی …
#   ℹ️ 3 candidate(s) found
#   ✅ Candidate 1/3 OK → 179_احمد_یاقوتی_crawled.jpg
#
# [180] احمدرضا جلالی   → searching images with query: احمدرضا جلالی  …
#   ⚠️ No candidates found by any provider.
#
# [181] احمدرضا زنده‌روح  → searching images with query: احمدرضا زنده‌روح …
#   ⚠️ No candidates found by any provider.
#
# [182] احمدرضا طالبیان  → searching images with query: احمدرضا طالبیان …
#   ⚠️ No candidates found by any provider.
#
# [183] احمدرضا عابدزاده  ▶︎ already downloaded — skipping
#
# [184] احمدعلی ابتهاج  → searching images with query: احمدعلی ابتهاج …
#   ⚠️ No candidates found by any provider.
#
# [185] ادسون   ▶︎ already downloaded — skipping
#
# [186] ادموند اختر  ▶︎ already downloaded — skipping
#
# [187] ادموند بزیک  ▶︎ already downloaded — skipping
#
# [188] ادموند مایوفسکی  ▶︎ already downloaded — skipping
#
# [189] ادمیر آدرویچ  ▶︎ already downloaded — skipping
#
# [190] ادوارد مانگاسار  → searching images with query: ادوارد مانگاسار …
#   ⚠️ No candidates found by any provider.
#
# [191] ادواردو فریرا  ▶︎ already downloaded — skipping
#
# [192] ادون حسنی  ▶︎ already downloaded — skipping
#
# [193] ادینیو  ▶︎ already downloaded — skipping
#
# [194] اردشیر قوانلوپور  → searching images with query: اردشیر قوانلوپور …
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 194_اردشیر_قوانلوپور_crawled.jpg
#
# [195] اردلان آشتیانی  ▶︎ already downloaded — skipping
#
# [196] ارسلان امینی  ▶︎ already downloaded — skipping
#
# [197] ارسلان علیجانی منفرد  → searching images with query: ارسلان علیجانی منفرد …
#   ⚠️ No candidates found by any provider.
#
# [198] ارسلان مطهری  ▶︎ already downloaded — skipping
#
# [199] ارسلان کاظمی  ▶︎ already downloaded — skipping
#
# [200] ارشاد یوسفی  ▶︎ already downloaded — skipping
#
# [201] ارشک محبی  → searching images with query: ارشک محبی …
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 201_ارشک_محبی_crawled.jpg
#
# [202] ارشیا ارباب بهرامی  ▶︎ already downloaded — skipping
#
# [203] ارشیا الماسی  → searching images with query: ارشیا الماسی …
#   ⚠️ No candidates found by any provider.
#
# [204] ارطغرل ساغلام  ▶︎ already downloaded — skipping
#
# [205] ارغوان رضایی  ▶︎ already downloaded — skipping
#
# [206] ارنست میدندروپ  ▶︎ already downloaded — skipping
#
# [207] ارنی برندتس  ▶︎ already downloaded — skipping
#
# [208] اروین بولکو  ▶︎ already downloaded — skipping
#
# [209] استانکو پوکله‌پوویچ  ▶︎ already downloaded — skipping
#
# [210] استوان مویسیلوویچ  ▶︎ already downloaded — skipping
#
# [211] استیون ان‌زونزی  ▶︎ already downloaded — skipping
#
# [212] استیون بیت‌آشور  ▶︎ already downloaded — skipping
#
# [213] اسحاق حاتمی‌فر  → searching images with query: اسحاق حاتمی‌فر …
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 213_اسحاق_حاتمیفر_crawled.jpg
#
# [214] اسحاق قویدل  ▶︎ already downloaded — skipping
#
# [215] اسدالله عظیمی  → searching images with query: اسدالله عظیمی …
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 215_اسدالله_عظیمی_crawled.jpg
#
# [216] اسدالله میهنی  → searching images with query: اسدالله میهنی …
#   ⚠️ No candidates found by any provider.
#
# [217] اسفندیار زرنگار  → searching images with query: اسفندیار زرنگار …
#   ⚠️ No candidates found by any provider.
#
# [218] اسلام جاهدی  ▶︎ already downloaded — skipping
#
# [219] اسما سعیدی  ▶︎ already downloaded — skipping
#
# [220] اسماعیل اسماعیلی  ▶︎ already downloaded — skipping
#
# [221] اسماعیل حلالی  ▶︎ already downloaded — skipping
#
# [222] اسماعیل شریفات  ▶︎ already downloaded — skipping
#
# [223] اسماعیل صفرزاده  → searching images with query: اسماعیل صفرزاده …
#   ⚠️ No candidates found by any provider.
#
# [224] اسماعیل عبادی  ▶︎ already downloaded — skipping
#
# [225] اسماعیل عبدی  ▶︎ already downloaded — skipping
#
# [226] اسماعیل علم‌خواه  ▶︎ already downloaded — skipping
#
# [227] اسماعیل مسافر  ▶︎ already downloaded — skipping
#
# [228] اسماعیل پاشاپور  → searching images with query: اسماعیل پاشاپور …
#   ⚠️ No candidates found by any provider.
#
# [229] اسماعیل کارتال  ▶︎ already downloaded — skipping
#
# [230] اسکندر شورا  → searching images with query: اسکندر شورا …
#   ⚠️ No candidates found by any provider.
#
# [231] اشراق نجف‌آبادی  ▶︎ already downloaded — skipping
#
# [232] اشرف وحیدیان  ▶︎ already downloaded — skipping
#
# [233] اشپیتیم آرفی  ▶︎ already downloaded — skipping
#
# [234] اشکان خورشیدی  ▶︎ already downloaded — skipping
#
# [235] اشکان دژآگه  ▶︎ already downloaded — skipping
#
# [236] اشکان سعادتی فرد  → searching images with query: اشکان سعادتی فرد …
#   ⚠️ No candidates found by any provider.
#
# [237] اشکان شکوفی  → searching images with query: اشکان شکوفی …
#   ⚠️ No candidates found by any provider.
#
# [238] اشکان نامداری  ▶︎ already downloaded — skipping
#
# [239] اصغر ابراهیمی  → searching images with query: اصغر ابراهیمی …
#   ℹ️ 1 candidate(s) found
#   ❌ Candidate 1/1 FAILED
#   ▶︎ RESULT: ❌ All candidates failed
#
# [240] اصغر احساسی  → searching images with query: اصغر احساسی …
#   ⚠️ No candidates found by any provider.
#
# [241] اصغر حاجیلو  ▶︎ already downloaded — skipping
#
# [242] اصغر شرفی  ▶︎ already downloaded — skipping
#
# [243] اصغر کاردوست  → searching images with query: اصغر کاردوست …
#   ⚠️ No candidates found by any provider.
#
# [244] اصغر گلی‌زاده  ▶︎ already downloaded — skipping
#
# [245] اعظم آخوندی  ▶︎ already downloaded — skipping
#
# [246] افسانه شیخی  → searching images with query: افسانه شیخی …
#   ℹ️ 1 candidate(s) found
#   ❌ Candidate 1/1 FAILED
#   ▶︎ RESULT: ❌ All candidates failed
#
# [247] افسانه چترنور  ▶︎ already downloaded — skipping
#
# [248] افشین اسماعیل‌زاده  → searching images with query: افشین اسماعیل‌زاده …
#   ⚠️ No candidates found by any provider.
#
# [249] افشین بیابانگرد  → searching images with query: افشین بیابانگرد …
#   ⚠️ No candidates found by any provider.
#
# [250] افشین سلیمی  → searching images with query: افشین سلیمی …
#   ⚠️ No candidates found by any provider.
#
# [251] افشین قطبی  ▶︎ already downloaded — skipping
#
# [252] افشین ناظمی  ▶︎ already downloaded — skipping
#
# [253] افشین نوروزی  → searching images with query: افشین نوروزی …
#   ℹ️ 2 candidate(s) found
#   ✅ Candidate 1/2 OK → 253_افشین_نوروزی_crawled.jpg
#
# [254] افشین پیروانی  ▶︎ already downloaded — skipping
#
# [255] افشین چاووشی  ▶︎ already downloaded — skipping
#
# [256] اف‌ام-۲۰۳۰  ▶︎ already downloaded — skipping
#
# [257] البرز حاجی‌پور  ▶︎ already downloaded — skipping
#
# [258] البرز زارعی  ▶︎ already downloaded — skipping
#
# [259] البرز زارعی کوهسرک  ▶︎ already downloaded — skipping
#
# [260] الشن مرادی  ▶︎ already downloaded — skipping
#
# [261] اللهیار صیادمنش  ▶︎ already downloaded — skipping
#
# [262] الله‌کرم استکی  → searching images with query: الله‌کرم استکی …
#   ⚠️ No candidates found by any provider.
#
# [263] الله‌یار صالح  ▶︎ already downloaded — skipping
#
# [264] الناز رکابی  ▶︎ already downloaded — skipping
#
# [265] الناز شفیعیان  → searching images with query: الناز شفیعیان …
#   ⚠️ No candidates found by any provider.
#
# [266] الناز قاسمی  ▶︎ already downloaded — skipping
#
# [267] الناز کمپانی  → searching images with query: الناز کمپانی …
#   ⚠️ No candidates found by any provider.
#
# [268] الهام حسینی  ▶︎ already downloaded — skipping
#
# [269] الهام رمضانی  → searching images with query: الهام رمضانی …
#   ℹ️ 2 candidate(s) found
#   ❌ Candidate 1/2 FAILED
#   ✅ Candidate 2/2 OK → 269_الهام_رمضانی_crawled.jpg
#
# [270] الهام شیخی   ▶︎ already downloaded — skipping
#
# [271] الهام فلاح  ▶︎ already downloaded — skipping
#
# [272] الهام قنبروف  → searching images with query: الهام قنبروف …
#   ⚠️ No candidates found by any provider.
#
# [273] الهام هاشمی  → searching images with query: الهام هاشمی …
#   ℹ️ 1 candidate(s) found
#   ❌ Candidate 1/1 FAILED
#   ▶︎ RESULT: ❌ All candidates failed
#
# [274] الهام هریجانی  → searching images with query: الهام هریجانی …
#   ⚠️ No candidates found by any provider.
#
# [275] الهام‌السادات اصغری  → searching images with query: الهام‌السادات اصغری …
#   ⚠️ No candidates found by any provider.
#
# [276] الهه احمدی  ▶︎ already downloaded — skipping
#
# [277] الهه منصوریان  ▶︎ already downloaded — skipping
#
# [278] الهه پورصالح  ▶︎ already downloaded — skipping
#
# [279] الویس کامسوبا  ▶︎ already downloaded — skipping
#
# [280] الکس سمیع‌زاده  → searching images with query: الکس سمیع‌زاده …
#   ⚠️ No candidates found by any provider.
#
# [281] الکساندر تادووسیان  → searching images with query: الکساندر تادووسیان …
#   ⚠️ No candidates found by any provider.
#
# [282] الکساندر مرکل  ▶︎ already downloaded — skipping
#
# [283] الیاس حضرتی  ▶︎ already downloaded — skipping
#
# [284] الیاس علی‌اکبری  ▶︎ already downloaded — skipping
#
# [285] الیاس هوریابند  ▶︎ already downloaded — skipping
#
# [286] الیاس پاکدل  → searching images with query: الیاس پاکدل …
#   ⚠️ No candidates found by any provider.
#
# [287] امامعلی حبیبی  ▶︎ already downloaded — skipping
#
# [288] امانوئل آغاسی  ▶︎ already downloaded — skipping
#
# [289] امانوئل آغاسیEmmanuel B. Aghassi  ▶︎ already downloaded — skipping
#
# [290] امان‌الله جهانبانی  ▶︎ already downloaded — skipping
#
# [291] امان‌الله پاپی  → searching images with query: امان‌الله پاپی …
#   ⚠️ No candidates found by any provider.
#
# [292] امید ابراهیمی  ▶︎ already downloaded — skipping
#
# [293] امید احمدی   ▶︎ already downloaded — skipping
#
# [294] امید احمدی‌صفا  → searching images with query: امید احمدی‌صفا …
#   ⚠️ No candidates found by any provider.
#
# [295] امید تیزتک  ▶︎ already downloaded — skipping
#
# [296] امید حامدی‌فر  ▶︎ already downloaded — skipping
#
# [297] امید خالدی  ▶︎ already downloaded — skipping
#
# [298] امید سه‌کناری  → searching images with query: امید سه‌کناری …
#   ⚠️ No candidates found by any provider.
#
# [299] امید سینگ  ▶︎ already downloaded — skipping
#
# [300] امید عالیشاه  ▶︎ already downloaded — skipping
#
# [301] امید لطف‌پور  → searching images with query: امید لطف‌پور …
#   ⚠️ No candidates found by any provider.
#
# [302] امید منصوری  ▶︎ already downloaded — skipping
#
# [303] امید نظامی‌پور  ▶︎ already downloaded — skipping
#
# [304] امید نظری  ▶︎ already downloaded — skipping
#
# [305] امید نمازی  ▶︎ already downloaded — skipping
#
# [306] امید نورافکن  ▶︎ already downloaded — skipping
#
# [307] امید نوروزی  ▶︎ already downloaded — skipping
#
# [308] امیدرضا روانخواه  ▶︎ already downloaded — skipping
#
# [309] امیر امینی  → searching images with query: امیر امینی …
#   ℹ️ 10 candidate(s) found
#   ✅ Candidate 1/10 OK → 309_امیر_امینی_crawled.jpg
#
# [310] امیر باقری  ▶︎ already downloaded — skipping
#
# [311] امیر توکلیان  ▶︎ already downloaded — skipping
#
# [312] امیر جعفری ارنگه  → searching images with query: امیر جعفری ارنگه …
#   ℹ️ 9 candidate(s) found
#   ✅ Candidate 1/9 OK → 312_امیر_جعفری_ارنگه_crawled.jpg
#
# [313] امیر جوهری‌خو  → searching images with query: امیر جوهری‌خو …
#   ⚠️ No candidates found by any provider.
#
# [314] امیر حاج رضایی  ▶︎ already downloaded — skipping
#
# [315] امیر حقوقی  → searching images with query: امیر حقوقی …
#   ℹ️ 6 candidate(s) found
#   ✅ Candidate 1/6 OK → 315_امیر_حقوقی_crawled.jpg
#
# [316] امیر دهداری  → searching images with query: امیر دهداری …
#   ⚠️ No candidates found by any provider.
#
# [317] امیر راهنمای رونقی  → searching images with query: امیر راهنمای رونقی …
#   ⚠️ No candidates found by any provider.
#
# [318] امیر روستایی  ▶︎ already downloaded — skipping
#
# [319] امیر زرگری  → searching images with query: امیر زرگری …
#   ⚠️ No candidates found by any provider.
#
# [320] امیر شاپورزاده  ▶︎ already downloaded — skipping
#
# [321] امیر شرفی  → searching images with query: امیر شرفی …
#   ⚠️ No candidates found by any provider.
#
# [322] امیر شمسایی  ▶︎ already downloaded — skipping
#
# [323] امیر صدیقی  → searching images with query: امیر صدیقی …
#   ℹ️ 10 candidate(s) found
#   ✅ Candidate 1/10 OK → 323_امیر_صدیقی_crawled.jpg
#
# [324] امیر عابدزاده  ▶︎ already downloaded — skipping
#
# [325] امیر عابدینی  ▶︎ already downloaded — skipping
#
# [326] امیر عراقی  → searching images with query: امیر عراقی …
#   ℹ️ 5 candidate(s) found
#   ✅ Candidate 1/5 OK → 326_امیر_عراقی_crawled.jpg
#
# [327] امیر عرب‌براقی  ▶︎ already downloaded — skipping
#
# [328] امیر علی سعدالله  ▶︎ already downloaded — skipping
#
# [329] امیر علی‌اکبری  ▶︎ already downloaded — skipping
#
# [330] امیر غفور  ▶︎ already downloaded — skipping
#
# [331] امیر قاسمی‌منجزی  → searching images with query: امیر قاسمی‌منجزی …
#   ⚠️ No candidates found by any provider.
#
# [332] امیر قلعه‌نویی  ▶︎ already downloaded — skipping
#
# [333] امیر قمی  ▶︎ already downloaded — skipping
#
# [334] امیر مرادی  ▶︎ already downloaded — skipping
#
# [335] امیر مرزوقی  → searching images with query: امیر مرزوقی …
#   ⚠️ No candidates found by any provider.
#
# [336] امیر معماری   ▶︎ already downloaded — skipping
#
# [337] امیر مهدی‌زاده  ▶︎ already downloaded — skipping
#
# [338] امیر هاشمی‌مقدم  ▶︎ already downloaded — skipping
#
# [339] امیر کاظم‌پور  → searching images with query: امیر کاظم‌پور …
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 339_امیر_کاظمپور_crawled.jpg
#
# [340] امیر یاوری  → searching images with query: امیر یاوری …
#   ℹ️ 10 candidate(s) found
#   ❌ Candidate 1/10 FAILED
#   ✅ Candidate 2/10 OK → 340_امیر_یاوری_crawled.jpg
#
# [341] امیرارسلان مطهری  ▶︎ already downloaded — skipping
#
# [342] امیرحسن فردوس  ▶︎ already downloaded — skipping
#
# [343] امیرحسین آذری  → searching images with query: امیرحسین آذری …
#   ⚠️ No candidates found by any provider.
#
# [344] امیرحسین اسفندیار  ▶︎ already downloaded — skipping
#
# [345] امیرحسین اسماعیل‌زاده  ▶︎ already downloaded — skipping
#
# [346] امیرحسین اصلانیان  ▶︎ already downloaded — skipping
#
# [347] امیرحسین تاتاری  ▶︎ already downloaded — skipping
#
# [348] امیرحسین توخته  ▶︎ already downloaded — skipping
#
# [349] امیرحسین حسینی  → searching images with query: امیرحسین حسینی …
#   ℹ️ 10 candidate(s) found
#   ✅ Candidate 1/10 OK → 349_امیرحسین_حسینی_crawled.jpg
#
# [350] امیرحسین حسین‌زاده  ▶︎ already downloaded — skipping
#
# [351] امیرحسین خدامرادی  ▶︎ already downloaded — skipping
#
# [352] امیرحسین رهبر  → searching images with query: امیرحسین رهبر …
#   ℹ️ 1 candidate(s) found
#   ❌ Candidate 1/1 FAILED
#   ▶︎ RESULT: ❌ All candidates failed
#
# [353] امیرحسین زارع  ▶︎ already downloaded — skipping
#
# [354] امیرحسین صابری  ▶︎ already downloaded — skipping
#
# [355] امیرحسین صادقی  ▶︎ already downloaded — skipping
#
# [356] امیرحسین علی‌پور دربید  ▶︎ already downloaded — skipping
#
# [357] امیرحسین فتحی  ▶︎ already downloaded — skipping
#
# [358] امیرحسین فداکار  ▶︎ already downloaded — skipping
#
# [359] امیرحسین فشنگچی  ▶︎ already downloaded — skipping
#
# [360] امیرحسین فیروزپور  → searching images with query: امیرحسین فیروزپور …
#   ⚠️ No candidates found by any provider.
#
# [361] امیرحسین مقصودی  ▶︎ already downloaded — skipping
#
# [362] امیرحسین هدایی  → searching images with query: امیرحسین هدایی …
#   ⚠️ No candidates found by any provider.
#
# [363] امیرحسین پیروانی  ▶︎ already downloaded — skipping
#
# [364] امیرحسین کارگر  ▶︎ already downloaded — skipping
#
# [365] امیرحسین کاووسی  → searching images with query: امیرحسین کاووسی …
#   ⚠️ No candidates found by any provider.
#
# [366] امیرحسین کیهانی  → searching images with query: امیرحسین کیهانی …
#   ⚠️ No candidates found by any provider.
#
# [367] امیرحسین یازرلو  → searching images with query: امیرحسین یازرلو …
#   ⚠️ No candidates found by any provider.
#
# [368] امیررضا خادم  ▶︎ already downloaded — skipping
#
# [369] امیررضا ده‌بزرگی  → searching images with query: امیررضا ده‌بزرگی …
#   ⚠️ No candidates found by any provider.
#
# [370] امیررضا رفیعی  ▶︎ already downloaded — skipping
#
# [371] امیررضا واعظی آشتیانی  ▶︎ already downloaded — skipping
#
# [372] امیررضا پورآقابالا  → searching images with query: امیررضا پورآقابالا …
#   ⚠️ No candidates found by any provider.
#
# [373] امیررضا پوررمضانعلی  ▶︎ already downloaded — skipping
#
# [374] امیرسیاوش ذوالفقاریان  ▶︎ already downloaded — skipping
#
# [375] امیرعلی آذرپیرا  ▶︎ already downloaded — skipping
#
# [376] امیرعلی صادقی  ▶︎ already downloaded — skipping
#
# [377] امیرعلی قلی‌زاده  → searching images with query: امیرعلی قلی‌زاده …
#   ℹ️ 1 candidate(s) found
#   ❌ Candidate 1/1 FAILED
#   ▶︎ RESULT: ❌ All candidates failed
#
# [378] امیرعلی کاظمی  → searching images with query: امیرعلی کاظمی …
#   ⚠️ No candidates found by any provider.
#
# [379] امیرمحمد نکونام  ▶︎ already downloaded — skipping
#
# [380] امیرمحمد گلزاده  ▶︎ already downloaded — skipping
#
# [381] امیرمحمد یزدانی  → searching images with query: امیرمحمد یزدانی …
#   ℹ️ 2 candidate(s) found
#   ✅ Candidate 1/2 OK → 381_امیرمحمد_یزدانی_crawled.jpg
#
# [382] امیرمسعود برومند  ▶︎ already downloaded — skipping
#
# [383] امیرممد گل زاده  ▶︎ already downloaded — skipping
#
# [384] امیرهوشنگ شریفی  → searching images with query: امیرهوشنگ شریفی …
#   ⚠️ No candidates found by any provider.
#
# [385] امیروالا معدنچی  → searching images with query: امیروالا معدنچی …
#   ⚠️ No candidates found by any provider.
#
# [386] امین اسماعیل‌نژاد  → searching images with query: امین اسماعیل‌نژاد …
#   ℹ️ 2 candidate(s) found
#   ✅ Candidate 1/2 OK → 386_امین_اسماعیلنژاد_crawled.jpg
#
# [387] امین بوداغی  → searching images with query: امین بوداغی …
#   ⚠️ No candidates found by any provider.
#
# [388] امین جهان‌عالیان  ▶︎ already downloaded — skipping
#
# [389] امین جهان‌کهن  ▶︎ already downloaded — skipping
#
# [390] امین دهقان  ▶︎ already downloaded — skipping
#
# [391] امین طاهری  ▶︎ already downloaded — skipping
#
# [392] امین قاسمی‌نژاد  ▶︎ already downloaded — skipping
#
# [393] امین متوسل‌زاده  ▶︎ already downloaded — skipping
#
# [394] امین منوچهری  ▶︎ already downloaded — skipping
#
# [395] امین میرزازاده  → searching images with query: امین میرزازاده …
#   ℹ️ 10 candidate(s) found
#   ✅ Candidate 1/10 OK → 395_امین_میرزازاده_crawled.jpg
#
# [396] امین نصری  → searching images with query: امین نصری …
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 396_امین_نصری_crawled.jpg
#
# [397] امین نظری  ▶︎ already downloaded — skipping
#
# [398] امین نیک‌فر  ▶︎ already downloaded — skipping
#
# [399] امین کاویانی‌نژاد  → searching images with query: امین کاویانی‌نژاد …
#   ⚠️ No candidates found by any provider.
#
# [400] انس بنی یاسین  ▶︎ already downloaded — skipping
#
# [401] انور هادژیابدیچ  → searching images with query: انور هادژیابدیچ …
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 401_انور_هادژیابدیچ_crawled.jpg
#
# [402] انوشا شاهقلی  ▶︎ already downloaded — skipping
#
# [403] انوشیروان نوریان  → searching images with query: انوشیروان نوریان …
#   ⚠️ No candidates found by any provider.
#
# [404] انگین فیرات  ▶︎ already downloaded — skipping
#
# [405] اورستیس جونیور آلوز  → searching images with query: اورستیس جونیور آلوز …
#   ⚠️ No candidates found by any provider.
#
# [406] اوسمار ویرا  ▶︎ already downloaded — skipping
#
# [407] اوسیانو دا کروز  ▶︎ already downloaded — skipping
#
# [408] اوشین ساهاکیان  → searching images with query: اوشین ساهاکیان …
#   ⚠️ No candidates found by any provider.
#
# [409] اولکسی پولیانسکی  ▶︎ already downloaded — skipping
#
# [410] اوگنی ایوانف  → searching images with query: اوگنی ایوانف …
#   ⚠️ No candidates found by any provider.
#
# [411] اویس حسن‌زاده  ▶︎ already downloaded — skipping
#
# [412] اویس ملاح  → searching images with query: اویس ملاح …
#   ⚠️ No candidates found by any provider.
#
# [413] اکبر افتخاری  ▶︎ already downloaded — skipping
#
# [414] اکبر ایمانی  ▶︎ already downloaded — skipping
#
# [415] اکبر ترکان  ▶︎ already downloaded — skipping
#
# [416] اکبر خزایی  ▶︎ already downloaded — skipping
#
# [417] اکبر خوجینی  → searching images with query: اکبر خوجینی …
#   ⚠️ No candidates found by any provider.
#
# [418] اکبر صادقی   ▶︎ already downloaded — skipping
#
# [419] اکبر فلاح  → searching images with query: اکبر فلاح …
#   ℹ️ 4 candidate(s) found
#   ✅ Candidate 1/4 OK → 419_اکبر_فلاح_crawled.jpg
#
# [420] اکبر میثاقیان  ▶︎ already downloaded — skipping
#
# [421] اکبر کارگرجم  ▶︎ already downloaded — skipping
#
# [422] اکرم خدابنده  ▶︎ already downloaded — skipping
#
# [423] ایان رمزی  ▶︎ already downloaded — skipping
#
# [424] ایان فایت  ▶︎ already downloaded — skipping
#
# [425] ایبای گومز  ▶︎ already downloaded — skipping
#
# [426] ایران الیاس‌ون  ▶︎ already downloaded — skipping
#
# [427] ایرج خورشیدفر  → searching images with query: ایرج خورشیدفر …
#   ⚠️ No candidates found by any provider.
#
# [428] ایرج دانایی‌فرد  ▶︎ already downloaded — skipping
#
# [429] ایرج سلیمانی  → searching images with query: ایرج سلیمانی …
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 429_ایرج_سلیمانی_crawled.jpg
#
# [430] ایرج عرب  ▶︎ already downloaded — skipping
#
# [431] ایرج ملک‌حسین‌پور  ▶︎ already downloaded — skipping
#
# [432] ایزار ایلخانوف  → searching images with query: ایزار ایلخانوف …
#   ⚠️ No candidates found by any provider.
#
# [433] ایلوش خوشابه  ▶︎ already downloaded — skipping
#
# [434] ایلی استان  ▶︎ already downloaded — skipping
#
# [435] ایمان انصاری  ▶︎ already downloaded — skipping
#
# [436] ایمان جمالی  ▶︎ already downloaded — skipping
#
# [437] ایمان حاجی‌هاشمی  → searching images with query: ایمان حاجی‌هاشمی …
#   ⚠️ No candidates found by any provider.
#
# [438] ایمان زندی  → searching images with query: ایمان زندی …
#   ⚠️ No candidates found by any provider.
#
# [439] ایمان زکی‌زاده  → searching images with query: ایمان زکی‌زاده …
#   ⚠️ No candidates found by any provider.
#
# [440] ایمان سلیمی  ▶︎ already downloaded — skipping
#
# [441] ایمان سنچولی  → searching images with query: ایمان سنچولی …
#   ⚠️ No candidates found by any provider.
#
# [442] ایمان شوریابی  ▶︎ already downloaded — skipping
#
# [443] ایمان صادقی   ▶︎ already downloaded — skipping
#
# [444] ایمان عالمی  ▶︎ already downloaded — skipping
#
# [445] ایمان مبعلی  ▶︎ already downloaded — skipping
#
# [446] ایمان محمدی  ▶︎ already downloaded — skipping
#
# [447] ایمان محمدیان  → searching images with query: ایمان محمدیان …
#   ⚠️ No candidates found by any provider.
#
# [448] ایمان مهدوی  → searching images with query: ایمان مهدوی …
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 448_ایمان_مهدوی_crawled.jpg
#
# [449] ایمان موسوی  ▶︎ already downloaded — skipping
#
# [450] ایمان کیانی  → searching images with query: ایمان کیانی …
#   ℹ️ 1 candidate(s) found
#   ❌ Candidate 1/1 FAILED
#   ▶︎ RESULT: ❌ All candidates failed
#
# [451] ایمن زاید  ▶︎ already downloaded — skipping
#
# [452] ایوان ترابالیک  ▶︎ already downloaded — skipping
#
# [453] ایوان مارکوویچ  ▶︎ already downloaded — skipping
#
# [454] ایوان پتروویچ  ▶︎ already downloaded — skipping
#
# [455] ایوب العملود  ▶︎ already downloaded — skipping
#
# [456] ایوب بنی‌نصرت  ▶︎ already downloaded — skipping
#
# [457] ایوب رستمی   ▶︎ already downloaded — skipping
#
# [458] ایوب والی  ▶︎ already downloaded — skipping
#
# [459] ایوب پورتقی  → searching images with query: ایوب پورتقی …
#   ⚠️ No candidates found by any provider.
#
# [460] ایگور اشتیماتس  ▶︎ already downloaded — skipping
#
# [461] ایگور الکساندرویچ  نتو  ▶︎ already downloaded — skipping
#
# [462] ایگور نتو  ▶︎ already downloaded — skipping
#
# [463] ایگور پوستونیسکی  ▶︎ already downloaded — skipping
#
# [464] بابک امیرطهماسب  → searching images with query: بابک امیرطهماسب …
#   ⚠️ No candidates found by any provider.
#
# [465] بابک حاتمی  ▶︎ already downloaded — skipping
#
# [466] بابک داوری  ▶︎ already downloaded — skipping
#
# [467] بابک فرهودی  → searching images with query: بابک فرهودی …
#   ⚠️ No candidates found by any provider.
#
# [468] بابک قربانی  ▶︎ already downloaded — skipping
#
# [469] بابک مرادی  ▶︎ already downloaded — skipping
#
# [470] بابک معصومی  ▶︎ already downloaded — skipping
#
# [471] بابک نورزاد  → searching images with query: بابک نورزاد …
#   ⚠️ No candidates found by any provider.
#
# [472] بابک پورغلامی  ▶︎ already downloaded — skipping
#
# [473] باران ارجمند  ▶︎ already downloaded — skipping
#
# [474] باسم عباس  ▶︎ already downloaded — skipping
#
# [475] باشگاه فوتبال زنان استقلال تهران  → searching images with query: باشگاه فوتبال زنان استقلال تهران …
#   ℹ️ 2 candidate(s) found
#   ✅ Candidate 1/2 OK → 475_باشگاه_فوتبال_زنان_استقلال_تهران_crawled.jpg
#
# [476] باشگاه فوتبال زنان خاتون بم  ▶︎ already downloaded — skipping
#
# [477] باشگاه فوتبال زنان ذوب‌آهن  → searching images with query: باشگاه فوتبال زنان ذوب‌آهن …
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 477_باشگاه_فوتبال_زنان_ذوبآهن_crawled.jpg
#
# [478] باشگاه فوتبال زنان سارگل  ▶︎ already downloaded — skipping
#
# [479] باشگاه فوتبال زنان سپاهان  → searching images with query: باشگاه فوتبال زنان سپاهان …
#   ℹ️ 2 candidate(s) found
#   ✅ Candidate 1/2 OK → 479_باشگاه_فوتبال_زنان_سپاهان_crawled.jpg
#
# [480] باشگاه فوتبال زنان شهرداری سیرجان  ▶︎ already downloaded — skipping
#
# [481] باشگاه فوتبال زنان ملوان بندر انزلی  → searching images with query: باشگاه فوتبال زنان ملوان بندر انزلی …
#   ℹ️ 7 candidate(s) found
#   ✅ Candidate 1/7 OK → 481_باشگاه_فوتبال_زنان_ملوان_بندر_انزلی_crawled.jpg
#
# [482] باشگاه فوتبال زنان ملی‌پوشان شهرکرد  ▶︎ already downloaded — skipping
#
# [483] باشگاه فوتبال زنان همیاری ارومیه  ▶︎ already downloaded — skipping
#
# [484] باشگاه فوتبال زنان هیئت فوتبال البرز  ▶︎ already downloaded — skipping
#
# [485] باشگاه فوتبال زنان وچان  ▶︎ already downloaded — skipping
#
# [486] باشگاه فوتبال زنان پالایش گاز ایلام  ▶︎ already downloaded — skipping
#
# [487] باشگاه فوتبال زنان پرسپولیس  → searching images with query: باشگاه فوتبال زنان پرسپولیس …
#   ℹ️ 5 candidate(s) found
#   ✅ Candidate 1/5 OK → 487_باشگاه_فوتبال_زنان_پرسپولیس_crawled.jpg
#
# [488] باشگاه فوتبال زنان کیان نیشابور  → searching images with query: باشگاه فوتبال زنان کیان نیشابور …
#   ⚠️ No candidates found by any provider.
#
# [489] باغداسار آبدیان  ▶︎ already downloaded — skipping
#
# [490] باقر محمدی  ▶︎ already downloaded — skipping
#
# [491] باقر کلهر  → searching images with query: باقر کلهر …
#   ℹ️ 1 candidate(s) found
#   ❌ Candidate 1/1 FAILED
#   ▶︎ RESULT: ❌ All candidates failed
#
# [492] بتول خلیل‌زاده  → searching images with query: بتول خلیل‌زاده …
#   ⚠️ No candidates found by any provider.
#
# [493] بختیار رحمانی  ▶︎ already downloaded — skipping
#
# [494] بدری اسدی  ▶︎ already downloaded — skipping
#
# [495] بدری لطیف  → searching images with query: بدری لطیف …
#   ⚠️ No candidates found by any provider.
#
# [496] برانکو ایوانکوویچ  ▶︎ already downloaded — skipping
#
# [497] بردیا دانشور  → searching images with query: بردیا دانشور …
#   ⚠️ No candidates found by any provider.
#
# [498] بردیا سعادت   ▶︎ already downloaded — skipping
#
# [499] برف‌انبار  → searching images with query: برف‌انبار …
#   ℹ️ 10 candidate(s) found
#   ✅ Candidate 1/10 OK → 499_برفانبار_crawled.jpg
#
# [500] برونو سزار  ▶︎ already downloaded — skipping
#
# [501] بشار رسن  ▶︎ already downloaded — skipping
#
# [502] بشیر باباجان‌زاده  ▶︎ already downloaded — skipping
#
# [503] بنجامین ابراهیم‌زاده  ▶︎ already downloaded — skipping
#
# [504] بنیک امیریان  → searching images with query: بنیک امیریان …
#   ⚠️ No candidates found by any provider.
#
# [505] بهادر عبدی  ▶︎ already downloaded — skipping
#
# [506] بهادر مولایی  ▶︎ already downloaded — skipping
#
# [507] بهادر نسیم‌اف  ▶︎ already downloaded — skipping
#
# [508] بهادر کرمی  → searching images with query: بهادر کرمی …
#   ℹ️ 1 candidate(s) found
#   ❌ Candidate 1/1 FAILED
#   ▶︎ RESULT: ❌ All candidates failed
#
# [509] بهاره قادریان  → searching images with query: بهاره قادریان …
#   ⚠️ No candidates found by any provider.
#
# [510] بهتاش فریبا  ▶︎ already downloaded — skipping
#
# [511] بهداد بیرانوند  ▶︎ already downloaded — skipping
#
# [512] بهداد سلیمی  ▶︎ already downloaded — skipping
#
# [513] بهرام اسماعیلی  → searching images with query: بهرام اسماعیلی …
#   ℹ️ 2 candidate(s) found
#   ✅ Candidate 1/2 OK → 513_بهرام_اسماعیلی_crawled.jpg
#
# [514] بهرام افشارزاده  ▶︎ already downloaded — skipping
#
# [515] بهرام توکلی   → searching images with query: بهرام توکلی  …
#   ℹ️ 2 candidate(s) found
#   ✅ Candidate 1/2 OK → 515_بهرام_توکلی_crawled.jpg
#
# [516] بهرام دباغ  → searching images with query: بهرام دباغ …
#   ⚠️ No candidates found by any provider.
#
# [517] بهرام رشیدی فرخی  ▶︎ already downloaded — skipping
#
# [518] بهرام مشتاقی  ▶︎ already downloaded — skipping
#
# [519] بهرام مهرپیما  → searching images with query: بهرام مهرپیما …
#   ℹ️ 3 candidate(s) found
#   ✅ Candidate 1/3 OK → 519_بهرام_مهرپیما_crawled.jpg
#
# [520] بهرام مودت  ▶︎ already downloaded — skipping
#
# [521] بهرام چوبین  ▶︎ already downloaded — skipping
#
# [522] بهرنگ صفری  ▶︎ already downloaded — skipping
#
# [523] بهروز جمشیدی  → searching images with query: بهروز جمشیدی …
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 523_بهروز_جمشیدی_crawled.jpg
#
# [524] بهروز رهبری‌فر  ▶︎ already downloaded — skipping
#
# [525] بهروز سلطانی  ▶︎ already downloaded — skipping
#
# [526] بهروز صحابه تبریزی  ▶︎ already downloaded — skipping
#
# [527] بهروز عطایی  ▶︎ already downloaded — skipping
#
# [528] بهروز مکوندی  ▶︎ already downloaded — skipping
#
# [529] بهروز نعمتی  ▶︎ already downloaded — skipping
#
# [530] بهروز یاری  ▶︎ already downloaded — skipping
#
# [531] بهزاد حیدرشاهی  ▶︎ already downloaded — skipping
#
# [532] بهزاد غلامپور  ▶︎ already downloaded — skipping
#
# [533] بهمن تیموری  → searching images with query: بهمن تیموری …
#   ℹ️ 5 candidate(s) found
#   ✅ Candidate 1/5 OK → 533_بهمن_تیموری_crawled.jpg
#
# [534] بهمن عسگری  → searching images with query: بهمن عسگری …
#   ℹ️ 4 candidate(s) found
#   ✅ Candidate 1/4 OK → 534_بهمن_عسگری_crawled.jpg
#
# [535] بهمن نصیری  → searching images with query: بهمن نصیری …
#   ℹ️ 4 candidate(s) found
#   ❌ Candidate 1/4 FAILED
#   ✅ Candidate 2/4 OK → 535_بهمن_نصیری_crawled.jpg
#
# [536] بهمن کامل  ▶︎ already downloaded — skipping
#
# [537] بهمن گلبارنژاد  ▶︎ already downloaded — skipping
#
# [538] بهناز خجسته‌پور  → searching images with query: بهناز خجسته‌پور …
#   ⚠️ No candidates found by any provider.
#
# [539] بهناز طاهرخانی  ▶︎ already downloaded — skipping
#
# [540] بهنام آذرمجیدی  → searching images with query: بهنام آذرمجیدی …
#   ⚠️ No candidates found by any provider.
#
# [541] بهنام ابوالقاسم‌پور  ▶︎ already downloaded — skipping
#
# [542] بهنام احسان‌پور  → searching images with query: بهنام احسان‌پور …
#   ⚠️ No candidates found by any provider.
#
# [543] بهنام اسبقی  → searching images with query: بهنام اسبقی …
#   ⚠️ No candidates found by any provider.
#
# [544] بهنام برزای  ▶︎ already downloaded — skipping
#
# [545] بهنام بیات  ▶︎ already downloaded — skipping
#
# [546] بهنام سراج  ▶︎ already downloaded — skipping
#
# [547] بهنام شیری  ▶︎ already downloaded — skipping
#
# [548] بهنام طاهرزاده  → searching images with query: بهنام طاهرزاده …
#   ⚠️ No candidates found by any provider.
#
# [549] بهنام طیبی  → searching images with query: بهنام طیبی …
#   ℹ️ 1 candidate(s) found
#   ❌ Candidate 1/1 FAILED
#   ▶︎ RESULT: ❌ All candidates failed
#
# [550] بهنام محمودی  ▶︎ already downloaded — skipping
#
# [551] بهنام مهدی‌زاده  → searching images with query: بهنام مهدی‌زاده …
#   ℹ️ 1 candidate(s) found
#   ❌ Candidate 1/1 FAILED
#   ▶︎ RESULT: ❌ All candidates failed
#
# [552] بهنام یخچالی  ▶︎ already downloaded — skipping
#
# [553] بوباکار تراوالی  ▶︎ already downloaded — skipping
#
# [554] بولی سامبو  ▶︎ already downloaded — skipping
#
# [555] بوژیدار رادوشویچ  ▶︎ already downloaded — skipping
#
# [556] بوگدان میلیچ  ▶︎ already downloaded — skipping
#
# [557] بویان نایدنوف  ▶︎ already downloaded — skipping
#
# [558] بویوک‌آغا حاجی‌اف  ▶︎ already downloaded — skipping
#
# [559] بیت‌الله عباس‌پور  ▶︎ already downloaded — skipping
#
# [560] بیوک جدی‌کار  ▶︎ already downloaded — skipping
#
# [561] بیوک وطنخواه  → searching images with query: بیوک وطنخواه …
#   ⚠️ No candidates found by any provider.
#
# [562] بیژن براتی  ▶︎ already downloaded — skipping
#
# [563] بیژن حیدری  ▶︎ already downloaded — skipping
#
# [564] بیژن ذوالفقارنسب  ▶︎ already downloaded — skipping
#
# [565] بیژن زرنگار  → searching images with query: بیژن زرنگار …
#   ⚠️ No candidates found by any provider.
#
# [566] بیژن طاهری  ▶︎ already downloaded — skipping
#
# [567] بیژن کنگرلو  → searching images with query: بیژن کنگرلو …
#   ⚠️ No candidates found by any provider.
#
# [568] تئو د یونگ  ▶︎ already downloaded — skipping
#
# [569] تاکافومی آکاهشی  ▶︎ already downloaded — skipping
#
# [570] ترانه احمدی  → searching images with query: ترانه احمدی …
#   ℹ️ 2 candidate(s) found
#   ✅ Candidate 1/2 OK → 570_ترانه_احمدی_crawled.jpg
#
# [571] ترانه کامیاب  → searching images with query: ترانه کامیاب …
#   ⚠️ No candidates found by any provider.
#
# [572] تقی اکبرنژاد  → searching images with query: تقی اکبرنژاد …
#   ⚠️ No candidates found by any provider.
#
# [573] تقی اکبری  → searching images with query: تقی اکبری …
#   ⚠️ No candidates found by any provider.
#
# [574] تقی داداشی  → searching images with query: تقی داداشی …
#   ⚠️ No candidates found by any provider.
#
# [575] تقی رضایی  → searching images with query: تقی رضایی …
#   ℹ️ 2 candidate(s) found
#   ✅ Candidate 1/2 OK → 575_تقی_رضایی_crawled.jpg
#
# [576] تقی عسگری  → searching images with query: تقی عسگری …
#   ℹ️ 10 candidate(s) found
#   ❌ Candidate 1/10 FAILED
#   ❌ Candidate 2/10 FAILED
#   ❌ Candidate 3/10 FAILED
#   ❌ Candidate 4/10 FAILED
#   ❌ Candidate 5/10 FAILED
#   ❌ Candidate 6/10 FAILED
#   ❌ Candidate 7/10 FAILED
#   ❌ Candidate 8/10 FAILED
#   ❌ Candidate 9/10 FAILED
#   ❌ Candidate 10/10 FAILED
#   ▶︎ RESULT: ❌ All candidates failed
#
# [577] تهمینه درگذنی  ▶︎ already downloaded — skipping
#
# [578] توحید غلامی  → searching images with query: توحید غلامی …
#   ℹ️ 1 candidate(s) found
#   ❌ Candidate 1/1 FAILED
#   ▶︎ RESULT: ❌ All candidates failed
#
# [579] توران شادپور  ▶︎ already downloaded — skipping
#
# [580] تورج ابراهیمی  → searching images with query: تورج ابراهیمی …
#   ℹ️ 3 candidate(s) found
#   ✅ Candidate 1/3 OK → 580_تورج_ابراهیمی_crawled.jpg
#
# [581] تورج حق‌وردی  ▶︎ already downloaded — skipping
#
# [582] توماس ویلیامسون  ▶︎ already downloaded — skipping
#
# [583] تومیسلاو ایوکوویچ  → searching images with query: تومیسلاو ایوکوویچ …
#   ⚠️ No candidates found by any provider.
#
# [584] تومیسلاو ایویچ  ▶︎ already downloaded — skipping
#
# [585] تونی اوسنیک  ▶︎ already downloaded — skipping
#
# [586] تکتم آخوندزاده  → searching images with query: تکتم آخوندزاده …
#   ⚠️ No candidates found by any provider.
#
# [587] تیاگو فریرا  ▶︎ already downloaded — skipping
#
# [588] تیم ملی فوتبال زنان ایران  ▶︎ already downloaded — skipping
#
# [589] تیم ملی فوتبال زیر ۱۷ سال زنان ایران  → searching images with query: تیم ملی فوتبال زیر ۱۷ سال زنان ایران …
# ...
#   ✅ Candidate 1/1 OK → 2872_پرستو_مه_نمای_اقدم_crawled.jpg
#
# [2873] پرهام مقصودلو  ▶︎ already downloaded — skipping
#
# [2874] پرو پییچ  ▶︎ already downloaded — skipping
#
# [2875] پروانه تهرانی  → searching images with query: پروانه تهرانی …
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 2875_پروانه_تهرانی_crawled.jpg
#
# [2876] پروانه محمدتقی‌پور طهرانی  → searching images with query: پروانه محمدتقی‌پور طهرانی …
#   ⚠️ No candidates found by any provider.
#
# [2877] پروانه کاظمی  → searching images with query: پروانه کاظمی …
#   ℹ️ 4 candidate(s) found
#   ✅ Candidate 1/4 OK → 2877_پروانه_کاظمی_crawled.jpg
#
# [2878] پرویز برومند  ▶︎ already downloaded — skipping
#
# [2879] پرویز جلایر  ▶︎ already downloaded — skipping
#
# [2880] پرویز خسروانی  ▶︎ already downloaded — skipping
#
# [2881] پرویز دهداری  ▶︎ already downloaded — skipping
#
# [2882] پرویز زیدوند  → searching images with query: پرویز زیدوند …
#   ⚠️ No candidates found by any provider.
#
# [2883] پرویز مظلومی  ▶︎ already downloaded — skipping
#
# [2884] پرویز میرزاحسن  → searching images with query: پرویز میرزاحسن …
#   ⚠️ No candidates found by any provider.
#
# [2885] پرویز هادی  ▶︎ already downloaded — skipping
#
# [2886] پرویز کریمی  ▶︎ already downloaded — skipping
#
# [2887] پرویز کوزه‌کنانی  ▶︎ already downloaded — skipping
#
# [2888] پری فردی  ▶︎ already downloaded — skipping
#
# [2889] پری نقی‌پور  ▶︎ already downloaded — skipping
#
# [2890] پریسا احمدی   → searching images with query: پریسا احمدی  …
#   ⚠️ No candidates found by any provider.
#
# [2891] پریسا براتچی   → searching images with query: پریسا براتچی  …
#   ⚠️ No candidates found by any provider.
#
# [2892] پریسا بهزادی  → searching images with query: پریسا بهزادی …
#   ⚠️ No candidates found by any provider.
#
# [2893] پریسا جهانفکریان  ▶︎ already downloaded — skipping
#
# [2894] پریسا جوادی  ▶︎ already downloaded — skipping
#
# [2895] پریسا فرشیدی  ▶︎ already downloaded — skipping
#
# [2896] پریچهر جمشیدی  ▶︎ already downloaded — skipping
#
# [2897] پطروس نظربگیان  ▶︎ already downloaded — skipping
#
# [2898] پهلوان ابراهیم حلاج تفتی یزدی  ▶︎ already downloaded — skipping
#
# [2899] پهلوان موسی خمیس  ▶︎ already downloaded — skipping
#
# [2900] پهلوان موسی خمیس گرزدین‌وند  ▶︎ already downloaded — skipping
#
# [2901] پوران زارع  ▶︎ already downloaded — skipping
#
# [2902] پوریا امینی  → searching images with query: پوریا امینی …
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 2902_پوریا_امینی_crawled.jpg
#
# [2903] پوریا حسین خانزاده  ▶︎ already downloaded — skipping
#
# [2904] پوریا درینی  ▶︎ already downloaded — skipping
#
# [2905] پوریا ساوه شمشکی  → searching images with query: پوریا ساوه شمشکی …
#   ⚠️ No candidates found by any provider.
#
# [2906] پوریا سرآبادانی  ▶︎ already downloaded — skipping
#
# [2907] پوریا فیاضی  ▶︎ already downloaded — skipping
#
# [2908] پوریا نوروزیان  → searching images with query: پوریا نوروزیان …
#   ⚠️ No candidates found by any provider.
#
# [2909] پوریا یلی  ▶︎ already downloaded — skipping
#
# [2910] پوریای ولی  ▶︎ already downloaded — skipping
#
# [2911] پوپک بسامی  → searching images with query: پوپک بسامی …
#   ℹ️ 2 candidate(s) found
#   ✅ Candidate 1/2 OK → 2911_پوپک_بسامی_crawled.jpg
#
# [2912] پویا ایدنی  ▶︎ already downloaded — skipping
#
# [2913] پویا تاجیک  → searching images with query: پویا تاجیک …
#   ⚠️ No candidates found by any provider.
#
# [2914] پویا دادمرز  ▶︎ already downloaded — skipping
#
# [2915] پویا رحمانی  ▶︎ already downloaded — skipping
#
# [2916] پویا ناصرپور  → searching images with query: پویا ناصرپور …
#   ⚠️ No candidates found by any provider.
#
# [2917] پویا نزهتی  ▶︎ already downloaded — skipping
#
# [2918] پویا پورعلی  ▶︎ already downloaded — skipping
#
# [2919] پژمان جمشیدی  ▶︎ already downloaded — skipping
#
# [2920] پژمان درستکار  → searching images with query: پژمان درستکار …
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 2920_پژمان_درستکار_crawled.jpg
#
# [2921] پژمان قلعه‌نویی  → searching images with query: پژمان قلعه‌نویی …
#   ⚠️ No candidates found by any provider.
#
# [2922] پژمان منتظری  ▶︎ already downloaded — skipping
#
# [2923] پژمان نوری  ▶︎ already downloaded — skipping
#
# [2924] پژمان پشتام  ▶︎ already downloaded — skipping
#
# [2925] پگاه زنگنه  → searching images with query: پگاه زنگنه …
#   ⚠️ No candidates found by any provider.
#
# [2926] پیام بویری  → searching images with query: پیام بویری …
#   ⚠️ No candidates found by any provider.
#
# [2927] پیام حیدری  ▶︎ already downloaded — skipping
#
# [2928] پیام خانلرخانی  → searching images with query: پیام خانلرخانی …
#   ⚠️ No candidates found by any provider.
#
# [2929] پیام صادقیان  ▶︎ already downloaded — skipping
#
# [2930] پیام قبادی  → searching images with query: پیام قبادی …
#   ⚠️ No candidates found by any provider.
#
# [2931] پیام نیازمند  ▶︎ already downloaded — skipping
#
# [2932] پیتر گریگوریان  → searching images with query: پیتر گریگوریان …
#   ⚠️ No candidates found by any provider.
#
# [2933] پیتسو موسیمانه  ▶︎ already downloaded — skipping
#
# [2934] پیر لیتبارسکی  ▶︎ already downloaded — skipping
#
# [2935] پیر کارلو  → searching images with query: پیر کارلو …
#   ℹ️ 10 candidate(s) found
#   ✅ Candidate 1/10 OK → 2935_پیر_کارلو_crawled.jpg
#
# [2936] پیروز آدمیت  → searching images with query: پیروز آدمیت …
#   ⚠️ No candidates found by any provider.
#
# [2937] پیروز قربانی  ▶︎ already downloaded — skipping
#
# [2938] پیمان اسدی   ▶︎ already downloaded — skipping
#
# [2939] پیمان اکبری  ▶︎ already downloaded — skipping
#
# [2940] پیمان بابایی  ▶︎ already downloaded — skipping
#
# [2941] پیمان بیابانی  → searching images with query: پیمان بیابانی …
#   ℹ️ 2 candidate(s) found
#   ❌ Candidate 1/2 FAILED
#   ❌ Candidate 2/2 FAILED
#   ▶︎ RESULT: ❌ All candidates failed
#
# [2942] پیمان جان  → searching images with query: پیمان جان …
#   ℹ️ 7 candidate(s) found
#   ✅ Candidate 1/7 OK → 2942_پیمان_جان_crawled.jpg
#
# [2943] پیمان حسینی  ▶︎ already downloaded — skipping
#
# [2944] پیمان قویدل  → searching images with query: پیمان قویدل …
#   ⚠️ No candidates found by any provider.
#
# [2945] پیمان میری  ▶︎ already downloaded — skipping
#
# [2946] پیمان نصیری  → searching images with query: پیمان نصیری …
#   ℹ️ 1 candidate(s) found
#   ❌ Candidate 1/1 FAILED
#   ▶︎ RESULT: ❌ All candidates failed
#
# [2947] چیرو  ▶︎ already downloaded — skipping
#
# [2948] ژاله سید هادی‌زاده  ▶︎ already downloaded — skipping
#
# [2949] ژانت کهن‌صدق  ▶︎ already downloaded — skipping
#
# [2950] ژایر   ▶︎ already downloaded — skipping
#
# [2951] ژرژ آفتاندیلیان  ▶︎ already downloaded — skipping
#
# [2952] ژرژ عیسی‌بگ  → searching images with query: ژرژ عیسی‌بگ …
#   ⚠️ No candidates found by any provider.
#
# [2953] ژرژ لیکنز  ▶︎ already downloaded — skipping
#
# [2954] ژلیکو میاچ  ▶︎ already downloaded — skipping
#
# [2955] ژنیک شهبازیان  ▶︎ already downloaded — skipping
#
# [2956] ژوزه آلبرتو کاستا  ▶︎ already downloaded — skipping
#
# [2957] ژوزه مورایس  ▶︎ already downloaded — skipping
#
# [2958] ژولیت گئورگیان  ▶︎ already downloaded — skipping
#
# [2959] ژیلا الماسی  ▶︎ already downloaded — skipping
#
# [2960] کاخابر کاکاشویلی  ▶︎ already downloaded — skipping
#
# [2961] کارلوس آلکساندر کاردوسو  ▶︎ already downloaded — skipping
#
# [2962] کارلوس هرناندز  ▶︎ already downloaded — skipping
#
# [2963] کارلوس چاواریا  ▶︎ already downloaded — skipping
#
# [2964] کارلوس چینیو  ▶︎ already downloaded — skipping
#
# [2965] کارلوس کی‌روش  ▶︎ already downloaded — skipping
#
# [2966] کارن بارسقیان  → searching images with query: کارن بارسقیان …
#   ⚠️ No candidates found by any provider.
#
# [2967] کارو حق‌وردیان  ▶︎ already downloaded — skipping
#
# [2968] کاظم اشتری  → searching images with query: کاظم اشتری …
#   ℹ️ 10 candidate(s) found
#   ✅ Candidate 1/10 OK → 2968_کاظم_اشتری_crawled.jpg
#
# [2969] کاظم رجبی  → searching images with query: کاظم رجبی …
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 2969_کاظم_رجبی_crawled.jpg
#
# [2970] کاظم ساریخانی  → searching images with query: کاظم ساریخانی …
#   ⚠️ No candidates found by any provider.
#
# [2971] کاظم غلامی  ▶︎ already downloaded — skipping
#
# [2972] کالینز جان  ▶︎ already downloaded — skipping
#
# [2973] کامبیز آتابای  ▶︎ already downloaded — skipping
#
# [2974] کامبیز درفشی جوان  → searching images with query: کامبیز درفشی جوان …
#   ⚠️ No candidates found by any provider.
#
# [2975] کامران شکری سالاری  → searching images with query: کامران شکری سالاری …
#   ⚠️ No candidates found by any provider.
#
# [2976] کامران شیرازی  ▶︎ already downloaded — skipping
#
# [2977] کامران قاسم‌پور  → searching images with query: کامران قاسم‌پور …
#   ℹ️ 3 candidate(s) found
#   ✅ Candidate 1/3 OK → 2977_کامران_قاسمپور_crawled.jpg
#
# [2978] کامران پنجوی  → searching images with query: کامران پنجوی …
#   ⚠️ No candidates found by any provider.
#
# [2979] کاملیا فلاح  ▶︎ already downloaded — skipping
#
# [2980] کاوه رضایی  ▶︎ already downloaded — skipping
#
# [2981] کاوه موسوی   → searching images with query: کاوه موسوی  …
#   ℹ️ 3 candidate(s) found
#   ✅ Candidate 1/3 OK → 2981_کاوه_موسوی_crawled.jpg
#
# [2982] کبیر بلو  → searching images with query: کبیر بلو …
#   ⚠️ No candidates found by any provider.
#
# [2983] کتایون خسرویار  ▶︎ already downloaded — skipping
#
# [2984] کرار جاسم  ▶︎ already downloaded — skipping
#
# [2985] کریستوفر کنت  ▶︎ already downloaded — skipping
#
# [2986] کریستوفر کنِت  ▶︎ already downloaded — skipping
#
# [2987] کریستین اوساگونا  ▶︎ already downloaded — skipping
#
# [2988] کریم احمدی  ▶︎ already downloaded — skipping
#
# [2989] کریم اسلامی  ▶︎ already downloaded — skipping
#
# [2990] کریم انصاری‌فرد  ▶︎ already downloaded — skipping
#
# [2991] کریم باقری  ▶︎ already downloaded — skipping
#
# [2992] کریم بوستانی  ▶︎ already downloaded — skipping
#
# [2993] کریم رئیسی‌نیا  ▶︎ already downloaded — skipping
#
# [2994] کریم شاهوردی  → searching images with query: کریم شاهوردی …
#   ⚠️ No candidates found by any provider.
#
# [2995] کسری طاهری  ▶︎ already downloaded — skipping
#
# [2996] کسری مهدی‌پورنژاد  → searching images with query: کسری مهدی‌پورنژاد …
#   ℹ️ 3 candidate(s) found
#   ✅ Candidate 1/3 OK → 2996_کسری_مهدیپورنژاد_crawled.jpg
#
# [2997] کمال آلیسپاهیچ  ▶︎ already downloaded — skipping
#
# [2998] کمال کامیابی‌نیا  ▶︎ already downloaded — skipping
#
# [2999] کمیل سوسکو  → searching images with query: کمیل سوسکو …
#   ⚠️ No candidates found by any provider.
#
# [3000] کمیل قاسمی  ▶︎ already downloaded — skipping
#
# [3001] کوثر اساسه  → searching images with query: کوثر اساسه …
#   ⚠️ No candidates found by any provider.
#
# [3002] کوروش باقری  → searching images with query: کوروش باقری …
#   ⚠️ No candidates found by any provider.
#
# [3003] کوروش بختیار  → searching images with query: کوروش بختیار …
#   ⚠️ No candidates found by any provider.
#
# [3004] کوروش رجلی  → searching images with query: کوروش رجلی …
#   ⚠️ No candidates found by any provider.
#
# [3005] کوروش قربانی  ▶︎ already downloaded — skipping
#
# [3006] کوروش محمدخانی  ▶︎ already downloaded — skipping
#
# [3007] کوروش ملایی  ▶︎ already downloaded — skipping
#
# [3008] کوروش ملکی  ▶︎ already downloaded — skipping
#
# [3009] کوفی شولز  ▶︎ already downloaded — skipping
#
# [3010] کولیس جان  ▶︎ already downloaded — skipping
#
# [3011] کوپال ناظمی  ▶︎ already downloaded — skipping
#
# [3012] کویستان خسروی  ▶︎ already downloaded — skipping
#
# [3013] کوین یانسن  ▶︎ already downloaded — skipping
#
# [3014] کیا اسکندانی  ▶︎ already downloaded — skipping
#
# [3015] کیا جورابچیان  ▶︎ already downloaded — skipping
#
# [3016] کیا قدمی  → searching images with query: کیا قدمی …
#   ⚠️ No candidates found by any provider.
#
# [3017] کیانوش رحمتی  ▶︎ already downloaded — skipping
#
# [3018] کیانوش رستمی  ▶︎ already downloaded — skipping
#
# [3019] کیخسرو کهیایی  → searching images with query: کیخسرو کهیایی …
#   ⚠️ No candidates found by any provider.
#
# [3020] کیروش استنلی  ▶︎ already downloaded — skipping
#
# [3021] کیمیا علیزاده  ▶︎ already downloaded — skipping
#
# [3022] کیمیا یزدیان  ▶︎ already downloaded — skipping
#
# [3023] کیمیا یوسفی  ▶︎ already downloaded — skipping
#
# [3024] کیهان تاکاهاشی  → searching images with query: کیهان تاکاهاشی …
#   ⚠️ No candidates found by any provider.
#
# [3025] کیوان دهناد  ▶︎ already downloaded — skipping
#
# [3026] کیوان شیرآقایی   → searching images with query: کیوان شیرآقایی  …
#   ⚠️ No candidates found by any provider.
#
# [3027] کیوان قنبرزاده  → searching images with query: کیوان قنبرزاده …
#   ⚠️ No candidates found by any provider.
#
# [3028] کیومرث ابوالملوکی  ▶︎ already downloaded — skipping
#
# [3029] کیومرث هاشمی  ▶︎ already downloaded — skipping
#
# [3030] گئورگ کاسپاروف  ▶︎ already downloaded — skipping
#
# [3031] گئورگی گئورگیف  ▶︎ already downloaded — skipping
#
# [3032] گئورگی گولسیانی  ▶︎ already downloaded — skipping
#
# [3033] گابریل کالدرون  ▶︎ already downloaded — skipping
#
# [3034] گابریله پین  ▶︎ already downloaded — skipping
#
# [3035] گادوین منشا  ▶︎ already downloaded — skipping
#
# [3036] گارنیک شه‌بندری  ▶︎ already downloaded — skipping
#
# [3037] گارنیک مهرابیان  ▶︎ already downloaded — skipping
#
# [3038] گالوست پطروسیان  → searching images with query: گالوست پطروسیان …
#   ⚠️ No candidates found by any provider.
#
# [3039] گریگور ملیکستیان  → searching images with query: گریگور ملیکستیان …
#   ⚠️ No candidates found by any provider.
#
# [3040] گریگول چابرادزه  ▶︎ already downloaded — skipping
#
# [3041] گغارد موساسی  ▶︎ already downloaded — skipping
#
# [3042] گلاره ناظمی  ▶︎ already downloaded — skipping
#
# [3043] گلنوش خسروی  ▶︎ already downloaded — skipping
#
# [3044] گلنوش سبقت‌الهی  ▶︎ already downloaded — skipping
#
# [3045] گودرز حبیبی  ▶︎ already downloaded — skipping
#
# [3046] گوران یرکوویچ  ▶︎ already downloaded — skipping
#
# [3047] گوستاوو بلانکو  ▶︎ already downloaded — skipping
#
# [3048] گیتی محبان  ▶︎ already downloaded — skipping
#
# [3049] گیسا بایبوردی  → searching images with query: گیسا بایبوردی …
#   ⚠️ No candidates found by any provider.
#
# [3050] یاسر خورشیدی میانایی  → searching images with query: یاسر خورشیدی میانایی …
#   ⚠️ No candidates found by any provider.
#
# [3051] یاسر همرنگ  ▶︎ already downloaded — skipping
#
# [3052] یاسین رضایی  → searching images with query: یاسین رضایی …
#   ⚠️ No candidates found by any provider.
#
# [3053] یاسین سلمانی  ▶︎ already downloaded — skipping
#
# [3054] یحیی گل‌محمدی  ▶︎ already downloaded — skipping
#
# [3055] یدالله اکبری  ▶︎ already downloaded — skipping
#
# [3056] یدالله جهانبازی  ▶︎ already downloaded — skipping
#
# [3057] یدالله محبی  → searching images with query: یدالله محبی …
#   ⚠️ No candidates found by any provider.
#
# [3058] یزدان میرزایی  → searching images with query: یزدان میرزایی …
#   ⚠️ No candidates found by any provider.
#
# [3059] یعقوب نجفی جویباری  → searching images with query: یعقوب نجفی جویباری …
#   ⚠️ No candidates found by any provider.
#
# [3060] یعقوب کریمی  ▶︎ already downloaded — skipping
#
# [3061] یعقوبعلی شورورزی  ▶︎ already downloaded — skipping
#
# [3062] یعقوبعلی شوروَرزی  ▶︎ already downloaded — skipping
#
# [3063] یو درویش  ▶︎ already downloaded — skipping
#
# [3064] یوانیس توپالیدیس  ▶︎ already downloaded — skipping
#
# [3065] یوسف سیدی  ▶︎ already downloaded — skipping
#
# [3066] یوسف سیدی گلی بلاغ  ▶︎ already downloaded — skipping
#
# [3067] یوسف صبری  → searching images with query: یوسف صبری …
#   ℹ️ 2 candidate(s) found
#   ✅ Candidate 1/2 OK → 3067_یوسف_صبری_crawled.jpg
#
# [3068] یوسف صفوت  ▶︎ already downloaded — skipping
#
# [3069] یوسف قادریان  ▶︎ already downloaded — skipping
#
# [3070] یوسف وکیا  ▶︎ already downloaded — skipping
#
# [3071] یوسف کرمی  → searching images with query: یوسف کرمی …
#   ℹ️ 10 candidate(s) found
#   ❌ Candidate 1/10 FAILED
#   ✅ Candidate 2/10 OK → 3071_یوسف_کرمی_crawled.jpg
#
# [3072] یونس امامی  → searching images with query: یونس امامی …
#   ℹ️ 3 candidate(s) found
#   ✅ Candidate 1/3 OK → 3072_یونس_امامی_crawled.jpg
#
# [3073] یونس اکبرپور  → searching images with query: یونس اکبرپور …
#   ℹ️ 1 candidate(s) found
#   ✅ Candidate 1/1 OK → 3073_یونس_اکبرپور_crawled.jpg
#
# [3074] یونس باهنر  ▶︎ already downloaded — skipping
#
# [3075] یونس دلفی  ▶︎ already downloaded — skipping
#
# [3076] یونس سرمستی  → searching images with query: یونس سرمستی …
#   ⚠️ No candidates found by any provider.
#
# [3077] یونس شاکری  ▶︎ already downloaded — skipping
#
# [3078] یونس فضلی جمور  ▶︎ already downloaded — skipping
#
# [3079] یونس مسعودی  ▶︎ already downloaded — skipping
#
# [3080] یوکیا سوگیتا  ▶︎ already downloaded — skipping
#
# [3081] یکتا جمالی  → searching images with query: یکتا جمالی …
#   ⚠️ No candidates found by any provider.
# Needed crawl: 1105
# Skipped (already True): 1977
# Succeeded:    652
# Failed:       855

# %%
PATH = Path("athlete_merged_with_bios.json")

with PATH.open("r", encoding="utf-8") as f:
    data = json.load(f)

true_count = 0
false_count = 0
missing_count = 0

for rec in data:
    val = rec.get("is_image_downloaded")
    if val is True:
        true_count += 1
    elif val is False:
        false_count += 1
    else:
        missing_count += 1

total = len(data)
print("\n=== is_image_downloaded status ===")
print(f"File: {PATH.name}")
print(f"Total records: {total}")
print(f"True : {true_count}")
print(f"False: {false_count}")
print(f"Missing/None: {missing_count}")
print(f"Checked sum: {true_count + false_count + missing_count} (should equal total)")
# Out:
# === is_image_downloaded status ===
# File: athlete_merged_with_bios.json
# Total records: 3082
# True : 0
# False: 0
# Missing/None: 3082
# Checked sum: 3082 (should equal total)

# %%
import os
import re
import json
from pathlib import Path

INPUT_JSON  = Path("athlete_merged_with_bios.json")
IMG_DIR     = Path("athlete_images")
OUTPUT_JSON = Path("athlete_merged_with_bios_imaged_crawled.json")

def sanitize_filename(s: str) -> str:
    s = (str(s) or "").strip()
    s = re.sub(r"\s+", "_", s)
    s = re.sub(r"[^\w\-.]+", "", s)
    return s or "image"

# --- load data ---
with INPUT_JSON.open("r", encoding="utf-8") as f:
    records = json.load(f)

# --- gather image filenames once (lowercased for case-insensitive contains) ---
if IMG_DIR.exists():
    image_files_lower = [p.name.lower() for p in IMG_DIR.iterdir() if p.is_file()]
else:
    print(f"⚠️  Images folder does not exist: {IMG_DIR} (treating as empty)")
    image_files_lower = []

# --- process records ---
out = []
true_count = 0
false_count = 0

print("\n" + "="*80)
print(f"Scanning images in: {IMG_DIR}")
print(f"Input JSON: {INPUT_JSON.name}")
print("="*80)

for idx, rec in enumerate(records):
    name = rec.get("name") or f"record_{idx}"
    safe_name = sanitize_filename(name).lower()

    # check if any filename includes the safe_name
    has_image = any(safe_name in fname for fname in image_files_lower)

    rec_out = dict(rec)
    rec_out["is_image_downloaded"] = bool(has_image)
    out.append(rec_out)

    if has_image:
        true_count += 1
        print(f"[{idx}] {name} → ✅ found file containing '{safe_name}'")
    else:
        false_count += 1
        print(f"[{idx}] {name} → ❌ no file containing '{safe_name}'")

# --- write output ---
with OUTPUT_JSON.open("w", encoding="utf-8") as f:
    json.dump(out, f, ensure_ascii=False, indent=2)

# --- summary ---
total = len(records)
print("\n" + "-"*80)
print(f"Output JSON: {OUTPUT_JSON.name}")
print(f"Total records: {total}")
print(f"is_image_downloaded = True : {true_count}")
print(f"is_image_downloaded = False: {false_count}")
print(f"Checked sum: {true_count + false_count} (should equal total)")
print("-"*80)
# Out:
# ================================================================================
# Scanning images in: athlete_images
# Input JSON: athlete_merged_with_bios.json
# ================================================================================
# [0] Hellper/صفحه تمرین → ❌ no file containing 'hellperصفحه_تمرین'
# [1] Jorvan Vieira → ✅ found file containing 'jorvan_vieira'
# [2] آتسو استویکوف → ✅ found file containing 'آتسو_استویکوف'
# [3] آتنا محمدی → ✅ found file containing 'آتنا_محمدی'
# [4] آتوسا پورکاشیان → ✅ found file containing 'آتوسا_پورکاشیان'
# [5] آتوسا گلشادنژاد → ❌ no file containing 'آتوسا_گلشادنژاد'
# [6] آتیلا حجازی → ✅ found file containing 'آتیلا_حجازی'
# [7] آدام جمیلی → ✅ found file containing 'آدام_جمیلی'
# [8] آدام همتی → ✅ found file containing 'آدام_همتی'
# [9] آدریانو آلوز → ✅ found file containing 'آدریانو_آلوز'
# [10] آرا هاکوبیان  → ✅ found file containing 'آرا_هاکوبیان'
# [11] آرارات آراکلیان → ❌ no file containing 'آرارات_آراکلیان'
# [12] آرامائیس تونویان → ❌ no file containing 'آرامائیس_تونویان'
# [13] آرتور میناسیان → ❌ no file containing 'آرتور_میناسیان'
# [14] آرتور یدیگاریان → ✅ found file containing 'آرتور_یدیگاریان'
# [15] آرتوش آساطوریان → ❌ no file containing 'آرتوش_آساطوریان'
# [16] آرداشس ساگینیان → ✅ found file containing 'آرداشس_ساگینیان'
# [17] آرزو حکیمی مقدم → ❌ no file containing 'آرزو_حکیمی_مقدم'
# [18] آرش استواری → ✅ found file containing 'آرش_استواری'
# [19] آرش افشین → ✅ found file containing 'آرش_افشین'
# [20] آرش برهانی → ✅ found file containing 'آرش_برهانی'
# [21] آرش خرم‌علی → ❌ no file containing 'آرش_خرمعلی'
# [140] احسان مرادیان → ✅ found file containing 'احسان_مرادیان'
# [141] احسان مهاجرشجاعی → ❌ no file containing 'احسان_مهاجرشجاعی'
# [142] احسان پنشنبه → ✅ found file containing 'احسان_پنشنبه'
# [143] احسان پهلوان → ✅ found file containing 'احسان_پهلوان'
# [144] احسان پیرهادی → ✅ found file containing 'احسان_پیرهادی'
# [145] احسان پیغمبری → ✅ found file containing 'احسان_پیغمبری'
# [146] احسن‌الله شیرکوند → ✅ found file containing 'احسنالله_شیرکوند'
# [147] احلام  → ✅ found file containing 'احلام'
# [148] احمد آل نعمه → ✅ found file containing 'احمد_آل_نعمه'
# [149] احمد آهی → ✅ found file containing 'احمد_آهی'
# [150] احمد اسکندرپور → ❌ no file containing 'احمد_اسکندرپور'
# [151] احمد افغان → ✅ found file containing 'احمد_افغان'
# [152] احمد الجبوری → ✅ found file containing 'احمد_الجبوری'
# [153] احمد امین‌زاده → ❌ no file containing 'احمد_امینزاده'
# [154] احمد اکبری → ✅ found file containing 'احمد_اکبری'
# [155] احمد ایری → ✅ found file containing 'احمد_ایری'
# [156] احمد ایزدپناه → ❌ no file containing 'احمد_ایزدپناه'
# [157] احمد بذری → ❌ no file containing 'احمد_بذری'
# [158] احمد جمشیدیان → ✅ found file containing 'احمد_جمشیدیان'
# [159] احمد خطیبی → ❌ no file containing 'احمد_خطیبی'
# [160] احمد درگاهی → ❌ no file containing 'احمد_درگاهی'
# [161] احمد دنیامالی → ✅ found file containing 'احمد_دنیامالی'
# [162] احمد زنده‌روح → ❌ no file containing 'احمد_زندهروح'
# [163] احمد سنجری → ❌ no file containing 'احمد_سنجری'
# [164] احمد صالحی → ✅ found file containing 'احمد_صالحی'
# [165] احمد صمدیان → ✅ found file containing 'احمد_صمدیان'
# [166] احمد عبدالله‌زاده → ✅ found file containing 'احمد_عبداللهزاده'
# [167] احمد قاسمی  → ✅ found file containing 'احمد_قاسمی'
# [168] احمد مؤمن‌زاده → ✅ found file containing 'احمد_مؤمنزاده'
# [169] احمد محمدنژاد جوان → ❌ no file containing 'احمد_محمدنژاد_جوان'
# [170] احمد محمدی  → ✅ found file containing 'احمد_محمدی'
# [171] احمد معین → ✅ found file containing 'احمد_معین'
# [172] احمد موسوی → ✅ found file containing 'احمد_موسوی'
# [173] احمد میرزاپور → ❌ no file containing 'احمد_میرزاپور'
# [174] احمد نوراللهی → ✅ found file containing 'احمد_نوراللهی'
# [175] احمد وفادار → ✅ found file containing 'احمد_وفادار'
# [176] احمد پیدایش → ✅ found file containing 'احمد_پیدایش'
# [177] احمد گلبو → ❌ no file containing 'احمد_گلبو'
# [178] احمد گوهری → ✅ found file containing 'احمد_گوهری'
# [179] احمد یاقوتی → ✅ found file containing 'احمد_یاقوتی'
# [180] احمدرضا جلالی  → ❌ no file containing 'احمدرضا_جلالی'
# [181] احمدرضا زنده‌روح → ❌ no file containing 'احمدرضا_زندهروح'
# [182] احمدرضا طالبیان → ❌ no file containing 'احمدرضا_طالبیان'
# [183] احمدرضا عابدزاده → ✅ found file containing 'احمدرضا_عابدزاده'
# [184] احمدعلی ابتهاج → ❌ no file containing 'احمدعلی_ابتهاج'
# [185] ادسون  → ✅ found file containing 'ادسون'
# [186] ادموند اختر → ✅ found file containing 'ادموند_اختر'
# [187] ادموند بزیک → ✅ found file containing 'ادموند_بزیک'
# [188] ادموند مایوفسکی → ✅ found file containing 'ادموند_مایوفسکی'
# [189] ادمیر آدرویچ → ✅ found file containing 'ادمیر_آدرویچ'
# [190] ادوارد مانگاسار → ❌ no file containing 'ادوارد_مانگاسار'
# [191] ادواردو فریرا → ✅ found file containing 'ادواردو_فریرا'
# [192] ادون حسنی → ✅ found file containing 'ادون_حسنی'
# [193] ادینیو → ✅ found file containing 'ادینیو'
# [194] اردشیر قوانلوپور → ✅ found file containing 'اردشیر_قوانلوپور'
# [195] اردلان آشتیانی → ✅ found file containing 'اردلان_آشتیانی'
# [196] ارسلان امینی → ✅ found file containing 'ارسلان_امینی'
# [197] ارسلان علیجانی منفرد → ❌ no file containing 'ارسلان_علیجانی_منفرد'
# [198] ارسلان مطهری → ✅ found file containing 'ارسلان_مطهری'
# [199] ارسلان کاظمی → ✅ found file containing 'ارسلان_کاظمی'
# [200] ارشاد یوسفی → ✅ found file containing 'ارشاد_یوسفی'
# [201] ارشک محبی → ✅ found file containing 'ارشک_محبی'
# [202] ارشیا ارباب بهرامی → ✅ found file containing 'ارشیا_ارباب_بهرامی'
# [203] ارشیا الماسی → ❌ no file containing 'ارشیا_الماسی'
# [204] ارطغرل ساغلام → ✅ found file containing 'ارطغرل_ساغلام'
# [205] ارغوان رضایی → ✅ found file containing 'ارغوان_رضایی'
# [206] ارنست میدندروپ → ✅ found file containing 'ارنست_میدندروپ'
# [207] ارنی برندتس → ✅ found file containing 'ارنی_برندتس'
# [208] اروین بولکو → ✅ found file containing 'اروین_بولکو'
# [209] استانکو پوکله‌پوویچ → ✅ found file containing 'استانکو_پوکلهپوویچ'
# [210] استوان مویسیلوویچ → ✅ found file containing 'استوان_مویسیلوویچ'
# [211] استیون ان‌زونزی → ✅ found file containing 'استیون_انزونزی'
# [212] استیون بیت‌آشور → ✅ found file containing 'استیون_بیتآشور'
# [213] اسحاق حاتمی‌فر → ✅ found file containing 'اسحاق_حاتمیفر'
# [214] اسحاق قویدل → ✅ found file containing 'اسحاق_قویدل'
# [215] اسدالله عظیمی → ✅ found file containing 'اسدالله_عظیمی'
# [216] اسدالله میهنی → ❌ no file containing 'اسدالله_میهنی'
# [217] اسفندیار زرنگار → ❌ no file containing 'اسفندیار_زرنگار'
# [218] اسلام جاهدی → ✅ found file containing 'اسلام_جاهدی'
# [219] اسما سعیدی → ✅ found file containing 'اسما_سعیدی'
# [220] اسماعیل اسماعیلی → ✅ found file containing 'اسماعیل_اسماعیلی'
# [221] اسماعیل حلالی → ✅ found file containing 'اسماعیل_حلالی'
# [222] اسماعیل شریفات → ✅ found file containing 'اسماعیل_شریفات'
# [223] اسماعیل صفرزاده → ❌ no file containing 'اسماعیل_صفرزاده'
# [265] الناز شفیعیان → ❌ no file containing 'الناز_شفیعیان'
# [266] الناز قاسمی → ✅ found file containing 'الناز_قاسمی'
# [267] الناز کمپانی → ❌ no file containing 'الناز_کمپانی'
# [268] الهام حسینی → ✅ found file containing 'الهام_حسینی'
# [269] الهام رمضانی → ✅ found file containing 'الهام_رمضانی'
# [270] الهام شیخی  → ✅ found file containing 'الهام_شیخی'
# [271] الهام فلاح → ✅ found file containing 'الهام_فلاح'
# [272] الهام قنبروف → ❌ no file containing 'الهام_قنبروف'
# [273] الهام هاشمی → ✅ found file containing 'الهام_هاشمی'
# [274] الهام هریجانی → ❌ no file containing 'الهام_هریجانی'
# [275] الهام‌السادات اصغری → ❌ no file containing 'الهامالسادات_اصغری'
# [276] الهه احمدی → ✅ found file containing 'الهه_احمدی'
# [277] الهه منصوریان → ✅ found file containing 'الهه_منصوریان'
# [278] الهه پورصالح → ✅ found file containing 'الهه_پورصالح'
# [279] الویس کامسوبا → ✅ found file containing 'الویس_کامسوبا'
# [280] الکس سمیع‌زاده → ❌ no file containing 'الکس_سمیعزاده'
# [281] الکساندر تادووسیان → ❌ no file containing 'الکساندر_تادووسیان'
# [282] الکساندر مرکل → ✅ found file containing 'الکساندر_مرکل'
# [283] الیاس حضرتی → ✅ found file containing 'الیاس_حضرتی'
# [284] الیاس علی‌اکبری → ✅ found file containing 'الیاس_علیاکبری'
# [285] الیاس هوریابند → ✅ found file containing 'الیاس_هوریابند'
# [286] الیاس پاکدل → ❌ no file containing 'الیاس_پاکدل'
# [287] امامعلی حبیبی → ✅ found file containing 'امامعلی_حبیبی'
# [288] امانوئل آغاسی → ✅ found file containing 'امانوئل_آغاسی'
# [289] امانوئل آغاسیEmmanuel B. Aghassi → ✅ found file containing 'امانوئل_آغاسیemmanuel_b._aghassi'
# [290] امان‌الله جهانبانی → ✅ found file containing 'امانالله_جهانبانی'
# [291] امان‌الله پاپی → ❌ no file containing 'امانالله_پاپی'
# [292] امید ابراهیمی → ✅ found file containing 'امید_ابراهیمی'
# [293] امید احمدی  → ✅ found file containing 'امید_احمدی'
# [294] امید احمدی‌صفا → ❌ no file containing 'امید_احمدیصفا'
# [295] امید تیزتک → ✅ found file containing 'امید_تیزتک'
# [296] امید حامدی‌فر → ✅ found file containing 'امید_حامدیفر'
# [297] امید خالدی → ✅ found file containing 'امید_خالدی'
# [298] امید سه‌کناری → ❌ no file containing 'امید_سهکناری'
# [299] امید سینگ → ✅ found file containing 'امید_سینگ'
# [300] امید عالیشاه → ✅ found file containing 'امید_عالیشاه'
# [301] امید لطف‌پور → ❌ no file containing 'امید_لطفپور'
# [302] امید منصوری → ✅ found file containing 'امید_منصوری'
# [303] امید نظامی‌پور → ✅ found file containing 'امید_نظامیپور'
# [304] امید نظری → ✅ found file containing 'امید_نظری'
# [305] امید نمازی → ✅ found file containing 'امید_نمازی'
# [306] امید نورافکن → ✅ found file containing 'امید_نورافکن'
# [307] امید نوروزی → ✅ found file containing 'امید_نوروزی'
# [308] امیدرضا روانخواه → ✅ found file containing 'امیدرضا_روانخواه'
# [309] امیر امینی → ✅ found file containing 'امیر_امینی'
# [310] امیر باقری → ✅ found file containing 'امیر_باقری'
# [311] امیر توکلیان → ✅ found file containing 'امیر_توکلیان'
# [312] امیر جعفری ارنگه → ✅ found file containing 'امیر_جعفری_ارنگه'
# [313] امیر جوهری‌خو → ❌ no file containing 'امیر_جوهریخو'
# [314] امیر حاج رضایی → ✅ found file containing 'امیر_حاج_رضایی'
# [315] امیر حقوقی → ✅ found file containing 'امیر_حقوقی'
# [316] امیر دهداری → ❌ no file containing 'امیر_دهداری'
# [317] امیر راهنمای رونقی → ❌ no file containing 'امیر_راهنمای_رونقی'
# [318] امیر روستایی → ✅ found file containing 'امیر_روستایی'
# [319] امیر زرگری → ❌ no file containing 'امیر_زرگری'
# [320] امیر شاپورزاده → ✅ found file containing 'امیر_شاپورزاده'
# [321] امیر شرفی → ❌ no file containing 'امیر_شرفی'
# [322] امیر شمسایی → ✅ found file containing 'امیر_شمسایی'
# [323] امیر صدیقی → ✅ found file containing 'امیر_صدیقی'
# [324] امیر عابدزاده → ✅ found file containing 'امیر_عابدزاده'
# [325] امیر عابدینی → ✅ found file containing 'امیر_عابدینی'
# [326] امیر عراقی → ✅ found file containing 'امیر_عراقی'
# [327] امیر عرب‌براقی → ✅ found file containing 'امیر_عرببراقی'
# [328] امیر علی سعدالله → ✅ found file containing 'امیر_علی_سعدالله'
# [329] امیر علی‌اکبری → ✅ found file containing 'امیر_علیاکبری'
# [330] امیر غفور → ✅ found file containing 'امیر_غفور'
# [331] امیر قاسمی‌منجزی → ❌ no file containing 'امیر_قاسمیمنجزی'
# [332] امیر قلعه‌نویی → ✅ found file containing 'امیر_قلعهنویی'
# [333] امیر قمی → ✅ found file containing 'امیر_قمی'
# [334] امیر مرادی → ✅ found file containing 'امیر_مرادی'
# [335] امیر مرزوقی → ❌ no file containing 'امیر_مرزوقی'
# [336] امیر معماری  → ✅ found file containing 'امیر_معماری'
# [337] امیر مهدی‌زاده → ✅ found file containing 'امیر_مهدیزاده'
# [338] امیر هاشمی‌مقدم → ✅ found file containing 'امیر_هاشمیمقدم'
# [339] امیر کاظم‌پور → ✅ found file containing 'امیر_کاظمپور'
# [340] امیر یاوری → ✅ found file containing 'امیر_یاوری'
# [341] امیرارسلان مطهری → ✅ found file containing 'امیرارسلان_مطهری'
# [342] امیرحسن فردوس → ✅ found file containing 'امیرحسن_فردوس'
# [343] امیرحسین آذری → ❌ no file containing 'امیرحسین_آذری'
# [344] امیرحسین اسفندیار → ✅ found file containing 'امیرحسین_اسفندیار'
# [345] امیرحسین اسماعیل‌زاده → ✅ found file containing 'امیرحسین_اسماعیلزاده'
# [346] امیرحسین اصلانیان → ✅ found file containing 'امیرحسین_اصلانیان'
# [347] امیرحسین تاتاری → ✅ found file containing 'امیرحسین_تاتاری'
# [348] امیرحسین توخته → ✅ found file containing 'امیرحسین_توخته'
# [349] امیرحسین حسینی → ✅ found file containing 'امیرحسین_حسینی'
# [350] امیرحسین حسین‌زاده → ✅ found file containing 'امیرحسین_حسینزاده'
# [351] امیرحسین خدامرادی → ✅ found file containing 'امیرحسین_خدامرادی'
# [352] امیرحسین رهبر → ❌ no file containing 'امیرحسین_رهبر'
# [353] امیرحسین زارع → ✅ found file containing 'امیرحسین_زارع'
# [354] امیرحسین صابری → ✅ found file containing 'امیرحسین_صابری'
# [355] امیرحسین صادقی → ✅ found file containing 'امیرحسین_صادقی'
# [356] امیرحسین علی‌پور دربید → ✅ found file containing 'امیرحسین_علیپور_دربید'
# [357] امیرحسین فتحی → ✅ found file containing 'امیرحسین_فتحی'
# [358] امیرحسین فداکار → ✅ found file containing 'امیرحسین_فداکار'
# [359] امیرحسین فشنگچی → ✅ found file containing 'امیرحسین_فشنگچی'
# [360] امیرحسین فیروزپور → ❌ no file containing 'امیرحسین_فیروزپور'
# [361] امیرحسین مقصودی → ✅ found file containing 'امیرحسین_مقصودی'
# [362] امیرحسین هدایی → ❌ no file containing 'امیرحسین_هدایی'
# [363] امیرحسین پیروانی → ✅ found file containing 'امیرحسین_پیروانی'
# [364] امیرحسین کارگر → ✅ found file containing 'امیرحسین_کارگر'
# [365] امیرحسین کاووسی → ❌ no file containing 'امیرحسین_کاووسی'
# [366] امیرحسین کیهانی → ❌ no file containing 'امیرحسین_کیهانی'
# [367] امیرحسین یازرلو → ❌ no file containing 'امیرحسین_یازرلو'
# [368] امیررضا خادم → ✅ found file containing 'امیررضا_خادم'
# [369] امیررضا ده‌بزرگی → ❌ no file containing 'امیررضا_دهبزرگی'
# [370] امیررضا رفیعی → ✅ found file containing 'امیررضا_رفیعی'
# [371] امیررضا واعظی آشتیانی → ✅ found file containing 'امیررضا_واعظی_آشتیانی'
# [372] امیررضا پورآقابالا → ❌ no file containing 'امیررضا_پورآقابالا'
# [373] امیررضا پوررمضانعلی → ✅ found file containing 'امیررضا_پوررمضانعلی'
# [374] امیرسیاوش ذوالفقاریان → ✅ found file containing 'امیرسیاوش_ذوالفقاریان'
# [375] امیرعلی آذرپیرا → ✅ found file containing 'امیرعلی_آذرپیرا'
# [376] امیرعلی صادقی → ✅ found file containing 'امیرعلی_صادقی'
# [377] امیرعلی قلی‌زاده → ❌ no file containing 'امیرعلی_قلیزاده'
# [378] امیرعلی کاظمی → ❌ no file containing 'امیرعلی_کاظمی'
# [379] امیرمحمد نکونام → ✅ found file containing 'امیرمحمد_نکونام'
# [380] امیرمحمد گلزاده → ✅ found file containing 'امیرمحمد_گلزاده'
# [381] امیرمحمد یزدانی → ✅ found file containing 'امیرمحمد_یزدانی'
# [382] امیرمسعود برومند → ✅ found file containing 'امیرمسعود_برومند'
# [383] امیرممد گل زاده → ✅ found file containing 'امیرممد_گل_زاده'
# [384] امیرهوشنگ شریفی → ❌ no file containing 'امیرهوشنگ_شریفی'
# [385] امیروالا معدنچی → ❌ no file containing 'امیروالا_معدنچی'
# [386] امین اسماعیل‌نژاد → ✅ found file containing 'امین_اسماعیلنژاد'
# [387] امین بوداغی → ❌ no file containing 'امین_بوداغی'
# [388] امین جهان‌عالیان → ✅ found file containing 'امین_جهانعالیان'
# [389] امین جهان‌کهن → ✅ found file containing 'امین_جهانکهن'
# [390] امین دهقان → ✅ found file containing 'امین_دهقان'
# [391] امین طاهری → ✅ found file containing 'امین_طاهری'
# [392] امین قاسمی‌نژاد → ✅ found file containing 'امین_قاسمینژاد'
# [393] امین متوسل‌زاده → ✅ found file containing 'امین_متوسلزاده'
# [394] امین منوچهری → ✅ found file containing 'امین_منوچهری'
# [395] امین میرزازاده → ✅ found file containing 'امین_میرزازاده'
# [396] امین نصری → ✅ found file containing 'امین_نصری'
# [397] امین نظری → ✅ found file containing 'امین_نظری'
# [398] امین نیک‌فر → ✅ found file containing 'امین_نیکفر'
# [399] امین کاویانی‌نژاد → ❌ no file containing 'امین_کاویانینژاد'
# [400] انس بنی یاسین → ✅ found file containing 'انس_بنی_یاسین'
# [401] انور هادژیابدیچ → ✅ found file containing 'انور_هادژیابدیچ'
# [402] انوشا شاهقلی → ✅ found file containing 'انوشا_شاهقلی'
# [403] انوشیروان نوریان → ❌ no file containing 'انوشیروان_نوریان'
# [404] انگین فیرات → ✅ found file containing 'انگین_فیرات'
# [405] اورستیس جونیور آلوز → ❌ no file containing 'اورستیس_جونیور_آلوز'
# [406] اوسمار ویرا → ✅ found file containing 'اوسمار_ویرا'
# [407] اوسیانو دا کروز → ✅ found file containing 'اوسیانو_دا_کروز'
# [408] اوشین ساهاکیان → ❌ no file containing 'اوشین_ساهاکیان'
# [409] اولکسی پولیانسکی → ✅ found file containing 'اولکسی_پولیانسکی'
# [410] اوگنی ایوانف → ❌ no file containing 'اوگنی_ایوانف'
# [411] اویس حسن‌زاده → ✅ found file containing 'اویس_حسنزاده'
# [412] اویس ملاح → ❌ no file containing 'اویس_ملاح'
# [413] اکبر افتخاری → ✅ found file containing 'اکبر_افتخاری'
# [414] اکبر ایمانی → ✅ found file containing 'اکبر_ایمانی'
# [415] اکبر ترکان → ✅ found file containing 'اکبر_ترکان'
# [416] اکبر خزایی → ✅ found file containing 'اکبر_خزایی'
# [417] اکبر خوجینی → ❌ no file containing 'اکبر_خوجینی'
# [418] اکبر صادقی  → ✅ found file containing 'اکبر_صادقی'
# [419] اکبر فلاح → ✅ found file containing 'اکبر_فلاح'
# [420] اکبر میثاقیان → ✅ found file containing 'اکبر_میثاقیان'
# [421] اکبر کارگرجم → ✅ found file containing 'اکبر_کارگرجم'
# [422] اکرم خدابنده → ✅ found file containing 'اکرم_خدابنده'
# [423] ایان رمزی → ✅ found file containing 'ایان_رمزی'
# [424] ایان فایت → ✅ found file containing 'ایان_فایت'
# [425] ایبای گومز → ✅ found file containing 'ایبای_گومز'
# [426] ایران الیاس‌ون → ✅ found file containing 'ایران_الیاسون'
# [427] ایرج خورشیدفر → ❌ no file containing 'ایرج_خورشیدفر'
# [428] ایرج دانایی‌فرد → ✅ found file containing 'ایرج_داناییفرد'
# [429] ایرج سلیمانی → ✅ found file containing 'ایرج_سلیمانی'
# [430] ایرج عرب → ✅ found file containing 'ایرج_عرب'
# [431] ایرج ملک‌حسین‌پور → ✅ found file containing 'ایرج_ملکحسینپور'
# [432] ایزار ایلخانوف → ❌ no file containing 'ایزار_ایلخانوف'
# [433] ایلوش خوشابه → ✅ found file containing 'ایلوش_خوشابه'
# [434] ایلی استان → ✅ found file containing 'ایلی_استان'
# [435] ایمان انصاری → ✅ found file containing 'ایمان_انصاری'
# [436] ایمان جمالی → ✅ found file containing 'ایمان_جمالی'
# [437] ایمان حاجی‌هاشمی → ❌ no file containing 'ایمان_حاجیهاشمی'
# [438] ایمان زندی → ❌ no file containing 'ایمان_زندی'
# [439] ایمان زکی‌زاده → ❌ no file containing 'ایمان_زکیزاده'
# [440] ایمان سلیمی → ✅ found file containing 'ایمان_سلیمی'
# [441] ایمان سنچولی → ❌ no file containing 'ایمان_سنچولی'
# [442] ایمان شوریابی → ✅ found file containing 'ایمان_شوریابی'
# [443] ایمان صادقی  → ✅ found file containing 'ایمان_صادقی'
# [444] ایمان عالمی → ✅ found file containing 'ایمان_عالمی'
# [445] ایمان مبعلی → ✅ found file containing 'ایمان_مبعلی'
# [446] ایمان محمدی → ✅ found file containing 'ایمان_محمدی'
# [447] ایمان محمدیان → ❌ no file containing 'ایمان_محمدیان'
# [448] ایمان مهدوی → ✅ found file containing 'ایمان_مهدوی'
# [449] ایمان موسوی → ✅ found file containing 'ایمان_موسوی'
# [450] ایمان کیانی → ❌ no file containing 'ایمان_کیانی'
# [451] ایمن زاید → ✅ found file containing 'ایمن_زاید'
# [452] ایوان ترابالیک → ✅ found file containing 'ایوان_ترابالیک'
# [453] ایوان مارکوویچ → ✅ found file containing 'ایوان_مارکوویچ'
# [454] ایوان پتروویچ → ✅ found file containing 'ایوان_پتروویچ'
# [455] ایوب العملود → ✅ found file containing 'ایوب_العملود'
# [456] ایوب بنی‌نصرت → ✅ found file containing 'ایوب_بنینصرت'
# [457] ایوب رستمی  → ✅ found file containing 'ایوب_رستمی'
# [458] ایوب والی → ✅ found file containing 'ایوب_والی'
# [459] ایوب پورتقی → ❌ no file containing 'ایوب_پورتقی'
# [460] ایگور اشتیماتس → ✅ found file containing 'ایگور_اشتیماتس'
# [461] ایگور الکساندرویچ  نتو → ✅ found file containing 'ایگور_الکساندرویچ_نتو'
# [462] ایگور نتو → ✅ found file containing 'ایگور_نتو'
# [463] ایگور پوستونیسکی → ✅ found file containing 'ایگور_پوستونیسکی'
# [464] بابک امیرطهماسب → ❌ no file containing 'بابک_امیرطهماسب'
# [465] بابک حاتمی → ✅ found file containing 'بابک_حاتمی'
# [466] بابک داوری → ✅ found file containing 'بابک_داوری'
# [467] بابک فرهودی → ❌ no file containing 'بابک_فرهودی'
# [468] بابک قربانی → ✅ found file containing 'بابک_قربانی'
# [469] بابک مرادی → ✅ found file containing 'بابک_مرادی'
# [470] بابک معصومی → ✅ found file containing 'بابک_معصومی'
# [471] بابک نورزاد → ❌ no file containing 'بابک_نورزاد'
# [472] بابک پورغلامی → ✅ found file containing 'بابک_پورغلامی'
# [505] بهادر عبدی → ✅ found file containing 'بهادر_عبدی'
# [506] بهادر مولایی → ✅ found file containing 'بهادر_مولایی'
# [507] بهادر نسیم‌اف → ✅ found file containing 'بهادر_نسیماف'
# [508] بهادر کرمی → ❌ no file containing 'بهادر_کرمی'
# [509] بهاره قادریان → ❌ no file containing 'بهاره_قادریان'
# [510] بهتاش فریبا → ✅ found file containing 'بهتاش_فریبا'
# [511] بهداد بیرانوند → ✅ found file containing 'بهداد_بیرانوند'
# [512] بهداد سلیمی → ✅ found file containing 'بهداد_سلیمی'
# [513] بهرام اسماعیلی → ✅ found file containing 'بهرام_اسماعیلی'
# [514] بهرام افشارزاده → ✅ found file containing 'بهرام_افشارزاده'
# [515] بهرام توکلی  → ✅ found file containing 'بهرام_توکلی'
# [516] بهرام دباغ → ❌ no file containing 'بهرام_دباغ'
# [517] بهرام رشیدی فرخی → ✅ found file containing 'بهرام_رشیدی_فرخی'
# [518] بهرام مشتاقی → ✅ found file containing 'بهرام_مشتاقی'
# [519] بهرام مهرپیما → ✅ found file containing 'بهرام_مهرپیما'
# [520] بهرام مودت → ✅ found file containing 'بهرام_مودت'
# [521] بهرام چوبین → ✅ found file containing 'بهرام_چوبین'
# [522] بهرنگ صفری → ✅ found file containing 'بهرنگ_صفری'
# [523] بهروز جمشیدی → ✅ found file containing 'بهروز_جمشیدی'
# [524] بهروز رهبری‌فر → ✅ found file containing 'بهروز_رهبریفر'
# [525] بهروز سلطانی → ✅ found file containing 'بهروز_سلطانی'
# [526] بهروز صحابه تبریزی → ✅ found file containing 'بهروز_صحابه_تبریزی'
# [527] بهروز عطایی → ✅ found file containing 'بهروز_عطایی'
# [528] بهروز مکوندی → ✅ found file containing 'بهروز_مکوندی'
# [529] بهروز نعمتی → ✅ found file containing 'بهروز_نعمتی'
# [530] بهروز یاری → ✅ found file containing 'بهروز_یاری'
# [531] بهزاد حیدرشاهی → ✅ found file containing 'بهزاد_حیدرشاهی'
# [532] بهزاد غلامپور → ✅ found file containing 'بهزاد_غلامپور'
# [533] بهمن تیموری → ✅ found file containing 'بهمن_تیموری'
# [534] بهمن عسگری → ✅ found file containing 'بهمن_عسگری'
# [535] بهمن نصیری → ✅ found file containing 'بهمن_نصیری'
# [536] بهمن کامل → ✅ found file containing 'بهمن_کامل'
# [537] بهمن گلبارنژاد → ✅ found file containing 'بهمن_گلبارنژاد'
# [538] بهناز خجسته‌پور → ❌ no file containing 'بهناز_خجستهپور'
# [539] بهناز طاهرخانی → ✅ found file containing 'بهناز_طاهرخانی'
# [540] بهنام آذرمجیدی → ❌ no file containing 'بهنام_آذرمجیدی'
# [541] بهنام ابوالقاسم‌پور → ✅ found file containing 'بهنام_ابوالقاسمپور'
# [542] بهنام احسان‌پور → ❌ no file containing 'بهنام_احسانپور'
# [543] بهنام اسبقی → ❌ no file containing 'بهنام_اسبقی'
# [544] بهنام برزای → ✅ found file containing 'بهنام_برزای'
# [545] بهنام بیات → ✅ found file containing 'بهنام_بیات'
# [546] بهنام سراج → ✅ found file containing 'بهنام_سراج'
# [547] بهنام شیری → ✅ found file containing 'بهنام_شیری'
# [548] بهنام طاهرزاده → ❌ no file containing 'بهنام_طاهرزاده'
# [549] بهنام طیبی → ❌ no file containing 'بهنام_طیبی'
# [550] بهنام محمودی → ✅ found file containing 'بهنام_محمودی'
# [551] بهنام مهدی‌زاده → ❌ no file containing 'بهنام_مهدیزاده'
# [552] بهنام یخچالی → ✅ found file containing 'بهنام_یخچالی'
# [553] بوباکار تراوالی → ✅ found file containing 'بوباکار_تراوالی'
# [554] بولی سامبو → ✅ found file containing 'بولی_سامبو'
# [555] بوژیدار رادوشویچ → ✅ found file containing 'بوژیدار_رادوشویچ'
# [556] بوگدان میلیچ → ✅ found file containing 'بوگدان_میلیچ'
# [557] بویان نایدنوف → ✅ found file containing 'بویان_نایدنوف'
# [558] بویوک‌آغا حاجی‌اف → ✅ found file containing 'بویوکآغا_حاجیاف'
# [559] بیت‌الله عباس‌پور → ✅ found file containing 'بیتالله_عباسپور'
# [560] بیوک جدی‌کار → ✅ found file containing 'بیوک_جدیکار'
# [561] بیوک وطنخواه → ❌ no file containing 'بیوک_وطنخواه'
# [562] بیژن براتی → ✅ found file containing 'بیژن_براتی'
# [563] بیژن حیدری → ✅ found file containing 'بیژن_حیدری'
# [564] بیژن ذوالفقارنسب → ✅ found file containing 'بیژن_ذوالفقارنسب'
# [565] بیژن زرنگار → ❌ no file containing 'بیژن_زرنگار'
# [566] بیژن طاهری → ✅ found file containing 'بیژن_طاهری'
# [567] بیژن کنگرلو → ❌ no file containing 'بیژن_کنگرلو'
# [568] تئو د یونگ → ✅ found file containing 'تئو_د_یونگ'
# [569] تاکافومی آکاهشی → ✅ found file containing 'تاکافومی_آکاهشی'
# [570] ترانه احمدی → ✅ found file containing 'ترانه_احمدی'
# [571] ترانه کامیاب → ❌ no file containing 'ترانه_کامیاب'
# [572] تقی اکبرنژاد → ❌ no file containing 'تقی_اکبرنژاد'
# [573] تقی اکبری → ❌ no file containing 'تقی_اکبری'
# [574] تقی داداشی → ❌ no file containing 'تقی_داداشی'
# [575] تقی رضایی → ✅ found file containing 'تقی_رضایی'
# [576] تقی عسگری → ❌ no file containing 'تقی_عسگری'
# [577] تهمینه درگذنی → ✅ found file containing 'تهمینه_درگذنی'
# [578] توحید غلامی → ❌ no file containing 'توحید_غلامی'
# [579] توران شادپور → ✅ found file containing 'توران_شادپور'
# [580] تورج ابراهیمی → ✅ found file containing 'تورج_ابراهیمی'
# [581] تورج حق‌وردی → ✅ found file containing 'تورج_حقوردی'
# [582] توماس ویلیامسون → ✅ found file containing 'توماس_ویلیامسون'
# [583] تومیسلاو ایوکوویچ → ❌ no file containing 'تومیسلاو_ایوکوویچ'
# [584] تومیسلاو ایویچ → ✅ found file containing 'تومیسلاو_ایویچ'
# [585] تونی اوسنیک → ✅ found file containing 'تونی_اوسنیک'
# [586] تکتم آخوندزاده → ❌ no file containing 'تکتم_آخوندزاده'
# [587] تیاگو فریرا → ✅ found file containing 'تیاگو_فریرا'
# [588] تیم ملی فوتبال زنان ایران → ✅ found file containing 'تیم_ملی_فوتبال_زنان_ایران'
# [589] تیم ملی فوتبال زیر ۱۷ سال زنان ایران → ✅ found file containing 'تیم_ملی_فوتبال_زیر_۱۷_سال_زنان_ایران'
# [590] تیم ملی فوتبال زیر ۱۹ سال زنان ایران → ✅ found file containing 'تیم_ملی_فوتبال_زیر_۱۹_سال_زنان_ایران'
# [591] تیم ملی فوتسال زنان ایران → ✅ found file containing 'تیم_ملی_فوتسال_زنان_ایران'
# [592] تیمور غیاثی → ✅ found file containing 'تیمور_غیاثی'
# [593] تیوی بیفوما → ✅ found file containing 'تیوی_بیفوما'
# [594] ثریا آقایی → ✅ found file containing 'ثریا_آقایی'
# [595] جابر انصاری → ✅ found file containing 'جابر_انصاری'
# [596] جابر بهروزی → ❌ no file containing 'جابر_بهروزی'
# [597] جابر روزبهانی → ❌ no file containing 'جابر_روزبهانی'
# [598] جابر صادق‌زاده → ✅ found file containing 'جابر_صادقزاده'
# [599] جادر دا سیلوا برازیرو → ✅ found file containing 'جادر_دا_سیلوا_برازیرو'
# [600] جاسم امیری → ✅ found file containing 'جاسم_امیری'
# [601] جاسم دلاوری → ✅ found file containing 'جاسم_دلاوری'
# [602] جاسم سلطانی → ❌ no file containing 'جاسم_سلطانی'
# [603] جاسم غلام الحمد → ❌ no file containing 'جاسم_غلام_الحمد'
# [604] جاسم ویشکائی → ❌ no file containing 'جاسم_ویشکائی'
# [605] جامی رفعتی → ❌ no file containing 'جامی_رفعتی'
# [606] جان توشاک → ✅ found file containing 'جان_توشاک'
# [607] جاناتان دا سیلوا پریرا → ❌ no file containing 'جاناتان_دا_سیلوا_پریرا'
# [608] جبار فعلی → ✅ found file containing 'جبار_فعلی'
# [609] جبار مهدیون → ❌ no file containing 'جبار_مهدیون'
# [610] جرج مراد → ✅ found file containing 'جرج_مراد'
# [611] جری بنگتسون → ✅ found file containing 'جری_بنگتسون'
# [612] جعفر احمدی → ✅ found file containing 'جعفر_احمدی'
# [613] جعفر باباخانی → ❌ no file containing 'جعفر_باباخانی'
# [614] جعفر سلماسی → ✅ found file containing 'جعفر_سلماسی'
# [615] جعفر سلمانی → ✅ found file containing 'جعفر_سلمانی'
# [616] جعفر پهلوانی → ❌ no file containing 'جعفر_پهلوانی'
# [617] جعفر کاشانی → ✅ found file containing 'جعفر_کاشانی'
# [618] جعفر کربلایی‌زاده → ❌ no file containing 'جعفر_کربلاییزاده'
# [619] جلال امیدیان → ✅ found file containing 'جلال_امیدیان'
# [620] جلال اکبری → ✅ found file containing 'جلال_اکبری'
# [621] جلال خدامی → ✅ found file containing 'جلال_خدامی'
# [622] جلال رابوکی → ✅ found file containing 'جلال_رابوکی'
# [623] جلال طالبی → ✅ found file containing 'جلال_طالبی'
# [624] جلال منصوری → ✅ found file containing 'جلال_منصوری'
# [625] جلال کاملی‌مفرد → ✅ found file containing 'جلال_کاملیمفرد'
# [626] جلال کشمیری → ✅ found file containing 'جلال_کشمیری'
# [627] جلال‌الدین علی‌محمدی → ✅ found file containing 'جلالالدین_علیمحمدی'
# [628] جلسون → ❌ no file containing 'جلسون'
# [629] جلیل ایمری → ✅ found file containing 'جلیل_ایمری'
# [630] جلیل باقری جدی → ❌ no file containing 'جلیل_باقری_جدی'
# [631] جمال میرزایی → ✅ found file containing 'جمال_میرزایی'
# [632] جمال ولی‌زاده → ❌ no file containing 'جمال_ولیزاده'
# [633] جمال چاوشی‌فر → ❌ no file containing 'جمال_چاوشیفر'
# [634] جمشید شاه‌محمدی  → ❌ no file containing 'جمشید_شاهمحمدی'
# [635] جمشید فانی → ✅ found file containing 'جمشید_فانی'
# [636] جمشید نصیری → ✅ found file containing 'جمشید_نصیری'
# [637] جمیله سروری → ✅ found file containing 'جمیله_سروری'
# [638] جهانبخت توفیق → ✅ found file containing 'جهانبخت_توفیق'
# [639] جهانگیر توکلی → ❌ no file containing 'جهانگیر_توکلی'
# [640] جهانگیر عراقی → ✅ found file containing 'جهانگیر_عراقی'
# [641] جواد الله‌وردی → ✅ found file containing 'جواد_اللهوردی'
# [642] جواد تقی‌پور → ❌ no file containing 'جواد_تقیپور'
# [643] جواد حسین‌آبادی → ✅ found file containing 'جواد_حسینآبادی'
# [644] جواد درفشی جوان → ✅ found file containing 'جواد_درفشی_جوان'
# [645] جواد زرینچه → ✅ found file containing 'جواد_زرینچه'
# [646] جواد شیرزاد → ✅ found file containing 'جواد_شیرزاد'
# [647] جواد فروغی → ✅ found file containing 'جواد_فروغی'
# [648] جواد قراب → ✅ found file containing 'جواد_قراب'
# [649] جواد محتشمیان → ✅ found file containing 'جواد_محتشمیان'
# [650] جواد محجوب → ✅ found file containing 'جواد_محجوب'
# [651] جواد نوروزی → ✅ found file containing 'جواد_نوروزی'
# [652] جواد نکونام → ✅ found file containing 'جواد_نکونام'
# [653] جواد کاظمیان → ✅ found file containing 'جواد_کاظمیان'
# [654] جواد کریمی → ✅ found file containing 'جواد_کریمی'
# [655] جواد یساری → ✅ found file containing 'جواد_یساری'
# [656] جورج توپالوویچ → ✅ found file containing 'جورج_توپالوویچ'
# [657] جوروان ویرا → ✅ found file containing 'جوروان_ویرا'
# [658] جونیور براندائو → ✅ found file containing 'جونیور_براندائو'
# [659] جیحون سلطان‌اف → ✅ found file containing 'جیحون_سلطاناف'
# [660] جی‌لوید ساموئل → ✅ found file containing 'جیلوید_ساموئل'
# [661] حامد آفاق → ❌ no file containing 'حامد_آفاق'
# [662] حامد بحیرایی → ✅ found file containing 'حامد_بحیرایی'
# [663] حامد تاب → ❌ no file containing 'حامد_تاب'
# [664] حامد تاری‌وردی → ❌ no file containing 'حامد_تاریوردی'
# [665] حامد حدادی → ✅ found file containing 'حامد_حدادی'
# [666] حامد حیدری → ✅ found file containing 'حامد_حیدری'
# [667] حامد رسولی → ❌ no file containing 'حامد_رسولی'
# [668] حامد رشیدی → ✅ found file containing 'حامد_رشیدی'
# [669] حامد سهراب‌نژاد → ❌ no file containing 'حامد_سهرابنژاد'
# [670] حامد صلحی‌پور → ✅ found file containing 'حامد_صلحیپور'
# [671] حامد فلاح‌زاده → ✅ found file containing 'حامد_فلاحزاده'
# [672] حامد لک → ✅ found file containing 'حامد_لک'
# [673] حامد ملک‌خانبانان → ❌ no file containing 'حامد_ملکخانبانان'
# [674] حامد ملک‌محمدی معمار → ❌ no file containing 'حامد_ملکمحمدی_معمار'
# [675] حامد میرزاپور → ✅ found file containing 'حامد_میرزاپور'
# [676] حامد نورمحمدی  → ✅ found file containing 'حامد_نورمحمدی'
# [677] حامد پاکدل → ✅ found file containing 'حامد_پاکدل'
# [678] حامد کاویانپور → ✅ found file containing 'حامد_کاویانپور'
# [679] حبیب بهمنی → ✅ found file containing 'حبیب_بهمنی'
# [680] حبیب فرعباسی → ✅ found file containing 'حبیب_فرعباسی'
# [681] حبیب کاشانی → ✅ found file containing 'حبیب_کاشانی'
# [682] حبیب گردانی → ✅ found file containing 'حبیب_گردانی'
# [683] حبیب‌الله اخلاقی → ✅ found file containing 'حبیبالله_اخلاقی'
# [684] حبیب‌الله ایگدر → ✅ found file containing 'حبیبالله_ایگدر'
# [685] حبیب‌الله بلور → ✅ found file containing 'حبیبالله_بلور'
# [686] حجت صدقی → ✅ found file containing 'حجت_صدقی'
# [687] حدیثه جمال → ✅ found file containing 'حدیثه_جمال'
# [688] حسام فوزی → ❌ no file containing 'حسام_فوزی'
# [689] حسام پ/صفحه تمرین → ❌ no file containing 'حسام_پصفحه_تمرین'
# [690] حسام پورهاشم → ❌ no file containing 'حسام_پورهاشم'
# [691] حسن آریان‌فرد → ❌ no file containing 'حسن_آریانفرد'
# [692] حسن اشجاری → ❌ no file containing 'حسن_اشجاری'
# [693] حسن اکبرنژاد → ✅ found file containing 'حسن_اکبرنژاد'
# [694] حسن اکرمی → ✅ found file containing 'حسن_اکرمی'
# [695] حسن بابک → ✅ found file containing 'حسن_بابک'
# [696] حسن باشت باوی → ❌ no file containing 'حسن_باشت_باوی'
# [697] حسن بیت‌سعید → ✅ found file containing 'حسن_بیتسعید'
# [698] حسن تفتیان → ✅ found file containing 'حسن_تفتیان'
# [699] حسن جعفری  → ✅ found file containing 'حسن_جعفری'
# [700] حسن حبیبی  → ✅ found file containing 'حسن_حبیبی'
# [701] حسن خان‌محمدی → ❌ no file containing 'حسن_خانمحمدی'
# [702] حسن رحیمی → ✅ found file containing 'حسن_رحیمی'
# [703] حسن رنگرز → ✅ found file containing 'حسن_رنگرز'
# [704] حسن روحانی  → ✅ found file containing 'حسن_روحانی'
# [705] حسن رودباریان → ✅ found file containing 'حسن_رودباریان'
# [706] حسن روشن → ✅ found file containing 'حسن_روشن'
# [707] حسن زاهدی  → ✅ found file containing 'حسن_زاهدی'
# [708] حسن زرافشان → ❌ no file containing 'حسن_زرافشان'
# [709] حسن سعدیان → ❌ no file containing 'حسن_سعدیان'
# [710] حسن شمشکی → ❌ no file containing 'حسن_شمشکی'
# [711] حسن شوشتری → ✅ found file containing 'حسن_شوشتری'
# [712] حسن عسگری  → ✅ found file containing 'حسن_عسگری'
# [713] حسن غفوری‌فرد → ✅ found file containing 'حسن_غفوریفرد'
# [714] حسن نایب‌آقا → ❌ no file containing 'حسن_نایبآقا'
# [715] حسن نظری → ✅ found file containing 'حسن_نظری'
# [716] حسن نوفلاح → ✅ found file containing 'حسن_نوفلاح'
# [717] حسن هوری → ✅ found file containing 'حسن_هوری'
# [718] حسن پاک‌اندام → ✅ found file containing 'حسن_پاکاندام'
# [719] حسن کامرانی‌فر → ✅ found file containing 'حسن_کامرانیفر'
# [720] حسن یزدانی → ✅ found file containing 'حسن_یزدانی'
# [721] حسن یوسفی افشار → ❌ no file containing 'حسن_یوسفی_افشار'
# [722] حسین آریانژاد → ✅ found file containing 'حسین_آریانژاد'
# [723] حسین آشنا → ✅ found file containing 'حسین_آشنا'
# [724] حسین ابراهیمی → ✅ found file containing 'حسین_ابراهیمی'
# [725] حسین ابوذری → ✅ found file containing 'حسین_ابوذری'
# [726] حسین اسدی → ✅ found file containing 'حسین_اسدی'
# [727] حسین افضلی → ❌ no file containing 'حسین_افضلی'
# [728] حسین اوجاقی → ❌ no file containing 'حسین_اوجاقی'
# [729] حسین بادامکی → ✅ found file containing 'حسین_بادامکی'
# [730] حسین باقری → ✅ found file containing 'حسین_باقری'
# [731] حسین برقچی → ❌ no file containing 'حسین_برقچی'
# [732] حسین بغلانی → ✅ found file containing 'حسین_بغلانی'
# [733] حسین بهشتی → ✅ found file containing 'حسین_بهشتی'
# [734] حسین تهامی → ✅ found file containing 'حسین_تهامی'
# [735] حسین توکلی → ✅ found file containing 'حسین_توکلی'
# [736] حسین جبارزادگان → ✅ found file containing 'حسین_جبارزادگان'
# [737] حسین حراجچی → ✅ found file containing 'حسین_حراجچی'
# [738] حسین حسینی  → ✅ found file containing 'حسین_حسینی'
# [739] حسین حیدری → ✅ found file containing 'حسین_حیدری'
# [740] حسین خالدی → ✅ found file containing 'حسین_خالدی'
# [741] حسین خانبان → ❌ no file containing 'حسین_خانبان'
# [742] حسین خطیبی  → ✅ found file containing 'حسین_خطیبی'
# [743] حسین رحمتی → ✅ found file containing 'حسین_رحمتی'
# [744] حسین رسولی → ❌ no file containing 'حسین_رسولی'
# [745] حسین رضازاده → ✅ found file containing 'حسین_رضازاده'
# [746] حسین روحانی → ✅ found file containing 'حسین_روحانی'
# [747] حسین زامهران → ✅ found file containing 'حسین_زامهران'
# [748] حسین زرینی → ✅ found file containing 'حسین_زرینی'
# [749] حسین زمانی → ✅ found file containing 'حسین_زمانی'
# [750] حسین ساوه‌شمشکی → ❌ no file containing 'حسین_ساوهشمشکی'
# [751] حسین ساکی → ✅ found file containing 'حسین_ساکی'
# [752] حسین سرودی → ✅ found file containing 'حسین_سرودی'
# [753] حسین سلطانی  → ✅ found file containing 'حسین_سلطانی'
# [754] حسین سمندر → ✅ found file containing 'حسین_سمندر'
# [755] حسین سمیعی → ✅ found file containing 'حسین_سمیعی'
# [756] حسین شاه‌حسینی → ✅ found file containing 'حسین_شاهحسینی'
# [757] حسین شایان → ❌ no file containing 'حسین_شایان'
# [758] حسین شمس → ✅ found file containing 'حسین_شمس'
# [759] حسین شهبازی → ✅ found file containing 'حسین_شهبازی'
# [760] حسین صادق عابدین → ❌ no file containing 'حسین_صادق_عابدین'
# [761] حسین صادقی  → ✅ found file containing 'حسین_صادقی'
# [762] حسین صدقیانی → ✅ found file containing 'حسین_صدقیانی'
# [763] حسین طوسی → ✅ found file containing 'حسین_طوسی'
# [764] حسین طیبی → ✅ found file containing 'حسین_طیبی'
# [765] حسین عبدی → ✅ found file containing 'حسین_عبدی'
# [766] حسین عسکری → ✅ found file containing 'حسین_عسکری'
# [767] حسین عسگری → ✅ found file containing 'حسین_عسگری'
# [768] حسین علاء → ✅ found file containing 'حسین_علاء'
# [769] حسین فاضلی → ✅ found file containing 'حسین_فاضلی'
# [770] حسین فرکی → ✅ found file containing 'حسین_فرکی'
# [771] حسین فکری → ✅ found file containing 'حسین_فکری'
# [772] حسین قجه‌ای → ✅ found file containing 'حسین_قجهای'
# [773] حسین قنبری → ✅ found file containing 'حسین_قنبری'
# [774] حسین ماهینی → ✅ found file containing 'حسین_ماهینی'
# [775] حسین محلوجی → ❌ no file containing 'حسین_محلوجی'
# [776] حسین معدنی → ✅ found file containing 'حسین_معدنی'
# [777] حسین ملاقاسمی → ✅ found file containing 'حسین_ملاقاسمی'
# [778] حسین مهربان → ✅ found file containing 'حسین_مهربان'
# [779] حسین مکاریان → ✅ found file containing 'حسین_مکاریان'
# [780] حسین نسیم → ✅ found file containing 'حسین_نسیم'
# [781] حسین نوری  → ✅ found file containing 'حسین_نوری'
# [782] حسین نیک‌نام → ✅ found file containing 'حسین_نیکنام'
# ...
# [2826] وحید بیاتلو → ✅ found file containing 'وحید_بیاتلو'
# [2827] وحید جدی → ✅ found file containing 'وحید_جدی'
# [2828] وحید جوهری → ✅ found file containing 'وحید_جوهری'
# [2829] وحید دلیرزهان → ❌ no file containing 'وحید_دلیرزهان'
# [2830] وحید سرلک → ✅ found file containing 'وحید_سرلک'
# [2831] وحید شفیعی → ✅ found file containing 'وحید_شفیعی'
# [2832] وحید شمسایی → ✅ found file containing 'وحید_شمسایی'
# [2833] وحید شیخ‌ویسی → ✅ found file containing 'وحید_شیخویسی'
# [2834] وحید طالب‌لو → ✅ found file containing 'وحید_طالبلو'
# [2835] وحید فاضلی → ✅ found file containing 'وحید_فاضلی'
# [2836] وحید محمدزاده → ✅ found file containing 'وحید_محمدزاده'
# [2837] وحید نجفی دمیرچی → ✅ found file containing 'وحید_نجفی_دمیرچی'
# [2838] وحید هاشمیان → ✅ found file containing 'وحید_هاشمیان'
# [2839] وحید کاظمی → ✅ found file containing 'وحید_کاظمی'
# [2840] وحید کشتکار → ❌ no file containing 'وحید_کشتکار'
# [2841] وحید گل‌خندان → ✅ found file containing 'وحید_گلخندان'
# [2842] وحیدرضا دستورانی → ✅ found file containing 'وحیدرضا_دستورانی'
# [2843] وحیده ایثاری → ✅ found file containing 'وحیده_ایثاری'
# [2844] وریا غفوری → ✅ found file containing 'وریا_غفوری'
# [2845] وزیر ورزش و جوانان → ✅ found file containing 'وزیر_ورزش_و_جوانان'
# [2846] ولاتکو گروزدانوسکی → ✅ found file containing 'ولاتکو_گروزدانوسکی'
# [2847] ولادیمیر کومان → ✅ found file containing 'ولادیمیر_کومان'
# [2848] ولسلی ننکا → ✅ found file containing 'ولسلی_ننکا'
# [2849] ولی اکبر → ✅ found file containing 'ولی_اکبر'
# [2850] ولی نورمحمدی → ✅ found file containing 'ولی_نورمحمدی'
# [2851] ولید اسماعیل → ✅ found file containing 'ولید_اسماعیل'
# [2852] وولودیمیر پریموف → ✅ found file containing 'وولودیمیر_پریموف'
# [2853] ویدا حلیمیان → ❌ no file containing 'ویدا_حلیمیان'
# [2854] ویسنته آرزه → ✅ found file containing 'ویسنته_آرزه'
# [2855] ویلیام آتشکده → ✅ found file containing 'ویلیام_آتشکده'
# [2856] وینفرید شفر → ✅ found file containing 'وینفرید_شفر'
# [2857] وینکو بگوویچ → ✅ found file containing 'وینکو_بگوویچ'
# [2858] پائولو آلوز → ✅ found file containing 'پائولو_آلوز'
# [2859] پائولو سرژیو → ✅ found file containing 'پائولو_سرژیو'
# [2860] پائولو سزار → ✅ found file containing 'پائولو_سزار'
# [2861] پاتریس کارترون → ✅ found file containing 'پاتریس_کارترون'
# [2862] پارسا محمدی → ✅ found file containing 'پارسا_محمدی'
# [2863] پانی کیانزاد → ✅ found file containing 'پانی_کیانزاد'
# [2864] پاکو خمز → ✅ found file containing 'پاکو_خمز'
# [2865] پایان رأفت → ✅ found file containing 'پایان_رأفت'
# [2866] پدرام قاضی‌پور → ✅ found file containing 'پدرام_قاضیپور'
# [2867] پدرو هنریکه → ✅ found file containing 'پدرو_هنریکه'
# [2868] پدرو هنریکه اولیویرا → ✅ found file containing 'پدرو_هنریکه_اولیویرا'
# [2869] پدیده بلوری‌زاده → ❌ no file containing 'پدیده_بلوریزاده'
# [2870] پردیس عیدی‌وندی → ❌ no file containing 'پردیس_عیدیوندی'
# [2871] پرستو حبیبی → ✅ found file containing 'پرستو_حبیبی'
# [2872] پرستو مه نمای اقدم → ✅ found file containing 'پرستو_مه_نمای_اقدم'
# [2873] پرهام مقصودلو → ✅ found file containing 'پرهام_مقصودلو'
# [2874] پرو پییچ → ✅ found file containing 'پرو_پییچ'
# [2875] پروانه تهرانی → ✅ found file containing 'پروانه_تهرانی'
# [2876] پروانه محمدتقی‌پور طهرانی → ❌ no file containing 'پروانه_محمدتقیپور_طهرانی'
# [2877] پروانه کاظمی → ✅ found file containing 'پروانه_کاظمی'
# [2878] پرویز برومند → ✅ found file containing 'پرویز_برومند'
# [2879] پرویز جلایر → ✅ found file containing 'پرویز_جلایر'
# [2880] پرویز خسروانی → ✅ found file containing 'پرویز_خسروانی'
# [2881] پرویز دهداری → ✅ found file containing 'پرویز_دهداری'
# [2882] پرویز زیدوند → ❌ no file containing 'پرویز_زیدوند'
# [2883] پرویز مظلومی → ✅ found file containing 'پرویز_مظلومی'
# [2884] پرویز میرزاحسن → ❌ no file containing 'پرویز_میرزاحسن'
# [2885] پرویز هادی → ✅ found file containing 'پرویز_هادی'
# [2886] پرویز کریمی → ✅ found file containing 'پرویز_کریمی'
# [2887] پرویز کوزه‌کنانی → ✅ found file containing 'پرویز_کوزهکنانی'
# [2888] پری فردی → ✅ found file containing 'پری_فردی'
# [2889] پری نقی‌پور → ✅ found file containing 'پری_نقیپور'
# [2890] پریسا احمدی  → ❌ no file containing 'پریسا_احمدی'
# [2891] پریسا براتچی  → ❌ no file containing 'پریسا_براتچی'
# [2892] پریسا بهزادی → ❌ no file containing 'پریسا_بهزادی'
# [2893] پریسا جهانفکریان → ✅ found file containing 'پریسا_جهانفکریان'
# [2894] پریسا جوادی → ✅ found file containing 'پریسا_جوادی'
# [2895] پریسا فرشیدی → ✅ found file containing 'پریسا_فرشیدی'
# [2896] پریچهر جمشیدی → ✅ found file containing 'پریچهر_جمشیدی'
# [2897] پطروس نظربگیان → ✅ found file containing 'پطروس_نظربگیان'
# [2898] پهلوان ابراهیم حلاج تفتی یزدی → ✅ found file containing 'پهلوان_ابراهیم_حلاج_تفتی_یزدی'
# [2899] پهلوان موسی خمیس → ✅ found file containing 'پهلوان_موسی_خمیس'
# [2900] پهلوان موسی خمیس گرزدین‌وند → ✅ found file containing 'پهلوان_موسی_خمیس_گرزدینوند'
# [2901] پوران زارع → ✅ found file containing 'پوران_زارع'
# [2902] پوریا امینی → ✅ found file containing 'پوریا_امینی'
# [2903] پوریا حسین خانزاده → ✅ found file containing 'پوریا_حسین_خانزاده'
# [2904] پوریا درینی → ✅ found file containing 'پوریا_درینی'
# [2905] پوریا ساوه شمشکی → ❌ no file containing 'پوریا_ساوه_شمشکی'
# [2906] پوریا سرآبادانی → ✅ found file containing 'پوریا_سرآبادانی'
# [2907] پوریا فیاضی → ✅ found file containing 'پوریا_فیاضی'
# [2908] پوریا نوروزیان → ❌ no file containing 'پوریا_نوروزیان'
# [2909] پوریا یلی → ✅ found file containing 'پوریا_یلی'
# [2910] پوریای ولی → ✅ found file containing 'پوریای_ولی'
# [2911] پوپک بسامی → ✅ found file containing 'پوپک_بسامی'
# [2912] پویا ایدنی → ✅ found file containing 'پویا_ایدنی'
# [2913] پویا تاجیک → ❌ no file containing 'پویا_تاجیک'
# [2914] پویا دادمرز → ✅ found file containing 'پویا_دادمرز'
# [2915] پویا رحمانی → ✅ found file containing 'پویا_رحمانی'
# [2916] پویا ناصرپور → ❌ no file containing 'پویا_ناصرپور'
# [2917] پویا نزهتی → ✅ found file containing 'پویا_نزهتی'
# [2918] پویا پورعلی → ✅ found file containing 'پویا_پورعلی'
# [2919] پژمان جمشیدی → ✅ found file containing 'پژمان_جمشیدی'
# [2920] پژمان درستکار → ✅ found file containing 'پژمان_درستکار'
# [2921] پژمان قلعه‌نویی → ❌ no file containing 'پژمان_قلعهنویی'
# [2922] پژمان منتظری → ✅ found file containing 'پژمان_منتظری'
# [2923] پژمان نوری → ✅ found file containing 'پژمان_نوری'
# [2924] پژمان پشتام → ✅ found file containing 'پژمان_پشتام'
# [2965] کارلوس کی‌روش → ✅ found file containing 'کارلوس_کیروش'
# [2966] کارن بارسقیان → ❌ no file containing 'کارن_بارسقیان'
# [2967] کارو حق‌وردیان → ✅ found file containing 'کارو_حقوردیان'
# [2968] کاظم اشتری → ✅ found file containing 'کاظم_اشتری'
# [2969] کاظم رجبی → ✅ found file containing 'کاظم_رجبی'
# [2970] کاظم ساریخانی → ❌ no file containing 'کاظم_ساریخانی'
# [2971] کاظم غلامی → ✅ found file containing 'کاظم_غلامی'
# [2972] کالینز جان → ✅ found file containing 'کالینز_جان'
# [2973] کامبیز آتابای → ✅ found file containing 'کامبیز_آتابای'
# [2974] کامبیز درفشی جوان → ❌ no file containing 'کامبیز_درفشی_جوان'
# [2975] کامران شکری سالاری → ❌ no file containing 'کامران_شکری_سالاری'
# [2976] کامران شیرازی → ✅ found file containing 'کامران_شیرازی'
# [2977] کامران قاسم‌پور → ✅ found file containing 'کامران_قاسمپور'
# [2978] کامران پنجوی → ❌ no file containing 'کامران_پنجوی'
# [2979] کاملیا فلاح → ✅ found file containing 'کاملیا_فلاح'
# [2980] کاوه رضایی → ✅ found file containing 'کاوه_رضایی'
# [2981] کاوه موسوی  → ✅ found file containing 'کاوه_موسوی'
# [2982] کبیر بلو → ❌ no file containing 'کبیر_بلو'
# [2983] کتایون خسرویار → ✅ found file containing 'کتایون_خسرویار'
# [2984] کرار جاسم → ✅ found file containing 'کرار_جاسم'
# [2985] کریستوفر کنت → ✅ found file containing 'کریستوفر_کنت'
# [2986] کریستوفر کنِت → ✅ found file containing 'کریستوفر_کنت'
# [2987] کریستین اوساگونا → ✅ found file containing 'کریستین_اوساگونا'
# [2988] کریم احمدی → ✅ found file containing 'کریم_احمدی'
# [2989] کریم اسلامی → ✅ found file containing 'کریم_اسلامی'
# [2990] کریم انصاری‌فرد → ✅ found file containing 'کریم_انصاریفرد'
# [2991] کریم باقری → ✅ found file containing 'کریم_باقری'
# [2992] کریم بوستانی → ✅ found file containing 'کریم_بوستانی'
# [2993] کریم رئیسی‌نیا → ✅ found file containing 'کریم_رئیسینیا'
# [2994] کریم شاهوردی → ❌ no file containing 'کریم_شاهوردی'
# [2995] کسری طاهری → ✅ found file containing 'کسری_طاهری'
# [2996] کسری مهدی‌پورنژاد → ✅ found file containing 'کسری_مهدیپورنژاد'
# [2997] کمال آلیسپاهیچ → ✅ found file containing 'کمال_آلیسپاهیچ'
# [2998] کمال کامیابی‌نیا → ✅ found file containing 'کمال_کامیابینیا'
# [2999] کمیل سوسکو → ❌ no file containing 'کمیل_سوسکو'
# [3000] کمیل قاسمی → ✅ found file containing 'کمیل_قاسمی'
# [3001] کوثر اساسه → ❌ no file containing 'کوثر_اساسه'
# [3002] کوروش باقری → ❌ no file containing 'کوروش_باقری'
# [3003] کوروش بختیار → ❌ no file containing 'کوروش_بختیار'
# [3004] کوروش رجلی → ❌ no file containing 'کوروش_رجلی'
# [3005] کوروش قربانی → ✅ found file containing 'کوروش_قربانی'
# [3006] کوروش محمدخانی → ✅ found file containing 'کوروش_محمدخانی'
# [3007] کوروش ملایی → ✅ found file containing 'کوروش_ملایی'
# [3008] کوروش ملکی → ✅ found file containing 'کوروش_ملکی'
# [3009] کوفی شولز → ✅ found file containing 'کوفی_شولز'
# [3010] کولیس جان → ✅ found file containing 'کولیس_جان'
# [3011] کوپال ناظمی → ✅ found file containing 'کوپال_ناظمی'
# [3012] کویستان خسروی → ✅ found file containing 'کویستان_خسروی'
# [3013] کوین یانسن → ✅ found file containing 'کوین_یانسن'
# [3014] کیا اسکندانی → ✅ found file containing 'کیا_اسکندانی'
# [3015] کیا جورابچیان → ✅ found file containing 'کیا_جورابچیان'
# [3016] کیا قدمی → ❌ no file containing 'کیا_قدمی'
# [3017] کیانوش رحمتی → ✅ found file containing 'کیانوش_رحمتی'
# [3018] کیانوش رستمی → ✅ found file containing 'کیانوش_رستمی'
# [3019] کیخسرو کهیایی → ❌ no file containing 'کیخسرو_کهیایی'
# [3020] کیروش استنلی → ✅ found file containing 'کیروش_استنلی'
# [3021] کیمیا علیزاده → ✅ found file containing 'کیمیا_علیزاده'
# [3022] کیمیا یزدیان → ✅ found file containing 'کیمیا_یزدیان'
# [3023] کیمیا یوسفی → ✅ found file containing 'کیمیا_یوسفی'
# [3024] کیهان تاکاهاشی → ❌ no file containing 'کیهان_تاکاهاشی'
# [3025] کیوان دهناد → ✅ found file containing 'کیوان_دهناد'
# [3026] کیوان شیرآقایی  → ❌ no file containing 'کیوان_شیرآقایی'
# [3027] کیوان قنبرزاده → ❌ no file containing 'کیوان_قنبرزاده'
# [3028] کیومرث ابوالملوکی → ✅ found file containing 'کیومرث_ابوالملوکی'
# [3029] کیومرث هاشمی → ✅ found file containing 'کیومرث_هاشمی'
# [3030] گئورگ کاسپاروف → ✅ found file containing 'گئورگ_کاسپاروف'
# [3031] گئورگی گئورگیف → ✅ found file containing 'گئورگی_گئورگیف'
# [3032] گئورگی گولسیانی → ✅ found file containing 'گئورگی_گولسیانی'
# [3033] گابریل کالدرون → ✅ found file containing 'گابریل_کالدرون'
# [3034] گابریله پین → ✅ found file containing 'گابریله_پین'
# [3035] گادوین منشا → ✅ found file containing 'گادوین_منشا'
# [3036] گارنیک شه‌بندری → ✅ found file containing 'گارنیک_شهبندری'
# [3037] گارنیک مهرابیان → ✅ found file containing 'گارنیک_مهرابیان'
# [3038] گالوست پطروسیان → ❌ no file containing 'گالوست_پطروسیان'
# [3039] گریگور ملیکستیان → ❌ no file containing 'گریگور_ملیکستیان'
# [3040] گریگول چابرادزه → ✅ found file containing 'گریگول_چابرادزه'
# [3041] گغارد موساسی → ✅ found file containing 'گغارد_موساسی'
# [3042] گلاره ناظمی → ✅ found file containing 'گلاره_ناظمی'
# [3043] گلنوش خسروی → ✅ found file containing 'گلنوش_خسروی'
# [3044] گلنوش سبقت‌الهی → ✅ found file containing 'گلنوش_سبقتالهی'
# [3045] گودرز حبیبی → ✅ found file containing 'گودرز_حبیبی'
# [3046] گوران یرکوویچ → ✅ found file containing 'گوران_یرکوویچ'
# [3047] گوستاوو بلانکو → ✅ found file containing 'گوستاوو_بلانکو'
# [3048] گیتی محبان → ✅ found file containing 'گیتی_محبان'
# [3049] گیسا بایبوردی → ❌ no file containing 'گیسا_بایبوردی'
# [3050] یاسر خورشیدی میانایی → ❌ no file containing 'یاسر_خورشیدی_میانایی'
# [3051] یاسر همرنگ → ✅ found file containing 'یاسر_همرنگ'
# [3052] یاسین رضایی → ❌ no file containing 'یاسین_رضایی'
# [3053] یاسین سلمانی → ✅ found file containing 'یاسین_سلمانی'
# [3054] یحیی گل‌محمدی → ✅ found file containing 'یحیی_گلمحمدی'
# [3055] یدالله اکبری → ✅ found file containing 'یدالله_اکبری'
# [3056] یدالله جهانبازی → ✅ found file containing 'یدالله_جهانبازی'
# [3057] یدالله محبی → ❌ no file containing 'یدالله_محبی'
# [3058] یزدان میرزایی → ❌ no file containing 'یزدان_میرزایی'
# [3059] یعقوب نجفی جویباری → ❌ no file containing 'یعقوب_نجفی_جویباری'
# [3060] یعقوب کریمی → ✅ found file containing 'یعقوب_کریمی'
# [3061] یعقوبعلی شورورزی → ✅ found file containing 'یعقوبعلی_شورورزی'
# [3062] یعقوبعلی شوروَرزی → ✅ found file containing 'یعقوبعلی_شورورزی'
# [3063] یو درویش → ✅ found file containing 'یو_درویش'
# [3064] یوانیس توپالیدیس → ✅ found file containing 'یوانیس_توپالیدیس'
# [3065] یوسف سیدی → ✅ found file containing 'یوسف_سیدی'
# [3066] یوسف سیدی گلی بلاغ → ✅ found file containing 'یوسف_سیدی_گلی_بلاغ'
# [3067] یوسف صبری → ✅ found file containing 'یوسف_صبری'
# [3068] یوسف صفوت → ✅ found file containing 'یوسف_صفوت'
# [3069] یوسف قادریان → ✅ found file containing 'یوسف_قادریان'
# [3070] یوسف وکیا → ✅ found file containing 'یوسف_وکیا'
# [3071] یوسف کرمی → ✅ found file containing 'یوسف_کرمی'
# [3072] یونس امامی → ✅ found file containing 'یونس_امامی'
# [3073] یونس اکبرپور → ✅ found file containing 'یونس_اکبرپور'
# [3074] یونس باهنر → ✅ found file containing 'یونس_باهنر'
# [3075] یونس دلفی → ✅ found file containing 'یونس_دلفی'
# [3076] یونس سرمستی → ❌ no file containing 'یونس_سرمستی'
# [3077] یونس شاکری → ✅ found file containing 'یونس_شاکری'
# [3078] یونس فضلی جمور → ✅ found file containing 'یونس_فضلی_جمور'
# [3079] یونس مسعودی → ✅ found file containing 'یونس_مسعودی'
# [3080] یوکیا سوگیتا → ✅ found file containing 'یوکیا_سوگیتا'
# [3081] یکتا جمالی → ❌ no file containing 'یکتا_جمالی'
#
# --------------------------------------------------------------------------------
# Output JSON: athlete_merged_with_bios_imaged_crawled.json
# Total records: 3082
# is_image_downloaded = True : 2347
# is_image_downloaded = False: 735
# Checked sum: 3082 (should equal total)
# --------------------------------------------------------------------------------

# %%
INPUT_JSON = Path("athlete_merged_with_bios_imaged_crawled.json")
IMG_DIR    = Path("athlete_images")

# Set to True if you want to preview without deleting
DRY_RUN = False

def sanitize_filename(s: str) -> str:
    s = (str(s) or "").strip()
    s = re.sub(r"\s+", "_", s)
    s = re.sub(r"[^\w\-.]+", "", s)
    return s or "image"

def find_image_number(fname: str) -> int:
    """
    Extract number after '_image' if present, e.g. '_image3' -> 3; else large number.
    """
    m = re.search(r"_image(\d+)\b", fname)
    return int(m.group(1)) if m else 10**9

def keep_priority_key(p: Path) -> tuple:
    """
    Sort key for deciding which image to KEEP.
    Lower tuple sorts first (higher priority).
    """
    name = p.name.lower()
    return (
        0 if "_crawled" in name else 1,        # prefer crawled
        find_image_number(name),               # then prefer lower image number
        0 if "_image." in name else 1,         # then prefer plain _image.jpg
        name                                   # final tie-breaker
    )

# --- load records ---
with INPUT_JSON.open("r", encoding="utf-8") as f:
    records = json.load(f)

if not IMG_DIR.exists():
    print(f"⚠️  Images folder does not exist: {IMG_DIR}. Nothing to clean.")
else:
    all_files = [p for p in IMG_DIR.iterdir() if p.is_file()]
    all_files_lower = {p.name.lower(): p for p in all_files}  # map for quick access

deleted_files = []
kept_map = {}  # record index -> kept filename (for logs)
dupe_records = 0
no_image_records = 0
already_singleton = 0

print("\n" + "="*92)
print("Deduplicating athlete_images based on safe_name from athlete_merged_with_bios_imaged_crawled.json")
print("="*92)

for idx, rec in enumerate(records):
    name = rec.get("name") or f"record_{idx}"
    safe_name = sanitize_filename(name).lower()

    # Gather matches by substring of safe_name in filename (case-insensitive)
    matches = [p for p in all_files if safe_name in p.name.lower()]

    if len(matches) == 0:
        no_image_records += 1
        print(f"[{idx}] {name} → ❌ no matching images")
        continue

    if len(matches) == 1:
        already_singleton += 1
        kept_map[idx] = matches[0].name
        print(f"[{idx}] {name} → ✅ 1 image: keep {matches[0].name}")
        continue

    # More than one: choose one to keep, delete others
    dupe_records += 1
    matches_sorted = sorted(matches, key=keep_priority_key)
    keep = matches_sorted[0]
    to_delete = matches_sorted[1:]
    kept_map[idx] = keep.name

    print(f"[{idx}] {name} → ⚠️ {len(matches)} images found")
    print(f"    keep   : {keep.name}")
    if to_delete:
        for f in to_delete:
            print(f"    delete : {f.name}")
            if not DRY_RUN:
                try:
                    os.remove(f)
                    deleted_files.append(f.name)
                except Exception as e:
                    print(f"      → deletion failed for {f.name}: {e}")

# --- report ---
print("\n" + "-"*92)
print("DEDUP REPORT")
print("-"*92)
total = len(records)
print(f"Total records examined:          {total}")
print(f"Records with no images:          {no_image_records}")
print(f"Records with exactly 1 image:    {already_singleton}")
print(f"Records with duplicates cleaned: {dupe_records}")
print(f"Total files deleted:             {len(deleted_files)}")
if deleted_files:
    sample = deleted_files[:15]
    print(f"Deleted (sample up to 15):       {sample}")
print(f"Dry run mode:                    {DRY_RUN}")
print("-"*92)
# Out:
# ============================================================================================
# Deduplicating athlete_images based on safe_name from athlete_merged_with_bios_imaged_crawled.json
# ============================================================================================
# [0] Hellper/صفحه تمرین → ❌ no matching images
# [1] Jorvan Vieira → ✅ 1 image: keep 1_Jorvan_Vieira_image1.jpg
# [2] آتسو استویکوف → ⚠️ 2 images found
#     keep   : 2_آتسو_استویکوف_crawled.jpg
#     delete : 2_آتسو_استویکوف_image.jpg
# [3] آتنا محمدی → ✅ 1 image: keep 3_آتنا_محمدی_image.jpg
# [4] آتوسا پورکاشیان → ✅ 1 image: keep 4_آتوسا_پورکاشیان_image.jpg
# [5] آتوسا گلشادنژاد → ❌ no matching images
# [6] آتیلا حجازی → ✅ 1 image: keep 6_آتیلا_حجازی_image.jpg
# [7] آدام جمیلی → ✅ 1 image: keep 7_آدام_جمیلی_image.jpg
# [8] آدام همتی → ✅ 1 image: keep 8_آدام_همتی_image.jpg
# [9] آدریانو آلوز → ✅ 1 image: keep 9_آدریانو_آلوز_image.jpg
# [10] آرا هاکوبیان  → ✅ 1 image: keep 10_آرا_هاکوبیان_crawled.jpg
# [11] آرارات آراکلیان → ❌ no matching images
# [12] آرامائیس تونویان → ❌ no matching images
# [13] آرتور میناسیان → ❌ no matching images
# [14] آرتور یدیگاریان → ✅ 1 image: keep 14_آرتور_یدیگاریان_image.jpg
# [15] آرتوش آساطوریان → ❌ no matching images
# [16] آرداشس ساگینیان → ✅ 1 image: keep 16_آرداشس_ساگینیان_crawled.jpg
# [17] آرزو حکیمی مقدم → ❌ no matching images
# [18] آرش استواری → ✅ 1 image: keep 18_آرش_استواری_image.jpg
# [19] آرش افشین → ✅ 1 image: keep 19_آرش_افشین_image.jpg
# [20] آرش برهانی → ✅ 1 image: keep 20_آرش_برهانی_image.jpg
# [21] آرش خرم‌علی → ❌ no matching images
# [22] آرش داجلیری → ✅ 1 image: keep 22_آرش_داجلیری_image.jpg
# [23] آرش رضاوند → ✅ 1 image: keep 23_آرش_رضاوند_image.jpg
# [24] آرش طاهباز → ✅ 1 image: keep 24_آرش_طاهباز_crawled.jpg
# [25] آرش کمانگیر → ✅ 1 image: keep 25_آرش_کمانگیر_image.jpg
# [26] آرشام یسایی → ✅ 1 image: keep 26_آرشام_یسایی__value.jpg
# [27] آرشاک آمیریان → ❌ no matching images
# [28] آرمان اکوان → ✅ 1 image: keep 28_آرمان_اکوان_image.jpg
# [29] آرمان رمضانی → ✅ 1 image: keep 29_آرمان_رمضانی_image.jpg
# [30] آرمان زنگنه → ❌ no matching images
# [31] آرمان علیزاده عبدولی → ✅ 1 image: keep 31_آرمان_علیزاده_عبدولی_crawled.jpg
# [32] آرمان غفاری → ✅ 1 image: keep 32_آرمان_غفاری_image.jpg
# [33] آرمان قاسمی → ✅ 1 image: keep 33_آرمان_قاسمی_image.jpg
# [34] آرماندو سا → ✅ 1 image: keep 34_آرماندو_سا_image.jpg
# [35] آرمن تیگرانیان  → ✅ 1 image: keep 35_آرمن_تیگرانیان_crawled.jpg
# [36] آرمناک پطروسیان → ✅ 1 image: keep 36_آرمناک_پطروسیان_image.jpg
# [37] آرمین افشین فر → ✅ 1 image: keep 37_آرمین_افشین_فر_image.jpg
# [38] آرمین تشکری → ✅ 1 image: keep 38_آرمین_تشکری__value.jpg
# [39] آرمین سهرابیان → ⚠️ 2 images found
#     keep   : 39_آرمین_سهرابیان_crawled.jpg
#     delete : 39_آرمین_سهرابیان_image.jpg
# [40] آرمین هادی‌پور → ✅ 1 image: keep 40_آرمین_هادیپور_image.jpg
# [41] آرمینا صادقیان → ✅ 1 image: keep 41_آرمینا_صادقیان_image.jpg
# [42] آرن داوودی → ✅ 1 image: keep 42_آرن_داوودی__value.jpg
# [43] آروین معظمی گودرزی → ✅ 1 image: keep 43_آروین_معظمی_گودرزی_image.jpg
# [44] آری هان → ⚠️ 2 images found
#     keep   : 44_آری_هان_crawled.jpg
#     delete : 44_آری_هان_image.jpg
# [45] آریا برزگر → ✅ 1 image: keep 45_آریا_برزگر_image.jpg
# [46] آریا جسورو هاسگاوا → ⚠️ 2 images found
#     keep   : 46_آریا_جسورو_هاسگاوا_crawled.jpg
#     delete : 46_آریا_جسورو_هاسگاوا_image.jpg
# [47] آریا داوری → ✅ 1 image: keep 47_آریا_داوری_image.jpg
# [48] آریا نسیمی‌شاد → ✅ 1 image: keep 48_آریا_نسیمیشاد_image.jpg
# [49] آرین سلیمی → ✅ 1 image: keep 49_آرین_سلیمی_image.jpg
# [50] آرین طاری → ✅ 1 image: keep 50_آرین_طاری_image.jpg
# [51] آرین غلامی → ✅ 1 image: keep 51_آرین_غلامی_image.jpg
# [52] آستان ارونوف → ✅ 1 image: keep 52_آستان_ارونوف_image.jpg
# [53] آقاخان چهارم → ✅ 1 image: keep 53_آقاخان_چهارم_image.jpg
# [54] آقوان مکرتچیان → ❌ no matching images
# [55] آلساندرو  → ✅ 1 image: keep 55_آلساندرو_image.jpg
# [56] آلمدین زیلیکیچ → ✅ 1 image: keep 56_آلمدین_زیلیکیچ__value.jpg
# [57] آلن راجرز → ✅ 1 image: keep 57_آلن_راجرز_image.jpg
# [58] آلوارو خوزه خیمنز گررو → ✅ 1 image: keep 58_آلوارو_خوزه_خیمنز_گررو_image.jpg
# [59] آلویس نانگ → ✅ 1 image: keep 59_آلویس_نانگ_image.jpg
# [60] آلکس آغاسی → ✅ 1 image: keep 60_آلکس_آغاسی__value.jpg
# [61] آلکو اسکندریان → ✅ 1 image: keep 61_آلکو_اسکندریان_image.jpg
# [62] آنا براتی → ❌ no matching images
# [63] آناهیتا زاهدی‌فر → ✅ 1 image: keep 63_آناهیتا_زاهدیفر_image.jpg
# [64] آناهیتا زمانیان → ✅ 1 image: keep 64_آناهیتا_زمانیان_image.jpg
# [65] آنتونی استوکس → ✅ 1 image: keep 65_آنتونی_استوکس_image.jpg
# [66] آنتونیو سیموئز → ✅ 1 image: keep 66_آنتونیو_سیموئز_image.jpg
# [67] آنتونیو مانیکونه → ❌ no matching images
# [68] آنتونیو ژوزه کونسیسائو اولیویرا → ✅ 1 image: keep 68_آنتونیو_ژوزه_کونسیسائو_اولیویرا_image.jpg
# [69] آندرانیک اسکندریان → ✅ 1 image: keep 69_آندرانیک_اسکندریان_image.jpg
# [70] آندرانیک تیموریان → ✅ 1 image: keep 70_آندرانیک_تیموریان_image.jpg
# [71] آندره آغاسی → ✅ 1 image: keep 71_آندره_آغاسی_image.jpg
# [139] احسان لشگری → ✅ 1 image: keep 139_احسان_لشگری_image.jpg
# [140] احسان مرادیان → ✅ 1 image: keep 140_احسان_مرادیان__value.jpg
# [141] احسان مهاجرشجاعی → ❌ no matching images
# [142] احسان پنشنبه → ✅ 1 image: keep 142_احسان_پنشنبه_image.jpg
# [143] احسان پهلوان → ✅ 1 image: keep 143_احسان_پهلوان_image.jpg
# [144] احسان پیرهادی → ✅ 1 image: keep 144_احسان_پیرهادی__value.jpg
# [145] احسان پیغمبری → ✅ 1 image: keep 145_احسان_پیغمبری_crawled.jpg
# [146] احسن‌الله شیرکوند → ✅ 1 image: keep 146_احسنالله_شیرکوند_image.jpg
# [147] احلام  → ✅ 1 image: keep 147_احلام_image.jpg
# [148] احمد آل نعمه → ✅ 1 image: keep 148_احمد_آل_نعمه_image.jpg
# [149] احمد آهی → ✅ 1 image: keep 149_احمد_آهی_image.jpg
# [150] احمد اسکندرپور → ❌ no matching images
# [151] احمد افغان → ✅ 1 image: keep 151_احمد_افغان_crawled.jpg
# [152] احمد الجبوری → ✅ 1 image: keep 152_احمد_الجبوری_image.jpg
# [153] احمد امین‌زاده → ❌ no matching images
# [154] احمد اکبری → ✅ 1 image: keep 154_احمد_اکبری_crawled.jpg
# [155] احمد ایری → ✅ 1 image: keep 155_احمد_ایری_crawled.jpg
# [156] احمد ایزدپناه → ❌ no matching images
# [157] احمد بذری → ❌ no matching images
# [158] احمد جمشیدیان → ✅ 1 image: keep 158_احمد_جمشیدیان_image.jpg
# [159] احمد خطیبی → ❌ no matching images
# [160] احمد درگاهی → ❌ no matching images
# [161] احمد دنیامالی → ✅ 1 image: keep 161_احمد_دنیامالی_image.jpg
# [162] احمد زنده‌روح → ❌ no matching images
# [163] احمد سنجری → ❌ no matching images
# [164] احمد صالحی → ✅ 1 image: keep 164_احمد_صالحی_crawled.jpg
# [165] احمد صمدیان → ✅ 1 image: keep 165_احمد_صمدیان_image.jpg
# [166] احمد عبدالله‌زاده → ✅ 1 image: keep 166_احمد_عبداللهزاده__value.jpg
# [167] احمد قاسمی  → ✅ 1 image: keep 167_احمد_قاسمی_crawled.jpg
# [168] احمد مؤمن‌زاده → ✅ 1 image: keep 168_احمد_مؤمنزاده_image.jpg
# [169] احمد محمدنژاد جوان → ❌ no matching images
# [170] احمد محمدی  → ✅ 1 image: keep 170_احمد_محمدی_crawled.jpg
# [171] احمد معین → ✅ 1 image: keep 171_احمد_معین_crawled.jpg
# [172] احمد موسوی → ⚠️ 2 images found
#     keep   : 172_احمد_موسوی_crawled.jpg
#     delete : 172_احمد_موسوی_image.jpg
# [173] احمد میرزاپور → ❌ no matching images
# [174] احمد نوراللهی → ✅ 1 image: keep 174_احمد_نوراللهی__value.jpg
# [175] احمد وفادار → ✅ 1 image: keep 175_احمد_وفادار_image.jpg
# [176] احمد پیدایش → ✅ 1 image: keep 176_احمد_پیدایش_crawled.jpg
# [177] احمد گلبو → ❌ no matching images
# [178] احمد گوهری → ✅ 1 image: keep 178_احمد_گوهری_image.jpg
# [179] احمد یاقوتی → ✅ 1 image: keep 179_احمد_یاقوتی_crawled.jpg
# [180] احمدرضا جلالی  → ❌ no matching images
# [181] احمدرضا زنده‌روح → ❌ no matching images
# [182] احمدرضا طالبیان → ❌ no matching images
# [183] احمدرضا عابدزاده → ⚠️ 2 images found
#     keep   : 183_احمدرضا_عابدزاده_crawled.jpg
#     delete : 183_احمدرضا_عابدزاده_image.jpg
# [184] احمدعلی ابتهاج → ❌ no matching images
# [185] ادسون  → ✅ 1 image: keep 185_ادسون_image.jpg
# [186] ادموند اختر → ✅ 1 image: keep 186_ادموند_اختر_image.jpg
# [187] ادموند بزیک → ✅ 1 image: keep 187_ادموند_بزیک_image.jpg
# [188] ادموند مایوفسکی → ✅ 1 image: keep 188_ادموند_مایوفسکی_image.jpg
# [189] ادمیر آدرویچ → ⚠️ 2 images found
#     keep   : 189_ادمیر_آدرویچ_crawled.jpg
#     delete : 189_ادمیر_آدرویچ__value.jpg
# [190] ادوارد مانگاسار → ❌ no matching images
# [191] ادواردو فریرا → ✅ 1 image: keep 191_ادواردو_فریرا_image.jpg
# [192] ادون حسنی → ✅ 1 image: keep 192_ادون_حسنی_image.jpg
# [193] ادینیو → ✅ 1 image: keep 193_ادینیو_image.jpg
# [194] اردشیر قوانلوپور → ✅ 1 image: keep 194_اردشیر_قوانلوپور_crawled.jpg
# [195] اردلان آشتیانی → ✅ 1 image: keep 195_اردلان_آشتیانی_image.jpg
# [196] ارسلان امینی → ✅ 1 image: keep 196_ارسلان_امینی_image.jpg
# [197] ارسلان علیجانی منفرد → ❌ no matching images
# [198] ارسلان مطهری → ⚠️ 2 images found
#     keep   : 198_ارسلان_مطهری_image1.jpg
#     delete : 341_امیرارسلان_مطهری_image.jpg
# [199] ارسلان کاظمی → ⚠️ 2 images found
#     keep   : 199_ارسلان_کاظمی_crawled.jpg
#     delete : 199_ارسلان_کاظمی_image.jpg
# [200] ارشاد یوسفی → ✅ 1 image: keep 200_ارشاد_یوسفی_image.jpg
# [201] ارشک محبی → ✅ 1 image: keep 201_ارشک_محبی_crawled.jpg
# [202] ارشیا ارباب بهرامی → ⚠️ 2 images found
#     keep   : 202_ارشیا_ارباب_بهرامی_crawled.jpg
#     delete : 202_ارشیا_ارباب_بهرامی__value.jpg
# [203] ارشیا الماسی → ❌ no matching images
# [204] ارطغرل ساغلام → ✅ 1 image: keep 204_ارطغرل_ساغلام_image.jpg
# [205] ارغوان رضایی → ✅ 1 image: keep 205_ارغوان_رضایی__value.jpg
# [206] ارنست میدندروپ → ✅ 1 image: keep 206_ارنست_میدندروپ_image.jpg
# [207] ارنی برندتس → ✅ 1 image: keep 207_ارنی_برندتس_image.jpg
# [208] اروین بولکو → ✅ 1 image: keep 208_اروین_بولکو_image.jpg
# [209] استانکو پوکله‌پوویچ → ✅ 1 image: keep 209_استانکو_پوکلهپوویچ_image.jpg
# [210] استوان مویسیلوویچ → ⚠️ 2 images found
#     keep   : 210_استوان_مویسیلوویچ_crawled.jpg
#     delete : 210_استوان_مویسیلوویچ_image.jpg
# [211] استیون ان‌زونزی → ✅ 1 image: keep 211_استیون_انزونزی_image.jpg
# [212] استیون بیت‌آشور → ✅ 1 image: keep 212_استیون_بیتآشور_image.jpg
# [213] اسحاق حاتمی‌فر → ✅ 1 image: keep 213_اسحاق_حاتمیفر_crawled.jpg
# [214] اسحاق قویدل → ✅ 1 image: keep 214_اسحاق_قویدل_image.jpg
# [215] اسدالله عظیمی → ✅ 1 image: keep 215_اسدالله_عظیمی_crawled.jpg
# [216] اسدالله میهنی → ❌ no matching images
# [217] اسفندیار زرنگار → ❌ no matching images
# [218] اسلام جاهدی → ✅ 1 image: keep 218_اسلام_جاهدی_image.jpg
# [219] اسما سعیدی → ✅ 1 image: keep 219_اسما_سعیدی_image.jpg
# [220] اسماعیل اسماعیلی → ✅ 1 image: keep 220_اسماعیل_اسماعیلی_image.jpg
# [221] اسماعیل حلالی → ✅ 1 image: keep 221_اسماعیل_حلالی_image.jpg
# [222] اسماعیل شریفات → ✅ 1 image: keep 222_اسماعیل_شریفات_image.jpg
# [223] اسماعیل صفرزاده → ❌ no matching images
# [224] اسماعیل عبادی → ✅ 1 image: keep 224_اسماعیل_عبادی_image.jpg
# [225] اسماعیل عبدی → ✅ 1 image: keep 225_اسماعیل_عبدی__value.jpg
# [226] اسماعیل علم‌خواه → ✅ 1 image: keep 226_اسماعیل_علمخواه_image.jpg
# [227] اسماعیل مسافر → ✅ 1 image: keep 227_اسماعیل_مسافر_image.jpg
# [228] اسماعیل پاشاپور → ❌ no matching images
# [229] اسماعیل کارتال → ✅ 1 image: keep 229_اسماعیل_کارتال_image.jpg
# [230] اسکندر شورا → ❌ no matching images
# [231] اشراق نجف‌آبادی → ✅ 1 image: keep 231_اشراق_نجفآبادی_image.jpg
# [232] اشرف وحیدیان → ✅ 1 image: keep 232_اشرف_وحیدیان_image.jpg
# [233] اشپیتیم آرفی → ✅ 1 image: keep 233_اشپیتیم_آرفی_image.jpg
# [234] اشکان خورشیدی → ✅ 1 image: keep 234_اشکان_خورشیدی__value.jpg
# [235] اشکان دژآگه → ✅ 1 image: keep 235_اشکان_دژآگه_image.jpg
# [236] اشکان سعادتی فرد → ❌ no matching images
# [237] اشکان شکوفی → ❌ no matching images
# [238] اشکان نامداری → ✅ 1 image: keep 238_اشکان_نامداری_image.jpg
# [239] اصغر ابراهیمی → ❌ no matching images
# [240] اصغر احساسی → ❌ no matching images
# [241] اصغر حاجیلو → ✅ 1 image: keep 241_اصغر_حاجیلو_image.jpg
# [242] اصغر شرفی → ✅ 1 image: keep 242_اصغر_شرفی_image.jpg
# [243] اصغر کاردوست → ❌ no matching images
# [244] اصغر گلی‌زاده → ✅ 1 image: keep 244_اصغر_گلیزاده_image.jpg
# [245] اعظم آخوندی → ✅ 1 image: keep 245_اعظم_آخوندی_image.jpg
# [246] افسانه شیخی → ❌ no matching images
# [247] افسانه چترنور → ✅ 1 image: keep 247_افسانه_چترنور__value.jpg
# [248] افشین اسماعیل‌زاده → ❌ no matching images
# [249] افشین بیابانگرد → ❌ no matching images
# [250] افشین سلیمی → ❌ no matching images
# [251] افشین قطبی → ✅ 1 image: keep 251_افشین_قطبی_image.jpg
# [252] افشین ناظمی → ✅ 1 image: keep 252_افشین_ناظمی__value.jpg
# [253] افشین نوروزی → ✅ 1 image: keep 253_افشین_نوروزی_crawled.jpg
# [254] افشین پیروانی → ✅ 1 image: keep 254_افشین_پیروانی_image.jpg
# [255] افشین چاووشی → ✅ 1 image: keep 255_افشین_چاووشی_image.jpg
# [256] اف‌ام-۲۰۳۰ → ✅ 1 image: keep 256_افام-۲۰۳۰_image.jpg
# [257] البرز حاجی‌پور → ✅ 1 image: keep 257_البرز_حاجیپور_image.jpg
# [258] البرز زارعی → ⚠️ 2 images found
#     keep   : 259_البرز_زارعی_کوهسرک_image1.jpg
#     delete : 258_البرز_زارعی_image.jpg
# [259] البرز زارعی کوهسرک → ✅ 1 image: keep 259_البرز_زارعی_کوهسرک_image1.jpg
# [260] الشن مرادی → ✅ 1 image: keep 260_الشن_مرادی__value.jpg
# [261] اللهیار صیادمنش → ✅ 1 image: keep 261_اللهیار_صیادمنش_image.jpg
# [262] الله‌کرم استکی → ❌ no matching images
# [263] الله‌یار صالح → ✅ 1 image: keep 263_اللهیار_صالح_image.jpg
# [264] الناز رکابی → ✅ 1 image: keep 264_الناز_رکابی_image.jpg
# [265] الناز شفیعیان → ❌ no matching images
# [266] الناز قاسمی → ✅ 1 image: keep 266_الناز_قاسمی_image.jpg
# [267] الناز کمپانی → ❌ no matching images
# [268] الهام حسینی → ✅ 1 image: keep 268_الهام_حسینی_image.jpg
# [269] الهام رمضانی → ✅ 1 image: keep 269_الهام_رمضانی_crawled.jpg
# [270] الهام شیخی  → ✅ 1 image: keep 270_الهام_شیخی_image.jpg
# [271] الهام فلاح → ✅ 1 image: keep 271_الهام_فلاح_image.jpg
# [272] الهام قنبروف → ❌ no matching images
# [273] الهام هاشمی → ✅ 1 image: keep 273_الهام_هاشمی_image.jpg
# [274] الهام هریجانی → ❌ no matching images
# [275] الهام‌السادات اصغری → ❌ no matching images
# [276] الهه احمدی → ⚠️ 2 images found
#     keep   : 276_الهه_احمدی_crawled.jpg
#     delete : 276_الهه_احمدی_image.jpg
# [277] الهه منصوریان → ✅ 1 image: keep 277_الهه_منصوریان_image.jpg
# [278] الهه پورصالح → ✅ 1 image: keep 278_الهه_پورصالح_image.jpg
# [279] الویس کامسوبا → ✅ 1 image: keep 279_الویس_کامسوبا_image.jpg
# [280] الکس سمیع‌زاده → ❌ no matching images
# [281] الکساندر تادووسیان → ❌ no matching images
# [282] الکساندر مرکل → ⚠️ 2 images found
#     keep   : 282_الکساندر_مرکل_crawled.jpg
#     delete : 282_الکساندر_مرکل__value.jpg
# [283] الیاس حضرتی → ✅ 1 image: keep 283_الیاس_حضرتی_image.jpg
# [284] الیاس علی‌اکبری → ✅ 1 image: keep 284_الیاس_علیاکبری_image.jpg
# [285] الیاس هوریابند → ✅ 1 image: keep 285_الیاس_هوریابند_image.jpg
# [286] الیاس پاکدل → ❌ no matching images
# [287] امامعلی حبیبی → ✅ 1 image: keep 287_امامعلی_حبیبی__value.jpg
# [288] امانوئل آغاسی → ⚠️ 2 images found
#     keep   : 289_امانوئل_آغاسیEmmanuel_B._Aghassi_image1.jpg
#     delete : 288_امانوئل_آغاسی_image.jpg
# [289] امانوئل آغاسیEmmanuel B. Aghassi → ✅ 1 image: keep 289_امانوئل_آغاسیEmmanuel_B._Aghassi_image1.jpg
# [290] امان‌الله جهانبانی → ✅ 1 image: keep 290_امانالله_جهانبانی_image.jpg
# [291] امان‌الله پاپی → ❌ no matching images
# [292] امید ابراهیمی → ✅ 1 image: keep 292_امید_ابراهیمی__value.jpg
# [293] امید احمدی  → ✅ 1 image: keep 293_امید_احمدی_image.jpg
# [294] امید احمدی‌صفا → ❌ no matching images
# [295] امید تیزتک → ✅ 1 image: keep 295_امید_تیزتک_image.jpg
# [296] امید حامدی‌فر → ✅ 1 image: keep 296_امید_حامدیفر_image.jpg
# [297] امید خالدی → ✅ 1 image: keep 297_امید_خالدی_image.jpg
# [298] امید سه‌کناری → ❌ no matching images
# [299] امید سینگ → ✅ 1 image: keep 299_امید_سینگ_image.jpg
# [300] امید عالیشاه → ✅ 1 image: keep 300_امید_عالیشاه_image.jpg
# [301] امید لطف‌پور → ❌ no matching images
# [302] امید منصوری → ✅ 1 image: keep 302_امید_منصوری_image.jpg
# [303] امید نظامی‌پور → ✅ 1 image: keep 303_امید_نظامیپور__value.jpg
# [304] امید نظری → ✅ 1 image: keep 304_امید_نظری_image.jpg
# [305] امید نمازی → ✅ 1 image: keep 305_امید_نمازی__value.jpg
# [306] امید نورافکن → ✅ 1 image: keep 306_امید_نورافکن_image.jpg
# [307] امید نوروزی → ✅ 1 image: keep 307_امید_نوروزی_image.jpg
# [308] امیدرضا روانخواه → ✅ 1 image: keep 308_امیدرضا_روانخواه_image.jpg
# [309] امیر امینی → ✅ 1 image: keep 309_امیر_امینی_crawled.jpg
# [310] امیر باقری → ✅ 1 image: keep 310_امیر_باقری_image.jpg
# [311] امیر توکلیان → ✅ 1 image: keep 311_امیر_توکلیان__value.jpg
# [312] امیر جعفری ارنگه → ✅ 1 image: keep 312_امیر_جعفری_ارنگه_crawled.jpg
# [313] امیر جوهری‌خو → ❌ no matching images
# [314] امیر حاج رضایی → ✅ 1 image: keep 314_امیر_حاج_رضایی_image.jpg
# [315] امیر حقوقی → ✅ 1 image: keep 315_امیر_حقوقی_crawled.jpg
# [316] امیر دهداری → ❌ no matching images
# [317] امیر راهنمای رونقی → ❌ no matching images
# [318] امیر روستایی → ✅ 1 image: keep 318_امیر_روستایی_image.jpg
# [319] امیر زرگری → ❌ no matching images
# [320] امیر شاپورزاده → ✅ 1 image: keep 320_امیر_شاپورزاده_image.jpg
# [321] امیر شرفی → ❌ no matching images
# [322] امیر شمسایی → ✅ 1 image: keep 322_امیر_شمسایی_image.jpg
# [323] امیر صدیقی → ✅ 1 image: keep 323_امیر_صدیقی_crawled.jpg
# [324] امیر عابدزاده → ✅ 1 image: keep 324_امیر_عابدزاده_image.jpg
# [325] امیر عابدینی → ✅ 1 image: keep 325_امیر_عابدینی_image.jpg
# [326] امیر عراقی → ✅ 1 image: keep 326_امیر_عراقی_crawled.jpg
# [327] امیر عرب‌براقی → ✅ 1 image: keep 327_امیر_عرببراقی_image.jpg
# [328] امیر علی سعدالله → ✅ 1 image: keep 328_امیر_علی_سعدالله_image.jpg
# [329] امیر علی‌اکبری → ✅ 1 image: keep 329_امیر_علیاکبری_image.jpg
# [330] امیر غفور → ✅ 1 image: keep 330_امیر_غفور_image.jpg
# [331] امیر قاسمی‌منجزی → ❌ no matching images
# [332] امیر قلعه‌نویی → ✅ 1 image: keep 332_امیر_قلعهنویی_image.jpg
# [333] امیر قمی → ⚠️ 2 images found
#     keep   : 333_امیر_قمی_crawled.jpg
#     delete : 333_امیر_قمی_image.jpg
# [334] امیر مرادی → ✅ 1 image: keep 334_امیر_مرادی_image.jpg
# [335] امیر مرزوقی → ❌ no matching images
# [336] امیر معماری  → ✅ 1 image: keep 336_امیر_معماری_image.jpg
# [337] امیر مهدی‌زاده → ✅ 1 image: keep 337_امیر_مهدیزاده__value.jpg
# [338] امیر هاشمی‌مقدم → ✅ 1 image: keep 338_امیر_هاشمیمقدم_image.jpg
# [339] امیر کاظم‌پور → ✅ 1 image: keep 339_امیر_کاظمپور_crawled.jpg
# [340] امیر یاوری → ✅ 1 image: keep 340_امیر_یاوری_crawled.jpg
# [341] امیرارسلان مطهری → ✅ 1 image: keep 341_امیرارسلان_مطهری_image.jpg
# [342] امیرحسن فردوس → ✅ 1 image: keep 342_امیرحسن_فردوس_image.jpg
# [343] امیرحسین آذری → ❌ no matching images
# [344] امیرحسین اسفندیار → ✅ 1 image: keep 344_امیرحسین_اسفندیار__value.jpg
# [345] امیرحسین اسماعیل‌زاده → ✅ 1 image: keep 345_امیرحسین_اسماعیلزاده_image.jpg
# [346] امیرحسین اصلانیان → ✅ 1 image: keep 346_امیرحسین_اصلانیان_image.jpg
# [347] امیرحسین تاتاری → ✅ 1 image: keep 347_امیرحسین_تاتاری_image.jpg
# [348] امیرحسین توخته → ✅ 1 image: keep 348_امیرحسین_توخته_image.jpg
# [349] امیرحسین حسینی → ✅ 1 image: keep 349_امیرحسین_حسینی_crawled.jpg
# [350] امیرحسین حسین‌زاده → ✅ 1 image: keep 350_امیرحسین_حسینزاده_crawled.jpg
# [351] امیرحسین خدامرادی → ✅ 1 image: keep 351_امیرحسین_خدامرادی_image.jpg
# [352] امیرحسین رهبر → ❌ no matching images
# [353] امیرحسین زارع → ✅ 1 image: keep 353_امیرحسین_زارع_image.jpg
# [354] امیرحسین صابری → ✅ 1 image: keep 354_امیرحسین_صابری_image.jpg
# [355] امیرحسین صادقی → ✅ 1 image: keep 355_امیرحسین_صادقی_image.jpg
# [356] امیرحسین علی‌پور دربید → ✅ 1 image: keep 356_امیرحسین_علیپور_دربید_image.jpg
# [357] امیرحسین فتحی → ✅ 1 image: keep 357_امیرحسین_فتحی_image.jpg
# [358] امیرحسین فداکار → ✅ 1 image: keep 358_امیرحسین_فداکار_image.jpg
# [359] امیرحسین فشنگچی → ✅ 1 image: keep 359_امیرحسین_فشنگچی_image.jpg
# [360] امیرحسین فیروزپور → ❌ no matching images
# [361] امیرحسین مقصودی → ✅ 1 image: keep 361_امیرحسین_مقصودی_crawled.jpg
# [362] امیرحسین هدایی → ❌ no matching images
# [363] امیرحسین پیروانی → ✅ 1 image: keep 363_امیرحسین_پیروانی_image.jpg
# [364] امیرحسین کارگر → ✅ 1 image: keep 364_امیرحسین_کارگر_image.jpg
# [365] امیرحسین کاووسی → ❌ no matching images
# [366] امیرحسین کیهانی → ❌ no matching images
# [367] امیرحسین یازرلو → ❌ no matching images
# [368] امیررضا خادم → ✅ 1 image: keep 368_امیررضا_خادم_image.jpg
# [369] امیررضا ده‌بزرگی → ❌ no matching images
# [370] امیررضا رفیعی → ✅ 1 image: keep 370_امیررضا_رفیعی_image.jpg
# [371] امیررضا واعظی آشتیانی → ✅ 1 image: keep 371_امیررضا_واعظی_آشتیانی_image.jpg
# [372] امیررضا پورآقابالا → ❌ no matching images
# [373] امیررضا پوررمضانعلی → ⚠️ 2 images found
#     keep   : 373_امیررضا_پوررمضانعلی_crawled.jpg
#     delete : 373_امیررضا_پوررمضانعلی_image.jpg
# [374] امیرسیاوش ذوالفقاریان → ✅ 1 image: keep 374_امیرسیاوش_ذوالفقاریان_image.jpg
# [375] امیرعلی آذرپیرا → ✅ 1 image: keep 375_امیرعلی_آذرپیرا_image.jpg
# [376] امیرعلی صادقی → ✅ 1 image: keep 376_امیرعلی_صادقی__value.jpg
# [377] امیرعلی قلی‌زاده → ❌ no matching images
# [378] امیرعلی کاظمی → ❌ no matching images
# [379] امیرمحمد نکونام → ✅ 1 image: keep 379_امیرمحمد_نکونام__value.jpg
# [380] امیرمحمد گلزاده → ⚠️ 2 images found
#     keep   : 380_امیرمحمد_گلزاده_crawled.jpg
#     delete : 380_امیرمحمد_گلزاده_image.jpg
# [381] امیرمحمد یزدانی → ✅ 1 image: keep 381_امیرمحمد_یزدانی_crawled.jpg
# [382] امیرمسعود برومند → ✅ 1 image: keep 382_امیرمسعود_برومند_image.jpg
# [383] امیرممد گل زاده → ✅ 1 image: keep 383_امیرممد_گل_زاده_image1.jpg
# [384] امیرهوشنگ شریفی → ❌ no matching images
# [385] امیروالا معدنچی → ❌ no matching images
# [386] امین اسماعیل‌نژاد → ✅ 1 image: keep 386_امین_اسماعیلنژاد_crawled.jpg
# [387] امین بوداغی → ❌ no matching images
# [388] امین جهان‌عالیان → ✅ 1 image: keep 388_امین_جهانعالیان_image.jpg
# [389] امین جهان‌کهن → ✅ 1 image: keep 389_امین_جهانکهن_image.jpg
# [390] امین دهقان → ✅ 1 image: keep 390_امین_دهقان_image.jpg
# [391] امین طاهری → ⚠️ 2 images found
#     keep   : 391_امین_طاهری_image.jpg
#     delete : 924_رامین_طاهری__value.jpg
# [392] امین قاسمی‌نژاد → ✅ 1 image: keep 392_امین_قاسمینژاد_image.jpg
# [393] امین متوسل‌زاده → ✅ 1 image: keep 393_امین_متوسلزاده_image.jpg
# [394] امین منوچهری → ✅ 1 image: keep 394_امین_منوچهری__value.jpg
# [395] امین میرزازاده → ✅ 1 image: keep 395_امین_میرزازاده_crawled.jpg
# [396] امین نصری → ✅ 1 image: keep 396_امین_نصری_crawled.jpg
# [397] امین نظری → ✅ 1 image: keep 397_امین_نظری_image.jpg
# [398] امین نیک‌فر → ✅ 1 image: keep 398_امین_نیکفر_image.jpg
# [399] امین کاویانی‌نژاد → ❌ no matching images
# [400] انس بنی یاسین → ✅ 1 image: keep 400_انس_بنی_یاسین_image.jpg
# [401] انور هادژیابدیچ → ✅ 1 image: keep 401_انور_هادژیابدیچ_crawled.jpg
# [402] انوشا شاهقلی → ✅ 1 image: keep 402_انوشا_شاهقلی_image.jpg
# [403] انوشیروان نوریان → ❌ no matching images
# [404] انگین فیرات → ✅ 1 image: keep 404_انگین_فیرات_image.jpg
# [405] اورستیس جونیور آلوز → ❌ no matching images
# [406] اوسمار ویرا → ✅ 1 image: keep 406_اوسمار_ویرا_image.jpg
# [407] اوسیانو دا کروز → ✅ 1 image: keep 407_اوسیانو_دا_کروز_image.jpg
# [408] اوشین ساهاکیان → ❌ no matching images
# [409] اولکسی پولیانسکی → ✅ 1 image: keep 409_اولکسی_پولیانسکی_image.jpg
# [410] اوگنی ایوانف → ❌ no matching images
# [411] اویس حسن‌زاده → ✅ 1 image: keep 411_اویس_حسنزاده_image.jpg
# [412] اویس ملاح → ❌ no matching images
# [413] اکبر افتخاری → ✅ 1 image: keep 413_اکبر_افتخاری__value.jpg
# [414] اکبر ایمانی → ✅ 1 image: keep 414_اکبر_ایمانی_image.jpg
# [415] اکبر ترکان → ✅ 1 image: keep 415_اکبر_ترکان_image.jpg
# [416] اکبر خزایی → ✅ 1 image: keep 416_اکبر_خزایی_image.jpg
# [417] اکبر خوجینی → ❌ no matching images
# [418] اکبر صادقی  → ✅ 1 image: keep 418_اکبر_صادقی_image.jpg
# [419] اکبر فلاح → ✅ 1 image: keep 419_اکبر_فلاح_crawled.jpg
# [420] اکبر میثاقیان → ✅ 1 image: keep 420_اکبر_میثاقیان__value.jpg
# [421] اکبر کارگرجم → ✅ 1 image: keep 421_اکبر_کارگرجم_image.jpg
# [422] اکرم خدابنده → ✅ 1 image: keep 422_اکرم_خدابنده__value.jpg
# [423] ایان رمزی → ✅ 1 image: keep 423_ایان_رمزی_image.jpg
# [424] ایان فایت → ✅ 1 image: keep 424_ایان_فایت_image.jpg
# [425] ایبای گومز → ✅ 1 image: keep 425_ایبای_گومز_image.jpg
# [426] ایران الیاس‌ون → ✅ 1 image: keep 426_ایران_الیاسون_image.jpg
# [427] ایرج خورشیدفر → ❌ no matching images
# [428] ایرج دانایی‌فرد → ✅ 1 image: keep 428_ایرج_داناییفرد_image.jpg
# [429] ایرج سلیمانی → ✅ 1 image: keep 429_ایرج_سلیمانی_crawled.jpg
# [430] ایرج عرب → ⚠️ 2 images found
#     keep   : 430_ایرج_عرب_crawled.jpg
#     delete : 430_ایرج_عرب_image.jpg
# [431] ایرج ملک‌حسین‌پور → ✅ 1 image: keep 431_ایرج_ملکحسینپور_image.jpg
# [432] ایزار ایلخانوف → ❌ no matching images
# [433] ایلوش خوشابه → ✅ 1 image: keep 433_ایلوش_خوشابه_image.jpg
# [434] ایلی استان → ✅ 1 image: keep 434_ایلی_استان_image.jpg
# [435] ایمان انصاری → ✅ 1 image: keep 435_ایمان_انصاری_crawled.jpg
# [436] ایمان جمالی → ✅ 1 image: keep 436_ایمان_جمالی_image.jpg
# [437] ایمان حاجی‌هاشمی → ❌ no matching images
# [438] ایمان زندی → ❌ no matching images
# [439] ایمان زکی‌زاده → ❌ no matching images
# [440] ایمان سلیمی → ✅ 1 image: keep 440_ایمان_سلیمی_image.jpg
# [441] ایمان سنچولی → ❌ no matching images
# [442] ایمان شوریابی → ✅ 1 image: keep 442_ایمان_شوریابی_image.jpg
# [443] ایمان صادقی  → ✅ 1 image: keep 443_ایمان_صادقی_image.jpg
# [444] ایمان عالمی → ✅ 1 image: keep 444_ایمان_عالمی_image.jpg
# [445] ایمان مبعلی → ✅ 1 image: keep 445_ایمان_مبعلی_image.jpg
# [446] ایمان محمدی → ✅ 1 image: keep 446_ایمان_محمدی_image.jpg
# [447] ایمان محمدیان → ❌ no matching images
# [448] ایمان مهدوی → ✅ 1 image: keep 448_ایمان_مهدوی_crawled.jpg
# [449] ایمان موسوی → ✅ 1 image: keep 449_ایمان_موسوی_image.jpg
# [450] ایمان کیانی → ❌ no matching images
# [451] ایمن زاید → ✅ 1 image: keep 451_ایمن_زاید__value.jpg
# [452] ایوان ترابالیک → ✅ 1 image: keep 452_ایوان_ترابالیک_image.jpg
# [453] ایوان مارکوویچ → ✅ 1 image: keep 453_ایوان_مارکوویچ__value.jpg
# [454] ایوان پتروویچ → ✅ 1 image: keep 454_ایوان_پتروویچ_image.jpg
# [455] ایوب العملود → ✅ 1 image: keep 455_ایوب_العملود_image.jpg
# [456] ایوب بنی‌نصرت → ✅ 1 image: keep 456_ایوب_بنینصرت__value.jpg
# [457] ایوب رستمی  → ✅ 1 image: keep 457_ایوب_رستمی_image.jpg
# [458] ایوب والی → ✅ 1 image: keep 458_ایوب_والی_image.jpg
# [459] ایوب پورتقی → ❌ no matching images
# [460] ایگور اشتیماتس → ⚠️ 2 images found
#     keep   : 460_ایگور_اشتیماتس_crawled.jpg
#     delete : 460_ایگور_اشتیماتس_image.jpg
# [461] ایگور الکساندرویچ  نتو → ✅ 1 image: keep 461_ایگور_الکساندرویچ_نتو_image1.jpg
# [462] ایگور نتو → ⚠️ 2 images found
#     keep   : 462_ایگور_نتو_crawled.jpg
#     delete : 462_ایگور_نتو_image.jpg
# [463] ایگور پوستونیسکی → ✅ 1 image: keep 463_ایگور_پوستونیسکی_image.jpg
# [464] بابک امیرطهماسب → ❌ no matching images
# [465] بابک حاتمی → ✅ 1 image: keep 465_بابک_حاتمی_image.jpg
# [493] بختیار رحمانی → ✅ 1 image: keep 493_بختیار_رحمانی_image.jpg
# [494] بدری اسدی → ⚠️ 2 images found
#     keep   : 494_بدری_اسدی_crawled.jpg
#     delete : 494_بدری_اسدی_image.jpg
# [495] بدری لطیف → ❌ no matching images
# [496] برانکو ایوانکوویچ → ✅ 1 image: keep 496_برانکو_ایوانکوویچ_image.jpg
# [497] بردیا دانشور → ❌ no matching images
# [498] بردیا سعادت  → ✅ 1 image: keep 498_بردیا_سعادت_image.jpg
# [499] برف‌انبار → ✅ 1 image: keep 499_برفانبار_crawled.jpg
# [500] برونو سزار → ✅ 1 image: keep 500_برونو_سزار_image.jpg
# [501] بشار رسن → ✅ 1 image: keep 501_بشار_رسن_image.jpg
# [502] بشیر باباجان‌زاده → ✅ 1 image: keep 502_بشیر_باباجانزاده_image.jpg
# [503] بنجامین ابراهیم‌زاده → ✅ 1 image: keep 503_بنجامین_ابراهیمزاده_image.jpg
# [504] بنیک امیریان → ❌ no matching images
# [505] بهادر عبدی → ✅ 1 image: keep 505_بهادر_عبدی_image.jpg
# [506] بهادر مولایی → ✅ 1 image: keep 506_بهادر_مولایی_image.jpg
# [507] بهادر نسیم‌اف → ✅ 1 image: keep 507_بهادر_نسیماف__value.jpg
# [508] بهادر کرمی → ❌ no matching images
# [509] بهاره قادریان → ❌ no matching images
# [510] بهتاش فریبا → ⚠️ 2 images found
#     keep   : 510_بهتاش_فریبا_crawled.jpg
#     delete : 510_بهتاش_فریبا_image.jpg
# [511] بهداد بیرانوند → ✅ 1 image: keep 511_بهداد_بیرانوند_crawled.jpg
# [512] بهداد سلیمی → ✅ 1 image: keep 512_بهداد_سلیمی_image.jpg
# [513] بهرام اسماعیلی → ✅ 1 image: keep 513_بهرام_اسماعیلی_crawled.jpg
# [514] بهرام افشارزاده → ✅ 1 image: keep 514_بهرام_افشارزاده_image.jpg
# [515] بهرام توکلی  → ✅ 1 image: keep 515_بهرام_توکلی_crawled.jpg
# [516] بهرام دباغ → ❌ no matching images
# [517] بهرام رشیدی فرخی → ✅ 1 image: keep 517_بهرام_رشیدی_فرخی_image.jpg
# [518] بهرام مشتاقی → ✅ 1 image: keep 518_بهرام_مشتاقی__value.jpg
# [519] بهرام مهرپیما → ✅ 1 image: keep 519_بهرام_مهرپیما_crawled.jpg
# [520] بهرام مودت → ✅ 1 image: keep 520_بهرام_مودت_image.jpg
# [521] بهرام چوبین → ✅ 1 image: keep 521_بهرام_چوبین_image.jpg
# [522] بهرنگ صفری → ✅ 1 image: keep 522_بهرنگ_صفری_image.jpg
# [523] بهروز جمشیدی → ✅ 1 image: keep 523_بهروز_جمشیدی_crawled.jpg
# [524] بهروز رهبری‌فر → ✅ 1 image: keep 524_بهروز_رهبریفر_image.jpg
# [525] بهروز سلطانی → ✅ 1 image: keep 525_بهروز_سلطانی_image.jpg
# [526] بهروز صحابه تبریزی → ⚠️ 2 images found
#     keep   : 526_بهروز_صحابه_تبریزی_crawled.jpg
#     delete : 526_بهروز_صحابه_تبریزی_image.jpg
# [527] بهروز عطایی → ✅ 1 image: keep 527_بهروز_عطایی_image.jpg
# [528] بهروز مکوندی → ✅ 1 image: keep 528_بهروز_مکوندی_image.jpg
# [529] بهروز نعمتی → ✅ 1 image: keep 529_بهروز_نعمتی__value.jpg
# [530] بهروز یاری → ⚠️ 2 images found
#     keep   : 530_بهروز_یاری_crawled.jpg
#     delete : 530_بهروز_یاری_image.jpg
# [531] بهزاد حیدرشاهی → ✅ 1 image: keep 531_بهزاد_حیدرشاهی_image.jpg
# [532] بهزاد غلامپور → ✅ 1 image: keep 532_بهزاد_غلامپور_image.jpg
# [533] بهمن تیموری → ✅ 1 image: keep 533_بهمن_تیموری_crawled.jpg
# [534] بهمن عسگری → ✅ 1 image: keep 534_بهمن_عسگری_crawled.jpg
# [535] بهمن نصیری → ✅ 1 image: keep 535_بهمن_نصیری_crawled.jpg
# [536] بهمن کامل → ✅ 1 image: keep 536_بهمن_کامل_image.jpg
# [537] بهمن گلبارنژاد → ✅ 1 image: keep 537_بهمن_گلبارنژاد_image.jpg
# [538] بهناز خجسته‌پور → ❌ no matching images
# [539] بهناز طاهرخانی → ✅ 1 image: keep 539_بهناز_طاهرخانی_image.jpg
# [540] بهنام آذرمجیدی → ❌ no matching images
# [541] بهنام ابوالقاسم‌پور → ✅ 1 image: keep 541_بهنام_ابوالقاسمپور_image.jpg
# [542] بهنام احسان‌پور → ❌ no matching images
# [543] بهنام اسبقی → ❌ no matching images
# [544] بهنام برزای → ✅ 1 image: keep 544_بهنام_برزای_image.jpg
# [545] بهنام بیات → ✅ 1 image: keep 545_بهنام_بیات_crawled.jpg
# [546] بهنام سراج → ✅ 1 image: keep 546_بهنام_سراج_image.jpg
# [547] بهنام شیری → ✅ 1 image: keep 547_بهنام_شیری_image.jpg
# [548] بهنام طاهرزاده → ❌ no matching images
# [549] بهنام طیبی → ❌ no matching images
# [550] بهنام محمودی → ✅ 1 image: keep 550_بهنام_محمودی_image.jpg
# [551] بهنام مهدی‌زاده → ❌ no matching images
# [552] بهنام یخچالی → ✅ 1 image: keep 552_بهنام_یخچالی_image.jpg
# [553] بوباکار تراوالی → ✅ 1 image: keep 553_بوباکار_تراوالی_image.jpg
# [554] بولی سامبو → ✅ 1 image: keep 554_بولی_سامبو__value.jpg
# [555] بوژیدار رادوشویچ → ✅ 1 image: keep 555_بوژیدار_رادوشویچ__value.jpg
# [556] بوگدان میلیچ → ✅ 1 image: keep 556_بوگدان_میلیچ_image.jpg
# [557] بویان نایدنوف → ✅ 1 image: keep 557_بویان_نایدنوف_image.jpg
# [558] بویوک‌آغا حاجی‌اف → ✅ 1 image: keep 558_بویوکآغا_حاجیاف_image.jpg
# [559] بیت‌الله عباس‌پور → ✅ 1 image: keep 559_بیتالله_عباسپور_image.jpg
# [560] بیوک جدی‌کار → ⚠️ 2 images found
#     keep   : 560_بیوک_جدیکار_crawled.jpg
#     delete : 560_بیوک_جدیکار_image.jpg
# [561] بیوک وطنخواه → ❌ no matching images
# [599] جادر دا سیلوا برازیرو → ✅ 1 image: keep 599_جادر_دا_سیلوا_برازیرو_image.jpg
# [600] جاسم امیری → ✅ 1 image: keep 600_جاسم_امیری_crawled.jpg
# [601] جاسم دلاوری → ✅ 1 image: keep 601_جاسم_دلاوری_image.jpg
# [602] جاسم سلطانی → ❌ no matching images
# [603] جاسم غلام الحمد → ❌ no matching images
# [604] جاسم ویشکائی → ❌ no matching images
# [605] جامی رفعتی → ❌ no matching images
# [606] جان توشاک → ✅ 1 image: keep 606_جان_توشاک_image.jpg
# [607] جاناتان دا سیلوا پریرا → ❌ no matching images
# [608] جبار فعلی → ✅ 1 image: keep 608_جبار_فعلی_image.jpg
# [609] جبار مهدیون → ❌ no matching images
# [610] جرج مراد → ✅ 1 image: keep 610_جرج_مراد_image.jpg
# [611] جری بنگتسون → ✅ 1 image: keep 611_جری_بنگتسون_image.jpg
# [612] جعفر احمدی → ✅ 1 image: keep 612_جعفر_احمدی_crawled.jpg
# [613] جعفر باباخانی → ❌ no matching images
# [614] جعفر سلماسی → ✅ 1 image: keep 614_جعفر_سلماسی_image.jpg
# [615] جعفر سلمانی → ✅ 1 image: keep 615_جعفر_سلمانی_image.jpg
# [616] جعفر پهلوانی → ❌ no matching images
# [617] جعفر کاشانی → ✅ 1 image: keep 617_جعفر_کاشانی_image.jpg
# [618] جعفر کربلایی‌زاده → ❌ no matching images
# [619] جلال امیدیان → ✅ 1 image: keep 619_جلال_امیدیان_image.jpg
# [620] جلال اکبری → ✅ 1 image: keep 620_جلال_اکبری_image.jpg
# [621] جلال خدامی → ✅ 1 image: keep 621_جلال_خدامی_crawled.jpg
# [622] جلال رابوکی → ✅ 1 image: keep 622_جلال_رابوکی_image.jpg
# [623] جلال طالبی → ✅ 1 image: keep 623_جلال_طالبی_image.jpg
# [624] جلال منصوری → ✅ 1 image: keep 624_جلال_منصوری_crawled.jpg
# [625] جلال کاملی‌مفرد → ✅ 1 image: keep 625_جلال_کاملیمفرد_crawled.jpg
# [626] جلال کشمیری → ✅ 1 image: keep 626_جلال_کشمیری_image.jpg
# [627] جلال‌الدین علی‌محمدی → ✅ 1 image: keep 627_جلالالدین_علیمحمدی_image.jpg
# [628] جلسون → ❌ no matching images
# [629] جلیل ایمری → ✅ 1 image: keep 629_جلیل_ایمری_crawled.jpg
# [630] جلیل باقری جدی → ❌ no matching images
# [631] جمال میرزایی → ✅ 1 image: keep 631_جمال_میرزایی_crawled.jpg
# [632] جمال ولی‌زاده → ❌ no matching images
# [633] جمال چاوشی‌فر → ❌ no matching images
# [634] جمشید شاه‌محمدی  → ❌ no matching images
# [635] جمشید فانی → ✅ 1 image: keep 635_جمشید_فانی_crawled.jpg
# [636] جمشید نصیری → ✅ 1 image: keep 636_جمشید_نصیری_image.jpg
# [637] جمیله سروری → ✅ 1 image: keep 637_جمیله_سروری_image.jpg
# [638] جهانبخت توفیق → ✅ 1 image: keep 638_جهانبخت_توفیق_image.jpg
# [639] جهانگیر توکلی → ❌ no matching images
# [640] جهانگیر عراقی → ✅ 1 image: keep 640_جهانگیر_عراقی_image.jpg
# [641] جواد الله‌وردی → ✅ 1 image: keep 641_جواد_اللهوردی_crawled.jpg
# [642] جواد تقی‌پور → ❌ no matching images
# [643] جواد حسین‌آبادی → ✅ 1 image: keep 643_جواد_حسینآبادی_crawled.jpg
# [644] جواد درفشی جوان → ✅ 1 image: keep 644_جواد_درفشی_جوان_image.jpg
# [645] جواد زرینچه → ✅ 1 image: keep 645_جواد_زرینچه_image.jpg
# [646] جواد شیرزاد → ⚠️ 2 images found
#     keep   : 646_جواد_شیرزاد_crawled.jpg
#     delete : 646_جواد_شیرزاد_image.jpg
# [647] جواد فروغی → ⚠️ 2 images found
#     keep   : 647_جواد_فروغی_crawled.jpg
#     delete : 647_جواد_فروغی_image.jpg
# [648] جواد قراب → ✅ 1 image: keep 648_جواد_قراب_image.jpg
# [649] جواد محتشمیان → ✅ 1 image: keep 649_جواد_محتشمیان_image.jpg
# [650] جواد محجوب → ✅ 1 image: keep 650_جواد_محجوب_image.jpg
# [651] جواد نوروزی → ✅ 1 image: keep 651_جواد_نوروزی_image.jpg
# [652] جواد نکونام → ✅ 1 image: keep 652_جواد_نکونام_image.jpg
# [653] جواد کاظمیان → ✅ 1 image: keep 653_جواد_کاظمیان_image.jpg
# [654] جواد کریمی → ✅ 1 image: keep 654_جواد_کریمی_image.jpg
# [655] جواد یساری → ✅ 1 image: keep 655_جواد_یساری__value.jpg
# [656] جورج توپالوویچ → ✅ 1 image: keep 656_جورج_توپالوویچ__value.jpg
# [657] جوروان ویرا → ✅ 1 image: keep 657_جوروان_ویرا_image.jpg
# [658] جونیور براندائو → ✅ 1 image: keep 658_جونیور_براندائو_image.jpg
# [659] جیحون سلطان‌اف → ✅ 1 image: keep 659_جیحون_سلطاناف_image.jpg
# [660] جی‌لوید ساموئل → ✅ 1 image: keep 660_جیلوید_ساموئل__value.jpg
# [661] حامد آفاق → ❌ no matching images
# [662] حامد بحیرایی → ✅ 1 image: keep 662_حامد_بحیرایی_image.jpg
# [663] حامد تاب → ❌ no matching images
# [664] حامد تاری‌وردی → ❌ no matching images
# [665] حامد حدادی → ✅ 1 image: keep 665_حامد_حدادی_image.jpg
# [666] حامد حیدری → ✅ 1 image: keep 666_حامد_حیدری_image.jpg
# [667] حامد رسولی → ❌ no matching images
# [668] حامد رشیدی → ✅ 1 image: keep 668_حامد_رشیدی_image.jpg
# [669] حامد سهراب‌نژاد → ❌ no matching images
# [670] حامد صلحی‌پور → ✅ 1 image: keep 670_حامد_صلحیپور_image.jpg
# [671] حامد فلاح‌زاده → ✅ 1 image: keep 671_حامد_فلاحزاده_image.jpg
# [672] حامد لک → ✅ 1 image: keep 672_حامد_لک_image.jpg
# [673] حامد ملک‌خانبانان → ❌ no matching images
# [674] حامد ملک‌محمدی معمار → ❌ no matching images
# [675] حامد میرزاپور → ✅ 1 image: keep 675_حامد_میرزاپور__value.jpg
# [676] حامد نورمحمدی  → ✅ 1 image: keep 676_حامد_نورمحمدی_image.jpg
# [677] حامد پاکدل → ✅ 1 image: keep 677_حامد_پاکدل_image.jpg
# [678] حامد کاویانپور → ✅ 1 image: keep 678_حامد_کاویانپور_image.jpg
# [679] حبیب بهمنی → ✅ 1 image: keep 679_حبیب_بهمنی_image.jpg
# [680] حبیب فرعباسی → ✅ 1 image: keep 680_حبیب_فرعباسی_image.jpg
# [681] حبیب کاشانی → ✅ 1 image: keep 681_حبیب_کاشانی_image.jpg
# [682] حبیب گردانی → ✅ 1 image: keep 682_حبیب_گردانی_image.jpg
# [683] حبیب‌الله اخلاقی → ✅ 1 image: keep 683_حبیبالله_اخلاقی_image.jpg
# [684] حبیب‌الله ایگدر → ✅ 1 image: keep 684_حبیبالله_ایگدر_image.jpg
# [685] حبیب‌الله بلور → ✅ 1 image: keep 685_حبیبالله_بلور_image.jpg
# [686] حجت صدقی → ⚠️ 2 images found
#     keep   : 686_حجت_صدقی_crawled.jpg
#     delete : 686_حجت_صدقی__value.jpg
# [687] حدیثه جمال → ✅ 1 image: keep 687_حدیثه_جمال_crawled.jpg
# [688] حسام فوزی → ❌ no matching images
# [689] حسام پ/صفحه تمرین → ❌ no matching images
# [690] حسام پورهاشم → ❌ no matching images
# [691] حسن آریان‌فرد → ❌ no matching images
# [692] حسن اشجاری → ❌ no matching images
# [693] حسن اکبرنژاد → ✅ 1 image: keep 693_حسن_اکبرنژاد_crawled.jpg
# [694] حسن اکرمی → ✅ 1 image: keep 694_حسن_اکرمی__value.jpg
# [695] حسن بابک → ✅ 1 image: keep 695_حسن_بابک_crawled.jpg
# [696] حسن باشت باوی → ❌ no matching images
# [697] حسن بیت‌سعید → ✅ 1 image: keep 697_حسن_بیتسعید_image.jpg
# [698] حسن تفتیان → ✅ 1 image: keep 698_حسن_تفتیان_crawled.jpg
# [699] حسن جعفری  → ✅ 1 image: keep 699_حسن_جعفری_crawled.jpg
# [700] حسن حبیبی  → ✅ 1 image: keep 700_حسن_حبیبی_image.jpg
# [701] حسن خان‌محمدی → ❌ no matching images
# [702] حسن رحیمی → ✅ 1 image: keep 702_حسن_رحیمی_image.jpg
# [703] حسن رنگرز → ✅ 1 image: keep 703_حسن_رنگرز_image.jpg
# [704] حسن روحانی  → ✅ 1 image: keep 704_حسن_روحانی_crawled.jpg
# [705] حسن رودباریان → ✅ 1 image: keep 705_حسن_رودباریان_image.jpg
# [706] حسن روشن → ⚠️ 2 images found
#     keep   : 706_حسن_روشن_crawled.jpg
#     delete : 706_حسن_روشن_image.jpg
# [707] حسن زاهدی  → ✅ 1 image: keep 707_حسن_زاهدی_crawled.jpg
# [708] حسن زرافشان → ❌ no matching images
# [709] حسن سعدیان → ❌ no matching images
# [710] حسن شمشکی → ❌ no matching images
# [711] حسن شوشتری → ✅ 1 image: keep 711_حسن_شوشتری_image.jpg
# [712] حسن عسگری  → ✅ 1 image: keep 712_حسن_عسگری_crawled.jpg
# [713] حسن غفوری‌فرد → ✅ 1 image: keep 713_حسن_غفوریفرد_image.jpg
# [714] حسن نایب‌آقا → ❌ no matching images
# [715] حسن نظری → ✅ 1 image: keep 715_حسن_نظری_image.jpg
# [716] حسن نوفلاح → ✅ 1 image: keep 716_حسن_نوفلاح_image.jpg
# [717] حسن هوری → ✅ 1 image: keep 717_حسن_هوری_image.jpg
# [718] حسن پاک‌اندام → ✅ 1 image: keep 718_حسن_پاکاندام_image.jpg
# [719] حسن کامرانی‌فر → ✅ 1 image: keep 719_حسن_کامرانیفر_crawled.jpg
# [720] حسن یزدانی → ⚠️ 2 images found
#     keep   : 720_حسن_یزدانی_image.jpg
#     delete : 2038_محسن_یزدانی__value.jpg
# [721] حسن یوسفی افشار → ❌ no matching images
# [722] حسین آریانژاد → ⚠️ 2 images found
#     keep   : 722_حسین_آریانژاد_crawled.jpg
#     delete : 722_حسین_آریانژاد_image.jpg
# [723] حسین آشنا → ✅ 1 image: keep 723_حسین_آشنا_image.jpg
# [724] حسین ابراهیمی → ✅ 1 image: keep 724_حسین_ابراهیمی_image.jpg
# [725] حسین ابوذری → ✅ 1 image: keep 725_حسین_ابوذری_image.jpg
# [726] حسین اسدی → ✅ 1 image: keep 726_حسین_اسدی_crawled.jpg
# [727] حسین افضلی → ❌ no matching images
# [728] حسین اوجاقی → ❌ no matching images
# [729] حسین بادامکی → ✅ 1 image: keep 729_حسین_بادامکی_image.jpg
# [730] حسین باقری → ✅ 1 image: keep 730_حسین_باقری__value.jpg
# [731] حسین برقچی → ❌ no matching images
# [732] حسین بغلانی → ✅ 1 image: keep 732_حسین_بغلانی__value.jpg
# [733] حسین بهشتی → ✅ 1 image: keep 733_حسین_بهشتی_crawled.jpg
# [734] حسین تهامی → ✅ 1 image: keep 734_حسین_تهامی__value.jpg
# [735] حسین توکلی → ✅ 1 image: keep 735_حسین_توکلی_image.jpg
# [736] حسین جبارزادگان → ✅ 1 image: keep 736_حسین_جبارزادگان_image.jpg
# [737] حسین حراجچی → ✅ 1 image: keep 737_حسین_حراجچی_image.jpg
# [738] حسین حسینی  → ⚠️ 3 images found
#     keep   : 349_امیرحسین_حسینی_crawled.jpg
#     delete : 1270_سید_حسین_حسینی_image.jpg
#     delete : 738_حسین_حسینی_image.jpg
# [739] حسین حیدری → ⚠️ 2 images found
#     keep   : 2194_محمدحسین_حیدری_crawled.jpg
#     delete : 739_حسین_حیدری_image.jpg
# [740] حسین خالدی → ✅ 1 image: keep 740_حسین_خالدی_crawled.jpg
# [741] حسین خانبان → ❌ no matching images
# [742] حسین خطیبی  → ⚠️ 2 images found
#     keep   : 742_حسین_خطیبی_crawled.jpg
#     delete : 742_حسین_خطیبی_image.jpg
# [743] حسین رحمتی → ⚠️ 2 images found
#     keep   : 743_حسین_رحمتی_crawled.jpg
#     delete : 743_حسین_رحمتی_image.jpg
# [744] حسین رسولی → ❌ no matching images
# [745] حسین رضازاده → ✅ 1 image: keep 745_حسین_رضازاده__value.jpg
# [746] حسین روحانی → ✅ 1 image: keep 746_حسین_روحانی_crawled.jpg
# ...
# [2852] وولودیمیر پریموف → ✅ 1 image: keep 2852_وولودیمیر_پریموف_image.jpg
# [2853] ویدا حلیمیان → ❌ no matching images
# [2854] ویسنته آرزه → ✅ 1 image: keep 2854_ویسنته_آرزه_image.jpg
# [2855] ویلیام آتشکده → ✅ 1 image: keep 2855_ویلیام_آتشکده_image.jpg
# [2856] وینفرید شفر → ✅ 1 image: keep 2856_وینفرید_شفر_image.jpg
# [2857] وینکو بگوویچ → ✅ 1 image: keep 2857_وینکو_بگوویچ_image.jpg
# [2858] پائولو آلوز → ✅ 1 image: keep 2858_پائولو_آلوز_crawled.jpg
# [2859] پائولو سرژیو → ✅ 1 image: keep 2859_پائولو_سرژیو_image.jpg
# [2860] پائولو سزار → ✅ 1 image: keep 2860_پائولو_سزار_image.jpg
# [2861] پاتریس کارترون → ✅ 1 image: keep 2861_پاتریس_کارترون_image.jpg
# [2862] پارسا محمدی → ✅ 1 image: keep 2862_پارسا_محمدی_crawled.jpg
# [2863] پانی کیانزاد → ✅ 1 image: keep 2863_پانی_کیانزاد_image.jpg
# [2864] پاکو خمز → ✅ 1 image: keep 2864_پاکو_خمز__value.jpg
# [2865] پایان رأفت → ✅ 1 image: keep 2865_پایان_رأفت_image.jpg
# [2866] پدرام قاضی‌پور → ✅ 1 image: keep 2866_پدرام_قاضیپور__value.jpg
# [2867] پدرو هنریکه → ⚠️ 2 images found
#     keep   : 2867_پدرو_هنریکه_image1.jpg
#     delete : 2868_پدرو_هنریکه_اولیویرا_image.jpg
# [2868] پدرو هنریکه اولیویرا → ✅ 1 image: keep 2868_پدرو_هنریکه_اولیویرا_image.jpg
# [2869] پدیده بلوری‌زاده → ❌ no matching images
# [2870] پردیس عیدی‌وندی → ❌ no matching images
# [2871] پرستو حبیبی → ✅ 1 image: keep 2871_پرستو_حبیبی_image.jpg
# [2872] پرستو مه نمای اقدم → ✅ 1 image: keep 2872_پرستو_مه_نمای_اقدم_crawled.jpg
# [2873] پرهام مقصودلو → ✅ 1 image: keep 2873_پرهام_مقصودلو_image.jpg
# [2874] پرو پییچ → ✅ 1 image: keep 2874_پرو_پییچ_image.jpg
# [2875] پروانه تهرانی → ✅ 1 image: keep 2875_پروانه_تهرانی_crawled.jpg
# [2876] پروانه محمدتقی‌پور طهرانی → ❌ no matching images
# [2877] پروانه کاظمی → ✅ 1 image: keep 2877_پروانه_کاظمی_crawled.jpg
# [2878] پرویز برومند → ✅ 1 image: keep 2878_پرویز_برومند_image.jpg
# [2879] پرویز جلایر → ✅ 1 image: keep 2879_پرویز_جلایر_image.jpg
# [2880] پرویز خسروانی → ✅ 1 image: keep 2880_پرویز_خسروانی_image.jpg
# [2881] پرویز دهداری → ✅ 1 image: keep 2881_پرویز_دهداری_image.jpg
# [2882] پرویز زیدوند → ❌ no matching images
# [2883] پرویز مظلومی → ✅ 1 image: keep 2883_پرویز_مظلومی_image.jpg
# [2884] پرویز میرزاحسن → ❌ no matching images
# [2885] پرویز هادی → ✅ 1 image: keep 2885_پرویز_هادی_image.jpg
# [2886] پرویز کریمی → ✅ 1 image: keep 2886_پرویز_کریمی_image.jpg
# [2887] پرویز کوزه‌کنانی → ✅ 1 image: keep 2887_پرویز_کوزهکنانی_image.jpg
# [2888] پری فردی → ✅ 1 image: keep 2888_پری_فردی__value.jpg
# [2889] پری نقی‌پور → ✅ 1 image: keep 2889_پری_نقیپور_image.jpg
# [2890] پریسا احمدی  → ❌ no matching images
# [2891] پریسا براتچی  → ❌ no matching images
# [2892] پریسا بهزادی → ❌ no matching images
# [2893] پریسا جهانفکریان → ✅ 1 image: keep 2893_پریسا_جهانفکریان__value.jpg
# [2894] پریسا جوادی → ✅ 1 image: keep 2894_پریسا_جوادی_image.jpg
# [2895] پریسا فرشیدی → ✅ 1 image: keep 2895_پریسا_فرشیدی_image.jpg
# [2896] پریچهر جمشیدی → ✅ 1 image: keep 2896_پریچهر_جمشیدی_image.jpg
# [2897] پطروس نظربگیان → ✅ 1 image: keep 2897_پطروس_نظربگیان_image.jpg
# [2898] پهلوان ابراهیم حلاج تفتی یزدی → ✅ 1 image: keep 2898_پهلوان_ابراهیم_حلاج_تفتی_یزدی_image1.jpg
# [2899] پهلوان موسی خمیس → ⚠️ 2 images found
#     keep   : 2900_پهلوان_موسی_خمیس_گرزدینوند_image1.jpg
#     delete : 2899_پهلوان_موسی_خمیس_image.jpg
# [2900] پهلوان موسی خمیس گرزدین‌وند → ✅ 1 image: keep 2900_پهلوان_موسی_خمیس_گرزدینوند_image1.jpg
# [2901] پوران زارع → ✅ 1 image: keep 2901_پوران_زارع__value.jpg
# [2902] پوریا امینی → ✅ 1 image: keep 2902_پوریا_امینی_crawled.jpg
# [2903] پوریا حسین خانزاده → ✅ 1 image: keep 2903_پوریا_حسین_خانزاده_image.jpg
# [2904] پوریا درینی → ✅ 1 image: keep 2904_پوریا_درینی_image.jpg
# [2905] پوریا ساوه شمشکی → ❌ no matching images
# [2906] پوریا سرآبادانی → ✅ 1 image: keep 2906_پوریا_سرآبادانی_image.jpg
# [2907] پوریا فیاضی → ✅ 1 image: keep 2907_پوریا_فیاضی_image.jpg
# [2908] پوریا نوروزیان → ❌ no matching images
# [2909] پوریا یلی → ✅ 1 image: keep 2909_پوریا_یلی_image.jpg
# [2910] پوریای ولی → ✅ 1 image: keep 2910_پوریای_ولی__value.jpg
# [2911] پوپک بسامی → ✅ 1 image: keep 2911_پوپک_بسامی_crawled.jpg
# [2912] پویا ایدنی → ✅ 1 image: keep 2912_پویا_ایدنی_image.jpg
# [2913] پویا تاجیک → ❌ no matching images
# [2914] پویا دادمرز → ✅ 1 image: keep 2914_پویا_دادمرز_image.jpg
# [2915] پویا رحمانی → ✅ 1 image: keep 2915_پویا_رحمانی_image.jpg
# [2916] پویا ناصرپور → ❌ no matching images
# [2917] پویا نزهتی → ✅ 1 image: keep 2917_پویا_نزهتی__value.jpg
# [2918] پویا پورعلی → ✅ 1 image: keep 2918_پویا_پورعلی_image.jpg
# [2919] پژمان جمشیدی → ✅ 1 image: keep 2919_پژمان_جمشیدی__value.jpg
# [2920] پژمان درستکار → ✅ 1 image: keep 2920_پژمان_درستکار_crawled.jpg
# [2921] پژمان قلعه‌نویی → ❌ no matching images
# [2922] پژمان منتظری → ✅ 1 image: keep 2922_پژمان_منتظری_image.jpg
# [2923] پژمان نوری → ✅ 1 image: keep 2923_پژمان_نوری_image.jpg
# [2924] پژمان پشتام → ✅ 1 image: keep 2924_پژمان_پشتام_image.jpg
# [2925] پگاه زنگنه → ❌ no matching images
# [2926] پیام بویری → ❌ no matching images
# [2927] پیام حیدری → ✅ 1 image: keep 2927_پیام_حیدری__value.jpg
# [2928] پیام خانلرخانی → ❌ no matching images
# [2929] پیام صادقیان → ✅ 1 image: keep 2929_پیام_صادقیان_image.jpg
# [2930] پیام قبادی → ❌ no matching images
# [2931] پیام نیازمند → ✅ 1 image: keep 2931_پیام_نیازمند_image.jpg
# [2932] پیتر گریگوریان → ❌ no matching images
# [2933] پیتسو موسیمانه → ✅ 1 image: keep 2933_پیتسو_موسیمانه_image.jpg
# [2934] پیر لیتبارسکی → ✅ 1 image: keep 2934_پیر_لیتبارسکی_image.jpg
# [2935] پیر کارلو → ✅ 1 image: keep 2935_پیر_کارلو_crawled.jpg
# [2936] پیروز آدمیت → ❌ no matching images
# [2937] پیروز قربانی → ✅ 1 image: keep 2937_پیروز_قربانی_image.jpg
# [2938] پیمان اسدی  → ✅ 1 image: keep 2938_پیمان_اسدی_image.jpg
# [2939] پیمان اکبری → ✅ 1 image: keep 2939_پیمان_اکبری__value.jpg
# [2940] پیمان بابایی → ✅ 1 image: keep 2940_پیمان_بابایی_image.jpg
# [2941] پیمان بیابانی → ❌ no matching images
# [2942] پیمان جان → ✅ 1 image: keep 2942_پیمان_جان_crawled.jpg
# [2943] پیمان حسینی → ✅ 1 image: keep 2943_پیمان_حسینی_image.jpg
# [2944] پیمان قویدل → ❌ no matching images
# [2945] پیمان میری → ✅ 1 image: keep 2945_پیمان_میری_image.jpg
# [2946] پیمان نصیری → ❌ no matching images
# [2947] چیرو → ✅ 1 image: keep 2947_چیرو_image1.jpg
# [2948] ژاله سید هادی‌زاده → ✅ 1 image: keep 2948_ژاله_سید_هادیزاده__value.jpg
# [2949] ژانت کهن‌صدق → ✅ 1 image: keep 2949_ژانت_کهنصدق_image.jpg
# [2950] ژایر  → ✅ 1 image: keep 2950_ژایر_image.jpg
# [2951] ژرژ آفتاندیلیان → ✅ 1 image: keep 2951_ژرژ_آفتاندیلیان_image.jpg
# [2952] ژرژ عیسی‌بگ → ❌ no matching images
# [2953] ژرژ لیکنز → ✅ 1 image: keep 2953_ژرژ_لیکنز__value.jpg
# [2954] ژلیکو میاچ → ✅ 1 image: keep 2954_ژلیکو_میاچ__value.jpg
# [2955] ژنیک شهبازیان → ✅ 1 image: keep 2955_ژنیک_شهبازیان_image.jpg
# [2956] ژوزه آلبرتو کاستا → ✅ 1 image: keep 2956_ژوزه_آلبرتو_کاستا_image.jpg
# [2957] ژوزه مورایس → ✅ 1 image: keep 2957_ژوزه_مورایس_image.jpg
# [2958] ژولیت گئورگیان → ✅ 1 image: keep 2958_ژولیت_گئورگیان_image.jpg
# [2959] ژیلا الماسی → ✅ 1 image: keep 2959_ژیلا_الماسی_image.jpg
# [2960] کاخابر کاکاشویلی → ✅ 1 image: keep 2960_کاخابر_کاکاشویلی_image.jpg
# [2961] کارلوس آلکساندر کاردوسو → ✅ 1 image: keep 2961_کارلوس_آلکساندر_کاردوسو_image.jpg
# [2962] کارلوس هرناندز → ✅ 1 image: keep 2962_کارلوس_هرناندز_image.jpg
# [2963] کارلوس چاواریا → ✅ 1 image: keep 2963_کارلوس_چاواریا_image.jpg
# [2964] کارلوس چینیو → ✅ 1 image: keep 2964_کارلوس_چینیو_image.jpg
# [2965] کارلوس کی‌روش → ✅ 1 image: keep 2965_کارلوس_کیروش_image.jpg
# [2966] کارن بارسقیان → ❌ no matching images
# [2967] کارو حق‌وردیان → ✅ 1 image: keep 2967_کارو_حقوردیان_image.jpg
# [2968] کاظم اشتری → ✅ 1 image: keep 2968_کاظم_اشتری_crawled.jpg
# [2969] کاظم رجبی → ✅ 1 image: keep 2969_کاظم_رجبی_crawled.jpg
# [2970] کاظم ساریخانی → ❌ no matching images
# [2971] کاظم غلامی → ✅ 1 image: keep 2971_کاظم_غلامی_image.jpg
# [2972] کالینز جان → ✅ 1 image: keep 2972_کالینز_جان_image.jpg
# [2973] کامبیز آتابای → ✅ 1 image: keep 2973_کامبیز_آتابای_image.jpg
# [2974] کامبیز درفشی جوان → ❌ no matching images
# [2975] کامران شکری سالاری → ❌ no matching images
# [2976] کامران شیرازی → ✅ 1 image: keep 2976_کامران_شیرازی_image.jpg
# [2977] کامران قاسم‌پور → ✅ 1 image: keep 2977_کامران_قاسمپور_crawled.jpg
# [2978] کامران پنجوی → ❌ no matching images
# [2979] کاملیا فلاح → ✅ 1 image: keep 2979_کاملیا_فلاح_image.jpg
# [2980] کاوه رضایی → ✅ 1 image: keep 2980_کاوه_رضایی_image.jpg
# [2981] کاوه موسوی  → ✅ 1 image: keep 2981_کاوه_موسوی_crawled.jpg
# [2982] کبیر بلو → ❌ no matching images
# [2983] کتایون خسرویار → ✅ 1 image: keep 2983_کتایون_خسرویار_image.jpg
# [2984] کرار جاسم → ✅ 1 image: keep 2984_کرار_جاسم__value.jpg
# [2985] کریستوفر کنت → ⚠️ 2 images found
#     keep   : 2986_کریستوفر_کنت_image1.jpg
#     delete : 2985_کریستوفر_کنت_image.jpg
# [2986] کریستوفر کنِت → ⚠️ 2 images found
#     keep   : 2986_کریستوفر_کنت_image1.jpg
#     delete : 2985_کریستوفر_کنت_image.jpg
#       → deletion failed for 2985_کریستوفر_کنت_image.jpg: [WinError 2] The system cannot find the file specified: 'athlete_images\\2985_کریستوفر_کنت_image.jpg'
# [2987] کریستین اوساگونا → ✅ 1 image: keep 2987_کریستین_اوساگونا__value.jpg
# [2988] کریم احمدی → ✅ 1 image: keep 2988_کریم_احمدی__value.jpg
# [2989] کریم اسلامی → ✅ 1 image: keep 2989_کریم_اسلامی_image.jpg
# [2990] کریم انصاری‌فرد → ✅ 1 image: keep 2990_کریم_انصاریفرد_image.jpg
# [2991] کریم باقری → ✅ 1 image: keep 2991_کریم_باقری_image.jpg
# [2992] کریم بوستانی → ✅ 1 image: keep 2992_کریم_بوستانی_image.jpg
# [2993] کریم رئیسی‌نیا → ✅ 1 image: keep 2993_کریم_رئیسینیا_image.jpg
# [2994] کریم شاهوردی → ❌ no matching images
# [2995] کسری طاهری → ✅ 1 image: keep 2995_کسری_طاهری_image.jpg
# [2996] کسری مهدی‌پورنژاد → ✅ 1 image: keep 2996_کسری_مهدیپورنژاد_crawled.jpg
# [2997] کمال آلیسپاهیچ → ✅ 1 image: keep 2997_کمال_آلیسپاهیچ_image.jpg
# [2998] کمال کامیابی‌نیا → ✅ 1 image: keep 2998_کمال_کامیابینیا_image.jpg
# [2999] کمیل سوسکو → ❌ no matching images
# [3000] کمیل قاسمی → ✅ 1 image: keep 3000_کمیل_قاسمی_image.jpg
# [3001] کوثر اساسه → ❌ no matching images
# [3002] کوروش باقری → ❌ no matching images
# [3003] کوروش بختیار → ❌ no matching images
# [3004] کوروش رجلی → ❌ no matching images
# [3005] کوروش قربانی → ✅ 1 image: keep 3005_کوروش_قربانی__value.jpg
# [3006] کوروش محمدخانی → ✅ 1 image: keep 3006_کوروش_محمدخانی__value.jpg
# [3007] کوروش ملایی → ✅ 1 image: keep 3007_کوروش_ملایی_image.jpg
# [3008] کوروش ملکی → ✅ 1 image: keep 3008_کوروش_ملکی_image.jpg
# [3009] کوفی شولز → ✅ 1 image: keep 3009_کوفی_شولز_image.jpg
# [3010] کولیس جان → ✅ 1 image: keep 3010_کولیس_جان_image1.jpg
# [3011] کوپال ناظمی → ✅ 1 image: keep 3011_کوپال_ناظمی_image.jpg
# [3012] کویستان خسروی → ✅ 1 image: keep 3012_کویستان_خسروی_image.jpg
# [3013] کوین یانسن → ✅ 1 image: keep 3013_کوین_یانسن__value.jpg
# [3014] کیا اسکندانی → ✅ 1 image: keep 3014_کیا_اسکندانی__value.jpg
# [3015] کیا جورابچیان → ✅ 1 image: keep 3015_کیا_جورابچیان__value.jpg
# [3016] کیا قدمی → ❌ no matching images
# [3017] کیانوش رحمتی → ✅ 1 image: keep 3017_کیانوش_رحمتی__value.jpg
# [3018] کیانوش رستمی → ✅ 1 image: keep 3018_کیانوش_رستمی__value.jpg
# [3019] کیخسرو کهیایی → ❌ no matching images
# [3020] کیروش استنلی → ✅ 1 image: keep 3020_کیروش_استنلی_image.jpg
# [3021] کیمیا علیزاده → ✅ 1 image: keep 3021_کیمیا_علیزاده__value.jpg
# [3022] کیمیا یزدیان → ✅ 1 image: keep 3022_کیمیا_یزدیان_image.jpg
# [3023] کیمیا یوسفی → ✅ 1 image: keep 3023_کیمیا_یوسفی_image.jpg
# [3024] کیهان تاکاهاشی → ❌ no matching images
# [3025] کیوان دهناد → ✅ 1 image: keep 3025_کیوان_دهناد_image.jpg
# [3026] کیوان شیرآقایی  → ❌ no matching images
# [3027] کیوان قنبرزاده → ❌ no matching images
# [3028] کیومرث ابوالملوکی → ✅ 1 image: keep 3028_کیومرث_ابوالملوکی_image.jpg
# [3029] کیومرث هاشمی → ✅ 1 image: keep 3029_کیومرث_هاشمی_image.jpg
# [3030] گئورگ کاسپاروف → ✅ 1 image: keep 3030_گئورگ_کاسپاروف_image.jpg
# [3031] گئورگی گئورگیف → ✅ 1 image: keep 3031_گئورگی_گئورگیف__value.jpg
# [3032] گئورگی گولسیانی → ✅ 1 image: keep 3032_گئورگی_گولسیانی__value.jpg
# [3033] گابریل کالدرون → ✅ 1 image: keep 3033_گابریل_کالدرون_image.jpg
# [3034] گابریله پین → ✅ 1 image: keep 3034_گابریله_پین_image.jpg
# [3035] گادوین منشا → ✅ 1 image: keep 3035_گادوین_منشا_image.jpg
# [3036] گارنیک شه‌بندری → ✅ 1 image: keep 3036_گارنیک_شهبندری_image.jpg
# [3037] گارنیک مهرابیان → ✅ 1 image: keep 3037_گارنیک_مهرابیان_image.jpg
# [3038] گالوست پطروسیان → ❌ no matching images
# [3039] گریگور ملیکستیان → ❌ no matching images
# [3040] گریگول چابرادزه → ✅ 1 image: keep 3040_گریگول_چابرادزه_image.jpg
# [3041] گغارد موساسی → ✅ 1 image: keep 3041_گغارد_موساسی_image.jpg
# [3042] گلاره ناظمی → ✅ 1 image: keep 3042_گلاره_ناظمی_image.jpg
# [3043] گلنوش خسروی → ✅ 1 image: keep 3043_گلنوش_خسروی_image.jpg
# [3044] گلنوش سبقت‌الهی → ✅ 1 image: keep 3044_گلنوش_سبقتالهی_image.jpg
# [3045] گودرز حبیبی → ✅ 1 image: keep 3045_گودرز_حبیبی_image.jpg
# [3046] گوران یرکوویچ → ✅ 1 image: keep 3046_گوران_یرکوویچ_image.jpg
# [3047] گوستاوو بلانکو → ✅ 1 image: keep 3047_گوستاوو_بلانکو_image.jpg
# [3048] گیتی محبان → ✅ 1 image: keep 3048_گیتی_محبان__value.jpg
# [3049] گیسا بایبوردی → ❌ no matching images
# [3050] یاسر خورشیدی میانایی → ❌ no matching images
# [3051] یاسر همرنگ → ✅ 1 image: keep 3051_یاسر_همرنگ_image.jpg
# [3052] یاسین رضایی → ❌ no matching images
# [3053] یاسین سلمانی → ✅ 1 image: keep 3053_یاسین_سلمانی__value.jpg
# [3054] یحیی گل‌محمدی → ✅ 1 image: keep 3054_یحیی_گلمحمدی_image.jpg
# [3055] یدالله اکبری → ✅ 1 image: keep 3055_یدالله_اکبری_image.jpg
# [3056] یدالله جهانبازی → ✅ 1 image: keep 3056_یدالله_جهانبازی_image.jpg
# [3057] یدالله محبی → ❌ no matching images
# [3058] یزدان میرزایی → ❌ no matching images
# [3059] یعقوب نجفی جویباری → ❌ no matching images
# [3060] یعقوب کریمی → ✅ 1 image: keep 3060_یعقوب_کریمی_image.jpg
# [3061] یعقوبعلی شورورزی → ⚠️ 2 images found
#     keep   : 3062_یعقوبعلی_شورورزی_image1.jpg
#     delete : 3061_یعقوبعلی_شورورزی_image.jpg
# [3062] یعقوبعلی شوروَرزی → ⚠️ 2 images found
#     keep   : 3062_یعقوبعلی_شورورزی_image1.jpg
#     delete : 3061_یعقوبعلی_شورورزی_image.jpg
#       → deletion failed for 3061_یعقوبعلی_شورورزی_image.jpg: [WinError 2] The system cannot find the file specified: 'athlete_images\\3061_یعقوبعلی_شورورزی_image.jpg'
# [3063] یو درویش → ✅ 1 image: keep 3063_یو_درویش_image.jpg
# [3064] یوانیس توپالیدیس → ✅ 1 image: keep 3064_یوانیس_توپالیدیس_image.jpg
# [3065] یوسف سیدی → ⚠️ 2 images found
#     keep   : 3066_یوسف_سیدی_گلی_بلاغ_image1.jpg
#     delete : 3065_یوسف_سیدی_image.jpg
# [3066] یوسف سیدی گلی بلاغ → ✅ 1 image: keep 3066_یوسف_سیدی_گلی_بلاغ_image1.jpg
# [3067] یوسف صبری → ✅ 1 image: keep 3067_یوسف_صبری_crawled.jpg
# [3068] یوسف صفوت → ✅ 1 image: keep 3068_یوسف_صفوت_image.jpg
# [3069] یوسف قادریان → ✅ 1 image: keep 3069_یوسف_قادریان_image.jpg
# [3070] یوسف وکیا → ✅ 1 image: keep 3070_یوسف_وکیا_image.jpg
# [3071] یوسف کرمی → ✅ 1 image: keep 3071_یوسف_کرمی_crawled.jpg
# [3072] یونس امامی → ✅ 1 image: keep 3072_یونس_امامی_crawled.jpg
# [3073] یونس اکبرپور → ✅ 1 image: keep 3073_یونس_اکبرپور_crawled.jpg
# [3074] یونس باهنر → ✅ 1 image: keep 3074_یونس_باهنر_image.jpg
# [3075] یونس دلفی → ✅ 1 image: keep 3075_یونس_دلفی__value.jpg
# [3076] یونس سرمستی → ❌ no matching images
# [3077] یونس شاکری → ✅ 1 image: keep 3077_یونس_شاکری_image.jpg
# [3078] یونس فضلی جمور → ✅ 1 image: keep 3078_یونس_فضلی_جمور_image.jpg
# [3079] یونس مسعودی → ✅ 1 image: keep 3079_یونس_مسعودی_image.jpg
# [3080] یوکیا سوگیتا → ✅ 1 image: keep 3080_یوکیا_سوگیتا_image.jpg
# [3081] یکتا جمالی → ❌ no matching images
#
# --------------------------------------------------------------------------------------------
# DEDUP REPORT
# --------------------------------------------------------------------------------------------
# Total records examined:          3082
# Records with no images:          735
# Records with exactly 1 image:    2223
# Records with duplicates cleaned: 124
# Total files deleted:             121
# Deleted (sample up to 15):       ['2_آتسو_استویکوف_image.jpg', '39_آرمین_سهرابیان_image.jpg', '44_آری_هان_image.jpg', '46_آریا_جسورو_هاسگاوا_image.jpg', '74_آندری_پانادیچ_image.jpg', '77_آوسنتی_گیلائوری_image.jpg', '92_ابراهیم_جوادی_image.jpg', '97_ابراهیم_صادقی_image.jpg', '130_احسان_امینی_image.jpg', '172_احمد_موسوی_image.jpg', '183_احمدرضا_عابدزاده_image.jpg', '189_ادمیر_آدرویچ__value.jpg', '341_امیرارسلان_مطهری_image.jpg', '199_ارسلان_کاظمی_image.jpg', '202_ارشیا_ارباب_بهرامی__value.jpg']
# Dry run mode:                    False
# --------------------------------------------------------------------------------------------
